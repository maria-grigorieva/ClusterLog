# %% [markdown]
# # Clusterlogs Notebook

# %%
import pandas as pd
from clusterlogs import multistage
import numpy as np

# %% [markdown]
# ### 1. Download data from file and create pandas DataFrame with index

# %%
df = pd.read_csv('test/Project.log', header=None)

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#                                                    0
# 0  # CMake ---> /cvmfs/atlas.cern.ch/repo/ATLASLo...
# 1  # CMake ---> /build1/atnight/localbuilds/night...
# 2  # CMake ---> /cvmfs/atlas.cern.ch/repo/ATLASLo...
# 3                  -- Install configuration: "Debug"
# 4  -- Installing: /build1/atnight/localbuilds/nig...

# %%
df = pd.read_csv('test/test_data.csv', index_col=0)

# %%
df.set_index('pandaid', inplace=True)

# %%
df
# Out:
#                       starttime  exeerrorcode  \
# pandaid
# 4498866929  2019-10-01T09:04:39            65
# 4498851809  2019-10-01T09:13:17            11
# 4499004301  2019-10-01T10:18:49            15
# 4499011565  2019-10-01T10:25:17            65
# 4499004297  2019-10-01T10:15:46            15
# ...                         ...           ...
# 4498731008  2019-10-01T09:09:13            65
# 4498443852  2019-10-01T09:26:03            11
# 4498731010  2019-10-01T09:09:38            65
# 4498730995  2019-10-01T09:08:50            65
# 4498443955  2019-10-01T09:45:56            11
#
#                                                  exeerrordiag
# pandaid
# 4498866929  Non-zero return code from EVNTtoHITS (8); Logf...
# 4498851809  Missing AthenaMP outputs file athenaMP-outputs...
# 4499004301  No events to process: 16000 (skipEvents) >= 23...
# 4499011565  Non-zero return code from AODtoDAOD (8); Logfi...
# 4499004297  No events to process: 14000 (skipEvents) >= 23...
# ...                                                       ...
# 4498731008  Non-zero return code from HITtoRDO (65); Logfi...
# 4498443852  Missing AthenaMP outputs file athenaMP-outputs...
# 4498731010  Non-zero return code from HITtoRDO (65); Logfi...
# 4498730995  Non-zero return code from HITtoRDO (65); Logfi...
# 4498443955  Missing AthenaMP outputs file athenaMP-outputs...
#
# [249 rows x 3 columns]

# %%
gp = df.groupby('exeerrordiag')

# %%
[i for i in gp.groups]
# Out:
# ['AODtoDAOD got a SIGKILL signal (exit code 137)',
#  'EVNTtoHITS got a SIGKILL signal (exit code 137)',
#  'Error reading user generated output file list',
#  'Fatal error in athena logfile: "G4 exception at line 13293 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "G4 exception at line 13383 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "G4 exception at line 17137 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "G4 exception at line 20330 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "G4 exception at line 21005 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "G4 exception at line 28872 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "G4 exception at line 30644 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "G4 exception at line 43572 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Logfile error in log.ESDtoAOD: "ToolSvc.HLTJetMon                                   ERROR Unknown exception caught, while filling histograms""',
#  'Fatal error in athena logfile: "Logfile error in log.EVNTtoHITS: "IOVDbSvc            ERROR Could not retrieve COOL data for folder /LAR/ElecCalibMC/MphysOverMcal tag  validityKeys [[],[]]""',
#  'Fatal error in athena logfile: "Logfile error in log.EVNTtoHITS: "IOVDbSvc            ERROR Could not retrieve COOL data for folder /LAR/ElecCalibMC/Noise tag LARElecCalibMCNoise-IOVDEP-00 validityKeys [[],[]]""',
#  'Fatal error in athena logfile: "Logfile error in log.EVNTtoHITS: "ISF_MC12LLPTrut...  ERROR Unable to register truth incident with unknown SimGeoID=0""',
#  'Fatal error in athena logfile: "Logfile error in log.RAWtoALL: "ToolSvc.HLTJetMon                                   ERROR Unknown exception caught, while filling histograms""',
#  'Fatal error in athena logfile: "Long ERROR message at line 2374 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line 2561 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line 2621 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line 2634 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line 2845 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line 3168 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line 3245 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line 3257 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line 3305 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line 3317 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line 3325 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line 3354 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line 3377 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line 3393 (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line 3414 (see jobReport for further details)"',
#  'File data18_13TeV.00363033.physics_Main.merge.AOD.f993_m2032._lb0113._0002.1 did not pass corruption test',
#  'Input file argument testRTT.RDO.pool.root globbed to NO input files - probably the file(s) are missing',
#  "Input file argument(s) ['RDO.pool.root'] globbed to NO input files - probably the file(s) are missing",
#  'LRMS error: (271) Job timeout',
#  'LRMS error: (271) Job was cancelled',
#  'Missing AthenaMP outputs file athenaMP-outputs-EVNTtoHITS-sim (probably athena crashed)',
#  'Missing AthenaMP outputs file athenaMP-outputs-HITtoRDO-h2r (probably athena crashed)',
#  'Missing AthenaMP outputs file athenaMP-outputs-RDOtoRDOTrigger-r2t (probably athena crashed)',
#  'No events to process: 10000 (skipEvents) >= 2343 (inputEvents of HITS',
#  'No events to process: 12000 (skipEvents) >= 2343 (inputEvents of HITS',
#  'No events to process: 14000 (skipEvents) >= 2343 (inputEvents of HITS',
#  'No events to process: 16000 (skipEvents) >= 2343 (inputEvents of HITS',
#  'No events to process: 18000 (skipEvents) >= 2343 (inputEvents of HITS',
#  'No events to process: 2000 (skipEvents) >= 2000 (inputEvents of EVNT',
#  'No events to process: 2100 (skipEvents) >= 2000 (inputEvents of EVNT',
#  'No events to process: 2200 (skipEvents) >= 2000 (inputEvents of EVNT',
#  'No events to process: 2400 (skipEvents) >= 2000 (inputEvents of EVNT',
#  'No events to process: 2500 (skipEvents) >= 2000 (inputEvents of EVNT',
#  'No events to process: 2600 (skipEvents) >= 2000 (inputEvents of EVNT',
#  'No events to process: 2700 (skipEvents) >= 2000 (inputEvents of EVNT',
#  'No events to process: 2800 (skipEvents) >= 2000 (inputEvents of EVNT',
#  'No events to process: 2900 (skipEvents) >= 2000 (inputEvents of EVNT',
#  'No events to process: 3200 (skipEvents) >= 2000 (inputEvents of EVNT',
#  'No events to process: 3300 (skipEvents) >= 2000 (inputEvents of EVNT',
#  'No events to process: 3400 (skipEvents) >= 2000 (inputEvents of EVNT',
#  'No events to process: 4000 (skipEvents) >= 2343 (inputEvents of HITS',
#  'No events to process: 8000 (skipEvents) >= 2343 (inputEvents of HITS',
#  'Non-zero return code from AODtoDAOD (64); Logfile error in log.AODtoDAOD: "JETM7Kernel_Skim                                    FATAL  Standard std::exception is caught"',
#  'Non-zero return code from AODtoDAOD (65); Logfile error in log.AODtoDAOD: "AthMpEvtLoopMgr                                     ERROR Failure in waiting or sub-process finished abnormally"',
#  'Non-zero return code from AODtoDAOD (65); Logfile error in log.AODtoDAOD: "AthMpEvtLoopMgr                                     FATAL makePool failed for AthMpEvtLoopMgr.SharedEvtQueueProvider"',
#  'Non-zero return code from AODtoDAOD (65); Long FATAL message at line 6228 (see jobReport for further details)',
#  'Non-zero return code from AODtoDAOD (8); Logfile error in log.AODtoDAOD: "AttributeError: \'module\' object has no attribute \'GetDecoratePromptTauAlgs\'"',
#  'Non-zero return code from AODtoDAOD (8); Logfile error in log.AODtoDAOD: "KeyError: \'nentries\'"',
#  'Non-zero return code from AODtoDAOD (8); Logfile error in log.AODtoDAOD: "RuntimeError: Smart slimming container BTagging_AntiKt4LCTopo does not exist or does not have a smart slimming list"',
#  'Non-zero return code from AODtoDAOD (8); Logfile error in log.AODtoDAOD: "Unable to identify specific exception"',
#  'Non-zero return code from ESDtoDPD (65); Logfile error in log.ESDtoDPD: "AthMpEvtLoopMgr                                     ERROR Failure in waiting or sub-process finished abnormally"',
#  'Non-zero return code from EVNTtoHITS (255)',
#  'Non-zero return code from EVNTtoHITS (33); Logfile error in log.EVNTtoHITS: "IOVDbSvc            FATAL Conditions database connection COOLOFL_INDET/OFLP200 cannot be opened - STOP"',
#  'Non-zero return code from EVNTtoHITS (65); G4 exception at line 12768 (see jobReport for further details)',
#  'Non-zero return code from EVNTtoHITS (65); Logfile error in log.EVNTtoHITS: "AthMpEvtLoopMgr     ERROR Failure in waiting or sub-process finished abnormally"',
#  'Non-zero return code from EVNTtoHITS (8); Logfile error in log.EVNTtoHITS: "ValueError:  ATLAS-P2-ITK-17-04-02 is not the expected type and/or the value is not allowed for: JobProperties.SimFlags.SimLayout"',
#  'Non-zero return code from HITtoRDO (65); Logfile error in log.HITtoRDO: "AthMpEvtLoopMgr     ERROR Failure in waiting or sub-process finished abnormally"',
#  'Non-zero return code from POOLMergeAthenaMPDESDMCALJET0 (8); Logfile error in log.POOLMergeAthenaMPDESDMCALJET0: "TypeError: %d format: a number is required, not NoneType"',
#  'Non-zero return code from RAWtoALL (65); Logfile error in log.RAWtoALL: "muonTrkTrackThinTool_CT                             ERROR FILE:LINE (StatusCode muonTrkTrackThinTool::execute()): code FAILURE: evtStore()->retrieve( alltracks, m_trackCollKey )"',
#  'Non-zero return code from RAWtoALL (65); Long ERROR message at line 16432 (see jobReport for further details)',
#  'Non-zero return code from RAWtoESD (65); Logfile error in log.RAWtoESD: "AthMpEvtLoopMgr                                     ERROR Failure in waiting or sub-process finished abnormally"',
#  'Non-zero return code from RAWtoESD (65); Logfile error in log.RAWtoESD: "AthenaHiveEventLoopMgr                              FATAL Failed event detected on s: 0  e: 0 w/ fail mode: AlgStall"',
#  'Non-zero return code from RAWtoESD (8); Logfile error in log.RAWtoESD: ""',
#  'Non-zero return code from RDOtoRDOTrigger (33); Logfile error in log.RDOtoRDOTrigger: "TrigSteer_HLT                                       FATAL Signature: (TE = EF_xe10_step1) : Could not find matching sequence for output TE."',
#  'Non-zero return code from RDOtoRDOTrigger (65); Logfile error in log.RDOtoRDOTrigger: "AthMpEvtLoopMgr                                     ERROR Failure in waiting or sub-process finished abnormally"']

# %%
for i in gp:
    print(i)
# Out:
# (-1,                       starttime  exeerrorcode  \
# pandaid
# 4497587840  2019-10-01T09:52:27            -1
# 4497587794  2019-10-01T09:06:30            -1
# 4497587800  2019-10-01T10:07:26            -1
# 4497587718  2019-10-01T09:39:27            -1
# 4497587788  2019-10-01T09:16:07            -1
# 4497587734  2019-10-01T10:07:49            -1
# 4497587776  2019-10-01T09:29:08            -1
# 4497587738  2019-10-01T09:26:10            -1
# 4497587798  2019-10-01T09:50:10            -1
# 4497587839  2019-10-01T10:10:51            -1
# 4497587781  2019-10-01T09:40:25            -1
# 4497587768  2019-10-01T10:23:28            -1
# 4497587799  2019-10-01T10:00:28            -1
# 4497587741  2019-10-01T09:27:26            -1
# 4497587824  2019-10-01T09:06:49            -1
# 4497587803  2019-10-01T09:52:10            -1
# 4497587747  2019-10-01T10:02:11            -1
# 4497587745  2019-10-01T09:23:31            -1
# 4497587726  2019-10-01T09:44:31            -1
# 4497587723  2019-10-01T09:14:27            -1
# 4497587828  2019-10-01T09:17:30            -1
# 4497587792  2019-10-01T09:55:10            -1
# 4498545009  2019-10-01T09:10:56            -1
# 4498545010  2019-10-01T09:10:57            -1
#
#                                    exeerrordiag
# pandaid
# 4497587840  LRMS error: (271) Job was cancelled
# 4497587794  LRMS error: (271) Job was cancelled
# 4497587800  LRMS error: (271) Job was cancelled
# 4497587718  LRMS error: (271) Job was cancelled
# 4497587788  LRMS error: (271) Job was cancelled
# 4497587734  LRMS error: (271) Job was cancelled
# 4497587776  LRMS error: (271) Job was cancelled
# 4497587738  LRMS error: (271) Job was cancelled
# 4497587798  LRMS error: (271) Job was cancelled
# 4497587839  LRMS error: (271) Job was cancelled
# 4497587781  LRMS error: (271) Job was cancelled
# 4497587768  LRMS error: (271) Job was cancelled
# 4497587799  LRMS error: (271) Job was cancelled
# 4497587741  LRMS error: (271) Job was cancelled
# 4497587824  LRMS error: (271) Job was cancelled
# 4497587803  LRMS error: (271) Job was cancelled
# 4497587747  LRMS error: (271) Job was cancelled
# 4497587745  LRMS error: (271) Job was cancelled
# 4497587726  LRMS error: (271) Job was cancelled
# 4497587723  LRMS error: (271) Job was cancelled
# 4497587828  LRMS error: (271) Job was cancelled
# 4497587792  LRMS error: (271) Job was cancelled
# 4498545009        LRMS error: (271) Job timeout
# 4498545010        LRMS error: (271) Job timeout  )
# (0,                       starttime  exeerrorcode  \
# pandaid
# 4498223385  2019-10-01T09:11:35             0
#
#                                              exeerrordiag
# pandaid
# 4498223385  Error reading user generated output file list  )
# (9,                       starttime  exeerrorcode  \
# pandaid
# 4498828350  2019-10-01T09:04:32             9
# 4499000863  2019-10-01T10:13:57             9
# 4498817673  2019-10-01T09:28:29             9
# 4499014812  2019-10-01T10:24:15             9
# 4498817665  2019-10-01T09:09:51             9
#
#                                                  exeerrordiag
# pandaid
# 4498828350  Input file argument(s) ['RDO.pool.root'] globb...
# 4499000863  Input file argument(s) ['RDO.pool.root'] globb...
# 4498817673  Input file argument(s) ['RDO.pool.root'] globb...
# 4499014812  Input file argument testRTT.RDO.pool.root glob...
# 4498817665  Input file argument(s) ['RDO.pool.root'] globb...  )
# (11,                       starttime  exeerrorcode  \
# pandaid
# 4498851809  2019-10-01T09:13:17            11
# 4499017793  2019-10-01T10:26:22            11
# 4497879322  2019-10-01T09:10:01            11
# 4498033362  2019-10-01T09:03:24            11
# 4498033795  2019-10-01T09:04:31            11
# 4498033879  2019-10-01T09:04:51            11
# 4498033868  2019-10-01T09:04:50            11
# 4498033997  2019-10-01T09:17:20            11
# 4498052901  2019-10-01T09:44:10            11
# 4498033728  2019-10-01T09:04:03            11
# 4498033809  2019-10-01T09:04:35            11
# 4498033740  2019-10-01T09:04:07            11
# 4498033830  2019-10-01T09:04:40            11
# 4498033183  2019-10-01T09:03:14            11
# 4497973740  2019-10-01T09:48:36            11
# 4497905056  2019-10-01T09:02:49            11
# 4498033709  2019-10-01T09:03:57            11
# 4498033824  2019-10-01T09:04:39            11
# 4498033965  2019-10-01T09:17:16            11
# 4498033200  2019-10-01T09:03:17            11
# 4497940257  2019-10-01T09:06:05            11
# 4498033977  2019-10-01T09:17:17            11
# 4498033985  2019-10-01T09:17:18            11
# 4498034089  2019-10-01T09:59:02            11
# 4498033523  2019-10-01T09:03:37            11
# 4497904901  2019-10-01T09:01:29            11
# 4498033854  2019-10-01T09:04:48            11
# 4498033805  2019-10-01T09:04:34            11
# 4498033126  2019-10-01T09:03:02            11
# 4498034012  2019-10-01T09:17:28            11
# 4498034085  2019-10-01T09:47:53            11
# 4498033499  2019-10-01T09:03:36            11
# 4498033755  2019-10-01T09:04:13            11
# 4498033251  2019-10-01T09:03:20            11
# 4498033818  2019-10-01T09:04:38            11
# 4497655712  2019-10-01T09:17:12            11
# 4497655778  2019-10-01T09:52:45            11
# 4498740999  2019-10-01T09:13:08            11
# 4498233345  2019-10-01T09:09:49            11
# 4498161048  2019-10-01T09:02:48            11
# 4498161052  2019-10-01T09:23:01            11
# 4498443984  2019-10-01T09:51:22            11
# 4498443761  2019-10-01T09:02:58            11
# 4498431150  2019-10-01T10:19:55            11
# 4498740983  2019-10-01T09:09:04            11
# 4498740998  2019-10-01T09:10:02            11
# 4498443860  2019-10-01T09:30:36            11
# 4498443988  2019-10-01T09:54:39            11
# 4498443869  2019-10-01T09:31:41            11
# 4498520374  2019-10-01T09:02:37            11
# 4498443769  2019-10-01T09:02:59            11
# 4498740996  2019-10-01T09:10:13            11
# 4498443852  2019-10-01T09:26:03            11
# 4498443955  2019-10-01T09:45:56            11
#
#                                                  exeerrordiag
# pandaid
# 4498851809  Missing AthenaMP outputs file athenaMP-outputs...
# 4499017793  Missing AthenaMP outputs file athenaMP-outputs...
# 4497879322  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033362  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033795  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033879  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033868  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033997  Missing AthenaMP outputs file athenaMP-outputs...
# 4498052901  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033728  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033809  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033740  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033830  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033183  Missing AthenaMP outputs file athenaMP-outputs...
# 4497973740  Missing AthenaMP outputs file athenaMP-outputs...
# 4497905056  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033709  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033824  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033965  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033200  Missing AthenaMP outputs file athenaMP-outputs...
# 4497940257  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033977  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033985  Missing AthenaMP outputs file athenaMP-outputs...
# 4498034089  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033523  Missing AthenaMP outputs file athenaMP-outputs...
# 4497904901  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033854  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033805  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033126  Missing AthenaMP outputs file athenaMP-outputs...
# 4498034012  Missing AthenaMP outputs file athenaMP-outputs...
# 4498034085  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033499  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033755  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033251  Missing AthenaMP outputs file athenaMP-outputs...
# 4498033818  Missing AthenaMP outputs file athenaMP-outputs...
# 4497655712  Missing AthenaMP outputs file athenaMP-outputs...
# 4497655778  Missing AthenaMP outputs file athenaMP-outputs...
# 4498740999  Missing AthenaMP outputs file athenaMP-outputs...
# 4498233345  Missing AthenaMP outputs file athenaMP-outputs...
# 4498161048  Missing AthenaMP outputs file athenaMP-outputs...
# 4498161052  Missing AthenaMP outputs file athenaMP-outputs...
# 4498443984  Missing AthenaMP outputs file athenaMP-outputs...
# 4498443761  Missing AthenaMP outputs file athenaMP-outputs...
# 4498431150  Missing AthenaMP outputs file athenaMP-outputs...
# 4498740983  Missing AthenaMP outputs file athenaMP-outputs...
# 4498740998  Missing AthenaMP outputs file athenaMP-outputs...
# 4498443860  Missing AthenaMP outputs file athenaMP-outputs...
# 4498443988  Missing AthenaMP outputs file athenaMP-outputs...
# 4498443869  Missing AthenaMP outputs file athenaMP-outputs...
# 4498520374  Missing AthenaMP outputs file athenaMP-outputs...
# 4498443769  Missing AthenaMP outputs file athenaMP-outputs...
# 4498740996  Missing AthenaMP outputs file athenaMP-outputs...
# 4498443852  Missing AthenaMP outputs file athenaMP-outputs...
# 4498443955  Missing AthenaMP outputs file athenaMP-outputs...  )
# (15,                       starttime  exeerrorcode  \
# pandaid
# 4499004301  2019-10-01T10:18:49            15
# 4499004297  2019-10-01T10:15:46            15
# 4499004287  2019-10-01T10:14:58            15
# 4499004291  2019-10-01T10:15:11            15
# 4499004281  2019-10-01T10:14:54            15
# 4499004294  2019-10-01T10:15:26            15
# 4499004304  2019-10-01T10:19:05            15
# 4498117632  2019-10-01T09:00:05            15
# 4498117637  2019-10-01T09:02:55            15
# 4498117639  2019-10-01T09:02:46            15
# 4498117633  2019-10-01T09:00:06            15
# 4498117636  2019-10-01T09:00:41            15
# 4498117643  2019-10-01T09:00:38            15
# 4498117635  2019-10-01T09:01:55            15
# 4498117638  2019-10-01T09:01:42            15
# 4498117631  2019-10-01T09:00:05            15
# 4498117644  2019-10-01T09:01:13            15
# 4498117640  2019-10-01T09:00:37            15
# 4498117645  2019-10-01T09:01:13            15
#
#                                                  exeerrordiag
# pandaid
# 4499004301  No events to process: 16000 (skipEvents) >= 23...
# 4499004297  No events to process: 14000 (skipEvents) >= 23...
# 4499004287  No events to process: 8000 (skipEvents) >= 234...
# 4499004291  No events to process: 10000 (skipEvents) >= 23...
# 4499004281  No events to process: 4000 (skipEvents) >= 234...
# 4499004294  No events to process: 12000 (skipEvents) >= 23...
# 4499004304  No events to process: 18000 (skipEvents) >= 23...
# 4498117632  No events to process: 2100 (skipEvents) >= 200...
# 4498117637  No events to process: 2600 (skipEvents) >= 200...
# 4498117639  No events to process: 2800 (skipEvents) >= 200...
# 4498117633  No events to process: 2200 (skipEvents) >= 200...
# 4498117636  No events to process: 2500 (skipEvents) >= 200...
# 4498117643  No events to process: 3200 (skipEvents) >= 200...
# 4498117635  No events to process: 2400 (skipEvents) >= 200...
# 4498117638  No events to process: 2700 (skipEvents) >= 200...
# 4498117631  No events to process: 2000 (skipEvents) >= 200...
# 4498117644  No events to process: 3300 (skipEvents) >= 200...
# 4498117640  No events to process: 2900 (skipEvents) >= 200...
# 4498117645  No events to process: 3400 (skipEvents) >= 200...  )
# (65,                       starttime  exeerrorcode  \
# pandaid
# 4498866929  2019-10-01T09:04:39            65
# 4499011565  2019-10-01T10:25:17            65
# 4499011462  2019-10-01T10:22:04            65
# 4499008082  2019-10-01T10:23:28            65
# 4499011446  2019-10-01T10:21:21            65
# ...                         ...           ...
# 4498636431  2019-10-01T10:00:51            65
# 4498283027  2019-10-01T09:43:09            65
# 4498731008  2019-10-01T09:09:13            65
# 4498731010  2019-10-01T09:09:38            65
# 4498730995  2019-10-01T09:08:50            65
#
#                                                  exeerrordiag
# pandaid
# 4498866929  Non-zero return code from EVNTtoHITS (8); Logf...
# 4499011565  Non-zero return code from AODtoDAOD (8); Logfi...
# 4499011462  Non-zero return code from AODtoDAOD (8); Logfi...
# 4499008082  Non-zero return code from AODtoDAOD (8); Logfi...
# 4499011446  Non-zero return code from AODtoDAOD (8); Logfi...
# ...                                                       ...
# 4498636431  Non-zero return code from AODtoDAOD (65); Logf...
# 4498283027  Non-zero return code from EVNTtoHITS (65); Log...
# 4498731008  Non-zero return code from HITtoRDO (65); Logfi...
# 4498731010  Non-zero return code from HITtoRDO (65); Logfi...
# 4498730995  Non-zero return code from HITtoRDO (65); Logfi...
#
# [113 rows x 3 columns])
# (66,                       starttime  exeerrorcode  \
# pandaid
# 4499000589  2019-10-01T10:21:24            66
#
#                                                  exeerrordiag
# pandaid
# 4499000589  File data18_13TeV.00363033.physics_Main.merge....  )
# (68,                       starttime  exeerrorcode  \
# pandaid
# 4499004413  2019-10-01T10:18:19            68
# 4498856214  2019-10-01T09:24:14            68
# 4499004382  2019-10-01T10:14:40            68
# 4499008470  2019-10-01T10:19:19            68
# 4498867837  2019-10-01T09:12:31            68
# 4499004383  2019-10-01T10:17:41            68
# 4498856185  2019-10-01T09:02:39            68
# 4499004385  2019-10-01T10:17:41            68
# 4499004412  2019-10-01T10:18:19            68
# 4498771928  2019-10-01T10:07:48            68
# 4498856145  2019-10-01T09:02:02            68
# 4498617609  2019-10-01T09:18:25            68
# 4498711098  2019-10-01T09:36:02            68
# 4498426980  2019-10-01T09:18:23            68
# 4498711135  2019-10-01T09:52:29            68
# 4498711033  2019-10-01T10:14:59            68
# 4498710959  2019-10-01T10:14:27            68
# 4498547627  2019-10-01T09:35:26            68
# 4498196825  2019-10-01T09:10:12            68
# 4498711028  2019-10-01T09:33:22            68
# 4498711093  2019-10-01T09:35:59            68
# 4498711035  2019-10-01T10:11:55            68
# 4498710960  2019-10-01T10:10:29            68
# 4498711129  2019-10-01T09:02:06            68
# 4498617607  2019-10-01T09:16:29            68
# 4498711022  2019-10-01T09:22:55            68
# 4498711073  2019-10-01T09:25:53            68
# 4498567181  2019-10-01T09:11:52            68
# 4498711108  2019-10-01T09:53:37            68
# 4498711038  2019-10-01T10:07:45            68
# 4498711125  2019-10-01T09:56:34            68
# 4498711128  2019-10-01T10:00:30            68
#
#                                                  exeerrordiag
# pandaid
# 4499004413  Fatal error in athena logfile: "Logfile error ...
# 4498856214  Fatal error in athena logfile: "G4 exception a...
# 4499004382  Fatal error in athena logfile: "Logfile error ...
# 4499008470  Fatal error in athena logfile: "Logfile error ...
# 4498867837  Fatal error in athena logfile: "G4 exception a...
# 4499004383  Fatal error in athena logfile: "Logfile error ...
# 4498856185  Fatal error in athena logfile: "G4 exception a...
# 4499004385  Fatal error in athena logfile: "Logfile error ...
# 4499004412  Fatal error in athena logfile: "Logfile error ...
# 4498771928  Fatal error in athena logfile: "Logfile error ...
# 4498856145  Fatal error in athena logfile: "G4 exception a...
# 4498617609  Fatal error in athena logfile: "Long ERROR mes...
# 4498711098  Fatal error in athena logfile: "Long ERROR mes...
# 4498426980  Fatal error in athena logfile: "G4 exception a...
# 4498711135  Fatal error in athena logfile: "Long ERROR mes...
# 4498711033  Fatal error in athena logfile: "Long ERROR mes...
# 4498710959  Fatal error in athena logfile: "Long ERROR mes...
# 4498547627  Fatal error in athena logfile: "G4 exception a...
# 4498196825  Fatal error in athena logfile: "G4 exception a...
# 4498711028  Fatal error in athena logfile: "Long ERROR mes...
# 4498711093  Fatal error in athena logfile: "Long ERROR mes...
# 4498711035  Fatal error in athena logfile: "Long ERROR mes...
# 4498710960  Fatal error in athena logfile: "Logfile error ...
# 4498711129  Fatal error in athena logfile: "Long ERROR mes...
# 4498617607  Fatal error in athena logfile: "Long ERROR mes...
# 4498711022  Fatal error in athena logfile: "Long ERROR mes...
# 4498711073  Fatal error in athena logfile: "Long ERROR mes...
# 4498567181  Fatal error in athena logfile: "G4 exception a...
# 4498711108  Fatal error in athena logfile: "Long ERROR mes...
# 4498711038  Fatal error in athena logfile: "Long ERROR mes...
# 4498711125  Fatal error in athena logfile: "Logfile error ...
# 4498711128  Fatal error in athena logfile: "Long ERROR mes...  )

# %%
df.index.values
# Out:
# array([4498866929, 4498851809, 4499004301, 4499011565, 4499004297,
#        4499011462, 4499008082, 4499011446, 4499011466, 4499008070,
#        4499008073, 4499008025, 4498813193, 4498808776, 4499004416,
#        4499004413, 4498813183, 4498856214, 4498813206, 4498813220,
#        4498997209, 4498768924, 4498828350, 4499000863, 4498817673,
#        4499004287, 4499011554, 4499008045, 4499004291, 4499008077,
#        4499012206, 4499008097, 4499017793, 4498813182, 4498813201,
#        4498813095, 4499000589, 4498813241, 4498812915, 4498813082,
#        4498997208, 4499004382, 4498812940, 4499008470, 4498795729,
#        4498867837, 4499011557, 4499011563, 4499011517, 4499004281,
#        4499008092, 4499008093, 4499011463, 4499008069, 4498997185,
#        4499004383, 4498812932, 4498813029, 4498813151, 4498813089,
#        4498856185, 4499016296, 4499004385, 4499007954, 4498997207,
#        4498979877, 4499011548, 4499011527, 4499008067, 4499011445,
#        4499008062, 4499008065, 4499004294, 4499007911, 4499000735,
#        4498812893, 4499007963, 4498812906, 4499004412, 4499004407,
#        4498812959, 4499014812, 4498771928, 4498782251, 4498817665,
#        4498774137, 4498774146, 4498984294, 4499004304, 4499008095,
#        4499011449, 4499008050, 4499008079, 4499011465, 4499007921,
#        4498812919, 4498812999, 4498812953, 4498856145, 4498813217,
#        4498812995, 4498813252, 4498808778, 4498813232, 4498117632,
#        4498117637, 4498117639, 4497879322, 4498033362, 4498033795,
#        4498033879, 4498033868, 4498033997, 4498052901, 4498033728,
#        4498033809, 4497587840, 4497587794, 4498117633, 4498117636,
#        4498117643, 4498033740, 4498033830, 4498033183, 4497973740,
#        4497905056, 4497587800, 4497587718, 4497587788, 4497587734,
#        4497587776, 4497587738, 4497587798, 4497587839, 4498117635,
#        4498117638, 4498033709, 4498033824, 4498033965, 4498033200,
#        4497940257, 4498033977, 4498033985, 4498034089, 4497587781,
#        4497587768, 4497587799, 4498117631, 4498117644, 4498033523,
#        4497904901, 4498033854, 4498033805, 4498033126, 4498034012,
#        4497587741, 4497587824, 4497587803, 4497587747, 4497587745,
#        4497587726, 4498117640, 4498117645, 4498034085, 4498033499,
#        4498033755, 4498033251, 4498033818, 4497655712, 4497655778,
#        4497587723, 4497587828, 4497587792, 4498676664, 4498640664,
#        4498617609, 4498711098, 4498634405, 4498744765, 4498744776,
#        4498731016, 4498740999, 4498426980, 4498545009, 4498374240,
#        4498144011, 4498233345, 4498636437, 4498711135, 4498636436,
#        4498711033, 4498710959, 4498744793, 4498636433, 4498161048,
#        4498161052, 4498731012, 4498744745, 4498744784, 4498223139,
#        4498730991, 4498443984, 4498443761, 4498547627, 4498196825,
#        4498545010, 4498711028, 4498711093, 4498711035, 4498431150,
#        4498744755, 4498710960, 4498731014, 4498744757, 4498740983,
#        4498733249, 4498744746, 4498691356, 4498711129, 4498617607,
#        4498711022, 4498711073, 4498567181, 4498711108, 4498223385,
#        4498730992, 4498740998, 4498730997, 4498730974, 4498733444,
#        4498443860, 4498443988, 4498443869, 4498744780, 4498495983,
#        4498520374, 4498648974, 4498711038, 4498711125, 4498711128,
#        4498636431, 4498283027, 4498443769, 4498740996, 4498731008,
#        4498443852, 4498731010, 4498730995, 4498443955])

# %% [raw]
# # Save relevant columns as a NumPy array for performing NumPy operations afterwards
# arr_slice = df[['Client', 'Month']].values
#
# # Get linear indices equivalent of those columns
# lidx = np.ravel_multi_index(arr_slice.T,arr_slice.max(0)+1)
#
# # Get unique IDs corresponding to each linear index (i.e. group) and grouped counts
# unq,unqtags,counts = np.unique(lidx,return_inverse=True,return_counts=True)
#
# # Index counts with the unique tags to map across all elements with the counts
# df["Nbcontrats"] = counts[unqtags]

# %%
arr_slice = np.array(df[['exeerrordiag']].values)

# %%
len(df[['exeerrordiag']].values)
# Out:
# 249

# %%
#np.c_[arr_slice, df.index.values]

# %%
#lidx = np.ravel_multi_index(arr_slice.T,arr_slice.max(0)+1)

# %%
unq,unqtags,counts = np.unique(arr_slice,return_counts=True,return_inverse=True)

# %%
unqtags
# Out:
# array([71, 36, 42, 62, 41, 64, 62, 62, 62, 62, 62, 58, 60, 59, 73, 15, 59,
#         4, 59, 59, 66, 69, 33, 33, 33, 57, 62, 64, 39, 62, 78, 62, 36, 59,
#        59, 59, 31, 59, 59, 59, 75, 11, 59, 14,  0, 10, 62, 62, 64, 56, 62,
#        62, 64, 62, 77, 15, 59, 59, 59, 59,  3, 59, 15, 59, 74,  1, 64, 62,
#        62, 62, 64, 62, 40, 61, 65, 59, 59, 59, 15, 79, 59, 32, 14,  1, 33,
#        67, 67, 68, 43, 62, 62, 62, 62, 62, 62, 59, 59, 60,  5, 59, 59, 59,
#        59, 59, 45, 49, 51, 37, 37, 37, 37, 37, 37, 37, 37, 37, 35, 35, 46,
#        48, 53, 37, 37, 37, 37, 37, 35, 35, 35, 35, 35, 35, 35, 35, 47, 50,
#        37, 37, 37, 37, 37, 37, 37, 37, 35, 35, 35, 44, 54, 37, 37, 37, 37,
#        37, 37, 35, 35, 35, 35, 35, 35, 52, 55, 37, 37, 37, 37, 37, 37, 37,
#        35, 35, 35, 59, 60, 25, 18, 59, 72, 72, 72, 38,  9, 34, 72, 59, 37,
#        59, 29, 59, 27, 21, 72, 59, 37, 37, 72, 72, 80, 63, 72, 37, 37,  6,
#         8, 34, 23, 16, 24, 37, 72, 13, 72, 72, 38, 76, 76,  1, 20, 30, 26,
#        22,  7, 17,  2, 72, 38, 72, 72, 76, 37, 37, 37, 80, 68, 37, 60, 28,
#        12, 19, 59, 70, 37, 38, 72, 37, 72, 72, 37])

# %%
df["Nbcontrats"] = counts[unqtags]

# %%
df = pd.read_csv('samples/fts_mess_panda.csv', index_col=0).set_index('id')

# %%
df.head()
# Out:
#                                               message  count
# id
# 1   DESTINATION MAKE_PARENT srm-ifce err: Permissi...     27
# 2   TRANSFER  globus_ftp_client: the server respon...   1467
# 3   TRANSFER  globus_ftp_client: the server respon...      2
# 4   TRANSFER  globus_ftp_client: the server respon...     34
# 5   TRANSFER  globus_ftp_client: the server respon...      9

# %%
df.shape
# Out:
# (22792, 2)

# %% [raw]
# 315761 element - HDBSCAN
#
# {'data_preparation': 33.654,
#  'tokenization': 25.3849,
#  'tokens_vectorization': 79.8579,
#  'sentence_vectorization': 1599.6386,
#  'dimensionality_reduction': 3.9598,
#  'hdbscan': 109.4471,
#  'extract_patterns': 85.691,
#  'reprocess': 30.1852,
#  'statistics': 13.302,
#  'process': 1981.1207}
#
#  number of clusters: 634
#
#  len(cluster.tokens.wordpunct_vocab) = 45650
#  len(cluster.tokens.pyonmttok_vocab) = 239925
#
#  DBSCAN
#
#  {'data_preparation': 34.2866,
#  'tokenization': 25.0582,
#  'tokens_vectorization': 0.1658,
#  'sentence_vectorization': 2347.2583,
#  'dimensionality_reduction': 3.7548,
#  'kneighbors': 79.9184,
#  'epsilon_search': 0.2989,
#  'dbscan': 27.8213,
#  'extract_patterns': 942.5469,
#  'reprocess': 756.5449,
#  'statistics': 12.6698,
#  'process': 4230.3263}
#
#  The same number of clusters...

# %% [markdown]
# ### 2. Initialize clusterization pipeline

# %% [raw]
# Required parameters are:
# - df - pandas DataFrame with error messages
# - target - name of a column with error messages
#
# Not required parameters are cluster_settings. If not defined - the default values are used.
# Note: It's better to use for big data samples with a vocabulary of more than 1000 tokens.
#
# CLUSTERING_DEFAULTS = {"tokenizer": "nltk",
#                        "w2v_size": "auto",
#                        "w2v_window": 5,
#                        "min_samples": 1}
#
# But you can define these parameters. For example,
#
# clustering_parameters = {'tokenizer':'nltk',
#                          'w2v_size': 200,
#                          'w2v_window': 5,
#                          'min_samples': 1}
#
# cluster = pipeline.ml_clustering(df, target, clustering_parameters)

# %%
target = 0

# %%
cluster = multistage.exec(df.head(150000), target, 'undrus.model')
# Out:
# /Users/maria/PycharmProjects/ClusterLog/clusterlogs/pipeline.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['cleaned'] = self.messages_cleaned
# /Users/maria/PycharmProjects/ClusterLog/clusterlogs/pipeline.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['tokenized'] = self.tokens.tokenized
# /Users/maria/PycharmProjects/ClusterLog/clusterlogs/pipeline.py:118: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['tokenized_cleaned'] = self.tokens.tokenized_cleaned
# /Users/maria/PycharmProjects/ClusterLog/clusterlogs/pipeline.py:232: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['cluster'] = self.cluster_labels
# /anaconda3/envs/anaconda37/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
cluster.clusterization.timings
# Out:
# {'data_preparation': 5.4886,
#  'tokenization': 10.4674,
#  'tokens_vectorization': 14.7409,
#  'sentence_vectorization': 42.084,
#  'dimensionality_reduction': 0.0311,
#  'kneighbors': 18.6969,
#  'epsilon_search': 0.2982,
#  'dbscan': 22.4796,
#  'extract_patterns': 35.7631,
#  'process': 131.0237}

# %%
cluster.clusterization.big
# Out:
#        cluster_name  cluster_size  \
# 32835         32835          1376
# 109715       109715          1376
# 109764       109764          1376
# 32884         32884          1376
# 2602           2602           919
# 1055           1055           804
# 78068         78068           492
# 15151         15151           346
# 72080         72080           313
# 71124         71124           304
# 2601           2601           290
# 2757           2757           229
# 40448         40448           214
# 69951         69951           185
# 69439         69439           185
# 68714         68714           161
# 102390       102390           150
# 25510         25510           150
# 87643         87643           142
# 10628         10628           142
# 72124         72124           136
# 79615         79615           130
# 40447         40447           127
# 55563         55563           123
# 68191         68191           120
# 69444         69444           115
# 69944         69944           115
# 43826         43826           112
# 78675         78675           110
# 1662           1662           110
# 75565         75565           105
# 68500         68500           102
# 68927         68927           100
#
#                                                   pattern  \
# 32835   - Installing: /build1/atnight/localbuilds/nigh...
# 109715  - Installing: /build1/atnight/localbuilds/nigh...
# 109764  - Installing: /build1/atnight/localbuilds/nigh...
# 32884   - Installing: /build1/atnight/localbuilds/nigh...
# 2602    - Installing: /build1/atnight/localbuilds/nigh...
# 1055    - Installing: /build1/atnight/localbuilds/nigh...
# 78068   - Installing: /build1/atnight/localbuilds/nigh...
# 15151   - Installing: /build1/atnight/localbuilds/nigh...
# 72080   - Installing: /build1/atnight/localbuilds/nigh...
# 71124   - Installing: /build1/atnight/localbuilds/nigh...
# 2601    - Installing: /build1/atnight/localbuilds/nigh...
# 2757    - Installing: /build1/atnight/localbuilds/nigh...
# 40448   - Installing: /build1/atnight/localbuilds/nigh...
# 69951   - Installing: /build1/atnight/localbuilds/nigh...
# 69439   - Installing: /build1/atnight/localbuilds/nigh...
# 68714   - Installing: /build1/atnight/localbuilds/nigh...
# 102390  - Installing: /build1/atnight/localbuilds/nigh...
# 25510   - Installing: /build1/atnight/localbuilds/nigh...
# 87643   - Installing: /build1/atnight/localbuilds/nigh...
# 10628   - Installing: /build1/atnight/localbuilds/nigh...
# 72124   - Installing: /build1/atnight/localbuilds/nigh...
# 79615   - Installing: /build1/atnight/localbuilds/nigh...
# 40447   - Installing: /build1/atnight/localbuilds/nigh...
# 55563   - Installing: /build1/atnight/localbuilds/nigh...
# 68191   - Installing: /build1/atnight/localbuilds/nigh...
# 69444   - Installing: /build1/atnight/localbuilds/nigh...
# 69944   - Installing: /build1/atnight/localbuilds/nigh...
# 43826   - Installing: /build1/atnight/localbuilds/nigh...
# 78675   - Installing: /build1/atnight/localbuilds/nigh...
# 1662    - Installing: /build1/atnight/localbuilds/nigh...
# 75565   - Installing: /build1/atnight/localbuilds/nigh...
# 68500   - Installing: /build1/atnight/localbuilds/nigh...
# 68927   - Installing: /build1/atnight/localbuilds/nigh...
#
#                                                  sequence  mean_similarity  \
# 32835   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 109715  [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 109764  [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 32884   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 2602    [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 1055    [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 78068   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 15151   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 72080   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 71124   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...            99.90
# 2601    [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 2757    [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 40448   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...            99.98
# 69951   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 69439   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 68714   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 102390  [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 25510   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 87643   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 10628   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 72124   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...            96.47
# 79615   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 40447   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...            99.97
# 55563   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 68191   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 69444   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 69944   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 43826   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 78675   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 1662    [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 75565   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 68500   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
# 68927   [-, ▁Installing, :, ▁/, build1, /, atnight, /,...           100.00
#
#         std_similarity                                            indices
# 32835             0.00  [39601, 39602, 39603, 39604, 39605, 39606, 396...
# 109715            0.00  [139017, 139018, 139019, 139020, 139021, 13902...
# 109764            0.00  [140446, 140447, 140448, 140449, 140450, 14045...
# 32884             0.00  [41030, 41031, 41032, 41033, 41034, 41035, 410...
# 2602              0.00  [4059, 4060, 4061, 4062, 4063, 13082, 18157, 1...
# 1055              0.00  [1835, 1836, 1837, 2217, 2218, 2219, 2220, 222...
# 78068             0.00  [101247, 101248, 101249, 101629, 101630, 10163...
# 15151             0.00  [18073, 18074, 18160, 25429, 25434, 25435, 254...
# 72080             0.00  [91719, 91822, 91838, 91907, 91958, 91982, 920...
# 71124             0.59  [90693, 90694, 90696, 90698, 90702, 90708, 917...
# 2601              0.00  [4057, 4058, 11642, 11643, 11644, 11645, 13081...
# 2757              0.00  [4241, 4242, 8671, 8672, 9724, 9725, 11591, 11...
# 40448             0.23  [50873, 50874, 50875, 50876, 50878, 50879, 508...
# 69951             0.00  [89122, 89123, 89124, 89125, 89126, 89127, 891...
# 69439             0.00  [88137, 88138, 88139, 88140, 88141, 88142, 881...
# 68714             0.00  [86835, 86836, 86837, 86838, 86839, 86840, 868...
# 102390            0.00  [129926, 129927, 129928, 129929, 129930, 12993...
# 25510             0.00  [30510, 30511, 30512, 30513, 30514, 30515, 305...
# 87643             0.00  [111874, 111875, 111876, 111877, 111878, 11187...
# 10628             0.00  [12458, 12459, 12460, 12461, 12462, 12463, 124...
# 72124             0.61  [91797, 92030, 92047, 92080, 92198, 92201, 922...
# 79615             0.00  [103471, 103472, 103473, 103474, 103475, 11249...
# 40447             0.30  [50867, 50868, 50924, 50925, 50926, 50927, 511...
# 55563             0.00  [70834, 70838, 70871, 70872, 70873, 70874, 708...
# 68191             0.00  [85768, 85769, 85770, 85772, 85773, 85774, 857...
# 69444             0.00  [88326, 88327, 88328, 88329, 88330, 88331, 883...
# 69944             0.00  [89001, 89002, 89003, 89004, 89005, 89006, 890...
# 43826             0.00  [56303, 56304, 56306, 56307, 56308, 56309, 563...
# 78675             0.00  [102022, 102023, 102024, 102025, 102026, 10202...
# 1662              0.00  [2610, 2611, 2612, 2613, 2614, 2615, 2616, 261...
# 75565             0.00  [97616, 97617, 97618, 97619, 97620, 97621, 976...
# 68500             0.00  [86426, 86427, 86428, 86429, 86430, 86431, 864...
# 68927             0.00  [87323, 87324, 87325, 87326, 87327, 87328, 873...

# %%
cluster.clusterization.small['pattern'].values[5]
# Out:
# '- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/src/Simulation/{*}/{*}/src/{*}'

# %%
cluster.clusters['pattern'].values
# Out:
# array(['-{*}: /build1/atnight/localbuilds/nightlies/21.0/build/{*}/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/{*}/{*}/{*}',
#        '-{*} /build1/atnight/localbuilds/nightlies/21.0/build/build/Athena/_CPack_Packages/Linux/RPM/Athena_21.0.105_x86_64-slc6-gcc62-dbg/usr/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/{*}/{*}',
#        '-{*}: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/{*}/{*}',
#        '-{*} /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/{*}/{*}',
#        'copying{*}/{*}/{*}/{*} -> /build1/atnight/localbuilds/nightlies/21.0/build/{*}/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/{*}/{*}',
#        'copying build/{*}/{*}/{*} -> /build1/atnight/localbuilds/nightlies/21.0/build/build/Athena/_CPack_Packages/Linux/RPM/Athena_21.0.105_x86_64-slc6-gcc62-dbg/usr/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/python/{*}',
#        '{*} /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/python/{*}/{*}/{*}'],
#       dtype=object)

# %%
cluster.outliers.to_csv('undrus_small_clusters.csv')

# %%
cluster.in_cluster(0)
# Out:
# ['-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findigprof.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindGSL.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHEPUtils.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindCASTOR.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindJava.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindShowerDeconstruction.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/GaudiFunctions.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindCORAL.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findtcmalloc.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindCLHEP.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindLAPACK.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindRivet.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPNG.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindFastJetContrib.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHerwig.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findsrm_ifce.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Finddqm-common.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/cpack_install.sh.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/mergeSelections.sh',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/extractCTestTest.py',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/mergeFiles.sh',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/extractCTestBuild.py',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/setup.sh.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/mergeClids.sh',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/atlas_ctest.sh.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/cpack_install.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/nightly_name.sh',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/cpack_dbg_install.sh.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/unit_test_executor.sh.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/atlas_build_run.sh.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findgmp.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findmysql.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasLibraryFunctions.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindXercesC.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasDictionaryFunctions.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindCairo.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findpygraphics.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPango.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPyquen.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindTauola.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindLibXml2.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindAlpGen.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findkiwisolver.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findqd.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHepPDT.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findtdaq-common.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findvalgrind.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHerwigpp.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findpip.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindCrmc.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/LCGFunctions.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findgraphviz.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FinddSFMT.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHydjet.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindROOT.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findgdb.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findchardet.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPythonInterp.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindQt4.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindRELAX.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindYODA.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPythia8.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindBoost.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindStarlight.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHerwig3.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findurllib3.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindUUID.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPhotospp.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindThePEG.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasCompilerSettings.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findgfal.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindBLAS.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindAIDA.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findyamlcpp.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findlibunwind.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindEigen.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findsqlite.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindFastJet.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findxz.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindFrontier_Client.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindQt5.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasFunctions.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindSoQt.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHijing.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindXrootd.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindZLIB.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findpacparser.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindMCUtils.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindQwt.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindGaudi.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasInternals.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindGeant4.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPythia6.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindMadGraph.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindSuperchic.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindSherpa.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findpyanalysis.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindMCTester.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Finddcap.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPhotos.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findcycler.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findidna.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findgperftools.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasInstallFunctions.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindFFTW.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findcppgsl.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findunwind.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindOracle.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasTestFunctions.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindGMock.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindTauolapp.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindCOOL.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindCoin3D.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findyampl.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindBaurMC.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindTBB.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findtdaq.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHepMCAnalysis.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findpytools.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindDavix.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findlwtnn.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHepMC.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/GaudiCPackSettings.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindLhapdf.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/DataLink_selection.xml.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/SerCnv_entries.cxx.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/CPackOptions.cmake.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/ExperimentalBuild.cmake.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/README.txt.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/NightlyBuild.cmake.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/ProjectConfig-version.cmake.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/ProjectConfig.cmake.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/PoolCnv_entries.h.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/SerCnvSimple.h.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/ElementLink_selection.xml.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/PoolCnvSimple.h.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/atlas_export_sanitizer.cmake.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/ReleaseData.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/PoolCnv_entries.cxx.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/ElementLinkVector_selection.xml.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/PoolCnv_load.cxx.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/PoolCnvMultiChan.h.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/PoolCnvItemList_joboptionsHdr.py.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/SerCnv_load.cxx.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/ClientCMakeLists.txt.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/CTestCustom.cmake.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/LICENSE.txt',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/ElementLinkDict.h.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/NavigableDict.h.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/Navigable_selection.xml.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/ElementLinkVectorDict.h.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/DataLinkDict.h.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/SerCnv_entries.h.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/PoolCnvItemList_joboptions.py.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons/CPackDbgRPMConfig.cmake.in',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Finddpm.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindQMTest.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findblackhat.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindEvtGen.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPythonLibs.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindDoxygen.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindJimmy.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindCppUnit.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindEXPAT.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findxapian.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHDF5.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindAPE.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/LCGConfig.cmake',
#  '-- Installing: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/LCGConfig-version.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findigprof.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindGSL.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHEPUtils.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindCASTOR.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindJava.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindShowerDeconstruction.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/GaudiFunctions.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindCORAL.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findtcmalloc.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindCLHEP.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindLAPACK.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindRivet.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPNG.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindFastJetContrib.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHerwig.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findsrm_ifce.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Finddqm-common.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/cpack_install.sh.in',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/mergeSelections.sh',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/extractCTestTest.py',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/mergeFiles.sh',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/extractCTestBuild.py',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/setup.sh.in',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/mergeClids.sh',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/atlas_ctest.sh.in',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/cpack_install.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/nightly_name.sh',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/cpack_dbg_install.sh.in',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/unit_test_executor.sh.in',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/atlas_build_run.sh.in',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findgmp.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findmysql.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasLibraryFunctions.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindXercesC.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasDictionaryFunctions.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindCairo.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findpygraphics.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPango.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPyquen.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindTauola.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindLibXml2.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindAlpGen.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findkiwisolver.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findqd.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHepPDT.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findtdaq-common.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findvalgrind.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHerwigpp.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findpip.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindCrmc.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/LCGFunctions.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findgraphviz.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FinddSFMT.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHydjet.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindROOT.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findgdb.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findchardet.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPythonInterp.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindQt4.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindRELAX.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindYODA.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPythia8.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindBoost.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindStarlight.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHerwig3.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findurllib3.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindUUID.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPhotospp.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindThePEG.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasCompilerSettings.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findgfal.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindBLAS.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindAIDA.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findyamlcpp.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findlibunwind.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindEigen.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findsqlite.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindFastJet.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findxz.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindFrontier_Client.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindQt5.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasFunctions.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindSoQt.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHijing.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindXrootd.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindZLIB.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findpacparser.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindMCUtils.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindQwt.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindGaudi.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasInternals.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindGeant4.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPythia6.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindMadGraph.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindSuperchic.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindSherpa.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findpyanalysis.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindMCTester.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Finddcap.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPhotos.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findcycler.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findidna.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findgperftools.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasInstallFunctions.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindFFTW.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findcppgsl.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findunwind.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindOracle.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasTestFunctions.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindGMock.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindTauolapp.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindCOOL.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindCoin3D.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findyampl.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindBaurMC.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindTBB.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findtdaq.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHepMCAnalysis.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findpytools.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindDavix.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findlwtnn.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHepMC.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/GaudiCPackSettings.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindLhapdf.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/skeletons',
# ...
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findtcmalloc.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindCLHEP.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindLAPACK.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindRivet.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPNG.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindFastJetContrib.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHerwig.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findsrm_ifce.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Finddqm-common.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/cpack_install.sh.in',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/mergeSelections.sh',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/extractCTestTest.py',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/mergeFiles.sh',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/extractCTestBuild.py',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/setup.sh.in',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/mergeClids.sh',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/atlas_ctest.sh.in',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/cpack_install.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/nightly_name.sh',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/cpack_dbg_install.sh.in',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/unit_test_executor.sh.in',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/atlas_build_run.sh.in',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findgmp.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findmysql.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasLibraryFunctions.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindXercesC.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasDictionaryFunctions.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindCairo.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findpygraphics.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPango.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPyquen.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindTauola.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindLibXml2.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindAlpGen.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findkiwisolver.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findqd.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHepPDT.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findtdaq-common.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findvalgrind.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHerwigpp.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findpip.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindCrmc.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/LCGFunctions.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findgraphviz.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FinddSFMT.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHydjet.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindROOT.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findgdb.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findchardet.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPythonInterp.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindQt4.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindRELAX.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindYODA.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPythia8.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindBoost.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindStarlight.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHerwig3.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findurllib3.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindUUID.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPhotospp.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindThePEG.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasCompilerSettings.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findgfal.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindBLAS.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindAIDA.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findyamlcpp.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findlibunwind.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindEigen.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findsqlite.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindFastJet.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findxz.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindFrontier_Client.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindQt5.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasFunctions.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindSoQt.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindHijing.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindXrootd.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindZLIB.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findpacparser.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindMCUtils.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindQwt.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindGaudi.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasInternals.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindGeant4.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPythia6.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindMadGraph.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindSuperchic.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindSherpa.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findpyanalysis.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindMCTester.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Finddcap.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindPhotos.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findcycler.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findidna.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findgperftools.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/AtlasInstallFunctions.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/FindFFTW.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findcppgsl.cmake',
#  '-- Up-to-date: /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/Findunwind.cmake',
#  ...]

# %%
cluster.outliers['pattern'].values
# Out:
# array(['running build', 'running install', 'running install_lib',
#        'running install_egg_info',
#        "writing list of installed files to '/build1/atnight/localbuilds/nightlies/21.0/build/build/Athena/External/{*}/{*}'",
#        'running build_py', 'running egg_info', 'running install_scripts',
#        "{*} manifest file '{*}/SOURCES.txt'",
#        'writing dependency_links to{*}/dependency_links.txt',
#        'writing top-level names to{*}/top_level.txt',
#        "reading manifest file '{*}/SOURCES.txt'",
#        "reading manifest template 'MANIFEST.in'",
#        'writing entry points to{*}/entry_points.txt',
#        "{*} manifest file 'src/{*}/SOURCES.txt'",
#        'copying build/lib.linux-x86_64-2.7/Crypto/SelfTest/Random/Fortuna/{*} -> /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/python/Crypto/SelfTest/Random/Fortuna',
#        "warning: no files found matching '*.{*}' under directory 'docs'",
#        'running build_ext',
#        "no previously-included directories found matching 'docs/{*}/{*}'",
#        '/build1/atnight/localbuilds/nightlies/21.0/build/build/Athena/x86_64-slc6-gcc62-dbg/{*}/{*}',
#        'Creating partial',
#        'CMake Warning at cmake_install.cmake:{*} (message):',
#        'writing dependency_links to src/{*}/dependency_links.txt',
#        'writing requirements to{*}/requires.txt',
#        "warning: no previously-included files matching '*.{*}' found under directory 'testsuite'",
#        'writing src/{*}/PKG-INFO',
#        'writing top-level names to src/{*}/top_level.txt',
#        'writing mccabe.egg-info/PKG-INFO',
#        'Skipping installation of /build1/atnight/localbuilds/nightlies/21.0/build/install/Athena/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/python/backports/__init__.py (namespace package)',
#        'writing requirements to src/flake8.egg-info/requires.txt',
#        'writing namespace_packages to src/configparser.egg-info/namespace_packages.txt',
#        'writing pycodestyle.egg-info/PKG-INFO',
#        'writing entry points to src/flake8.egg-info/entry_points.txt',
#        'writing namespace_packages to pycodestyle.egg-info/namespace_packages.txt',
#        'writing scandir.egg-info/PKG-INFO',
#        "warning: no previously-included files matching '*.pyc' found anywhere in distribution",
#        'writing pyAMI.egg-info/PKG-INFO',
#        'writing bunch.egg-info/PKG-INFO',
#        'writing simplejson.egg-info/PKG-INFO', 'running build_scripts',
#        'warning: GMP or MPIR library not found; Not building Crypto.PublicKey._fastmath.',
#        'writing pip.egg-info/PKG-INFO', 'running build_configure',
#        'writing pyflakes.egg-info/PKG-INFO',
#        'writing grin.egg-info/PKG-INFO',
#        'writing datadiff.egg-info/PKG-INFO',
#        'writing futures.egg-info/PKG-INFO',
#        'writing affinity.egg-info/PKG-INFO',
#        'writing Beaker.egg-info/PKG-INFO',
#        '# CMake ---> /build1/atnight/localbuilds/nightlies/21.0/build/install/AthenaExternals/21.0.105/InstallArea/x86_64-slc6-gcc62-dbg/cmake/modules/scripts/mergeFiles.sh /build1/atnight/localbuilds/nightlies/21.0/build/build/Athena/x86_64-slc6-gcc62-dbg/lib/Athena.rootmap /build1/atnight/localbuilds/nightlies/21.0/build/build/Athena/CMakeFiles/AthenaRootMapMergeFiles.txt',
#        '-- Install configuration: "Debug"',
#        '# CMake ---> /cvmfs/atlas.cern.ch/repo/ATLASLocalRootBase/x86_64/Cmake/3.11.0/Linux-x86_64/bin/cmake -P cmake_install.cmake',
#        '# CMake ---> /cvmfs/atlas.cern.ch/repo/ATLASLocalRootBase/x86_64/Cmake/3.11.0/Linux-x86_64/bin/cmake -E make_directory /build1/atnight/localbuilds/nightlies/21.0/build/build/Athena/x86_64-slc6-gcc62-dbg/lib',
#        'writing enum34.egg-info/PKG-INFO'], dtype=object)

# %%
len(cluster.tokens.pyonmttok_vocab)
# Out:
# 5090

# %%
cluster.df['cluster_2'].unique()
# Out:
# array(['56', '61', '59', '60', '44', '8', '47', '53', '46', '57', '45',
#        '58', '2', '52', '51', '63', '65', '40', '1', '7', '28', '55',
#        '41', '62', '42', '23', '22', '34', '15', '64', '35', '37', '54',
#        '13', '49', '48', '3', '33', '26', '6', '43', '21', '31', '38',
#        '24', '9', '10', '12', '50', '11', '0', '20', '14', '16', '25',
#        '4', '36', '5', '30', '29', '32', '27', '39', '19', '18', '17'],
#       dtype=object)

# %%
cluster.patterns_stats.to_csv('patterns_stats_DBSCAN.csv')

# %%
cluster.results[['cluster_name','pattern','cluster_size','mean_similarity']].to_csv('day_log_DBSCAN.csv')

# %%
sum(cluster.results['cluster_size'])
# Out:
# 315761

# %%
cluster.results.sort_values(by=['cluster_size'])
# Out:
#    cluster_name  cluster_size  \
# 65            9             1
# 63            7             1
# 0             0             1
# 45            5             1
# 34            4             1
# ..          ...           ...
# 61           64           234
# 62           65           262
# 12            2           324
# 64            8           633
# 52           56          1089
#
#                                               pattern  \
# 65  # CMake ---> /*/atnight/localbuilds/nightlies/...
# 63   void PlotView::resizeEvent (QResizeEvent *eve...
# 0                                        # Dummy file
# 45                          m_alignModuleMaps size: *
# 34                  Warning: Unused variable rule: **
# ..                                                ...
# 61  # CMake ---> /cvmfs/sft.cern.ch/lcg/releases/g...
# 62  # CMake ---> /cvmfs/sft.cern.ch/lcg/releases/g...
# 12                            ^~~~~~~~~~~~~~~~~~~~~~~
# 64  clid.db clid.db will be written to /*/atnight/...
# 52  # CMake ---> /cvmfs/atlas.cern.ch/repo/ATLASLo...
#
#                                              sequence  mean_similarity  \
# 65  [#, CMake, --->, /*/atnight/localbuilds/nightl...             1.00
# 63  [void, PlotView::resizeEvent, (QResizeEvent, *...             1.00
# 0                                    [#, Dummy, file]             1.00
# 45                      [m_alignModuleMaps, size:, *]             1.00
# 34            [Warning:, Unused, variable, rule:, **]             1.00
# ..                                                ...              ...
# 61  [#, CMake, --->, /cvmfs/sft.cern.ch/lcg/releas...             0.51
# 62  [#, CMake, --->, /cvmfs/sft.cern.ch/lcg/releas...             0.58
# 12                          [^~~~~~~~~~~~~~~~~~~~~~~]             0.36
# 64  [clid.db, clid.db, will, be, written, to, /*/a...             0.07
# 52  [#, CMake, --->, /cvmfs/atlas.cern.ch/repo/ATL...             0.76
#
#     std_similarity
# 65            0.00
# 63            0.00
# 0             0.00
# 45            0.00
# 34            0.00
# ..             ...
# 61            0.09
# 62            0.11
# 12            0.48
# 64            0.21
# 52            0.12
#
# [66 rows x 6 columns]

# %%
#cluster.results[['pattern']].values

# %%
#cluster.in_cluster(19,2).tolist()

# %%
print(x)
# Out:
# []

# %% [markdown]
# ### 4. Get clusters statistics

# %% [raw]
# Clusters Statistics returns DataFrame with statistic for all clusters:
# - "cluster_name" - name of a cluster
# - "cluster_size" - number of log messages in cluster
# - "pattern" - all common substrings in messages in the cluster
# - "vocab" - all tokens in error messasges
# - "vocab_length" - the length of cluster's vocabulary
# - "mean_length" - average length of log messages in cluster
# - "std_length" - standard deviation of length of log messages in cluster
# - "mean_similarity" - average similarity of log messages in cluster
# (calculated as the levenshtein distances between the 1st and all other log messages)
# - "std_similarity" - standard deviation of similarity of log messages in cluster

# %%
output = cluster_output.Output(cluster.df, 
                               cluster.target)

# %%
mode = 'INDEX'

# %%
output.clustered_output(mode)
stats = output.statistics(output_mode='frame')

# %%
stats.sort_values(by=['mean_similarity'])
# Out:
#     cluster_name  cluster_size  \
# 35            35             9
# 65            65             9
# 111          111             2
# 41            41             3
# 17            17             5
# ..           ...           ...
# 92            92             9
# 58            58             9
# 54            54             8
# 42            42            10
# 148          148             1
#
#                                                pattern  mean_length  \
# 35   Input file argument T globbed to NO input file...       100.78
# 65   Failed in data staging: Failed checking source...       181.56
# 111  Non-zero return code from OMerge (*); Logfile ...        95.00
# 41   File DAOD_D*.*._*.pool.root.* did not pass cor...        62.33
# 17   Non-zero return code from AODtoDAOD (*); Logfi...       129.40
# ..                                                 ...          ...
# 92   Non-zero return code from EVNTtoHITS (*); Logf...       126.00
# 58   Non-zero return code from AODtoDAOD (*); Logfi...       116.00
# 54   Fatal error in athena logfile: "Long ERROR mes...        97.00
# 42   Non-zero return code from generate (*); Logfil...       138.00
# 148  Non-zero return code from EVNTtoHITS (*); Logf...       103.00
#
#      mean_similarity  std_length  std_similarity
# 35              0.90        3.99            0.03
# 65              0.94        7.23            0.03
# 111             0.94        2.00            0.00
# 41              0.95        0.94            0.01
# 17              0.95        3.20            0.03
# ..               ...         ...             ...
# 92              1.00        0.00            0.00
# 58              1.00        0.00            0.00
# 54              1.00        0.00            0.00
# 42              1.00        0.00            0.00
# 148             1.00        0.00            0.00
#
# [149 rows x 7 columns]

# %%
patterns = stats.sort_values(by='mean_similarity')[['pattern']].values

# %%
patterns
# Out:
# array([['Input file argument T globbed to NO input files - probably the file(s) are missing'],
#        ['Failed in data staging: Failed checking source replica * Failed to obtain information about file: No such file or directory: Failed to stat file *_session******..b.'],
#        ['Non-zero return code from OMerge (*); Logfile error in log.OMerge: "KeyError: \'nentries\'"'],
#        ['File DAOD_D*.*._*.pool.root.* did not pass corruption test'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "* FATAL Standard std::exception is caught"'],
#        ['Non-zero return code from generate (*); Logfile error in log.generate: "*: MadSpin was run but can\'t find output folder Events**_decayed_*"'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "* fault: Event counter: *; Run: *; Evt: *; Current algorithm: tag; Current Function: unknown"'],
#        ['Fatal error in athena logfile: "Logfile error in log.toA: "ToolSvc.HLTJetMon ERROR Unknown exception caught, while filling histograms""'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "StreamDAOD_* FATAL * failed."'],
#        ['Non-zero return code from generate (*); Logfile error in log.generate: "StreamEVGEN FATAL * failed."'],
#        ['Non-zero return code from RAWtoALL (*); Long ERROR message at line * (see jobReport for further details)'],
#        ['Fatal error in athena logfile: "Logfile error in log.ESDtoAOD: "ToolSvc.* ERROR Failed to calculate gap after BCID * to a filled bunch! This shouldn\'t have happened!""'],
#        ['Non-zero return code from * (*); Logfile error in log.*: "IOError: [Errno *] Input*error: \'**.*****.*.***_*-slc*-gcc*-opt*(truncated)'],
#        ['Non-zero return code from HITtoRDO (*); Logfile error in log.HITtoRDO: "* FATAL Error adding sub events to *"'],
#        ['Fatal error in athena logfile: "Logfile error in log.RAWtoESD: "TRT_RDO_* ERROR Failed to convert persistent object to transient: Failed to add collection to ID Container""'],
#        ['Fatal error in athena logfile: "Logfile error in log.AODtoDAOD: "ToolSvc.Trk::* ERROR The determinant of the track covariance matrix is negative: -*.*e+*""'],
#        ['Failed in data staging: Failed to prepare destination * Failed to prepare destination: File exists: File requests have failed.: The requested SURL is locked by another upload.'],
#        ['Non-zero return code from RAWtoESD (*); Logfile error in log.RAWtoESD: "IOVDbSvc FATAL Conditions database connection COOLOFL_TILE** cannot be opened - STOP"'],
#        ['Non-zero return code from * (*)'],
#        ['Non-zero return code from generate (*); Logfile error in log.generate: "TypeError: \'int\' object is not iterable"'],
#        ['Failed in data staging: Could not resolve any source replicas for rucio* Resolving of index service for source failed: No such file or directory: No valid locations found'],
#        ['Non-zero return code from RAWtoESD (*); Logfile error in log.RAWtoESD: "TypeError: reduce() of empty sequence with no initial value"'],
#        ['Non-zero return code from EVNTtoHITS (*); Logfile error in log.EVNTtoHITS: "* fault: Event counter: *; Run: unknown; Evt: unknown; Current algorithm: ISF_Kernel_FullG*; Current Function: unknown"'],
#        ['Non-zero return code from AODtoDAOD (*)'],
#        ['Non-zero return code from ESDtoDPD (*); Logfile error in log.ESDtoDPD: "* ERROR Failure in waiting or sub-process finished abnormally"'],
#        ['File * did not pass corruption test'],
#        ['Non-zero return code from EVNTtoHITS (*); Logfile error in log.EVNTtoHITS: "Unable to identify specific exception"'],
#        ['Non-zero return code from HITtoRDO (*); Logfile error in log.HITtoRDO: "IOError: [Errno *] Input*error: \'**.*****.*.***_*-slc*-gcc*-opt****.py\'"'],
#        ['Job submission to LRMS failed'],
#        ['Non-zero return code from * (*); Logfile error in log.*: "* fault: Event counter: *; Run: *; Evt: *; Current algorithm: <NONE>; Current Function: unknown"'],
#        ['Failed in data staging: Failed to prepare destination * Failed to prepare destination: File exists: File requests have failed.: File exists: ******_*TeV******._*.pool.root.*; Failed in data staging: Failed to prepare destination *'],
#        ['Non-zero return code from * (*); Logfile error in log.*: "TypeError: %d format: a number is required, not NoneType"'],
#        ['Fatal error in athena logfile: "Logfile error in log.*: "*.HLTJetMon ERROR Invalid ElementLink to online jet""'],
#        ['Non-zero return code from EVNTtoHITS (*); G* exception at line * (see jobReport for further details)'],
#        ['Non-zero return code from HITtoRDO (*); Logfile error in log.HITtoRDO: "* fault: Event counter: *; Run: *; Evt: *; Current algorithm: <NONE>; Current Function: unknown"'],
#        ['Non-zero return code from EVNTtoHITS (*); Logfile error in log.EVNTtoHITS: "*"'],
#        ['Non-zero return code from * (*); Logfile error in log.*: "TrigSteer_HLT FATAL Signature: (TE = EF_xe*_step*) : Could not find matching sequence for output TE."'],
#        ['Non-zero return code from RAWtoESD (*); Logfile error in log.RAWtoESD: "* FATAL Failed event detected on s: * e: * w*fail mode: AlgStall"'],
#        ['EVNTtoHITS got a SIGIOT signal (exit code *); Core dump at line * (see jobReport for further details)'],
#        ['Input file argument ${IN_MINBIAS_LOW*} globbed to NO input files - probably the file(s) are missing'],
#        ['Non-zero return code from * (*); Logfile error in log.*: "PerfMonSvc FATAL in *(): standard std::exception is caught"'],
#        ['Non-zero return code from EVNTtoHITS (*); Logfile error in log.EVNTtoHITS: "* FATAL Failed to write *"'],
#        ['Non-zero return code from HITtoRDO (*); Logfile error in log.HITtoRDO: "StreamRDO FATAL * failed."'],
#        ['Fatal error in athena logfile: "Logfile error in log.AODtoDAOD: "StreamDAOD_EXOT* FATAL * failed.""'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "* FATAL Unable to apply Inner Detector alignments"'],
#        ['Non-zero return code from generate (*); Logfile error in log.generate: "Herwig* FATAL Standard std::exception is caught"'],
#        ['Non-zero return code from RAWtoALL (*); Logfile error in log.RAWtoALL: "*_CT ERROR FILE:LINE (StatusCode *::execute()): code FAILURE: evtStore()->retrieve( alltracks, m_* )"'],
#        ['AODtoDAOD got a SIGKILL signal (exit code *); Logfile error in log.AODtoDAOD: "AODFix_* FATAL Standard std::exception is caught"'],
#        ['Job was gone while performing data transfer'],
#        ['Non-zero return code from EVNTtoHITS (*); Logfile error in log.EVNTtoHITS: "* fault: Event counter: *; Run: unknown; Evt: unknown; Current algorithm: *; Current Function: unknown"'],
#        ['Non-zero return code from EVNTtoHITS (*); Logfile error in log.EVNTtoHITS: "error: can\'t start new thread"'],
#        ['Non-zero return code from EVNTtoHITS (*); Logfile error in log.EVNTtoHITS: "cannot commit - no transaction is active ( CORAL : "*::execute" from "CORAL***" ) (C++ exception of type coral::Exception)"'],
#        ['AODtoDAOD got a SIGKILL signal (exit code *); Logfile error in log.AODtoDAOD: "* ERROR Failure in waiting or sub-process finished abnormally"'],
#        ['Non-zero return code from HITtoRDO (*); Logfile error in log.HITtoRDO: "SysError in <TFile::WriteBuffer>: error writing to file tmp.RDO_* (-*) (No space left on device)"'],
#        ['generate got a SIGKILL signal (exit code *)'],
#        ['Non-zero return code from RAWtoESD (*); Logfile error in log.RAWtoESD: "* fault: Event counter: *; Run: *; Evt: *; Current algorithm: <NONE>; Current Function: unknown"'],
#        ['AODtoDAOD got a SIGHUP signal (exit code *)'],
#        ['Fatal error in athena logfile: "Logfile error in log.*: "StreamRDO FATAL * failed.""'],
#        ['Non-zero return code from RAWtoESD (*); Logfile error in log.RAWtoESD: "Core dump from CoreDumpSvc: Event counter: *; Run: *; Evt: *; Current algorithm: *; Current Function: unknown"'],
#        ['Non-zero return code from * (*); Logfile error in log.*: "*_FullScan_IDTrig ERROR Memory allocation issue caught: std::bad_alloc"'],
#        ['Non-zero return code from * (*); Logfile error in log.*: "StreamHITS FATAL Check number of writes failed. See messages above to identify which continer is not always written"'],
#        ['AODMerge got a SIGKILL signal (exit code *)'],
#        ['Non-zero return code from athena (*); Logfile error in log.athena: "AthAlgSeq FATAL Standard std::exception is caught"'],
#        ['Non-zero return code from * (*); Logfile error in log.*: "* ERROR No valid track link found"'],
#        ['Non-zero return code from HITtoRDO (*); Logfile error in log.HITtoRDO: "PoolSvc FATAL Cannot disconnect Stream: *"'],
#        ['Fatal error in athena logfile: "Logfile error in log.*: "*_eGammaB ERROR std::exception caught: std::exception""'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "ImportError: No module named *"'],
#        ['Non-zero return code from generate (*)'],
#        ['Non-zero return code from ESDtoAOD (*); Logfile error in log.ESDtoAOD: "TypeError: \'NoneType\' object is not callable"'],
#        ['* got a SIGABRT signal (exit code *); Logfile error in log.*: "* ERROR std::bad_alloc"'],
#        ['Non-zero return code from OverlayBS (*); Logfile error in log.OverlayBS: "digitmaker* FATAL Standard std::exception is caught"'],
#        ['Non-zero return code from * (*); Long FATAL message at line * (see jobReport for further details)'],
#        ['Failed in data staging: Failed to prepare destination * Failed to prepare destination: File exists: File requests have failed.: File exists: ******_*TeV******._*.job.log.tgz.*; Failed in data staging: Failed to prepare destination srm:'],
#        ['Non-zero return code from EVNTtoHITS (*); Logfile error in log.EVNTtoHITS: "* fault: Event counter: *; Run: unknown; Evt: unknown; Current algorithm: <NONE>; Current Function: unknown"'],
#        ['LRMS error: (*) Job was cancelled by SLURM'],
#        ['Non-zero return code from * (*); Logfile error in log.*: "ImportError: No module named *"'],
#        ['Non-zero return code from * (*); Logfile error in log.*: "* ERROR Unable to open ROOT file "tmp.RDO._*" with options "READ""'],
#        ['AODtoDAOD got a SIGBUS signal (exit code *); Logfile error in log.AODtoDAOD: "Core dump from CoreDumpSvc: Event counter: *; Run: unknown; Evt: unknown; Current algorithm: AODFix_btagging_*; Current Function: unknown"'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "* FATAL Cannot get Output *"'],
#        ['Non-zero return code from EVNTtoHITS (*); Logfile error in log.EVNTtoHITS: "* ERROR Failure in waiting or sub-process finished abnormally"'],
#        ['Missing AthenaMP outputs file athenaMP-outputs-*-r*t (probably athena crashed)'],
#        ['No events to process: * (skipEvents) >= * (inputEvents of EVNT'],
#        ["Input file argument(s) ['RDO.pool.root'] globbed to NO input files - probably the file(s) are missing"],
#        ['Non-zero return code from HITtoRDO (*); Logfile error in log.HITtoRDO: "* ERROR Failure in waiting or sub-process finished abnormally"'],
#        ['Fatal error in athena logfile: "Logfile error in log.generate: "Core dump from CoreDumpSvc: Event counter: *; Run: unknown; Evt: unknown; Current algorithm: EvgenGenSeq; Current Function: _dl_relocate_object""'],
#        ['Non-zero return code from AODtoDAOD (*); Long FATAL message at line * (see jobReport for further details)'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "StreamDAOD_EXOT* FATAL * failed."'],
#        ['Non-zero return code from EVNTtoHITS (*); Logfile error in log.EVNTtoHITS: "* ERROR Unable to open ROOT file "EVNT.*._*.pool.root.*" with options "READ""'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "KeyError: \'nentries\'"'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "* fault: Event counter: *; Run: *; Evt: *; Current algorithm: <NONE>; Current Function: unknown"'],
#        ['File data*_*TeV.***_m*._lb*._*.* did not pass corruption test'],
#        [': ****'],
#        ['Non-zero return code from * (*); Logfile error in log.*: "* ERROR Failure in waiting or sub-process finished abnormally"'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "SyntaxError: invalid token"'],
#        ['EVNTtoHITS got a SIGKILL signal (exit code *)'],
#        ['LRMS error: (*) Job failed'],
#        ['Non-zero return code from EVNTtoHITS (*); Logfile error in log.EVNTtoHITS: "IOVDbSvc FATAL Conditions database connection COOLOFL_INDET** cannot be opened - STOP"'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "* ERROR Failure in waiting or sub-process finished abnormally"'],
#        ['Missing AthenaMP outputs file **r (probably athena crashed)'],
#        ['No events to process: * (skipEvents) >= * (inputEvents of HITS'],
#        ['Non-zero return code from EVNTtoHITS (*)'],
#        ['Error reading user generated output file list'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "* FATAL makePool failed for *.*"'],
#        ['LRMS error: (*) Job was cancelled'],
#        ['AODtoDAOD got a SIGKILL signal (exit code *)'],
#        ['Fatal error in athena logfile: "Logfile error in log.EVNTtoHITS: "ISF_MC*LLPTrut... ERROR Unable to register truth incident with unknown SimGeoID=*""'],
#        ['Fatal error in athena logfile: "G* exception at line * (see jobReport for further details)"'],
#        ['Non-zero return code from EVNTtoHITS (*); Core dump at line * (see jobReport for further details)'],
#        ['Data type graph error'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "*: \'str\' object has no attribute \'items\'"'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "*: \'module\' object has no attribute \'*\'"'],
#        ['LRMS error: (*) Job timeout'],
#        ['Failed in data staging: Failed to prepare destination * Failed to prepare destination: File exists: File requests have failed.: File exists: *******_mce_*CV*.tx*.log.*.*.log'],
#        ['Non-zero return code from generate (*); Logfile error in log.generate: "Py:Generate ERROR MC*.*.*_ttbar_hdamp*p*_*_ljets_BFiltBBVeto.py contains a * field of more than * characters: please rename."'],
#        ['LRMS error: (-*) Job timeout'],
#        ['Non-zero return code from RAWtoESD (*); Logfile error in log.RAWtoESD: "* ERROR Failure in waiting or sub-process finished abnormally"'],
#        ['Non-zero return code from RAWtoESD (*); Long FATAL message at line * (see jobReport for further details)'],
#        ['Non-zero return code from ESDtoAOD (*); Logfile error in log.ESDtoAOD: "* ERROR Failure in waiting or sub-process finished abnormally"'],
#        ['Missing AthenaMP outputs file **e (probably athena crashed)'],
#        ['Missing AthenaMP outputs file * (probably athena crashed)'],
#        ['Non-zero return code from HepEvnt (*); Logfile error in log.HepEvnt: "StreamAOD FATAL * failed."'],
#        ['Fatal error in athena logfile: "Logfile error in log.RAWtoESD: "ToolSvc.Trk::* ERROR The determinant of the track covariance matrix is negative: -*.*e+*""'],
#        ['Non-zero return code from EVNTtoHITS (*); Logfile error in log.EVNTtoHITS: "IOVDbSvc FATAL Conditions database connection COOLOFL_TRT** cannot be opened - STOP"'],
#        ['EVNTtoHITS got a SIGIOT signal (exit code *); G* exception at line * (see jobReport for further details)'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "IOError: [Errno *] Input*error: \'**.*****.*.*.***_*-slc*-gcc*-opt** (truncated)'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "Unable to identify specific exception"'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "* FATAL Standard std::exception is caught"'],
#        ['Non-zero return code from HITSMerge (*); Logfile error in log.HITSMerge: ""'],
#        ['Non-zero return code from RAWtoESD (*); Logfile error in log.RAWtoESD: ""'],
#        ['File EVNT.*._*.pool.root.* did not pass corruption test'],
#        ['Two identical output *: *'],
#        ['File AOD.*._*.pool.root.* did not pass corruption test'],
#        ['Failed to clean up session dir before downloading inputs'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "*: Smart slimming container BTagging_* does not exist or does not have a smart slimming list"'],
#        ['Non-zero return code from EVNTtoHITS (*); Logfile error in log.EVNTtoHITS: "ValueError: ATLAS-P*-ITK-*-*-* is not the expected type and*the value is not allowed for: *.SimFlags.SimLayout"'],
#        ['LRMS error: (-*) Job missing from SLURM'],
#        ['Failed in data staging: Failed checking source replica * Failed to obtain information about file: Permission denied'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "* fault: Event counter: *; Run: *; Evt: *; Current algorithm: *; Current Function: unknown"'],
#        ['Event count check for EVNT to HITS failed: found * events, expected from * to *; Core dump at line * (see jobReport for further details)'],
#        ['Non-zero return code from EVNTtoHITS (*); Logfile error in log.EVNTtoHITS: "* fault: Event counter: *; Run: *; Evt: *; Current algorithm: ISF_Kernel_FullG*; Current Function: unknown"'],
#        ['Non-zero return code from generate (*); Logfile error in log.generate: "*: \'EvgenConfig\' object has no attribute \'*\'"'],
#        ['Non-zero return code from generate (*); Logfile error in log.generate: "*: include file MC*.*.*_CMSPow_CMSpy_ttbar.py can not be found"'],
#        ['Non-zero return code from EVNTtoHITS (*); Logfile error in log.EVNTtoHITS: "* FATAL makePool failed for *.*"'],
#        ['ESDtoDPD got a SIGKILL signal (exit code *)'],
#        ['Non-zero return code from EVNTtoHITS (*); Logfile error in log.EVNTtoHITS: "* FATAL in *(): standard std::exception is caught"'],
#        ['Non-zero return code from AODtoDAOD (*); Logfile error in log.AODtoDAOD: "PoolSvc FATAL Cannot disconnect Stream: *"'],
#        ['Fatal error in athena logfile: "Long ERROR message at line * (see jobReport for further details)"'],
#        ['Non-zero return code from generate (*); Logfile error in log.generate: "IOError: [Errno *] No such file or directory: \'***_**_events.lhe\'"'],
#        ['Non-zero return code from EVNTtoHITS (*); Logfile error in log.EVNTtoHITS: "StreamHITS FATAL * failed."']],
#       dtype=object)

# %%
stats_1 = output.postprocessing(1)

# %%
stats_1.sort_values(by=['mean_similarity'])
# Out:
#    cluster_name  cluster_size  \
# 0           0.0          1811
# 2           2.0           205
# 10         10.0             2
# 7           7.0            61
# 6           6.0            10
# 4           4.0            36
# 12         12.0           218
# 5           5.0             7
# 19         19.0          1141
# 1           1.0             4
# 13         13.0            38
# 20         20.0            27
# 3           3.0            97
# 16         16.0           602
# 27         27.0           427
# 8           8.0             1
# 14         14.0             2
# 15         15.0             3
# 17         17.0             8
# 18         18.0             8
# 25         25.0            18
# 22         22.0            11
# 23         23.0            14
# 24         24.0            15
# 11         11.0             1
# 26         26.0            30
# 28         28.0            84
# 29         29.0           109
# 21         21.0            10
# 9           9.0             1
#
#                                               pattern  mean_length  \
# 0                      Non-zero return code from  (*)       122.31
# 2           Fatal error in athena logfile: " eo in o"       122.61
# 10  AODtoDAOD got a SIGKILL signal (exit code *); ...       134.50
# 7   Nonet code *); o at line * (see jobReport for ...       104.56
# 6   Failed in data staging: ld en source replica *...       180.40
# 4                 File * did not pass corruption test        58.19
# 12                               LRMS error: (*) Job         28.89
# 5   Failed in data staging: Failed to prepare dest...       198.57
# 19  Input file argument  globbed to NO input files...        99.07
# 1                      Non-zero return code from  (*)        36.75
# 13  Non-zero return code from  (*); Logfile error ...       168.32
# 20             Eto got a SIGKILL signal (exit code *)        44.26
# 3                  AOD got a SIG signal (exit code *)        43.98
# 16  Missing AthenaMP outputs file * (probably athe...        60.31
# 27  No events to process: * (skipEvents) >= * (inp...        62.00
# 8   * got a SIGABRT signal (exit code *); Logfile ...        86.00
# 14                      Job submission to LRMS failed        29.00
# 15  AODtoDAOD got a SIGBUS signal (exit code *); L...       216.00
# 17  Failed to clean up session dir before download...        56.00
# 18  Fatal error in athena logfile: "Long ERROR mes...        97.00
# 25                                             : ****         6.00
# 22  Failed in data staging: Failed checking source...       115.00
# 23                          Two identical output *: *        25.00
# 24  Non-zero return code from generate (*); Logfil...       197.00
# 11        Job was gone while performing data transfer        43.00
# 26  Fatal error in athena logfile: "Logfile error ...       209.00
# 28                              Data type graph error        21.00
# 29      Error reading user generated output file list        45.00
# 21  Event count check for EVNT to HITS failed: fou...       136.00
# 9         generate got a SIGKILL signal (exit code *)        43.00
#
#     mean_similarity  std_length  std_similarity
# 0              0.43       29.71            0.14
# 2              0.53       28.78            0.11
# 10             0.68        6.50            0.00
# 7              0.76        1.25            0.06
# 6              0.77        7.68            0.15
# 4              0.80        5.07            0.04
# 12             0.83        3.64            0.06
# 5              0.84       28.71            0.08
# 19             0.90        0.51            0.00
# 1              0.91        3.34            0.06
# 13             0.93        4.98            0.03
# 20             0.93        0.97            0.03
# 3              0.95        0.14            0.04
# 16             0.97        4.85            0.04
# 27             0.98        0.00            0.00
# 8              1.00        0.00            0.00
# 14             1.00        0.00            0.00
# 15             1.00        0.00            0.00
# 17             1.00        0.00            0.00
# 18             1.00        0.00            0.00
# 25             1.00        0.00            0.00
# 22             1.00        0.00            0.00
# 23             1.00        0.00            0.00
# 24             1.00        0.00            0.00
# 11             1.00        0.00            0.00
# 26             1.00        0.00            0.00
# 28             1.00        0.00            0.00
# 29             1.00        0.00            0.00
# 21             1.00        0.00            0.00
# 9              1.00        0.00            0.00

# %%
output.in_cluster(20,2)
# Out:
# array(['EVNTtoHITS got a SIGKILL signal (exit code 137)',
#        'EVNTtoHITS got a SIGKILL signal (exit code 137)',
#        'EVNTtoHITS got a SIGKILL signal (exit code 137)',
#        'EVNTtoHITS got a SIGKILL signal (exit code 137)',
#        'EVNTtoHITS got a SIGKILL signal (exit code 137)',
#        'ESDtoDPD got a SIGKILL signal (exit code 137)',
#        'ESDtoDPD got a SIGKILL signal (exit code 137)',
#        'ESDtoDPD got a SIGKILL signal (exit code 137)',
#        'ESDtoDPD got a SIGKILL signal (exit code 137)',
#        'EVNTtoHITS got a SIGKILL signal (exit code 137)',
#        'EVNTtoHITS got a SIGKILL signal (exit code 137)',
#        'ESDtoDPD got a SIGKILL signal (exit code 137)',
#        'EVNTtoHITS got a SIGKILL signal (exit code 137)',
#        'ESDtoDPD got a SIGKILL signal (exit code 137)',
#        'ESDtoDPD got a SIGKILL signal (exit code 137)',
#        'EVNTtoHITS got a SIGKILL signal (exit code 137)',
#        'EVNTtoHITS got a SIGKILL signal (exit code 137)',
#        'EVNTtoHITS got a SIGKILL signal (exit code 137)',
#        'EVNTtoHITS got a SIGKILL signal (exit code 137)',
#        'EVNTtoHITS got a SIGKILL signal (exit code 137)',
#        'ESDtoDPD got a SIGKILL signal (exit code 137)',
#        'ESDtoDPD got a SIGKILL signal (exit code 137)',
#        'EVNTtoHITS got a SIGKILL signal (exit code 137)',
#        'EVNTtoHITS got a SIGKILL signal (exit code 137)',
#        'EVNTtoHITS got a SIGKILL signal (exit code 137)',
#        'EVNTtoHITS got a SIGKILL signal (exit code 137)',
#        'ESDtoDPD got a SIGKILL signal (exit code 137)'], dtype=object)

# %%
patterns1 = stats_1.sort_values(by='mean_similarity')[['pattern']].values

# %%
patterns1
# Out:
# array([['Non-zero return code from  (*)'],
#        ['Non-zero return code from  (*); Logfile error in log.: "Eor: * u: *tretoOtion un'],
#        ['Fatal error in athena logfile: "Logfile error in log.: "  e""'],
#        ['AODtoDAOD got a SIGKILL signal (exit code *); Logfile error in log.AODtoDAOD: "* F tnrd oa"'],
#        ['Failed in data staging: ld en source replica * ailed: No such file or directory: aid oat f'],
#        ['Nonet code *); o at line * (see jobReport for further details)'],
#        ['File * did not pass corruption test'],
#        ['Failed in data staging: Failed to prepare destination * Failed to prepare destination: File exists: File requests have failed.: '],
#        ['LRMS error: (*) Job '],
#        ['Input file argument  globbed to NO input files - probably the file(s) are missing'],
#        ['Non-zero return code from  (*)'],
#        ['Eto got a SIGKILL signal (exit code *)'],
#        ['Fatal error in athena logfile: "on at line * (see jobReport for further details)"'],
#        ['Non-zero return code from AtoD (*); Logfile error in log.AtoD: " fu: Event counter: *; Run: *; Evt: *; Current algorithm: ; Current Function: unknown"'],
#        ['AOD got a SIG signal (exit code *)'],
#        ['Missing AthenaMP outputs file * (probably athena crashed)'],
#        ['No events to process: * (skipEvents) >= * (inputEvents of T'],
#        ['Data type graph error'],
#        ['* got a SIGABRT signal (exit code *); Logfile error in log.*: "* ERROR std::bad_alloc"'],
#        ['Job submission to LRMS failed'],
#        ['AODtoDAOD got a SIGBUS signal (exit code *); Logfile error in log.AODtoDAOD: "Core dump from CoreDumpSvc: Event counter: *; Run: unknown; Evt: unknown; Current algorithm: AODFix_btagging_*; Current Function: unknown"'],
#        ['Error reading user generated output file list'],
#        ['Failed to clean up session dir before downloading inputs'],
#        ['Failed in data staging: Failed checking source replica * Failed to obtain information about file: Permission denied'],
#        ['Two identical output *: *'],
#        [': ****'],
#        ['generate got a SIGKILL signal (exit code *)'],
#        ['Fatal error in athena logfile: "Logfile error in log.generate: "Core dump from CoreDumpSvc: Event counter: *; Run: unknown; Evt: unknown; Current algorithm: EvgenGenSeq; Current Function: _dl_relocate_object""'],
#        ['Event count check for EVNT to HITS failed: found * events, expected from * to *; Core dump at line * (see jobReport for further details)'],
#        ['Job was gone while performing data transfer']], dtype=object)

# %%
import difflib

# %%
sorted_df = output.stat_df.sort_values(by=['cluster_size'])[['cluster_size','cluster_name','pattern']]

# %%
sorted_df
# Out:
#      cluster_size cluster_name  \
# 149             1          149
# 138             1          138
# 136             1          136
# 139             1          139
# 140             1          140
# ..            ...          ...
# 29            140           29
# 13            385           13
# 10            549           10
# 20            805           20
# 62           1098           62
#
#                                                pattern
# 149  Non-zero return code from EVNTtoHITS (*); Logf...
# 138  Non-zero return code from * (*); Logfile error...
# 136  Non-zero return code from ESDtoAOD (*); Logfil...
# 139  Non-zero return code from * (*); Logfile error...
# 140  Non-zero return code from * (*); Logfile error...
# ..                                                 ...
# 29            Non-zero return code from EVNTtoHITS (*)
# 13   No events to process: * (skipEvents) >= * (inp...
# 10   Missing AthenaMP outputs file **r (probably at...
# 20   Non-zero return code from AODtoDAOD (*); Logfi...
# 62   Input file argument ${IN_MINBIAS_LOW/L} globbe...
#
# [150 rows x 3 columns]

# %%
def match(df, new_clusters):
    start = df.head(1)['pattern'].values[0]
#     print(start)
    ratio = [difflib.SequenceMatcher(None, start, x).ratio() for x in df['pattern']]
    df['ratio'] = ratio
    filtered = df[df['ratio'] > 0.6]['cluster_name'].values
    new_clusters.append(filtered)
#     print(filtered)
    df.drop(df[df['cluster_name'].isin(filtered)].index, inplace=True)
#     print(df)
    while df.shape[0] > 0:
        match(df, new_clusters)

# %%
new_clusters = []
# start = sorted_df.head(1)['pattern'].values[0]
# print(start)
match(sorted_df, new_clusters)

# %%
new_clusters
# Out:
# [array(['149', '136', '139', '133', '142', '143', '146', '144', '123',
#         '105', '102', '51', '87', '79', '73', '72', '118', '112', '106',
#         '48', '122', '109', '110', '108', '59', '90', '17', '3', '58',
#         '93', '1', '36', '70', '39', '52', '74', '37', '24', '14', '45',
#         '19'], dtype=object),
#  array(['138', '97', '25', '86', '85', '9', '57'], dtype=object),
#  array(['140'], dtype=object),
#  array(['141', '117', '76', '67', '23', '28'], dtype=object),
#  array(['135', '148', '30', '29'], dtype=object),
#  array(['134', '81', '80'], dtype=object),
#  array(['132', '95'], dtype=object),
#  array(['131', '128', '91', '22'], dtype=object),
#  array(['145', '137', '88'], dtype=object),
#  array(['130', '84', '82', '101'], dtype=object),
#  array(['129'], dtype=object),
#  array(['127', '21', '99'], dtype=object),
#  array(['126'], dtype=object),
#  array(['124', '41', '8', '32', '26'], dtype=object),
#  array(['107'], dtype=object),
#  array(['120', '115', '69'], dtype=object),
#  array(['121', '89', '27', '71', '113', '100', '54', '40', '43'],
#        dtype=object),
#  array(['116'], dtype=object),
#  array(['114'], dtype=object),
#  array(['111'], dtype=object),
#  array(['4', '94', '119', '77', '66', '98', '125', '46', '7', '6', '47',
#         '33'], dtype=object),
#  array(['104'], dtype=object),
#  array(['83', '96', '78', '60', '56'], dtype=object),
#  array(['2'], dtype=object),
#  array(['92'], dtype=object),
#  array(['12', '103', '75', '10'], dtype=object),
#  array(['68'], dtype=object),
#  array(['65', '55'], dtype=object),
#  array(['35', '49', '62'], dtype=object),
#  array(['42', '38', '16', '34'], dtype=object),
#  array(['63'], dtype=object),
#  array(['11'], dtype=object),
#  array(['61'], dtype=object),
#  array(['15', '20'], dtype=object),
#  array(['64'], dtype=object),
#  array(['44'], dtype=object),
#  array(['147'], dtype=object),
#  array(['50'], dtype=object),
#  array(['18', '13'], dtype=object),
#  array(['31'], dtype=object),
#  array(['5'], dtype=object),
#  array(['53'], dtype=object),
#  array(['0'], dtype=object)]

# %%
a = []
for i in new_clusters:
    x = cluster.df[cluster.df['cluster'].isin(i)].index
    a.append({'cluster_name':i[-1],'idx':x})
print(a)

for i in a:
    cluster.df.loc[i['idx'], 'cluster_level_2'] = i['cluster_name']
# Out:
# [{'cluster_name': '19', 'idx': Int64Index([   2,    6,    7,    8,    9,   46,   59,   62,   63,   64,
#             ...
#             4861, 4874, 4875, 4897, 4912, 4915, 4937, 4949, 4956, 4967],
#            dtype='int64', length=568)}, {'cluster_name': '57', 'idx': Int64Index([  50,   54,   55,  105,  275,  394,  580,  581,  645,  674,  914,
#              923,  925,  926,  987,  993,  994, 1012, 1022, 1030, 1031, 1032,
#             1037, 1246, 1268, 1343, 1389, 1555, 1843, 1845, 1863, 1944, 1948,
#             1952, 1956, 1957, 1961, 2298, 2372, 2811, 2815, 2825, 2843, 2888,
#             2913, 2915, 2926, 2932, 2933, 3022, 3251, 3524, 3572, 3763, 3772,
#             3850, 3869, 3897, 3902, 3912, 4382, 4490, 4753, 4758, 4845, 4855,
#             4883],
#            dtype='int64')}, {'cluster_name': '140', 'idx': Int64Index([4037], dtype='int64')}, {'cluster_name': '28', 'idx': Int64Index([  90,  128,  260,  280,  290,  306,  408,  409,  410,  419,
#             ...
#             4374, 4390, 4403, 4405, 4406, 4425, 4427, 4458, 4707, 4851],
#            dtype='int64', length=125)}, {'cluster_name': '29', 'idx': Int64Index([ 130,  133,  135,  138,  139,  141,  147,  148,  150,  155,
#             ...
#             4103, 4115, 4124, 4126, 4139, 4187, 4189, 4235, 4276, 4881],
#            dtype='int64', length=144)}, {'cluster_name': '80', 'idx': Int64Index([911, 912, 1851, 1854, 3790, 3793, 3798, 4756], dtype='int64')}, {'cluster_name': '95', 'idx': Int64Index([1312, 1325, 1347, 1354, 1387, 3193, 3303, 3757], dtype='int64')}, {'cluster_name': '22', 'idx': Int64Index([88, 1082, 1109, 1983, 2002, 2006, 2054, 2075, 2963, 3048, 3203,
#             3426, 4011],
#            dtype='int64')}, {'cluster_name': '88', 'idx': Int64Index([1068, 1789, 3801, 4654], dtype='int64')}, {'cluster_name': '101', 'idx': Int64Index([942, 967, 1553, 3425, 3458, 4422, 4798], dtype='int64')}, {'cluster_name': '129', 'idx': Int64Index([3343], dtype='int64')}, {'cluster_name': '99', 'idx': Int64Index([84, 1534, 2089, 2443, 3199, 3999], dtype='int64')}, {'cluster_name': '126', 'idx': Int64Index([3143], dtype='int64')}, {'cluster_name': '26', 'idx': Int64Index([  41,  108,  115,  169,  181,  245,  470,  596,  597, 1056, 1084,
#             1089, 1092, 1115, 1135, 1255, 2020, 2060, 2076, 2524, 2975, 2985,
#             3004, 3024, 3075, 3258, 3477, 3762, 3979, 3983, 4014, 4022, 4091,
#             4327, 4736, 4979],
#            dtype='int64')}, {'cluster_name': '107', 'idx': Int64Index([2009], dtype='int64')}, {'cluster_name': '69', 'idx': Int64Index([609, 2288, 2793], dtype='int64')}, {'cluster_name': '43', 'idx': Int64Index([ 117,  239,  259,  322,  328,  335,  350,  367,  369,  375,
#             ...
#             4444, 4475, 4862, 4911, 4917, 4947, 4953, 4954, 4955, 4958],
#            dtype='int64', length=158)}, {'cluster_name': '116', 'idx': Int64Index([2361], dtype='int64')}, {'cluster_name': '114', 'idx': Int64Index([2234], dtype='int64')}, {'cluster_name': '111', 'idx': Int64Index([2211], dtype='int64')}, {'cluster_name': '33', 'idx': Int64Index([  11,   24,   28,   29,   37,   43,  178,  184,  301,  305,  327,
#              344,  468,  474,  553,  630,  791,  804,  851, 1253, 1276, 1306,
#             1486, 1520, 1643, 1779, 2067, 2085, 2121, 2189, 2201, 2279, 2305,
#             2703, 2867, 3051, 3134, 3138, 3272, 3397, 3482, 3615, 3723, 4161,
#             4175, 4205, 4252, 4253, 4397, 4452, 4519, 4691, 4782, 4803, 4871,
#             4873],
#            dtype='int64')}, {'cluster_name': '104', 'idx': Int64Index([1852], dtype='int64')}, {'cluster_name': '56', 'idx': Int64Index([ 387,  398,  416,  429,  432,  433,  436,  437,  484,  501,
#             ...
#             4899, 4904, 4905, 4906, 4907, 4913, 4942, 4968, 4985, 4986],
#            dtype='int64', length=204)}, {'cluster_name': '2', 'idx': Int64Index([5, 10], dtype='int64')}, {'cluster_name': '92', 'idx': Int64Index([1119, 2965], dtype='int64')}, {'cluster_name': '10', 'idx': Int64Index([  51,   52,   53,   57,  154,  381,  388,  389,  390,  392,
#             ...
#             4849, 4850, 4853, 4854, 4856, 4858, 4859, 4880, 4965, 4969],
#            dtype='int64', length=602)}, {'cluster_name': '68', 'idx': Int64Index([590, 592, 1565, 1566, 1567, 2518, 4434, 4435], dtype='int64')}, {'cluster_name': '55', 'idx': Int64Index([ 384,  385,  386,  530,  535, 1315, 1510, 1512, 2452, 3239, 3240,
#             3241, 3277, 3412, 3413, 3414, 4239, 4240, 4241, 4386],
#            dtype='int64')}, {'cluster_name': '62', 'idx': Int64Index([ 192,  311,  337,  430,  476,  482,  483,  486,  490,  491,
#             ...
#             4991, 4992, 4993, 4994, 4995, 4996, 4997, 4998, 4999, 5000],
#            dtype='int64', length=1141)}, {'cluster_name': '34', 'idx': Int64Index([  68,  182,  194,  201,  234,  235,  253,  297,  298,  314,  316,
#              320,  345,  373,  397,  457, 1053, 1054, 1055, 1139, 1189, 1190,
#             1240, 1242, 1288, 1289, 1291, 1299, 1300, 1301, 1304, 1333, 1352,
#             1404, 1405, 1406, 1407, 1975, 1976, 1977, 2073, 2080, 2123, 2124,
#             2125, 2126, 2145, 2195, 2196, 2200, 2217, 2244, 2254, 2256, 2270,
#             2355, 2356, 2357, 3057, 3078, 3263, 3934, 3949, 3950, 4034, 4047,
#             4048, 4082, 4156, 4157, 4162, 4215, 4222, 4223, 4224, 4230, 4243,
#             4316, 4317],
#            dtype='int64')}, {'cluster_name': '63', 'idx': Int64Index([519, 811, 1379, 1528, 2307, 2574, 3161, 3364, 4194, 4254], dtype='int64')}, {'cluster_name': '11', 'idx': Int64Index([56, 356, 414, 1338, 1341, 1394, 2304, 2516, 3269, 3281, 4200, 4266,
#             4309],
#            dtype='int64')}, {'cluster_name': '61', 'idx': Int64Index([439, 442, 443, 1391, 1392, 2339, 2929, 2930, 2931, 3748, 3919,
#             4306, 4308, 4857],
#            dtype='int64')}, {'cluster_name': '20', 'idx': Int64Index([  61,   78,   82,   83,   85,   86,   87,   89,   91,   92,
#             ...
#             4878, 4889, 4893, 4900, 4916, 4948, 4957, 4960, 4964, 4976],
#            dtype='int64', length=819)}, {'cluster_name': '64', 'idx': Int64Index([ 529,  531, 1511, 1513, 2451, 2453, 3408, 3409, 3410, 3411, 3415,
#             3416, 3417, 4387],
#            dtype='int64')}, {'cluster_name': '44', 'idx': Int64Index([ 263,  264,  277, 1215, 2142, 2143, 2144, 2162, 2169, 3101, 3129,
#             4096, 4112, 4127, 4128],
#            dtype='int64')}, {'cluster_name': '147', 'idx': Int64Index([4879, 4908, 4909, 4910, 4914, 4921, 4925, 4926, 4927, 4929, 4930,
#             4933, 4950, 4951, 4952, 4972, 4974, 4975],
#            dtype='int64')}, {'cluster_name': '50', 'idx': Int64Index([ 313,  317,  379,  411,  418,  475,  479, 1271, 1357, 1358, 1360,
#             1430, 2224, 2281, 2384, 2386, 2387, 2388, 3158, 3164, 3172, 3284,
#             3285, 3291, 3292, 3340, 3342, 4170, 4231, 4264],
#            dtype='int64')}, {'cluster_name': '13', 'idx': Int64Index([  58,   60,   70,   71,   73,   75,   76,   77,   79,   80,
#             ...
#             4797, 4802, 4804, 4806, 4807, 4808, 4809, 4810, 4811, 4813],
#            dtype='int64', length=427)}, {'cluster_name': '31', 'idx': Int64Index([ 142,  143,  144,  145,  146,  161,  162,  163,  164,  165,  166,
#              167,  170,  174,  175,  218,  219,  220,  225,  226,  227,  230,
#              265,  266, 1100, 1101, 1102, 1117, 1118, 1123, 1124, 1127, 1128,
#             1174, 1181, 1182, 1186, 1216, 2039, 2040, 2055, 2057, 2058, 2059,
#             2061, 2065, 2066, 2108, 2115, 2116, 2117, 2118, 2119, 2163, 3012,
#             3013, 3014, 3015, 3018, 3019, 3025, 3026, 3067, 3072, 3073, 3116,
#             3117, 3118, 4018, 4023, 4024, 4025, 4026, 4027, 4028, 4069, 4070,
#             4071, 4072, 4074, 4079, 4080, 4081, 4113],
#            dtype='int64')}, {'cluster_name': '5', 'idx': Int64Index([  16,   93,  100,  172,  210,  216,  243,  271,  299,  326,  334,
#              341,  370,  473,  835,  878, 1073, 1122, 1142, 1166, 1184, 1191,
#             1257, 1285, 1294, 1311, 1359, 1363, 1378, 1380, 1412, 1429, 1472,
#             1480, 1803, 1828, 1930, 1963, 2000, 2015, 2070, 2081, 2186, 2237,
#             2250, 2295, 2364, 2511, 2532, 2537, 2629, 2766, 2984, 3077, 3127,
#             3168, 3179, 3186, 3198, 3224, 3261, 3264, 3293, 3300, 3505, 3512,
#             3714, 3747, 3786, 3825, 3952, 4015, 4061, 4077, 4114, 4118, 4119,
#             4147, 4180, 4197, 4250, 4273, 4278, 4325, 4401, 4402, 4679, 4865,
#             4884],
#            dtype='int64')}, {'cluster_name': '53', 'idx': Int64Index([ 368,  380,  417,  444,  446,  448,  450,  452,  453,  454,  462,
#              464,  466,  469,  503,  537,  601, 1149, 1219, 1283, 1313, 1345,
#             1349, 1369, 1390, 1403, 1411, 1424, 1425, 1481, 1525, 1527, 1570,
#             2181, 2268, 2272, 2289, 2302, 2328, 2340, 2344, 2347, 2349, 2368,
#             2379, 2383, 2423, 2442, 2449, 2480, 2561, 3040, 3089, 3141, 3148,
#             3236, 3238, 3262, 3309, 3311, 3313, 3325, 3326, 3337, 3338, 3357,
#             3391, 3423, 4106, 4153, 4198, 4204, 4208, 4236, 4294, 4297, 4307,
#             4310, 4311, 4312, 4313, 4315, 4318, 4319, 4321, 4385, 4391, 4395,
#             4430, 4459],
#            dtype='int64')}, {'cluster_name': '0', 'idx': Int64Index([   0,    1,    3,    4,   12,   13,   14,   15,   17,   18,
#             ...
#             4389, 4411, 4413, 4415, 4416, 4419, 4420, 4421, 4895, 4943],
#            dtype='int64', length=109)}]

# %%
cluster.df['cluster_level_2'].describe()
# Out:
# count     5001
# unique      43
# top         62
# freq      1141
# Name: cluster_level_2, dtype: object

# %%
sorted_list = sorted_df['pattern'].tolist()

# %%
start = sorted_list[0]
print(start)
ratio = []
for x in sorted_list:
    ratio.append(difflib.SequenceMatcher(None, start, x).ratio())
print(ratio)
ids = [i for i,x in enumerate(ratio) if x > 0.6]
print(ids)
# Out:
# Non-zero return code from EVNTtoHITS (*); Logfile error in log.EVNTtoHITS: "StreamHITS FATAL * failed."
# [1.0, 0.5638766519823789, 0.6181818181818182, 0.6272727272727273, 0.592057761732852, 0.1917808219178082, 0.44776119402985076, 0.4740740740740741, 0.6698113207547169, 0.6334841628959276, 0.32727272727272727, 0.4397163120567376, 0.6564102564102564, 0.3488372093023256, 0.39069767441860465, 0.2302158273381295, 0.5757575757575758, 0.3333333333333333, 0.5957446808510638, 0.6538461538461539, 0.17582417582417584, 0.15942028985507245, 0.663594470046083, 0.611353711790393, 0.5144927536231884, 0.5989304812834224, 0.455026455026455, 0.48, 0.2054794520547945, 0.5220588235294118, 0.39344262295081966, 0.5194805194805194, 0.273972602739726, 0.5886524822695035, 0.6255506607929515, 0.5841584158415841, 0.8682926829268293, 0.5517241379310345, 0.578397212543554, 0.5092250922509225, 0.784688995215311, 0.7159090909090909, 0.03289473684210526, 0.1793103448275862, 0.6666666666666666, 0.49122807017543857, 0.1643835616438356, 0.845771144278607, 0.6188340807174888, 0.47342995169082125, 0.4329004329004329, 0.7980295566502463, 0.625, 0.5517241379310345, 0.490272373540856, 0.6390041493775933, 0.4507042253521127, 0.5907172995780591, 0.5092250922509225, 0.7465437788018433, 0.861878453038674, 0.18181818181818182, 0.5801526717557252, 0.28431372549019607, 0.36619718309859156, 0.21262458471760798, 0.5779816513761468, 0.4962962962962963, 0.20689655172413793, 0.6731707317073171, 0.37037037037037035, 0.032679738562091505, 0.5637583892617449, 0.13664596273291926, 0.5953488372093023, 0.5035971223021583, 0.639269406392694, 0.4808362369337979, 0.6046511627906976, 0.2898550724637681, 0.7303370786516854, 0.1625, 0.8341708542713567, 0.639269406392694, 0.22784810126582278, 0.6741573033707865, 0.5907172995780591, 0.1728395061728395, 0.4927536231884058, 0.35797665369649806, 0.5874125874125874, 0.14012738853503184, 0.5907172995780591, 0.07547169811320754, 0.36213991769547327, 0.28, 0.26459143968871596, 0.639269406392694, 0.1945945945945946, 0.7685589519650655, 0.8720379146919431, 0.5363984674329502, 0.1643835616438356, 0.6, 0.5818181818181818, 0.22594142259414227, 0.5, 0.18309859154929578, 0.05504587155963303, 0.5802047781569966, 0.16793893129770993, 0.5185185185185185, 0.171875, 0.508833922261484, 0.1891891891891892, 0.5739910313901345, 0.05504587155963303, 0.14634146341463414, 0.4908424908424908, 0.6464646464646465, 0.65625, 0.6372549019607843, 0.8058252427184466, 0.8, 0.07692307692307693, 0.5907172995780591, 0.18627450980392157, 0.21818181818181817, 0.16574585635359115, 0.6970954356846473, 0.4807692307692308, 0.26356589147286824, 0.5596707818930041, 0.19117647058823528, 0.6691449814126395, 0.6082949308755761, 0.6055045871559633, 0.1774193548387097, 0.55, 0.28865979381443296, 0.40476190476190477, 0.16923076923076924, 0.16326530612244897, 0.7272727272727273, 0.20270270270270271, 0.5594405594405595, 0.20606060606060606, 0.1728395061728395, 0.5690376569037657, 0.17733990147783252]
# [0, 2, 3, 8, 9, 12, 19, 22, 23, 34, 36, 40, 41, 44, 47, 48, 51, 52, 55, 59, 60, 69, 76, 78, 80, 82, 83, 85, 97, 99, 100, 119, 120, 121, 122, 123, 129, 134, 135, 136, 143]

# %%
result = output.postprocessing()

# %%
result
# Out:
# matrix([[1.        , 0.18644068, 0.31446541, ..., 0.20979021, 0.19402985,
#          0.1773399 ],
#         [0.18644068, 1.        , 0.22564103, ..., 0.1452514 , 0.51973684,
#          0.56903766],
#         [0.33962264, 0.21538462, 1.        , ..., 0.23529412, 0.14977974,
#          0.17283951],
#         ...,
#         [0.11188811, 0.16759777, 0.21568627, ..., 1.        , 0.14218009,
#          0.20547945],
#         [0.21641791, 0.53947368, 0.15859031, ..., 0.12322275, 1.        ,
#          0.50922509],
#         [0.1773399 , 0.56903766, 0.17283951, ..., 0.17808219, 0.50922509,
#          1.        ]])

# %%
import numpy as np

# %%
threshold = 0.6
rows = np.where(result > threshold)

# %%
rows
# Out:
# (array([  0,   0,   0, ..., 149, 149, 149]),
#  array([  0,  23,  51, ..., 139, 141, 149]))

# %%
similar
# Out:
# matrix([[1.        , 0.8159204 , 0.89010989, ..., 0.86829268, 0.62555066,
#          1.        ]])

# %% [markdown]
# ### Timings for all stages of clusterization pipeline

# %% [markdown]
# process - timing of all process

# %%
cluster.timings

# %% [markdown]
# ### Get all error messages in single cluster

# %%
output.in_cluster(10)

# %%
output.in_cluster(34)

# %% [markdown]
# ### Output clusters - mode == 'ALL'  (for cluster '2')

# %%
output.clustered_output(mode='ALL')['1']

# %% [markdown]
# ### Output clusters - mode == 'INDEX' (for cluster '2')

# %%
output.clustered_output(mode='INDEX')['1']

# %% [markdown]
# ### Output clusters - mode == 'TARGET' (for cluster '2')

# %%
output.clustered_output(mode='TARGET')['1']

# %% [markdown]
# ### Output clusters - cluster labels

# %%
cluster.cluster_labels

# %% [markdown]
# ### Get epsilon value (which was used in DBSCAN algorithm)

# %%
cluster.epsilon
