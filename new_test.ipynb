# %%
from clusterlogs import pipeline

# %%
df.head(100000).to_csv('samples/all_logs_100K.csv')

# %%
df.head()['message'].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9a7765aec7b8> in <module>
# ----> 1 df.head()['message'].values
#
# NameError: name 'df' is not defined

# %%
df[10000:11000]['0'].values
# Out:
# array(['RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM18VH_3J20 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_BPH-2M8-2MU4_BPH-0DR15-2MU4 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_BPH-7M15-2MU4_BPH-0DR24-2MU4 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_BPH-2M8-MU6MU4_BPH-0DR15-MU6MU4 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_BPH-8M15-MU6MU4_BPH-0DR22-MU6MU4 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MU6MU4-BO is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_2MU4-B is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_2MU6-B is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_J15.0ETA25_2J15.31ETA49 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_BPH-2M8-2MU4-B_BPH-0DR15-2MU4 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_BPH-7M15-2MU4_BPH-0DR24-2MU4-B is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM12_W-MT35_XS50 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM15_W-MT35_XS60 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_BPH-7M15-2MU4_BPH-0DR24-2MU4-BO is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_BPH-2M8-MU6MU4-B_BPH-0DR15-MU6MU4 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_2MU4-BO is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_2MU6-BO is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MU6_2MU4-B is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_DY-DR-2MU4 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM15VH_2EM8VH_MU6 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM10VH_W-MT35_XS50 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_DY-BOX-2MU6 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_LFV-MU is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_LFV-EM8I is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_LFV-EM15I is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM7_MU15 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_DPHI-J20s2XE50 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_DPHI-J20XE50 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_DPHI-CJ20XE50 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MJJ-900 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MJJ-800 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MJJ-700 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MJJ-400 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MU4_J50_XE40 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_2MU4_J40_XE20 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_LFV-MU6 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MJJ-100 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_HT150-JJ15.ETA49 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM15VH_W-MT35_XS60 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_J4-MATCH is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_DR25-TAU20ITAU12I is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_DR-MU10TAU12I is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_TAU30_EMPTY is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM20VH_W-MT35_XS60 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_TAU30_UNPAIRED_ISO is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM22VHI_W-MT35_XS40 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM15TAU12I-J25 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_TAU20ITAU12I-J25 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_DR-TAU20ITAU12I is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_BOX-TAU20ITAU12I is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_LAR-EM is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_LAR-J is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_DR-EM15TAU12I is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_LATE-MU10_XE50 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_LATE-MU10_J50 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_SC111 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_SC85 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MU6_MJJ-200 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MU6_MJJ-300 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MU6_MJJ-400 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MU6_MJJ-500 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_J30_2J20_4J20.0ETA49_MJJ-400 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_J30_2J20_4J20.0ETA49_MJJ-700 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_J30_2J20_4J20.0ETA49_MJJ-800 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_J30_2J20_4J20.0ETA49_MJJ-900 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_3J20_4J20.0ETA49_MJJ-400 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_3J20_4J20.0ETA49_MJJ-700 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_3J20_4J20.0ETA49_MJJ-800 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_3J20_4J20.0ETA49_MJJ-900 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_XE35_MJJ-200 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM7_FIRSTEMPTY is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_RD0_ABORTGAPNOTCALIB is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_3J25.0ETA23 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_TE20 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_TE10.0ETA24 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_TE20.0ETA24 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM15HI_TAU20IM_2TAU15_J25_2J20_3J15 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_AFP_C_MU4 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_J12_BGRP12 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_J30.31ETA49_BGRP12 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MU6_J30.0ETA49_2J20.0ETA49 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_4J20.0ETA49 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM12_W-MT25_W-15DPHI-JXE-0_W-15DPHI-EMXE_W-90RO2-XEHT-0 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM18VH_MJJ-300 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_DR25-TAU20ITAU12I-J25 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_30M-EM20ITAU12 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_TAU8_UNPAIRED_ISO is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM7_UNPAIRED_ISO is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_RD2_BGRP12 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_TAU8_FIRSTEMPTY is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_LHCF_UNPAIRED_ISO is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_LHCF_EMPTY is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM15VH_2EM10VH_3EM7 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM15VH_3EM8VH is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MJJ-400-CF is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_2EM18VH is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM8I_MU10 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM15VH_3EM10VH is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_2MU6_3MU4 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_BGRP9 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM18VH_3EM8VH is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_TE5 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM18VH_2EM10VH_3EM7 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_TE25.0ETA24 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_TE5.0ETA24 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM20VH_FIRSTEMPTY is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM22VHI_FIRSTEMPTY is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MU20_FIRSTEMPTY is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_J100_FIRSTEMPTY is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_J100.31ETA49_FIRSTEMPTY is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM12_W-MT25_W-15DPHI-JXE-0_W-15DPHI-EMXE_XS20 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_TE70.0ETA24 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_TE40.0ETA24 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_ZDC_A is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_ZDC_C is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_ZDC_AND is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_ZDC_A_C is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM15HI is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM15I is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_BPH-2M9-2MU4_BPH-0DR15-2MU4 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_BPH-2M9-MU6MU4_BPH-0DR15-MU6MU4 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MU20_J40 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM20VH_2EM10VH_3EM8VH is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MU20_XE30 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MU4_2EM3_J20_XE30_DPHI-J20s2XE30 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_3EM3_J40_XE50_DPHI-J20s2XE50 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM12_W-MT25_W-15DPHI-JXE-0_W-15DPHI-EMXE is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM15_W-MT35_W-05DPHI-JXE-0_W-05DPHI-EM15XE_XS30 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM15_W-MT35_W-05DPHI-JXE-0_W-05DPHI-EM15XE is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_HT150-JJ15.ETA49_MJJ-400 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_RD2_BGRP14 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_RD3_BGRP15 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_TAU8_UNPAIRED_NONISO is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_EM7_UNPAIRED_NONISO is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MU4_UNPAIRED_NONISO is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_J85_3J30 is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_4J20_FTK is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_ALFA_B7L1U is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_ALFA_B7L1L is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_ALFA_A7L1U is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_ALFA_A7L1L is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_ALFA_A7R1U is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_ALFA_A7R1L is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_ALFA_B7R1U is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_ALFA_B7R1L is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MU15_FTK is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MU20_TAU12IM_FTK is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MU6_FTK is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_MU20_FTK is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_TAU12IM_FTK is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_TAU20IM_2TAU12IM_J25_2J20_3J12_FTK is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_DR-TAU20ITAU12I-J25_FTK is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_4J15_FTK is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_4J15.0ETA25_FTK is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_J15_FTK is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_J40_FTK is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_J100_FTK is not used by any HLT chain\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO L1 item L1_CALREQ2 is not used by any HLT chain\n',
#        "RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.menu.GenerateMenu    INFO Processing chain : ['e5_lhtight_idperf', 'L1_EM3', [], ['Main'], ['RATE:IDMonitoring', 'BW:Egamma', 'BW:ID'], -1]\n",
#        'RDOtoRDOTrigger 17:22:48 Py:Athena            INFO Importing TriggerMenu.menu.SignatureDicts\n',
#        'RDOtoRDOTrigger 17:22:48 Py:TriggerMenu.muon.generateMuonChainDefs.py    INFO Importing TriggerMenu.muon.generateMuonChainDefs\n',
#        'RDOtoRDOTrigger 17:22:48 Py:Athena            INFO Importing TriggerMenu.muon.MuonDef\n',
#        'RDOtoRDOTrigger 17:22:48 Py:Athena            INFO including file "InDetTrigRecExample/InDetTrigRec_jobOptions.py"\n',
#        'RDOtoRDOTrigger 17:22:48 Py:InDetTrigRec_jobOptions.py    INFO InDetTrigRec_jobOptions: InDetTrigFlags not set - setting to defaults\n',
#        'RDOtoRDOTrigger 17:22:48 InDetJobProperties::setupDefaults():  jobproperties.Beam.beamType() is collisions bunch spacing is 25\n',
#        'RDOtoRDOTrigger 17:22:48 Initializing InDetJobProperties with DetFlags, GlobalFlags and other high level flags.\n',
#        'RDOtoRDOTrigger 17:22:48 InDetJobProperties::setupDefaults():  jobproperties.Beam.beamType() is collisions bunch spacing is 25\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO The JobProperty doNewTracking is blocked\n',
#        'RDOtoRDOTrigger 17:22:48 Initialization of InDetFlags finished - locking container!\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobPropertyContainer::    INFO The JobProperty Container InDetTrigJobProperties is locked\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.AODall = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.Enabled = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.ForceCoolVectorPayload = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.ForceCoraCool = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.InDet25nsec = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.KeepFirstParameters = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.KeepParameters = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.TRTOff = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.checkDeadElementsOnTrack = True\n',
#        "RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.conversionVertexCutSetup = 'ConversionPileUp'\n",
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.cutLevel = 14\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.cutSCTOccupancy = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.disableInDetReco = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.disableTracking = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doBackTracking = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doBeamGas = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doBeamHalo = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doBremRecovery = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doCaloSeededAmbi = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doCaloSeededBrem = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doCaloSeededRefit = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doCaloSeededTRTSegments = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doCommissioning = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doConvVtxD3PD = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doConvVtxNtuple = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doConversions = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doCosmics = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doDBM = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doDBMstandalone = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doDCSAccess = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doDVRetracking = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doDigitalROTCreation = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doFatras = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doForwardTracks = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doHIP300 = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doHadCaloSeededSSS = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doHeavyIon = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doHighPileup = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doHolesOnTrack = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doIBL = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doIdealPseudoTracking = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doInnerDetectorCommissioning = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doLargeD0 = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doLowBetaFinder = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doLowMuRunSetup = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doLowPt = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doLowPtLargeD0 = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doMCBytestream = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doMinBias = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doMinimalReco = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doMonitoringAlignment = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doMonitoringGlobal = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doMonitoringPixel = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doMonitoringPrimaryVertexingEnhanced = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doMonitoringSCT = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doMonitoringTRT = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doNNToTCalibration = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doNewTracking = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doOverlapSP = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doPRDFormation = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doParticleConversion = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doParticleCreation = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doPerfMon = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doPhysValMon = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doPixelClusterSplitting = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doPixelPRDFormation = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doPixelTrkD3PD = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doPixelTrkNtuple = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doPrimaryVertex3DFinding = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doPrintConfigurables = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doPseudoTracking = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doRefit = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doRefitInvalidCov = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doRejectInvalidCov = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doResolveBackTracks = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doRobustReco = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSCTIntimeHits = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSCTModuleVeto = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSCT_PRDFormation = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSGDeletion = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSLHC = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSLHCConversionFinding = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSLHCVeryForward = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSSSfilter = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSctClusterNtuple = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSctTrkD3PD = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSctTrkNtuple = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSecVertexFinder = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSharedHits = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSiSPSeededTrackFinder = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSimpleV0Finder = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSingleCollisionVertexReco = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSlimPoolTrack = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSlimming = None\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSpacePointFormation = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSplitReco = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doSplitVertexFindingForMonitoring = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doStandardPlots = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doStatistics = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doStoreTrackSeeds = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doTIDE_Ambi = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doTIDE_RescalePixelCovariances = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doTRTExtensionNew = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doTRTGlobalOccupancy = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doTRTPhaseCalculation = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doTRTSeededTrackFinder = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doTRTStandalone = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doTRT_PRDFormation = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doTrackSegmentsDisappearing = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doTrackSegmentsPixel = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doTrackSegmentsSCT = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doTrackSegmentsTRT = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doTriggerD3PD = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doTrkD3PD = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doTrkNtuple = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doTrtSegments = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doTrtTrkD3PD = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doTrtTrkNtuple = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doTruth = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doV0Finder = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doV0VtxD3PD = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doV0VtxNtuple = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doVertexFinding = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doVertexFindingForMonitoring = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doVeryLowPt = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doVtxBeamSpot = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doVtxD3PD = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doVtxLumi = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doVtxMonitoringD3PD = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doVtxNtuple = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doWriteTracksToESD = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doiPatRec = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doxAOD = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.doxKalman = None\n',
#        "RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.kalmanUpdator = 'smatrix'\n",
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.keepAdditionalHitsOnTrackParticle = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.loadSimpleTRTSeededSPFinder = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.loadTRTSeededSPFinder = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.loadTools = True\n',
#        "RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.magField = 'None'\n",
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.materialInteractions = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.materialInteractionsType = 3\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.noTRTTiming = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.pT_SSScut = -1\n',
#        "RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.perigeeExpression = 'BeamLine'\n",
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.pixelClusterBadClusterID = 3\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.pixelClusterSplitMinPt = 1000\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.pixelClusterSplitProb1 = 0.6\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.pixelClusterSplitProb1_run1 = 0.5\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.pixelClusterSplitProb2 = 0.2\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.pixelClusterSplitProb2_run1 = 0.5\n',
#        "RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.pixelClusterSplittingType = 'NeuralNet'\n",
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.postProcessing = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.preProcessing = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.priVtxCutLevel = 3\n',
#        "RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.primaryVertexCutSetup = 'Offline'\n",
#        "RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.primaryVertexSetup = 'IterativeFinding'\n",
#        "RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.primaryVertexSortingSetup = 'SumPt2Sorting'\n",
#        "RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.propagatorType = 'RungeKutta'\n",
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.redoTRT_LR = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.refitROT = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.removeTRTNoise = False\n',
#        "RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.secondaryVertexCutSetup = 'PileUp'\n",
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.selectSCTIntimeHits = True\n',
#        "RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.trackFitterType = 'GlobalChi2Fitter'\n",
#        "RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.trtExtensionType = 'xk'\n",
#        "RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.truthMatchStrategy = 'TruthMatchRatio'\n",
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.useBeamConstraint = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.useBroadClusterErrors = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.useBroadPixClusterErrors = None\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.useBroadSCTClusterErrors = None\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.useConditionsClasses = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.useDCS = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.useDynamicAlignFolders = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.useExistingTracksAsInput = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.useHVForSctDCS = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.useMBTSTimeDiff = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.useNewSiSPSeededTF = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.useV0Fitter = False\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.useZvertexTool = False\n',
#        "RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.vertexSeedFinder = 'SlidingWindowMultiSeedFinder'\n",
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.writePRDs = True\n',
#        'RDOtoRDOTrigger 17:22:48 Py:JobProperty ::    INFO  x-> JobProperties.InDetTrigJobProperties.writeRDOs = False\n',
#        'RDOtoRDOTrigger 17:22:48 ****** Inner Detector Flags ********************************************************\n',
#        'RDOtoRDOTrigger 17:22:48 *\n',
#        'RDOtoRDOTrigger 17:22:48 * PreProcessing:\n',
#        'RDOtoRDOTrigger 17:22:48 * ==============\n',
#        'RDOtoRDOTrigger 17:22:48 *\n',
#        'RDOtoRDOTrigger 17:22:48 * -----> 25 nsec setup for SCT/TRT\n',
#        'RDOtoRDOTrigger 17:22:48 *\n',
#        'RDOtoRDOTrigger 17:22:48 * run PrepRawDataFormation\n',
#        'RDOtoRDOTrigger 17:22:48 * - use 01X masking for SCT readout in reconstruction\n',
#        'RDOtoRDOTrigger 17:22:48 * - cut on SCT occupancy for masking noisy modules\n',
#        'RDOtoRDOTrigger 17:22:48 * run SpacePointFormation\n',
#        'RDOtoRDOTrigger 17:22:48 *\n',
#        'RDOtoRDOTrigger 17:22:48 * TrackFinding:\n',
#        'RDOtoRDOTrigger 17:22:48 * =============\n',
#        'RDOtoRDOTrigger 17:22:48 *\n',
#        'RDOtoRDOTrigger 17:22:48 * NewTracking is ON:\n',
#        'RDOtoRDOTrigger 17:22:48 * - run SiSPSeededTrackFinder\n',
#        'RDOtoRDOTrigger 17:22:48 * - run AmbiguitySolver\n',
#        'RDOtoRDOTrigger 17:22:48 * - run TRT_TrackExtension\n',
#        'RDOtoRDOTrigger 17:22:48 * - run TrackExtensionProcessor\n',
#        'RDOtoRDOTrigger 17:22:48 *   and redo LR and tube hits in fit for TRT !!!\n',
#        'RDOtoRDOTrigger 17:22:48 *\n',
#        'RDOtoRDOTrigger 17:22:48 * BackTracking is ON:\n',
# ...
#        "RDOtoRDOTrigger 17:22:53 Py:JetRec_jobOptions    INFO <class 'JetMomentTools.JetMomentToolsConf.JetVertexTaggerTool'>\n",
#        "RDOtoRDOTrigger 17:22:53 Py:JetRec_jobOptions    INFO <class 'JetMomentTools.JetMomentToolsConf.JetTrackMomentsTool'>\n",
#        "RDOtoRDOTrigger 17:22:53 Py:JetRec_jobOptions    INFO <class 'JetMomentTools.JetMomentToolsConf.JetTrackSumMomentsTool'>\n",
#        "RDOtoRDOTrigger 17:22:53 Py:JetRec_jobOptions    INFO <class 'JetMomentTools.JetMomentToolsConf.JetClusterMomentsTool'>\n",
#        "RDOtoRDOTrigger 17:22:53 Py:JetRec_jobOptions    INFO <class 'JetMomentTools.JetMomentToolsConf.JetVoronoiMomentsTool'>\n",
#        "RDOtoRDOTrigger 17:22:53 Py:JetRec_jobOptions    INFO <class 'JetMomentTools.JetMomentToolsConf.JetIsolationTool'>\n",
#        "RDOtoRDOTrigger 17:22:53 Py:JetRec_jobOptions    INFO <class 'JetMomentTools.JetMomentToolsConf.JetIsolationTool'>\n",
#        "RDOtoRDOTrigger 17:22:53 Py:JetRec_jobOptions    INFO <class 'JetMomentTools.JetMomentToolsConf.JetLArHVTool'>\n",
#        "RDOtoRDOTrigger 17:22:53 Py:JetRec_jobOptions    INFO <class 'JetMomentTools.JetMomentToolsConf.JetECPSFractionTool'>\n",
#        "RDOtoRDOTrigger 17:22:53 Py:JetRec_jobOptions    INFO <class 'JetMomentTools.JetMomentToolsConf.JetOriginCorrectionTool'>\n",
#        "RDOtoRDOTrigger 17:22:53 Py:JetRec_jobOptions    INFO <class 'JetMomentTools.JetMomentToolsConf.JetOriginCorrectionTool'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetMomentTools.JetMomentToolsConf.JetConstitFourMomTool'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetMomentTools.JetMomentToolsConf.JetConstitFourMomTool'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetMomentTools.JetMomentToolsConf.JetConstitFourMomTool'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetSubStructureMomentTools.JetSubStructureMomentToolsConf.NSubjettinessTool'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetSubStructureMomentTools.JetSubStructureMomentToolsConf.KtDeltaRTool'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetSubStructureMomentTools.JetSubStructureMomentToolsConf.KTSplittingScaleTool'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetSubStructureMomentTools.JetSubStructureMomentToolsConf.AngularityTool'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetSubStructureMomentTools.JetSubStructureMomentToolsConf.DipolarityTool'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetSubStructureMomentTools.JetSubStructureMomentToolsConf.PlanarFlowTool'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetSubStructureMomentTools.JetSubStructureMomentToolsConf.KtMassDropTool'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetSubStructureMomentTools.JetSubStructureMomentToolsConf.EnergyCorrelatorTool'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetSubStructureMomentTools.JetSubStructureMomentToolsConf.EnergyCorrelatorGeneralizedTool'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetSubStructureMomentTools.JetSubStructureMomentToolsConf.EnergyCorrelatorGeneralizedRatiosTool'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetSubStructureMomentTools.JetSubStructureMomentToolsConf.CenterOfMassShapesTool'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetSubStructureMomentTools.JetSubStructureMomentToolsConf.JetPullTool'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetSubStructureMomentTools.JetSubStructureMomentToolsConf.JetChargeTool'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetSubStructureMomentTools.JetSubStructureMomentToolsConf.ShowerDeconstructionTool'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetSubStructureMomentTools.JetSubStructureMomentToolsConf.QwTool'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetRec.JetRecConf.JetConstitRemover'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO <class 'JetRec.JetRecConf.JetSorter'>\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO JetRecStandardToolManager.py: Removed tools: ['gakt2trackget', 'gakt4trackget']\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO JetRecStandardToolManager.py: Removed tools: ['gakt2trackget', 'gakt4trackget']\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO JetRecStandardToolManager.py: Removed tools: ['gakt2trackget', 'gakt4trackget']\n",
#        "RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO JetRecStandardToolManager.py: Removed tools: ['ecpsfrac']\n",
#        'RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO JetRecStandardToolManager.py: End.\n',
#        'RDOtoRDOTrigger 17:22:56 Py:JetRec_jobOptions    INFO JetRecStandard: End.\n',
#        'RDOtoRDOTrigger 17:22:56 \n',
#        'RDOtoRDOTrigger 17:22:56 ===============================================================================\n',
#        'RDOtoRDOTrigger 17:22:56 ====                       TrigEgamma isEM bit masks                      =====\n',
#        'RDOtoRDOTrigger 17:22:56 ====  ElectronLoose1:                              0x0016885d              =====\n',
#        'RDOtoRDOTrigger 17:22:56 ====  ElectronMedium1:                             0x029fbfdd              =====\n',
#        'RDOtoRDOTrigger 17:22:56 ====  ElectronTight1:                              0x1bdfbf5d              =====\n',
#        'RDOtoRDOTrigger 17:22:56 ====  ElectronLooseHLT:                            0x0016885d              =====\n',
#        'RDOtoRDOTrigger 17:22:56 ====  ElectronMediumHLT:                           0x129fbffd              =====\n',
#        'RDOtoRDOTrigger 17:22:56 ====  ElectronTightHLT:                            0x1b9fbffd              =====\n',
#        'RDOtoRDOTrigger 17:22:56 ====  PhotonLoose:                                 0x00007c01              =====\n',
#        'RDOtoRDOTrigger 17:22:56 ====  PhotonLooseEF:                               0x0000007d              =====\n',
#        'RDOtoRDOTrigger 17:22:56 ====  PhotonMedium:                                0x00207c01              =====\n',
#        'RDOtoRDOTrigger 17:22:56 ====  PhotonMediumEF:                              0x0000805d              =====\n',
#        'RDOtoRDOTrigger 17:22:56 ====  PhotonTight:                                 0x003ffc01              =====\n',
#        'RDOtoRDOTrigger 17:22:56 ===============================================================================\n',
#        'RDOtoRDOTrigger 17:22:56 \n',
#        'RDOtoRDOTrigger 17:22:56 Py:TrigEgammaPidTools    INFO TrigEgammaPidTools version ElectronPhotonSelectorTools/trigger/rel21_20180312/\n',
#        'RDOtoRDOTrigger 17:22:57 Py:TrigEgammaMVACalibFactories    INFO MVA version version egammaMVACalib/online/v6\n',
#        'RDOtoRDOTrigger 17:22:57 Py:TrigEgammaMVACalibFactories    INFO Cluster Correction version v12phiflip_noecorrnogap\n',
#        'RDOtoRDOTrigger 17:22:57 Py:TrigEgammaToolFactories    INFO MVA version version egammaMVACalib/online/v6\n',
#        'RDOtoRDOTrigger 17:22:57 Py:TrigEgammaToolFactories    INFO Cluster Correction version v12phiflip_noecorrnogap\n',
#        'RDOtoRDOTrigger 17:22:57 Py:CaloNoiseToolDefault    INFO  Using CaloNoiseToolDB\n',
#        'RDOtoRDOTrigger 17:22:57 Py:CaloNoiseToolDBMC::__init__     INFO entering\n',
#        'RDOtoRDOTrigger 17:22:57 Py:CaloNoiseToolDBMC::__init__     INFO offline mode: use luminosity from /CALO/Ofl/Noise/PileuUpNoiseLumi to scale pileup noise\n',
#        'RDOtoRDOTrigger 17:22:57 Py:CaloNoiseCondMC    INFO offline mode: use luminosity from /CALO/Ofl/Noise/PileuUpNoiseLumi to scale pileup noise\n',
#        'RDOtoRDOTrigger 17:22:57 True\n',
#        'RDOtoRDOTrigger 17:22:57 Py:CaloNoiseCondMC    INFO offline mode: use luminosity from /CALO/Ofl/Noise/PileuUpNoiseLumi to scale pileup noise\n',
#        "RDOtoRDOTrigger 17:22:57 Py:JetRec_jobOptions    INFO <class 'TrigHLTJetRec.TrigHLTJetRecConf.TriggerPseudoJetGetter2'>\n",
#        "RDOtoRDOTrigger 17:22:57 Py:JetRec_jobOptions    INFO <class 'EventShapeTools.EventShapeToolsConf.EventDensityTool'>\n",
#        'RDOtoRDOTrigger 17:22:57 TrigHLTJetRecConfig._getEnergyDensityTool Added energyDensity tools "jetTriggerEnergyDensityTool_Central_EM" to jtm\n',
#        "RDOtoRDOTrigger 17:22:57 Py:JetRec_jobOptions    INFO <class 'EventShapeTools.EventShapeToolsConf.EventDensityTool'>\n",
#        'RDOtoRDOTrigger 17:22:57 TrigHLTJetRecConfig._getEnergyDensityTool Added energyDensity tools "jetTriggerEnergyDensityTool_Forward_EM" to jtm\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Athena            INFO Importing TriggerMenu.muon.MuonDefIdTest\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Athena            INFO Importing TriggerMenu.bphysics.generateBPhysicsChainDefs\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Athena            INFO Importing TriggerMenu.met.generateMETChainDefs\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Athena            INFO Importing TriggerMenu.met.MissingETDef\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Athena            INFO Importing TriggerMenu.tau.generateTauChainDefs\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Athena            INFO Importing TriggerMenu.tau.TauDef\n',
#        'RDOtoRDOTrigger 17:22:57 Py:TriggerMenu.egamma.generateElectronChainDefs    INFO Importing TriggerMenu.egamma.generateElectronChainDefs\n',
#        'RDOtoRDOTrigger 17:22:57 Py:TrigDataAccess    INFO Not possible anymore to enable HLT calo offset correction, tools deprecated\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Adding new Public Tool ===> EMShowerBuilder/TrigEgammaShowerBuilder\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Adding new Public Tool ===> EMFourMomBuilder/TrigEMFourMomBuilder\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Athena            INFO Importing TriggerMenu.egamma.ElectronDef\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Athena            INFO Importing TriggerMenu.egamma.EgammaDef\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Athena            INFO Importing TrigEgammaHypo.TrigEFElectronHypoConfig\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Athena            INFO Importing TrigEgammaHypo.TrigEFPhotonHypoConfig\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Adding new Public Tool ===> EMConversionBuilder/TrigEMConversionBuilder\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Adding new Public Tool ===> EMPIDBuilder/TrigPhotonPIDBuilder\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Adding new Public Tool ===> EMExtrapolationTools/TrigEMExtrapolationTools\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Adding new Public Tool ===> EMTrackMatchBuilder/TrigEMTrackMatchBuilder\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> EMShowerBuilder/TrigEgammaShowerBuilder  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Adding new Public Tool ===> EMPIDBuilder/TrigElectronPIDBuilder\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Adding new Public Tool ===> EMPIDBuilder/TrigElectronCaloPIDBuilder\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Adding new Public Tool ===> CaloFillRectangularCluster/trigegamma_CaloFillRectangularCluster\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Adding new Public Tool ===> CP::IsolationCorrectionTool/NewLeakageCorrToolTrig\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Adding new Public Tool ===> xAOD::CaloClustersInConeTool/xAOD__CaloClustersInConeTool\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Adding new Public Tool ===> EGammaAmbiguityTool/TrigEGammaAmbiguityTool\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> CaloFillRectangularCluster/trigegamma_CaloFillRectangularCluster  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> CP::IsolationCorrectionTool/NewLeakageCorrToolTrig  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> EMFourMomBuilder/TrigEMFourMomBuilder  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> EMConversionBuilder/TrigEMConversionBuilder  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> EMPIDBuilder/TrigPhotonPIDBuilder  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> EMExtrapolationTools/TrigEMExtrapolationTools  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> EMTrackMatchBuilder/TrigEMTrackMatchBuilder  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> EMShowerBuilder/TrigEgammaShowerBuilder  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> EMPIDBuilder/TrigElectronPIDBuilder  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> EMPIDBuilder/TrigElectronCaloPIDBuilder  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> CaloFillRectangularCluster/trigegamma_CaloFillRectangularCluster  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> CP::IsolationCorrectionTool/NewLeakageCorrToolTrig  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> xAOD::CaloClustersInConeTool/xAOD__CaloClustersInConeTool  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> EGammaAmbiguityTool/TrigEGammaAmbiguityTool  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> CaloFillRectangularCluster/trigegamma_CaloFillRectangularCluster  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> CP::IsolationCorrectionTool/NewLeakageCorrToolTrig  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> EMFourMomBuilder/TrigEMFourMomBuilder  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> EMConversionBuilder/TrigEMConversionBuilder  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> EMPIDBuilder/TrigPhotonPIDBuilder  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> EMExtrapolationTools/TrigEMExtrapolationTools  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> EMTrackMatchBuilder/TrigEMTrackMatchBuilder  already in ToolSvc, using existing instance\n',
#        'RDOtoRDOTrigger 17:22:57 Py:Factories         INFO Public Tool with name ==> EMShowerBuilder/TrigEgammaShowerBuilder  already in ToolSvc, using existing instance\n'],
#       dtype=object)

# %%
import pandas as pd
import pprint

df = pd.read_csv('samples/all_logs.csv',index_col=0)
target = '0'
result = pipeline.ml_clustering(df.head(10000), target, mode='process', model_name='test/all_logs.model').process()
# Out:
# /Users/maria/PyCharmProjects/ClusterLogs/clusterlogs/pipeline.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['cleaned'] = self.preprocessed.process()
# Data Preparation finished
# Found 4299 equal groups
# Tokenization finished
# /Users/maria/anaconda3/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# /Users/maria/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:392: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /Users/maria/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Vectorization of tokens finished
# Vectorization of sentences is finished
# Vocabulary size = 4460
# Number of dimensions is 271
# DBSCAN finished with 1307 clusters

# %%
result.df[1000:2000]['cleaned'].values
# Out:
# array(['HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.cavernInputCols = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.dataRunNumber = {*}\n',
#        "HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.digiSteeringConf = 'StandardPileUpToolsAlg'\n",
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.doBeamGas = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.doBeamHalo = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.doBichselSimulation = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.doCaloNoise = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.doCavern = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.doDigiTruth = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.doFwdNoise = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.doHighPtMinBias = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.doInDetNoise = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.doLowPtMinBias = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.doMuonNoise = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.doRadiationDamage = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.doXingByXingPileUp = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.experimentalDigi = []\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.finalBunchCrossing = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.initialBunchCrossing = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.numberOfBeamGas = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.numberOfBeamHalo = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.numberOfCavern = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.numberOfCollisions = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.numberOfHighPtMinBias = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.numberOfLowPtMinBias = {*}\n',
#        "HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.overrideMetadata = ['PhysicsList']\n",
#        "HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.physicsList = 'QGSP_BERT'\n",
#        "HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.pileupDSID = {'High Pt Minimum Bias': {*}, 'Low Pt Minimum Bias': {*}}\n",
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.readSeedsFromFile = {*}\n',
#        "HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.rndmSeedInputFile = 'AtRanluxGenSvc.in'\n",
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.rndmSeedList = []\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> {*} = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> {*} = {*}\n',
#        "HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.rndmSvc = 'AtDSFMTGenSvc'\n",
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.simRunNumber = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Digitization.specialConfiguration = {*}\n',
#        'HITtoRDO {*} Py:DigitizationReadMetadata INFO Checking for Signal Simulation MetaData...\n',
#        'HITtoRDO {*} Py:AthFile INFO opening [/cvmfs/atlas-nightlies.cern.ch/repo/data/data-art/{*}/{*}/{*}]...\n',
#        'HITtoRDO {*} Py:DigitizationFlags INFO Found Run Number {*} in hits file metadata.\n',
#        'HITtoRDO {*} Py:DigitizationReadMetadata INFO specialConfiguration directive: {*}\n',
#        'HITtoRDO {*} Py:DigitizationReadMetadata INFO Checking Digitization properties against Signal Simulation MetaData...\n',
#        'HITtoRDO {*} Py:DigitizationReadMetadata INFO Digitization properties: [IOVDbGlobalTag = {*}], Signal Simulation MetaData: [IOVDbGlobalTag = {*}]\n',
#        "HITtoRDO {*} Py:DigitizationReadMetadata INFO Ensured {*} sub-detectors which were not simulated were switched off: ['Lucid', 'ZDC', 'ALFA', 'AFP', 'FwdRegion', 'HGTD', 'Micromegas', 'sTGC']\n",
#        'HITtoRDO {*} : {*} pixel SCT TRT BCM DBM Lucid ZDC ALFA AFP FwdRegion em HEC FCal Tile MDT CSC TGC RPC sTGC Micromegas Truth {*} BField FTK\n',
#        'HITtoRDO {*} dcs : {*} ON ON ON ON ON -- -- -- -- -- ON ON ON ON ON ON ON ON -- -- ON -- ON --\n',
#        'HITtoRDO {*} detdescr : {*} ON ON ON ON ON -- -- -- -- -- ON ON ON ON ON ON ON ON -- -- ON -- ON --\n',
#        'HITtoRDO {*} digitize : {*} ON ON ON ON ON -- -- -- -- -- ON ON ON ON ON ON ON ON -- -- ON -- ON --\n',
#        'HITtoRDO {*} geometry : {*} ON ON ON ON ON -- -- -- -- -- ON ON ON ON ON ON ON ON -- -- ON -- ON --\n',
#        'HITtoRDO {*} haveRDO : {*} ON ON ON ON ON -- -- -- -- -- ON ON ON ON ON ON ON ON -- -- ON -- ON --\n',
#        'HITtoRDO {*} haveRIO : {*} -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --\n',
#        'HITtoRDO {*} makeRIO : {*} -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --\n',
#        'HITtoRDO {*} overlay : {*} -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --\n',
#        'HITtoRDO {*} pileup : {*} ON ON ON ON ON -- -- -- -- -- ON ON ON ON ON ON ON ON -- -- ON -- ON --\n',
#        'HITtoRDO {*} readRDOBS : {*} -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --\n',
#        'HITtoRDO {*} readRDOPool : {*} ON ON ON ON ON -- -- -- -- -- ON ON ON ON ON ON ON ON -- -- ON -- ON --\n',
#        'HITtoRDO {*} readRIOBS : {*} -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --\n',
#        'HITtoRDO {*} readRIOPool : {*} -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --\n',
#        'HITtoRDO {*} simulate : {*} -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --\n',
#        'HITtoRDO {*} {*} : {*} ON ON ON ON ON -- -- -- -- -- ON ON ON ON ON ON ON ON -- -- ON -- ON --\n',
#        'HITtoRDO {*} writeBS : {*} -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --\n',
#        'HITtoRDO {*} writeRDOPool : {*} ON ON ON ON ON -- -- -- -- -- ON ON ON ON ON ON ON ON -- -- ON -- ON --\n',
#        'HITtoRDO {*} writeRIOPool : {*} -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --\n',
#        'HITtoRDO {*} Py:DigitizationReadMetadata INFO Completed checks of Digitization properties against Signal Simulation MetaData.\n',
#        'HITtoRDO {*} Py:DigitizationReadMetadata INFO Completed all checks against Signal Simulation MetaData.\n',
#        'HITtoRDO {*} Py:Athena INFO including file "Digitization/ConfigDigitization.py"\n',
#        'HITtoRDO {*} Py:Athena INFO SetGeometryVersion.py obtained major release version {*}\n',
#        'HITtoRDO {*} Py:Athena INFO including file "IdDictDetDescrCnv/IdDictDetDescrCnv_joboptions.py"\n',
#        'HITtoRDO {*} Py:ConfiguredFactory INFO imported {*} confDb modules in {*} seconds\n',
#        'HITtoRDO {*} Py:Athena INFO Importing MagFieldServices.SetupField\n',
#        'HITtoRDO {*} Py:Athena INFO Importing MagFieldServices.MagFieldServicesConfig\n',
#        'HITtoRDO {*} Py:Athena INFO including file "Digitization/RunNumberOverride.py"\n',
#        'HITtoRDO {*} Overriding run number to be: %s {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} You are attempting to access the jobproperty JobProperties.Digitization.RunAndLumiOverrideList which has not been set\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} You are attempting to access the jobproperty JobProperties.AthenaCommonFlags.SkipEvents which has not been set\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} You are attempting to access the jobproperty JobProperties.Digitization.RunAndLumiOverrideList which has not been set\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} You are attempting to access the jobproperty JobProperties.AthenaCommonFlags.SkipEvents which has not been set\n',
#        'HITtoRDO {*} Py:DigiConfigChecker INFO Beam jobProperties values:\n',
#        "HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Beam.beamType = 'collisions'\n",
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Beam.bunchSpacing = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Beam.energy = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} x-> JobProperties.Beam.numberOfCollisions = {*}\n',
#        'HITtoRDO {*} Py:JobProperty :: {*} --> JobProperties.Beam.override = {*}\n',
#        "HITtoRDO {*} Py:JobPropertyContainer:: {*} Locked all Digitization JobProperties except ['rndmSeedList'].\n",
#        'HITtoRDO {*} Py:Athena INFO including file "Digitization/DetectorDigitization.py"\n',
#        'HITtoRDO {*} /* Service PixelCablingSvc/PixelCablingSvc *\n',
#        'HITtoRDO {*} |-AuditFinalize = {*}\n',
#        'HITtoRDO {*} |-AuditInitialize = {*}\n',
#        'HITtoRDO {*} |-AuditReinitialize = {*}\n',
#        'HITtoRDO {*} |-AuditRestart = {*}\n',
#        'HITtoRDO {*} |-AuditServices = {*}\n',
#        'HITtoRDO {*} |-AuditStart = {*}\n',
#        'HITtoRDO {*} |-AuditStop = {*}\n',
#        'HITtoRDO {*} |-OutputLevel = {*}\n',
#        'HITtoRDO {*} \\----- (End of Service PixelCablingSvc/PixelCablingSvc) --------------------------------------------\n',
#        'HITtoRDO {*} Py:Athena INFO including file "TRT_Digitization/TRT_Digitization_CommonOptions.py"\n',
#        'HITtoRDO {*} Py:Athena INFO including file "PartPropSvc/PartPropSvc.py"\n',
#        'HITtoRDO {*} Py:LArPileUpToolDefault: {*} ---- in getLArPileUpTool\n',
#        'HITtoRDO {*} Py:Athena INFO including file "CaloDetMgrDetDescrCnv/CaloDetMgrDetDescrCnv_joboptions.py"\n',
#        'HITtoRDO {*} Py:Athena INFO including file "CaloConditions/CaloConditions_jobOptions.py"\n',
#        'HITtoRDO {*} Py:Athena INFO including file "CaloConditions/LArTTCellMap_ATLAS_jobOptions.py"\n',
#        'HITtoRDO {*} Py:Athena INFO including file "CaloConditions/CaloTTIdMap_ATLAS_jobOptions.py"\n',
#        'HITtoRDO {*} Py:Athena INFO including file "LArDetDescr/LArDetDescr_joboptions.py"\n',
#        'HITtoRDO {*} now initializing the LAr readout geometry : {*} Atlas flavour\n',
#        'HITtoRDO {*} Py:Athena INFO including file "LArConditionsCommon/LArConditionsCommon_MC_jobOptions.py"\n',
#        'HITtoRDO {*} Py:JobPropertyContainer:: {*} {*}\n',
#        'HITtoRDO {*} Py:JobPropertyContainer:: {*} use global tag for all LArElecCalibMC constants\n',
#        'HITtoRDO {*} Py:Athena INFO including file "LArConditionsCommon/LArIdMap_MC_jobOptions.py"\n',
#        'HITtoRDO {*} Py:JobPropertyContainer:: {*} setting folder /LAR/Identifier/OnOffIdMap with tag {*}\n',
#        'HITtoRDO {*} Py:JobPropertyContainer:: {*} setting folder /LAR/Identifier/CalibIdMap with tag {*}\n',
#        'HITtoRDO {*} Py:JobPropertyContainer:: {*} setting folder /LAR/Identifier/FebRodMap with tag {*}\n',
#        'HITtoRDO {*} Py:LArPileUpToolDefault: {*} do not use high gain in Fcal digitization\n',
#        'HITtoRDO {*} Py:Athena INFO including file "CaloDetMgrDetDescrCnv/CaloDetMgrDetDescrCnv_joboptions.py"\n',
#        'HITtoRDO {*} Py:Athena INFO including file "TileConditions/TileConditions_jobOptions.py"\n',
#        'HITtoRDO {*} Py:TileInfoConf. INFO Adding TileCablingSvc to ServiceMgr\n',
#        'HITtoRDO {*} Py:MetaReader INFO Current mode used: {*}\n',
#        "HITtoRDO {*} Py:MetaReader INFO Current filenames: ['/cvmfs/atlas-nightlies.cern.ch/repo/data/data-art/{*}/{*}/{*}']\n",
#        'HITtoRDO {*} Py:MetaReader INFO MetaReader is called with the parameter "unique_tag_info_values" set to True. This is a workaround to remove all duplicate values from "/TagInfo" key\n',
#        'HITtoRDO {*} Py:TileConditions_jobOptions.py INFO Forcing {*} ({*}) cabling for run {*} with geometry {*}\n',
#        'HITtoRDO {*} Py:TileConditions_jobOptions.py INFO Adjusting TileInfo for {*} samples\n',
#        'HITtoRDO {*} Py:TileConditions_jobOptions.py INFO setting up COOL for TileCal conditions data\n',
#        'HITtoRDO {*} Py:TileInfoConf. INFO Changing default TileBadChanTool configuration to COOL source\n',
#        'HITtoRDO {*} Py:TileInfoConf. INFO Changing default TileCondToolEmscale configuration to COOL source\n',
#        'HITtoRDO {*} Py:TileInfoConf. INFO Changing default TileCondToolNoiseSample configuration to COOL source\n',
#        'HITtoRDO {*} Py:TileInfoConf. INFO Changing default TileCondToolTiming configuration to COOL source\n',
#        'HITtoRDO {*} Py:TileConditions_jobOptions.py INFO Adjusting TileInfo to return cell noise for Opt.Filter with iterations\n',
#        'HITtoRDO {*} Py:TileConditions_jobOptions.py INFO Setting {*} ADC configuration\n',
#        'HITtoRDO {*} Py:TileInfoConf. INFO Setting {*} Tile ADC\n',
#        'HITtoRDO {*} Py:Athena INFO Importing MuonCnvExample.MuonCalibConfig\n',
#        'HITtoRDO {*} Py:Athena INFO Importing MuonCnvExample.MuonCnvUtils\n',
#        'HITtoRDO {*} Py:Athena INFO Importing module MuonCnvExample.MuonCalibFlags\n',
#        'HITtoRDO {*} Py:MuonCnvExample.MuonCalibFlags INFO Changing default mdtPropagationSpeedBeta = {*}\n',
#        'HITtoRDO {*} Py:CscCondDbAlg INFO Adding folder CSC_OFL:/CSC/FTHOLD to IOVDbSvc\n',
#        'HITtoRDO {*} Py:CscCondDbAlg INFO Adding folder CSC_OFL:/CSC/NOISE to IOVDbSvc\n',
#        'HITtoRDO {*} Py:CscCondDbAlg INFO Adding folder CSC_OFL:/CSC/PED to IOVDbSvc\n',
#        'HITtoRDO {*} Py:CscCondDbAlg INFO Adding folder CSC_OFL:/CSC/PSLOPE to IOVDbSvc\n',
#        'HITtoRDO {*} Py:CscCondDbAlg INFO Adding folder CSC_OFL:/CSC/RMS to IOVDbSvc\n',
#        'HITtoRDO {*} Py:CscCondDbAlg INFO Adding folder CSC_OFL:/CSC/STAT to IOVDbSvc\n',
#        'HITtoRDO {*} Py:CscCondDbAlg INFO Adding folder CSC_OFL:/CSC/{*} to IOVDbSvc\n',
#        'HITtoRDO {*} Py:CscCondDbAlg INFO Adding folder CSC_OFL:/CSC/{*} to IOVDbSvc\n',
#        'HITtoRDO {*} Py:MdtCondDbAlg INFO Adding folder DCS_OFL:/MDT/DCS/DROPPEDCH to IOVDbSvc\n',
#        'HITtoRDO {*} Py:MdtCondDbAlg INFO Adding folder DCS_OFL:/MDT/DCS/PSLVCHSTATE to IOVDbSvc\n',
#        'HITtoRDO {*} Py:RpcCondDbAlg INFO Adding folder RPC_OFL:/RPC/DQMF/ELEMENT_STATUS to IOVDbSvc\n',
#        'HITtoRDO {*} Py:Athena INFO including file "Digitization/InDetDigitization.py"\n',
#        'HITtoRDO {*} Py:DigiConfigChecker INFO Switching {*}()\n',
#        'HITtoRDO {*} Py:DigiConfigChecker INFO Experts may enable {*} {*} simulation by setting {*}= {*} in a preExec or in their main job options.\n',
#        'HITtoRDO {*} Py:Athena INFO including file "Digitization/CaloDigitization.py"\n',
#        'HITtoRDO {*} Py:LArAutoCorrTotalCondAlg::__init__ INFO entering LArAutoCorrTotalCondAlgDefault\n',
#        'HITtoRDO {*} Py:LArAutoCorrTotalCondAlg::__init__ INFO setup for computing total noise autocorrelation without pileup\n',
#        'HITtoRDO {*} Py:LArOFCCondAlg INFO entering LArOFCCondAlgDefault\n',
#        'HITtoRDO {*} Py:LArOFCCondAlg INFO setup for no pileup optimization\n',
#        'HITtoRDO {*} Py:Athena INFO including file "TileSimAlgs/TileDigiCommon_jobOptions.py"\n',
#        'HITtoRDO {*} Py:Configured::existingOutput:TileDigitsGetter: {*} one object not in output TileDigitsContainer:TileDigitsCnt\n',
#        'HITtoRDO {*} Py:Configured::existingOutput:TileDigitsGetter: {*} No output objects already available. Continue.\n',
#        'HITtoRDO {*} Py:TileDigitsGetter::configure: {*} entering\n',
#        'HITtoRDO {*} Py:TileInfoConf. INFO Changing default TileCondToolPHYPULSECool configuration to COOL source\n',
#        'HITtoRDO {*} Py:TileDigitsGetter::configure: {*} now adding to topSequence\n',
#        'HITtoRDO {*} Py:Configured::__init__:TileDigitsGetter: {*} Configured/Enabled\n',
#        'HITtoRDO {*} Py:TileDigitiization INFO Setting max/min time for parabolic correction to +/- {*} ns\n',
#        'HITtoRDO {*} Py:Configured::existingOutput:TileRawChannelGetter: {*} No output objects already available. Continue.\n',
#        'HITtoRDO {*} Py:TileRawChannelGetter::configure: {*} entering\n',
#        'HITtoRDO {*} |- AmpMinForAmpCorrection = {*}\n',
#        'HITtoRDO {*} |- BestPhaseFromCOOL = {*}\n',
#        'HITtoRDO {*} |- OfcFromCOOL = {*}\n',
#        "HITtoRDO {*} |- TileDigitsContainer = 'TileDigitsCnt'\n",
#        "HITtoRDO {*} |- TileRawChannelContainer = 'TileRawChannelCnt'\n",
#        'HITtoRDO {*} |- TileRunType = {*}\n',
#        'HITtoRDO {*} |- TimeMaxForAmpCorrection = {*} (Default: {*})\n',
#        'HITtoRDO {*} |- TimeMinForAmpCorrection = {*} (Default: {*})\n',
#        'HITtoRDO {*} |- calibrateEnergy = {*}\n',
#        'HITtoRDO {*} |- correctAmplitude = {*}\n',
#        'HITtoRDO {*} |- correctPedestalDifference = {*}\n',
#        'HITtoRDO {*} |- correctTime = {*}\n',
#        'HITtoRDO {*} |- correctTimeNI = {*}\n',
#        'HITtoRDO {*} |- doTileFit = {*}\n',
#        'HITtoRDO {*} |- doTileFitCool = {*}\n',
#        'HITtoRDO {*} |- doTileFlat = {*}\n',
#        'HITtoRDO {*} |- doTileMF = {*}\n',
#        'HITtoRDO {*} |- doTileManyAmps = {*}\n',
#        'HITtoRDO {*} |- {*} = {*}\n', 'HITtoRDO {*} |- {*} = {*}\n',
#        'HITtoRDO {*} |- doTileOptATLAS = {*} (Default: {*})\n',
#        'HITtoRDO {*} |- doTileOverflowFit = {*}\n',
#        'HITtoRDO {*} |- doTileQIE = {*}\n',
#        'HITtoRDO {*} |- doTileWiener = {*}\n',
#        'HITtoRDO {*} |- noiseFilter = {*}\n',
#        'HITtoRDO {*} |- readDigits = {*}\n',
#        'HITtoRDO {*} |- simulateTrips = {*}\n',
#        'HITtoRDO {*} |- zeroAmplitudeWithoutDigits = {*}\n',
#        'HITtoRDO {*} Py:TileInfoConf. INFO Changing default TileCondToolOfcCool configuration to COOL source for {*}\n',
#        'HITtoRDO {*} Py:TileRawChannelGetter::configure: {*} adding now TileRawChannelBuilderFitFilter to the algorithm: {*}\n',
#        'HITtoRDO {*} Py:TileRawChannelGetter::configure: {*} set up TileRawChannelBuilderFitOverflow to TileRawChannelBuilderFitFilter\n',
#        'HITtoRDO {*} Py:TileRawChannelGetter::configure: {*} adding now {*} with name TileRawChannelBuilderOptATLAS to the algorithm: {*}\n',
#        'HITtoRDO {*} Py:TileRawChannelGetter::configure: {*} now adding to topSequence\n',
#        'HITtoRDO {*} |- AmpMinForAmpCorrection = {*}\n',
#        'HITtoRDO {*} |- BestPhaseFromCOOL = {*}\n',
#        'HITtoRDO {*} |- OfcFromCOOL = {*}\n',
#        "HITtoRDO {*} |- TileDigitsContainer = 'TileDigitsCnt'\n",
#        "HITtoRDO {*} |- TileRawChannelContainer = 'TileRawChannelCnt'\n",
#        'HITtoRDO {*} |- TileRunType = {*}\n',
#        'HITtoRDO {*} |- TimeMaxForAmpCorrection = {*} (Default: {*})\n',
#        'HITtoRDO {*} |- TimeMinForAmpCorrection = {*} (Default: {*})\n',
#        'HITtoRDO {*} |- calibrateEnergy = {*}\n',
#        'HITtoRDO {*} |- correctAmplitude = {*}\n',
#        'HITtoRDO {*} |- correctPedestalDifference = {*}\n',
#        'HITtoRDO {*} |- correctTime = {*}\n',
#        'HITtoRDO {*} |- correctTimeNI = {*}\n',
#        'HITtoRDO {*} |- doTileFit = {*}\n',
#        'HITtoRDO {*} |- doTileFitCool = {*}\n',
#        'HITtoRDO {*} |- doTileFlat = {*}\n',
#        'HITtoRDO {*} |- doTileMF = {*}\n',
#        'HITtoRDO {*} |- doTileManyAmps = {*}\n',
#        'HITtoRDO {*} |- {*} = {*}\n', 'HITtoRDO {*} |- {*} = {*}\n',
#        'HITtoRDO {*} |- doTileOptATLAS = {*} (Default: {*})\n',
#        'HITtoRDO {*} |- doTileOverflowFit = {*}\n',
#        'HITtoRDO {*} |- doTileQIE = {*}\n',
#        'HITtoRDO {*} |- doTileWiener = {*}\n',
#        'HITtoRDO {*} |- noiseFilter = {*}\n',
#        'HITtoRDO {*} |- readDigits = {*}\n',
#        'HITtoRDO {*} |- simulateTrips = {*}\n',
#        'HITtoRDO {*} |- zeroAmplitudeWithoutDigits = {*}\n',
#        'HITtoRDO {*} Py:Configured::__init__:TileRawChannelGetter: {*} Configured/Enabled\n',
#        'HITtoRDO {*} Py:Athena INFO including file "TileSimAlgs/TileSamplingFraction_jobOptions.py"\n',
#        'HITtoRDO {*} Py:TileSamplingFraction_jobOptions.py INFO Using {*}/s.f. = {*} for QGSP_BERT physics list and {*} {*} ({*})\n',
#        'HITtoRDO {*} Py:TileSamplingFraction_jobOptions.py INFO Switching ON noise in Tile Digitization\n',
#        'HITtoRDO {*} Py:TileDigitiization INFO /* Service TileInfoLoader/TileInfoLoader *\n',
#        'HITtoRDO {*} |-ADCmaskValue = {*} (default: {*})\n',
#        'HITtoRDO {*} |-ADCmax = {*} (default: {*})\n',
#        'HITtoRDO {*} |-AuditFinalize = {*}\n',
#        'HITtoRDO {*} |-AuditInitialize = {*}\n',
#        'HITtoRDO {*} |-AuditReinitialize = {*}\n',
#        'HITtoRDO {*} |-AuditRestart = {*}\n',
#        'HITtoRDO {*} |-AuditServices = {*}\n',
#        'HITtoRDO {*} |-AuditStart = {*}\n',
#        'HITtoRDO {*} |-AuditStop = {*}\n',
#        "HITtoRDO {*} |-DigitsShapeFileHi = 'pulsehi_physics.dat'\n",
#        "HITtoRDO {*} |-DigitsShapeFileLo = 'pulselo_physics.dat'\n",
#        'HITtoRDO {*} |-EmScaleA = {*} (default: {*})\n',
#        'HITtoRDO {*} {*} = {*}\n', 'HITtoRDO {*} {*} = {*}\n',
#        'HITtoRDO {*} {*} = {*}\n', 'HITtoRDO {*} {*} = {*}\n',
#        'HITtoRDO {*} {*} = {*}\n', 'HITtoRDO {*} {*} = {*}\n',
#        'HITtoRDO {*} |-EmScaleMBTSinner = {*}\n',
#        'HITtoRDO {*} |-EmScaleMBTSouter = {*}\n',
#        'HITtoRDO {*} |-LoadWienerFilterWeights = {*}\n',
#        'HITtoRDO {*} {*} = {*}\n', 'HITtoRDO {*} {*} = {*}\n',
#        'HITtoRDO {*} {*} = {*}\n', 'HITtoRDO {*} {*} = {*}\n',
#        'HITtoRDO {*} {*} = {*}\n', 'HITtoRDO {*} {*} = {*}\n',
#        'HITtoRDO {*} {*} = {*}\n', 'HITtoRDO {*} {*} = {*}\n',
#        'HITtoRDO {*} {*} = {*}\n', 'HITtoRDO {*} {*} = {*}\n',
#        'HITtoRDO {*} |-MuRcvCalib = {*}\n',
#        'HITtoRDO {*} |-MuRcvMax = {*}\n',
#        'HITtoRDO {*} |-MuRcvNoiseSigma = {*}\n',
#        'HITtoRDO {*} |-MuRcvPed = {*}\n',
#        'HITtoRDO {*} |-MuRcvThresh = {*}\n',
#        'HITtoRDO {*} |-NPhElec = {*}\n',
#        'HITtoRDO {*} |-NPhElecA = {*}\n',
#        'HITtoRDO {*} |-NPhElecC = {*}\n',
#        'HITtoRDO {*} |-NPhElecD = {*}\n',
#        'HITtoRDO {*} |-NPhElecE = {*}\n', 'HITtoRDO {*} {*} = {*}\n',
#        'HITtoRDO {*} |-NPhElecMBTSinner = {*}\n',
#        'HITtoRDO {*} |-NPhElecMBTSouter = {*}\n',
#        'HITtoRDO {*} |-NSamples = {*} (default: {*})\n',
#        'HITtoRDO {*} |-NoiseScaleIndex = {*} (default: {*})\n',
#        'HITtoRDO {*} |-OutputLevel = {*}\n', 'HITtoRDO {*} {*} = {*}\n',
#        'HITtoRDO {*} {*} = {*}\n', 'HITtoRDO {*} {*} = {*}\n',
#        'HITtoRDO {*} {*} = {*}\n', 'HITtoRDO {*} {*} = {*}\n',
#        'HITtoRDO {*} {*} = {*}\n', 'HITtoRDO {*} {*} = {*}\n',
#        'HITtoRDO {*} |-ThresholdDigits = {*}\n',
#        'HITtoRDO {*} |-ThresholdRawChannel = {*}\n',
#        'HITtoRDO {*} |-TileCoherNoise = {*}\n',
#        'HITtoRDO {*} |-TileNoise = {*} (default: {*})\n',
#        'HITtoRDO {*} |-TileZeroSuppress = {*}\n',
#        'HITtoRDO {*} |-TrigSample = {*} (default: {*})\n',
#        'HITtoRDO {*} |-WienerFilterLuminosity = {*}\n',
#        'HITtoRDO {*} |-WienerFilterPhysicsNSamples = {*}\n',
#        "HITtoRDO {*} |-filename_DecoCovaFilePrefix = 'DecoCovaMatrix'\n",
#        "HITtoRDO {*} {*} = 'pulse_adder_muon_physics.dat'\n",
#        "HITtoRDO {*} |-filename_MuRcvShapeFile = 'pulse_adder_muonRcv_physics.dat'\n",
#        "HITtoRDO {*} {*} = 'pulse_adder_tower_physics.dat'\n",
#        "HITtoRDO {*} |-filename_dleakhi = '{*}'\n",
#        "HITtoRDO {*} |-filename_dleaklo = '{*}'\n",
#        "HITtoRDO {*} |-filename_dsleakhi = '{*}'\n",
#        "HITtoRDO {*} |-filename_dsleaklo = '{*}'\n",
#        "HITtoRDO {*} |-filename_hi_cis = '{*}'\n",
#        "HITtoRDO {*} |-filename_hi_cis_der = '{*}'\n",
#        "HITtoRDO {*} |-filename_hi_las = 'pulsehi_laser.dat'\n",
#        "HITtoRDO {*} |-filename_hi_las_der = 'dpulsehi_laser.dat'\n",
#        "HITtoRDO {*} |-filename_hi_phys = 'pulsehi_physics.dat'\n",
#        "HITtoRDO {*} |-filename_hi_phys_der = 'dpulsehi_physics.dat'\n",
#        "HITtoRDO {*} |-filename_leakhi = '{*}'\n",
#        "HITtoRDO {*} |-filename_leaklo = '{*}'\n",
#        "HITtoRDO {*} |-filename_lo_cis = '{*}'\n",
#        "HITtoRDO {*} |-filename_lo_cis_der = '{*}'\n",
#        "HITtoRDO {*} |-filename_lo_las = 'pulselo_laser.dat'\n",
#        "HITtoRDO {*} |-filename_lo_las_der = 'dpulselo_laser.dat'\n",
#        "HITtoRDO {*} |-filename_lo_phys = 'pulselo_physics.dat'\n",
#        "HITtoRDO {*} |-filename_lo_phys_der = 'dpulselo_physics.dat'\n",
#        "HITtoRDO {*} |-filename_nk_noise = 'noise_digi_nk.dat'\n",
#        "HITtoRDO {*} |-filename_orig_noise = 'noise_digi_orig.dat'\n",
#        "HITtoRDO {*} |-filename_shi_cis = '{*}'\n",
#        "HITtoRDO {*} |-filename_shi_cis_der = '{*}'\n",
#        "HITtoRDO {*} |-filename_sleakhi = '{*}'\n",
#        "HITtoRDO {*} |-filename_sleaklo = '{*}'\n",
#        "HITtoRDO {*} |-filename_slo_cis = '{*}'\n",
#        "HITtoRDO {*} |-filename_slo_cis_der = '{*}'\n",
#        'HITtoRDO {*} \\----- (End of Service TileInfoLoader/TileInfoLoader) ----------------------------------------------\n',
#        'HITtoRDO {*} Py:TileDigitiization INFO /* Private AlgTool {*}/TileRawChannelBuilderOptATLAS *\n',
#        'HITtoRDO {*} |-AmpMinForAmpCorrection = {*} (default: {*})\n',
#        'HITtoRDO {*} |-AmplitudeCorrection = {*} (default: {*})\n',
#        'HITtoRDO {*} |-AuditFinalize = {*}\n',
#        'HITtoRDO {*} |-AuditInitialize = {*}\n',
#        'HITtoRDO {*} |-AuditReinitialize = {*}\n',
#        'HITtoRDO {*} |-AuditRestart = {*}\n',
#        'HITtoRDO {*} |-AuditStart = {*}\n',
#        'HITtoRDO {*} |-AuditStop = {*}\n',
#        'HITtoRDO {*} |-AuditTools = {*}\n',
#        'HITtoRDO {*} |-BestPhase = {*} (default: {*})\n',
#        'HITtoRDO {*} |-ConfTB = {*}\n',
#        "HITtoRDO {*} |-DSPContainer = '' (default: 'StoreGateSvc+')\n",
#        'HITtoRDO {*} |-DataPoolSize = {*}\n',
#        "HITtoRDO {*} |-DetStore = {*}('StoreGateSvc/DetectorStore')\n",
#        'HITtoRDO {*} |-EmulateDSP = {*}\n',
#        "HITtoRDO {*} |-EvtStore = {*}('StoreGateSvc')\n",
#        'HITtoRDO {*} |-ExtraInputs = [] (default: [])\n',
#        'HITtoRDO {*} |-ExtraOutputs = [] (default: [])\n',
#        'HITtoRDO {*} |-FirstSample = {*}\n',
#        'HITtoRDO {*} |-MaxIterations = {*} (default: {*})\n',
#        'HITtoRDO {*} |-MaxTime = {*}\n', 'HITtoRDO {*} |-MinTime = {*}\n',
#        'HITtoRDO {*} {*} = {*} (default: {*})\n',
#        "HITtoRDO {*} |-MonitorService = 'MonitorSvc'\n",
#        'HITtoRDO {*} |-NoiseFilterTools = {*}([])\n',
#        'HITtoRDO {*} |-NoiseThresholdHG = {*}\n',
#        'HITtoRDO {*} |-NoiseThresholdLG = {*}\n',
#        'HITtoRDO {*} {*} = {*} (default: {*})\n',
#        'HITtoRDO {*} |-OutputLevel = {*}\n',
#        'HITtoRDO {*} |-PedestalMode = {*}\n',
#        'HITtoRDO {*} |-RunType = {*} (default: {*})\n',
#        "HITtoRDO {*} |-TileCablingSvc = {*}('TileCablingSvc')\n",
#        "HITtoRDO {*} |-TileCondIdTransforms = {*}('TileCondIdTransforms/TileCondIdTransforms')\n",
#        "HITtoRDO {*} |-TileCondToolEmscale = {*}('TileCondToolEmscale/TileCondToolEmscale')\n",
#        "HITtoRDO {*} |-TileCondToolNoiseSample = {*}('TileCondToolNoiseSample/TileCondToolNoiseSample')\n",
#        "HITtoRDO {*} |-TileCondToolOfc = {*}('TileCondToolOfcCool/TileCondToolOfcCool')\n",
#        "HITtoRDO {*} | (default: 'TileCondToolOfc/TileCondToolOfc')\n",
#        "HITtoRDO {*} |-TileCondToolTiming = {*}('TileCondToolTiming/TileCondToolTiming')\n",
#        "HITtoRDO {*} |-TileDQstatus = 'StoreGateSvc+TileDQstatus'\n",
#        "HITtoRDO {*} |-TileInfoName = 'TileInfo'\n",
#        "HITtoRDO {*} |-TileRawChannelContainer = 'TileRawChannelCnt' (default: 'StoreGateSvc+{*}')\n",
#        'HITtoRDO {*} |-TimeCorrection = {*} (default: {*})\n',
#        'HITtoRDO {*} |-TimeForConvergence = {*}\n',
#        'HITtoRDO {*} |-TimeMaxForAmpCorrection = {*} (default: {*})\n',
#        'HITtoRDO {*} |-TimeMinForAmpCorrection = {*} (default: {*})\n',
#        'HITtoRDO {*} |-UseDSPCorrection = {*}\n',
#        'HITtoRDO {*} |-calibrateEnergy = {*} (default: {*})\n',
#        'HITtoRDO {*} |-correctTime = {*} (default: {*})\n',
#        'HITtoRDO {*} |=/* Private AlgTool TileCondIdTransforms/TileCondIdTransforms *\n',
#        'HITtoRDO {*} | |-AuditFinalize = {*}\n',
#        'HITtoRDO {*} | |-AuditInitialize = {*}\n',
#        'HITtoRDO {*} | |-AuditReinitialize = {*}\n',
#        'HITtoRDO {*} | |-AuditRestart = {*}\n',
#        'HITtoRDO {*} | |-AuditStart = {*}\n',
#        'HITtoRDO {*} | |-AuditStop = {*}\n',
#        'HITtoRDO {*} | |-AuditTools = {*}\n',
#        "HITtoRDO {*} | |-DetStore = {*}('StoreGateSvc/DetectorStore')\n",
#        "HITtoRDO {*} | |-EvtStore = {*}('StoreGateSvc')\n",
#        'HITtoRDO {*} | |-ExtraInputs = [] (default: [])\n',
#        'HITtoRDO {*} | |-ExtraOutputs = [] (default: [])\n',
#        "HITtoRDO {*} | |-MonitorService = 'MonitorSvc'\n",
#        'HITtoRDO {*} | |-OutputLevel = {*}\n',
#        'HITtoRDO {*} | \\----- (End of Private AlgTool TileCondIdTransforms/TileCondIdTransforms) --------------------------\n',
#        'HITtoRDO {*} |=/* Private AlgTool TileCondToolEmscale/TileCondToolEmscale *\n',
#        'HITtoRDO {*} | |-AuditFinalize = {*}\n',
#        'HITtoRDO {*} | |-AuditInitialize = {*}\n',
#        'HITtoRDO {*} | |-AuditReinitialize = {*}\n',
#        'HITtoRDO {*} | |-AuditRestart = {*}\n',
#        'HITtoRDO {*} | |-AuditStart = {*}\n',
#        'HITtoRDO {*} | |-AuditStop = {*}\n',
#        'HITtoRDO {*} | |-AuditTools = {*}\n',
#        "HITtoRDO {*} | |-DetStore = {*}('StoreGateSvc/DetectorStore')\n",
#        "HITtoRDO {*} | |-EvtStore = {*}('StoreGateSvc')\n",
#        'HITtoRDO {*} | |-ExtraInputs = [] (default: [])\n',
#        'HITtoRDO {*} | |-ExtraOutputs = [] (default: [])\n',
#        "HITtoRDO {*} | |-MonitorService = 'MonitorSvc'\n",
#        'HITtoRDO {*} | |-OutputLevel = {*}\n',
#        "HITtoRDO {*} | |-TileEMScale = 'TileEMScale' (default: 'ConditionStore+TileEMScale')\n",
#        'HITtoRDO {*} | \\----- (End of Private AlgTool TileCondToolEmscale/TileCondToolEmscale) ----------------------------\n',
#        'HITtoRDO {*} |=/* Private AlgTool TileCondToolNoiseSample/TileCondToolNoiseSample *\n',
#        'HITtoRDO {*} | |-AuditFinalize = {*}\n',
#        'HITtoRDO {*} | |-AuditInitialize = {*}\n',
#        'HITtoRDO {*} | |-AuditReinitialize = {*}\n',
#        'HITtoRDO {*} | |-AuditRestart = {*}\n',
#        'HITtoRDO {*} | |-AuditStart = {*}\n',
#        'HITtoRDO {*} | |-AuditStop = {*}\n',
#        'HITtoRDO {*} | |-AuditTools = {*}\n',
#        "HITtoRDO {*} | |-DetStore = {*}('StoreGateSvc/DetectorStore')\n",
#        "HITtoRDO {*} | |-EvtStore = {*}('StoreGateSvc')\n",
#        'HITtoRDO {*} | |-ExtraInputs = [] (default: [])\n',
#        'HITtoRDO {*} | |-ExtraOutputs = [] (default: [])\n',
#        "HITtoRDO {*} | |-MonitorService = 'MonitorSvc'\n",
#        'HITtoRDO {*} | |-OutputLevel = {*}\n',
#        "HITtoRDO {*} | |-TileEMScale = 'ConditionStore+TileEMScale'\n",
#        "HITtoRDO {*} | |-TileOnlineSampleNoise = '' (default: 'ConditionStore+TileOnlineSampleNoise')\n",
#        "HITtoRDO {*} | |-TileSampleNoise = 'TileSampleNoise' (default: 'ConditionStore+TileSampleNoise')\n",
#        'HITtoRDO {*} | \\----- (End of Private AlgTool TileCondToolNoiseSample/TileCondToolNoiseSample) --------------------\n',
#        'HITtoRDO {*} |=/* Private AlgTool TileCondToolOfcCool/TileCondToolOfcCool *\n',
#        'HITtoRDO {*} | |-AuditFinalize = {*}\n',
#        'HITtoRDO {*} | |-AuditInitialize = {*}\n',
#        'HITtoRDO {*} | |-AuditReinitialize = {*}\n',
#        'HITtoRDO {*} | |-AuditRestart = {*}\n',
#        'HITtoRDO {*} | |-AuditStart = {*}\n',
#        'HITtoRDO {*} | |-AuditStop = {*}\n',
#        'HITtoRDO {*} | |-AuditTools = {*}\n',
#        "HITtoRDO {*} | |-DetStore = {*}('StoreGateSvc/DetectorStore')\n",
#        "HITtoRDO {*} | |-EvtStore = {*}('StoreGateSvc')\n",
#        'HITtoRDO {*} | |-ExtraInputs = [] (default: [])\n',
#        'HITtoRDO {*} | |-ExtraOutputs = [] (default: [])\n',
#        "HITtoRDO {*} | |-MonitorService = 'MonitorSvc'\n",
#        'HITtoRDO {*} | |-OutputLevel = {*}\n',
#        "HITtoRDO {*} | |-TileOfc = '{*}' (default: 'ConditionStore+TileOfc')\n",
#        'HITtoRDO {*} | \\----- (End of Private AlgTool TileCondToolOfcCool/TileCondToolOfcCool) ----------------------------\n',
#        'HITtoRDO {*} |=/* Private AlgTool TileCondToolTiming/TileCondToolTiming *\n',
#        'HITtoRDO {*} | |-AuditFinalize = {*}\n',
#        'HITtoRDO {*} | |-AuditInitialize = {*}\n',
#        'HITtoRDO {*} | |-AuditReinitialize = {*}\n',
#        'HITtoRDO {*} | |-AuditRestart = {*}\n',
#        'HITtoRDO {*} | |-AuditStart = {*}\n',
#        'HITtoRDO {*} | |-AuditStop = {*}\n',
#        'HITtoRDO {*} | |-AuditTools = {*}\n',
#        "HITtoRDO {*} | |-DetStore = {*}('StoreGateSvc/DetectorStore')\n",
#        "HITtoRDO {*} | |-EvtStore = {*}('StoreGateSvc')\n",
#        'HITtoRDO {*} | |-ExtraInputs = [] (default: [])\n',
#        'HITtoRDO {*} | |-ExtraOutputs = [] (default: [])\n',
#        "HITtoRDO {*} | |-MonitorService = 'MonitorSvc'\n",
#        'HITtoRDO {*} | |-OutputLevel = {*}\n',
#        "HITtoRDO {*} | |-TileTiming = 'TileTiming' (default: 'ConditionStore+TileTiming')\n",
#        'HITtoRDO {*} | \\----- (End of Private AlgTool TileCondToolTiming/TileCondToolTiming) ------------------------------\n',
#        'HITtoRDO {*} \\----- (End of Private AlgTool {*}/TileRawChannelBuilderOptATLAS) ------\n',
#        'HITtoRDO {*} Py:Athena INFO including file "{*}/{*}"\n',
#        'HITtoRDO {*} {*} {*} one object not in output {*}\n',
#        'HITtoRDO {*} {*} {*} No output objects already available. Continue.\n',
#        'HITtoRDO {*} {*} {*} entering\n',
#        'HITtoRDO {*} {*} {*} now adding to topSequence\n',
#        'HITtoRDO {*} {*} {*} Configured/Enabled\n',
#        'HITtoRDO {*} Py:Athena INFO including file "Digitization/MuonDigitization.py"\n',
#        "HITtoRDO {*} Py:Athena INFO importing module 'MuonCnvExample.MuonCablingConfig'\n",
#        'HITtoRDO {*} Py:Athena INFO Importing MuonCnvExample.MuonCnvFlags\n',
#        "HITtoRDO {*} Py:MuonCnvExample.MuonCnvFlags INFO Changing default TgcCablingMode = '{*}'\n",
#        "HITtoRDO {*} Py:MuonCnvExample.MuonCnvFlags INFO Changing default TgcCablingMode = 'auto'\n",
#        "HITtoRDO {*} Py:MuonCnvExample.MuonCnvFlags INFO Changing default TgcCablingMode = '{*}'\n",
#        'HITtoRDO {*} Py:Athena INFO configuring Muon cabling in MuonCablingConfig\n',
#        'HITtoRDO {*} Py:Athena INFO importing the MetaReader for MuoncablingConfig\n',
#        'HITtoRDO {*} Py:MetaReader INFO Current mode used: {*}\n',
#        "HITtoRDO {*} Py:MetaReader INFO Current filenames: ['/cvmfs/atlas-nightlies.cern.ch/repo/data/data-art/{*}/{*}/{*}']\n",
#        'HITtoRDO {*} Py:MetaReader INFO MetaReader is called with the parameter "unique_tag_info_values" set to True. This is a workaround to remove all duplicate values from "/TagInfo" key\n',
#        'HITtoRDO {*} Py:Athena INFO No RPC cabling taginfo found. Using normal configuration.\n',
#        'HITtoRDO {*} Py:Athena INFO RPC cabling is using mode: {*}\n',
#        'HITtoRDO {*} Py:Athena INFO TGC cabling is using mode: {*}\n',
#        'HITtoRDO {*} Py:Athena INFO MDT cabling is using mode: {*}\n',
#        'HITtoRDO {*} Py:Athena INFO Adding MDT/CABLING folders to conddb\n',
#        'HITtoRDO {*} Py:Athena INFO including file "Digitization/{*}"\n',
#        'HITtoRDO {*} Py:Athena INFO including file "{*}/{*}"\n',
#        'HITtoRDO {*} {*} {*} No output objects already available. Continue.\n',
#        'HITtoRDO {*} {*} {*} entering\n',
#        'HITtoRDO {*} {*} {*} Using hit map from LArDigitMaker algoritm\n',
#        'HITtoRDO {*} {*} {*} now adding to topSequence\n',
#        'HITtoRDO {*} {*} {*} Configured/Enabled\n',
#        'HITtoRDO {*} Py:Athena INFO including file "TileSimAlgs/{*}"\n',
#        'HITtoRDO {*} {*} {*} one object not in output {*}\n',
#        'HITtoRDO {*} {*} {*} No output objects already available. Continue.\n',
#        'HITtoRDO {*} {*} {*} entering\n',
#        'HITtoRDO {*} {*} {*} now adding to topSequence\n',
#        'HITtoRDO {*} {*} {*} Configured/Enabled\n',
#        'HITtoRDO {*} Py:Athena INFO including file "TileSimAlgs/TileMuonReceiver_jobOptions.py"\n',
#        "HITtoRDO {*} Py:DigitizationFlags INFO Adding Digitization random number seed stored in jobProperties to Random Number Service 'AtDSFMTGenSvc'\n",
#        'HITtoRDO {*} Py:DigitizationFlags INFO Random Number Seeds stored in digitization jobProperty: []\n',
#        "HITtoRDO {*} Py:DigitizationFlags INFO Random Number Seeds attached to Service 'AtDSFMTGenSvc': []\n",
#        'HITtoRDO {*} Py:Digitization INFO Digitization Configured Successfully.\n',
#        'HITtoRDO {*} Py:JobPropertyContainer:: {*} The JobProperty Container Digitization is locked\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO Setting the Digitization MetaData IOV from the IOVDbMetaDataTool\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO Filling Digitization MetaData\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "doInDetNoise" to be True\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "doCaloNoise" to be True\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "doMuonNoise" to be True\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "bunchSpacing" to be {*}\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "initialBunchCrossing" to be {*}\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "finalBunchCrossing" to be {*}\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "doCavern" to be False\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "doBeamGas" to be False\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "doBeamHalo" to be False\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "rndmSvc" to be AtDSFMTGenSvc\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "physicsList" to be QGSP_BERT\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "overrideMetadata" to be [\'PhysicsList\']\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "pileupDSID" to be {\'Low Pt Minimum Bias\': {*}, \'High Pt Minimum Bias\': {*}}\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "digiSteeringConf" to be StandardPileUpToolsAlg\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "BeamIntensityPattern" to be None\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "beamType" to be collisions\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "intraTrainBunchSpacing" to be {*}\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "IOVDbGlobalTag" to be {*}\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} N_LowPtMinBiasInputFiles to be {*}\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} N_HighPtMinBiasInputFiles to be {*}\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} N_cavernInputFiles to be {*}\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} N_beamGasInputFiles to be {*}\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} N_beamHaloInputFiles to be {*}\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "DetDescrVersion" to be {*}\n',
#        'HITtoRDO {*} Py:DigitizationWriteMetadata INFO DigitizationMetaData: {*} "{*}" to be NONE\n',
#        "HITtoRDO {*} Py:DigitizationWriteMetadata INFO No attribute 'HGTD_on' found on DetFlags.digitize\n",
#        "HITtoRDO {*} Py:DigitizationWriteMetadata INFO Setting 'DigitizedDetectors' = ['pixel', 'SCT', 'TRT', 'BCM', 'LAr', 'Tile', 'MDT', 'CSC', 'TGC', 'RPC', 'Truth']\n",
#        'HITtoRDO {*} ParameterDbFiller.genDb: {*} parameters <ROOT.cool::Record object at {*}>\n',
#        'HITtoRDO {*} ParameterDbFiller.genDb: {*} object\n',
#        'HITtoRDO {*} ParameterDbFiller.dumpDb: {*} database: {*}//;schema= {*}= {*}\n',
#        'HITtoRDO {*} ParameterDbFiller.dumpDb: {*} folder /Digitization/Parameters\n',
#        'HITtoRDO {*} ParameterDbFiller.dumpDb: {*} of IOV payloads {*}\n',
#        'HITtoRDO {*} ParameterDbFiller.dumpDb: {*} {*} [r,l]: [ {*} , {*} ]until [r,l]: [ {*} , {*} ]payload <ROOT.cool::Record object at {*}>chan {*}\n',
#        'HITtoRDO {*} Py:Athena INFO including file "AthenaCommon/runbatch.py"\n',
#        "HITtoRDO {*} ApplicationMgr INFO Updating Gaudi::PluginService::SetDebug(level) to level= 'PluginDebugLevel'{*}\n",
#        "HITtoRDO {*} ApplicationMgr INFO Updating Gaudi::PluginService::SetDebug(level) to level= 'PluginDebugLevel'{*}\n",
#        'HITtoRDO {*} ApplicationMgr SUCCESS\n',
#        'HITtoRDO {*} ====================================================================================================================================\n',
#        'HITtoRDO {*} Welcome to ApplicationMgr (GaudiCoreSvc {*})\n',
#        'HITtoRDO {*} running on {*} on Wed Feb {*} {*} {*}\n',
#        'HITtoRDO {*} ====================================================================================================================================\n',
#        'HITtoRDO {*} ApplicationMgr INFO Application Manager Configured successfully\n',
#        "HITtoRDO {*} ApplicationMgr INFO Updating Gaudi::PluginService::SetDebug(level) to level= 'PluginDebugLevel'{*}\n",
#        'HITtoRDO {*} StatusCodeSvc INFO initialize\n',
#        'HITtoRDO {*} MemStatAuditor INFO Memory usage has changed after AuditorSvc Initialize \tvirtual size = {*} MB \tresident set size = {*} MB deltaVsize = {*} MB\n',
#        'HITtoRDO {*} PerfMonSvc: {*} Initializing PerfMonSvc...\n',
#        'HITtoRDO {*} PerfMonSvc: {*} monitoring level: {*}\n',
#        'HITtoRDO {*} PerfMonSvc: {*} opening pmon-stream file [ntuple.pmon.stream]...\n',
#        'HITtoRDO {*} PerfMonSvc: {*} Retrieving PyPerfMonSvc object...\n',
#        'HITtoRDO {*} PerfMonSvc: {*} Retrieving PyPerfMonSvc object...\n',
#        'HITtoRDO {*} PerfMonSvc: {*} Retrieving PyPerfMonSvc object... [OK]\n',
#        'HITtoRDO {*} Py:PerfMonSvc INFO initialization [cpu= {*} ms vmem= {*} MB]\n',
#        'HITtoRDO {*} Py:PerfMonSvc INFO configuring PerfMonSvc to store perfmon-infos into [ntuple.pmon.gz]\n',
#        'HITtoRDO {*} Py:PerfMonSvc INFO Components being monitored: {*}\n',
#        'HITtoRDO {*} Py:PerfMonSvc INFO I/O containers: {*}\n',
#        'HITtoRDO {*} Py:PerfMonSvc INFO pmon-stream: [ntuple.pmon.stream]\n',
#        'HITtoRDO {*} Py:PerfMonSvc INFO installing pmon-malloc hooks: {*}\n',
#        'HITtoRDO {*} Py:PerfMonSvc INFO pmon-malloc hooks enabled: {*}\n',
#        'HITtoRDO {*} Py:PerfMonSvc INFO initialization [cpu= {*} ms vmem= {*} MB] [OK]\n',
#        'HITtoRDO {*} MemStatAuditor INFO Memory usage has changed after IoComponentMgr Initialize \tvirtual size = {*} MB \tresident set size = {*} MB deltaVsize = {*} MB\n',
#        'HITtoRDO {*} MemStatAuditor INFO Memory usage has changed after PerfMonSvc Initialize \tvirtual size = {*} MB \tresident set size = {*} MB deltaVsize = {*} MB\n',
#        'HITtoRDO {*} AthDictLoaderSvc INFO in initialize...\n',
#        'HITtoRDO {*} AthDictLoaderSvc INFO acquired Dso-registry\n',
#        'HITtoRDO {*} ClassIDSvc INFO getRegistryEntries: {*} {*} CLIDRegistry entries for module ALL\n',
#        'HITtoRDO {*} MemStatAuditor INFO Memory usage has changed after ClassIDSvc Initialize \tvirtual size = {*} MB \tresident set size = {*} MB deltaVsize = {*} MB\n',
#        'HITtoRDO {*} MemStatAuditor INFO Memory usage has changed after AthDictLoaderSvc Initialize \tvirtual size = {*} MB \tresident set size = {*} MB deltaVsize = {*} MB\n',
#        'HITtoRDO {*} CoreDumpSvc INFO install f-a-t-a-l handler... (flag = {*})\n',
#        'HITtoRDO {*} CoreDumpSvc INFO Handling signals: {*}(Segmentation fault) {*}(Bus error) {*}(Illegal instruction) {*}(Floating point exception)\n',
#        'HITtoRDO {*} MemStatAuditor INFO Memory usage has changed after CoreDumpSvc Initialize \tvirtual size = {*} MB \tresident set size = {*} MB deltaVsize = {*} MB\n',
#        'HITtoRDO {*} MemStatAuditor INFO Memory usage has changed after EventPersistencySvc Initialize \tvirtual size = {*} MB \tresident set size = {*} MB deltaVsize = {*} MB\n',
#        'HITtoRDO {*} MetaDataSvc INFO Initializing MetaDataSvc - package version {*}\n',
#        'HITtoRDO {*} MemStatAuditor INFO Memory usage has changed after InputMetaDataStore_Impl Initialize \tvirtual size = {*} MB \tresident set size = {*} MB deltaVsize = {*} MB\n',
#        'HITtoRDO {*} AthenaPoolCnvSvc INFO Initializing AthenaPoolCnvSvc - package version {*}\n',
#        'HITtoRDO {*} MemStatAuditor INFO Memory usage has changed after DataModelCompatSvc Initialize \tvirtual size = {*} MB \tresident set size = {*} MB deltaVsize = {*} MB\n',
#        'HITtoRDO {*} PoolSvc INFO io_register[PoolSvc](xmlcatalog_file:PoolFileCatalog.xml) [ok]\n',
#        "HITtoRDO {*} PoolSvc INFO Set connectionsvc retry/timeout/IDLE timeout to 'ConnectionRetrialPeriod'{*}/ 'ConnectionRetrialTimeOut'{*}/ 'ConnectionTimeOut'{*} seconds with connection cleanup disabled\n",
#        'HITtoRDO {*} PoolSvc INFO Frontier compression level set to {*}\n',
#        'HITtoRDO {*} DBReplicaSvc INFO Frontier server at (serverurl= {*}//{*}/atlr)(serverurl= {*}//{*}/atlr)(serverurl= {*}//{*}/{*})(proxyurl= {*}//{*})(proxyurl= {*}//{*})(proxyurl= {*}//{*})(proxyurl= {*}//{*})(proxyurl= {*}//{*}) will be considered for COOL data\n',
#        'HITtoRDO {*} DBReplicaSvc INFO Read replica configuration from /{*}/ci-builds/master/Athena/build/Athena/{*}/share/dbreplica.config\n',
#        'HITtoRDO {*} DBReplicaSvc INFO Total of {*} servers found for host {*} [ATLF ATLAS_COOLPROD atlas_dd ATLAS_CONFIG {*} INTR ATONR_COOL ATONR_CONF {*} ATLF ]\n',
#        'HITtoRDO {*} MemStatAuditor INFO Memory usage has changed after DBReplicaSvc Initialize \tvirtual size = {*} MB \tresident set size = {*} MB deltaVsize = {*} MB\n',
#        'HITtoRDO {*} PoolSvc INFO Successfully setup replica sorting algorithm\n',
#        'HITtoRDO {*} PoolSvc INFO Setting up APR FileCatalog and Streams\n',
#        'HITtoRDO {*} MemStatAuditor INFO Memory usage has changed after Gaudi::MultiFileCatalog Initialize \tvirtual size = {*} MB \tresident set size = {*} MB deltaVsize = {*} MB\n',
#        'HITtoRDO {*} PoolSvc WARNING Unable to locate catalog for prfile:poolcond/PoolCat_oflcond.xml check your ATLAS_POOLCOND_PATH and DATAPATH variables\n',
#        'HITtoRDO {*} PoolSvc WARNING Unable to locate catalog for apcfile:poolcond/PoolCat_oflcond.xml check your ATLAS_POOLCOND_PATH and DATAPATH variables\n',
#        'HITtoRDO {*} PoolSvc INFO Resolved path (via ATLAS_POOLCOND_PATH) is /cvmfs/atlas-condb.cern.ch/repo/conditions/poolcond/PoolFileCatalog.xml\n',
#        'HITtoRDO {*} PoolSvc INFO POOL WriteCatalog is xmlcatalog_file:PoolFileCatalog.xml\n',
#        'HITtoRDO {*} DbSession INFO Open DbSession\n',
#        'HITtoRDO {*} Domain[ROOT_All] INFO > Access DbDomain READ [ROOT_All]\n',
#        'HITtoRDO {*} MemStatAuditor INFO Memory usage has changed after PoolSvc Initialize \tvirtual size = {*} MB \tresident set size = {*} MB deltaVsize = {*} MB\n',
#        'HITtoRDO {*} MemStatAuditor INFO Memory usage has changed after AthenaPoolCnvSvc Initialize \tvirtual size = {*} MB \tresident set size = {*} MB deltaVsize = {*} MB\n',
#        'HITtoRDO {*} MemStatAuditor INFO Memory usage has changed after FileMgr Initialize \tvirtual size = {*} MB \tresident set size = {*} MB deltaVsize = {*} MB\n',
#        'HITtoRDO {*} MemStatAuditor INFO Memory usage has changed after ToolSvc.IOVDbMetaDataTool Initialize \tvirtual size = {*} MB \tresident set size = {*} MB deltaVsize = {*} MB\n',
#        "HITtoRDO {*} MetaDataSvc INFO Found MetaDataTools = {*}(['IOVDbMetaDataTool'])\n",
# ...
#        'HITtoRDO {*} IBLParameterSvc INFO IBL geometry\n',
#        'HITtoRDO {*} MemStatAuditor INFO Memory usage has changed after IBLParameterSvc Initialize \tvirtual size = {*} MB \tresident set size = {*} MB deltaVsize = {*} MB\n',
#        'HITtoRDO {*} EventPersistenc... INFO Added successfully Conversion service:TagInfoMgr\n',
#        'HITtoRDO {*} EventPersistenc... INFO Added successfully Conversion service:DetDescrCnvSvc\n',
#        'HITtoRDO {*} PixelIDDetDescrCnv INFO in createObj: {*} a PixelID helper object in the detector store\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO in initialize\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO in createObj: {*} a IdDictManager object in the detector store\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO IdDictName: {*}/ATLAS_IDS.xml\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO Reading InnerDetector IdDict file InDetIdDictFiles/{*}\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO Reading LArCalorimeter IdDict file IdDictParser/{*}\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO Reading TileCalorimeter IdDict file IdDictParser/IdDictTileCalorimeter.xml\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO Reading Calorimeter IdDict file IdDictParser/{*}\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO Reading MuonSpectrometer IdDict file IdDictParser/{*}\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO Reading ForwardDetectors IdDict file IdDictParser/{*}\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO Found id dicts:\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO Using dictionary tag: {*}\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO Dictionary ATLAS version default DetDescr tag (using default) file\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO Dictionary Calorimeter version default DetDescr tag {*} file IdDictParser/{*}\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO Dictionary ForwardDetectors version default DetDescr tag {*} file IdDictParser/{*}\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO Dictionary InnerDetector version IBL-DBM DetDescr tag {*} file InDetIdDictFiles/{*}\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO Dictionary LArCalorimeter version fullAtlas DetDescr tag {*} file IdDictParser/{*}\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO Dictionary LArElectrode version fullAtlas DetDescr tag (using default) file\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO Dictionary LArHighVoltage version fullAtlas DetDescr tag (using default) file\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO Dictionary MuonSpectrometer version {*} DetDescr tag {*} file IdDictParser/{*}\n',
#        'HITtoRDO {*} IdDictDetDescrCnv INFO Dictionary TileCalorimeter version fullAtlasAndTestBeam DetDescr tag {*} file IdDictParser/IdDictTileCalorimeter.xml\n',
#        'HITtoRDO {*} PixelID INFO Initialize from dictionary\n',
#        'HITtoRDO {*} AtlasDetectorID INFO initialize_from_dictionary - OK\n',
#        'HITtoRDO {*} indet {*} {*},{*},{*},{*},{*},{*},{*},{*} {*} {*} {*} {*} {*} min/max {*} {*} values {*} {*} {*} {*} {*} {*} {*} {*} indexes {*} {*} {*} {*} {*} {*} {*} {*} {*} {*} {*} {*} indices {*} prev {*} next {*} mode enumerated cont mode none\n',
#        'HITtoRDO {*} pixel {*} {*} {*} {*} {*} {*} {*} min/max {*} {*} values indexes indices {*} prev {*} next {*} mode both_bounded cont mode none\n',
#        'HITtoRDO {*} bec {*} {*},{*},{*},{*},{*} {*} {*} {*} {*} {*} min/max {*} {*} values {*} {*} {*} {*} {*} indexes {*} {*} {*} {*} {*} {*} {*} {*} {*} indices {*} prev {*} next {*} mode enumerated cont mode none\n',
#        'HITtoRDO {*} bec_shift {*} {*} {*} {*} {*} {*} {*} min/max {*} {*} values indexes indices {*} prev {*} next {*} mode both_bounded cont mode none\n',
#        'HITtoRDO {*} lay_disk {*} {*} {*} {*} {*} {*} {*} min/max {*} {*} values indexes indices {*} prev {*} next {*} mode both_bounded cont mode none\n',
#        'HITtoRDO {*} lay_disk_shift {*} {*} {*} {*} {*} {*} {*} min/max {*} {*} values indexes indices {*} prev {*} next {*} mode both_bounded cont mode none\n',
#        'HITtoRDO {*} phi_mod {*} {*} {*} {*} {*} {*} {*} min/max {*} {*} values indexes indices {*} prev {*} next {*} mode both_bounded cont mode none\n',
#        'HITtoRDO {*} phi_mod_shift {*} {*} {*} {*} {*} {*} {*} min/max {*} {*} values indexes indices {*} prev {*} next {*} mode both_bounded cont mode none\n',
#        'HITtoRDO {*} eta_mod {*} {*} {*} {*} {*} {*} {*} min/max {*} {*} values indexes indices {*} prev {*} next {*} mode both_bounded cont mode none\n',
#        'HITtoRDO {*} eta_mod_shift {*} {*} {*} {*} {*} {*} {*} min/max {*} {*} values indexes indices {*} prev {*} next {*} mode both_bounded cont mode none\n',
#        'HITtoRDO {*} phi_index {*} {*} {*} {*} {*} {*} {*} min/max {*} {*} values indexes indices {*} prev {*} next {*} mode both_bounded cont mode none\n',
#        'HITtoRDO {*} eta_index {*} {*} {*} {*} {*} {*} {*} min/max {*} {*} values indexes indices {*} prev {*} next {*} mode both_bounded cont mode none\n',
#        'HITtoRDO {*} bec_eta_mod {*} {*} {*} {*} {*} {*} {*} min/max {*} {*} values indexes indices {*} prev {*} next {*} mode both_bounded cont mode none\n',
#        'HITtoRDO {*} PixelID::initLevelsFromDict - found levels\n',
#        'HITtoRDO {*} subdet {*}\n', 'HITtoRDO {*} part {*}\n',
#        'HITtoRDO {*} barrel_endcap {*}\n',
#        'HITtoRDO {*} layer or disk {*}\n',
#        'HITtoRDO {*} phi_module {*}\n', 'HITtoRDO {*} eta_module {*}\n',
#        'HITtoRDO {*} phi_index {*}\n', 'HITtoRDO {*} eta_index {*}\n',
#        'HITtoRDO {*} InDetGeometryDBSvc INFO GeometryDBSvc Initialized\n',
#        'HITtoRDO {*} MemStatAuditor INFO Memory usage has changed after InDetGeometryDBSvc Initialize \tvirtual size = {*} MB \tresident set size = {*} MB deltaVsize = {*} MB\n',
#        "HITtoRDO {*} GeoModelSvc.Pix... INFO BCM_GeoModel tool retrieved: {*} = {*}('InDetDD::BCM_Builder/InDetDD::BCM_Builder')\n",
#        "HITtoRDO {*} GeoModelSvc.Pix... INFO BLM_GeoModel tool retrieved: {*} = {*}('InDetDD::BLM_Builder/InDetDD::BLM_Builder')\n",
#        'HITtoRDO {*} GeoModelSvc.Pix... INFO Service builder tool not specified.\n',
#        'HITtoRDO {*} PixelGeoModel INFO Retrieving Record Sets from database ...\n',
#        'HITtoRDO {*} PixelGeoModel INFO Key = {*} Node = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO ... Record Sets retrieved.\n',
#        'HITtoRDO {*} PixelGeoModel INFO DBM switch = {*} {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Building Pixel Detector\n',
#        'HITtoRDO {*} PixelGeoModel INFO Version: {*}, Name: {*}, Layout: {*}, Code Version: {*}, Description: {*}\n',
#        'HITtoRDO {*} GEOPIXELSERVICES pixel : {*} {*} // {*}\n',
#        'HITtoRDO {*} GEOPIXELSERVICES barrel : {*} {*} // {*} {*}\n',
#        'HITtoRDO {*} GEOPIXELSERVICES endcap : {*} {*} // {*} {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Build detailed stave support description : {*} {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO {*}/SiPl radial shift : {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Module thicknesses : {*} P/N {*} {*} {*} SiPl P/N {*} {*} {*} // {*} {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Pixel modules {*} -> planar/{*} : {*} {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Module length/gap : {*} / {*} {*} -> Stave length : {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO planar/{*}/endblock/NonActive lengths : {*} {*} {*} {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Flex thickness (max) : {*} computed for {*} modules\n',
#        'HITtoRDO {*} PixelGeoModel INFO Omega MidStaveCenterX = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Omega MidStaveAngle = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Omega MidStaveRadius = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Omega EndStaveCenterX = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Omega EndStaveCenterY = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Omega EndStaveAngle = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Omega EndStaveRadius = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Omega Thickness = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO MechanicalStaveWidth = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO MechanicalStaveLength = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO MechanicalStaveOffset = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO StaveModuleOffset = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO MechanicalStaveEndBlockLength = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO FacePlateThick = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO TubeOuterDiam = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO TubeInnerDiam = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO TubeMiddlePos = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO FlexBaseThick = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO FlexLayerThick = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO FlexWidth = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO FlexOffset = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO XOffset / ladder = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO * OMEGA : {*} Stycast {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO *> new material : {*} {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO * FacePlate : {*} Stycast {*} grease : {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO *> new material : {*} {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO * FacePlate : {*} grease\n',
#        'HITtoRDO {*} PixelGeoModel INFO *> new material : {*} {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Flex angle : {*} Flex pos. in Z : ({*},{*},{*}) {*} / ({*},{*},{*}) {*} / ({*},{*},{*}) {*} / ({*},{*},{*}) {*} / ({*},{*},{*}) {*} / ({*},{*},{*}) {*} / ({*},{*},{*}) {*} / ({*},{*},{*}) {*} /\n',
#        'HITtoRDO {*} PixelGeoModel INFO * TUBE : {*} Stycast {*} diam {*} {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO *> new material : {*} {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO IBL EOS : {*} stave length : {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO IBL EOS : {*} Zpos : {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO IBL EOS : {*} Zpos : {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO IBL EOS : {*} length : {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO IBL EOS : {*} srv length : {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Flex half thickness srv : {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO stave xoffset = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO stave yoffset = {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Stave envelop length : {*} -> {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO * LAYER {*} planar/{*} modules : {*} {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Layer IBL / stave ring : {*} radius max {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Layer {*} in/out radius {*} {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO IBL stave ring support\n',
#        'HITtoRDO {*} PixelGeoModel INFO Build IBL stave ring services\n',
#        'HITtoRDO {*} PixelGeoModel INFO Build detailed stave ring support : {*} AC\n',
#        'HITtoRDO {*} PixelGeoModel INFO Build detailed stave ring support - logVol : {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Build detailed stave ring support : {*} AC\n',
#        'HITtoRDO {*} PixelGeoModel INFO Build detailed stave ring support - logVol : {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Build detailed stave ring support : {*} Mid\n',
#        'HITtoRDO {*} PixelGeoModel INFO Build detailed stave ring support - logVol : {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Build IBL I-Flex services\n',
#        'HITtoRDO {*} PixelGeoModel INFO * LAYER {*} planar/{*} modules : {*} {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Layer {*} in/out radius {*} {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO * LAYER {*} planar/{*} modules : {*} {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Layer {*} in/out radius {*} {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO * LAYER {*} planar/{*} modules : {*} {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Layer {*} in/out radius {*} {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Build IBL I-Flex services\n',
#        'HITtoRDO {*} PixelGeoModel INFO Build IBL I-Flex services\n',
#        'HITtoRDO {*} PixelGeoModel INFO Build IBL I-Flex services\n',
#        'HITtoRDO {*} PixelGeoModel INFO Build IBL fwd services - CAD tool design / S. {*} : {*}/{*}\n',
#        'HITtoRDO {*} GeoModelSvc.Pix... INFO Building BCM with Version Tag: {*} at Node: {*}\n',
#        'HITtoRDO {*} GeoModelSvc.Pix... INFO BCM Version: {*} Package Version: {*}\n',
#        'HITtoRDO {*} MemStatAuditor INFO Memory usage has changed after UpdateAddr::BCMParameters preLoadProxy \tvirtual size = {*} MB \tresident set size = {*} MB deltaVsize = {*} MB\n',
#        'HITtoRDO {*} GeoModelSvc.Pix... INFO Building BLM with Version Tag: {*} at Node: {*}\n',
#        'HITtoRDO {*} GeoModelSvc.Pix... INFO BLM Version: {*} Package Version: {*}\n',
#        'HITtoRDO {*} MemStatAuditor INFO Memory usage has changed after UpdateAddr::BLMParameters preLoadProxy \tvirtual size = {*} MB \tresident set size = {*} MB deltaVsize = {*} MB\n',
#        'HITtoRDO {*} PixelDetectorMa... INFO Registering alignment channel with key /Indet/Align/ID, level {*}, with frame global.\n',
#        'HITtoRDO {*} PixelDetectorMa... INFO Registering alignment channel with key /Indet/Align/PIX, level {*}, with frame global.\n',
#        'HITtoRDO {*} PixelDetectorMa... INFO Registering alignment channel with key /Indet/Align/{*}, level {*}, with frame local.\n',
#        'HITtoRDO {*} PixelDetectorMa... INFO Registering alignment channel with key /Indet/Align/{*}, level {*}, with frame local.\n',
#        'HITtoRDO {*} PixelDetectorMa... INFO Registering alignment channel with key /Indet/Align/{*}, level {*}, with frame local.\n',
#        'HITtoRDO {*} PixelDetectorMa... INFO Registering alignment channel with key /Indet/Align/{*}, level {*}, with frame local.\n',
#        'HITtoRDO {*} PixelDetectorMa... INFO Registering alignment channel with key /Indet/Align/{*}, level {*}, with frame local.\n',
#        'HITtoRDO {*} PixelDetectorMa... INFO Registering alignment channel with key /Indet/Align/{*}, level {*}, with frame local.\n',
#        'HITtoRDO {*} PixelDetectorMa... INFO Registering alignment channel with key /Indet/Align/{*}, level {*}, with frame local.\n',
#        'HITtoRDO {*} PixelDetectorMa... INFO Registering alignment channel with key /Indet/Align/{*}, level {*}, with frame local.\n',
#        'HITtoRDO {*} PixelDetectorMa... INFO Registering alignment channel with key /Indet/Align/{*}, level {*}, with frame local.\n',
#        'HITtoRDO {*} PixelDetectorMa... INFO Registering alignment channel with key /Indet/Align/{*}, level {*}, with frame local.\n',
#        'HITtoRDO {*} PixelGeoModel INFO Doing consistency checks.\n',
#        'HITtoRDO {*} PixelGeoModel INFO Number of barrel elements : {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Number of endcap elements : {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Number of endcap elements (DBM) : {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO Total : {*}\n',
#        'HITtoRDO {*} PixelGeoModel INFO MaxHash : {*}\n',
#        'HITtoRDO {*} GeoModelSvc INFO GeoModelSvc.PixelDetectorTool\t SZ= {*} \t Time = {*}\n',
#        'HITtoRDO {*} GeoModelSvc.SCT... INFO Building SCT with Version Tag: {*} at Node: {*}\n',
#        'HITtoRDO {*} GeoModelSvc.SCT... INFO SCT Version: {*} Package Version: {*}\n',
#        'HITtoRDO {*} SCT_IDDetDescrCnv INFO in createObj: {*} a SCT_ID helper object in the detector store\n',
#        'HITtoRDO {*} SCT_ID INFO Initialize from dictionary\n',
#        'HITtoRDO {*} AtlasDetectorID INFO initialize_from_dictionary - OK\n',
#        'HITtoRDO {*} indet {*} {*},{*},{*},{*},{*},{*},{*},{*} {*} {*} {*} {*} {*}\n',
#        'HITtoRDO {*} {*} {*} {*} {*} {*} {*} {*}\n',
#        'HITtoRDO {*} {*} {*},{*},{*} {*} {*} {*} {*} {*}\n',
#        'HITtoRDO {*} {*} {*} f {*} {*} {*} {*}\n',
#        'HITtoRDO {*} {*} {*} {*} {*} {*} {*} {*}\n',
#        'HITtoRDO {*} {*} {*} f {*} {*} {*} {*}\n',
#        'HITtoRDO {*} {*} {*} {*} fffffbffffffffff {*} {*} {*}\n'],
#       dtype=object)

# %%
df.head()['0'].values
# Out:
# array(['------------------------------------------------------------------\n',
#        '[CI_TEST] Starting test script /var/lib/jenkins/workspace/CI-test-driver/ci_test_driver/Trigger_athenaHLT.citest\n',
#        '[CI_TEST] on machine aibuild16-013.cern.ch\n',
#        '[CI_TEST] Wall clock time limit is 30 minutes\n',
#        '------------------------------------------------------------------\n'],
#       dtype=object)

# %%
result.df[result.df['message']==" '/cvmfs/atlas-nightlies.cern.ch/repo/data/data-art/TriggerTest/valid1.410000.PowhegPythiaEvtGen_P2012_ttbar_hdamp172p5_nonallhad.digit.RDO_FTK.e4993_s3214_r11234_d1505/RDO_FTK.17071950._000235.pool.root.1'] (Default: [])\n"]['cleaned'].values
# Out:
# array([" '/cvmfs/atlas-nightlies.cern.ch/repo/data/data-art/TriggerTest/{*}/{*}'] (Default: [])\n"],
#       dtype=object)

# %%
result.in_cluster(result.result,0)
# Out:
# array(['\tAthena_PLATFORM=x86_64-centos7-gcc8-opt\n',
#        '\tAthena_PLATFORM=x86_64-centos7-gcc8-opt\n',
#        '\tAtlasVersion=22.0.10\n', ...,
#        "17:31:14 |-ErrorReadKeyName     = 'ConditionStore+/TRT/Calib/errors2d'\n",
#        "17:31:14 |-ErrorSlopeFolderName = '/TRT/Calib/slopes'\n",
#        "17:31:14 |-ItemList                   = ['EventInfo#*', 'xAOD::EventInfo#*', 'xAOD::EventAuxInfo#*', 'xAOD::EventInfoContainer#*', 'xAOD::EventInfoAuxContainer#*', 'LumiBlockCollection#*', 'RecoTimingObj#EVNTtoHITS_timings', 'RecoTimingObj#HITStoRDO_timings', 'McEventCollection#*', 'TrackRecordCollection#*', 'xAOD::JetContainer#InTimeAntiKt4TruthJets', 'xAOD::JetAuxContainer#InTimeAntiKt4TruthJetsAux.', 'xAOD::JetContainer#OutOfTimeAntiKt4TruthJets', 'xAOD::JetAuxContainer#OutOfTimeAntiKt4TruthJetsAux.', 'CscSimDataCollection#CSC_SDO', 'MuonSimDataCollection#MDT_SDO', 'MuonSimDataCollection#RPC_SDO', 'MuonSimDataCollection#TGC_SDO', 'CaloCalibrationHitContainer#*', 'InDetSimDataCollection#PixelSDO_Map', 'InDetSimDataCollection#SCT_SDO_Map', 'InDetSimDataCollection#TRT_SDO_Map', 'InDetSimDataCollection#BCM_SDO_Map', 'PixelRDO_Container#*', 'InDetBSErrContainer#*', 'SCT_RDO_Container#*', 'TRT_RDO_Container#*', 'TRT_BSIdErrContainer#*', 'TRT_BSErrContainer#*', 'LArRawChannelContainer#*', 'LArDigitContainer#LArDigitContainer_MC_Thinned', 'LArFebErrorSummary#*', 'TileRawChannelContainer#*', 'TileDigitsContainer#TileDigitsFlt', 'TileL2Container#TileL2Cnt', 'CscRawDataContainer#*', 'CscDigitContainer#*', 'MdtCsmContainer#*', 'RpcPadContainer#*', 'TgcRdoContainer#*', 'BCM_RDO_Container#*', 'LArTTL1Container#*', 'TileTTL1Container#*', 'TileDigitsContainer#MuRcvDigitsCnt', 'TileRawChannelContainer#MuRcvRawChCnt', 'TileMuonReceiverContainer#*']\n"],
#       dtype=object)

# %%
result.result.sort_values(by=['cluster_size'], ascending=False)
# Out:
#                                                pattern  \
# 93                     HITtoRDO {*} ---> Daughter: {*}
# 106  HITtoRDO {*}{*}. INFO Time User : {*}= {*} [{*...
# 57   HITtoRDO {*} *Stat* INFO | "{*} {*} | {*} | {*...
# 379  HITtoRDO {*} MemStatAuditor INFO Memory usage ...
# 121  HITtoRDO {*}{*}. INFO Time User : {*}= {*} [{*...
# ..                                                 ...
# 648  HITtoRDO {*} Py:JobProperty :: {*} x-> JobProp...
# 649  HITtoRDO {*} Py:JobProperty :: {*} x-> JobProp...
# 650  HITtoRDO {*} Py:JobProperty :: {*} x-> JobProp...
# 651  HITtoRDO {*} Py:JobPropertyContainer:: {*} Loc...
# 769  HITtoRDO {*} StandardPileUpT... INFO No overla...
#
#                                               sequence  \
# 93   [HITtoRDO, ▁{, *, }, ▁-, -, -, >, ▁Daughter, :...
# 106  [HITtoRDO, ▁{, *, }, {, *, }, ., ▁INFO, ▁Time,...
# 57   [HITtoRDO, ▁{, *, }, ▁*, Stat, *, ▁INFO, ▁|, ▁...
# 379  [HITtoRDO, ▁{, *, }, ▁MemStatAuditor, ▁INFO, ▁...
# 121  [HITtoRDO, ▁{, *, }, {, *, }, ., ▁INFO, ▁Time,...
# ..                                                 ...
# 648  [HITtoRDO, ▁{, *, }, ▁Py, :, JobProperty, ▁:, ...
# 649  [HITtoRDO, ▁{, *, }, ▁Py, :, JobProperty, ▁:, ...
# 650  [HITtoRDO, ▁{, *, }, ▁Py, :, JobProperty, ▁:, ...
# 651  [HITtoRDO, ▁{, *, }, ▁Py, :, JobPropertyContai...
# 769  [HITtoRDO, ▁{, *, }, ▁StandardPileUpT, ., ., ....
#
#                                                indices  cluster_size
# 93   [2392, 2394, 2396, 2398, 2399, 2400, 2402, 240...          2186
# 106  [8315, 6785, 7081, 7272, 7513, 8320, 6771, 677...          1333
# 57   [8979, 8810, 8896, 8899, 8777, 8791, 8981, 859...           691
# 379  [4852, 4851, 6354, 4869, 5630, 5631, 6468, 155...           324
# 121  [8376, 8372, 8375, 8092, 8374, 8087, 8377, 836...           318
# ..                                                 ...           ...
# 648                                             [1080]             1
# 649                                              [977]             1
# 650                                              [982]             1
# 651                                             [1082]             1
# 769                                             [5300]             1
#
# [1307 rows x 4 columns]

# %%
clusters, outliers = result.split_clusters(result.result, 'cluster_size')

# %%
clusters
# Out:
#                                                 pattern  \
# 21                           < REGTEST: {*}{*} '{*}'{*}
# 57    HITtoRDO {*} *Stat* INFO | "{*} {*} | {*} | {*...
# 93                      HITtoRDO {*} ---> Daughter: {*}
# 106   HITtoRDO {*}{*}. INFO Time User : {*}= {*} [{*...
# 111   HITtoRDO {*}{*}:{*} INFO Time User : {*}= {*} ...
# 121   HITtoRDO {*}{*}. INFO Time User : {*}= {*} [{*...
# 188       HITtoRDO {*} CreateComposition: {*} Volume{*}
# 189      HITtoRDO {*} CreateComposition: {*} Volume {*}
# 379   HITtoRDO {*} MemStatAuditor INFO Memory usage ...
# 1189  RDOtoRDOTrigger {*} Py:TriggerMenu.menu.Genera...
# 1199            RDOtoRDOTrigger {*} {*} INFO Define {*}
#
#                                                sequence  \
# 21    [<, ▁REGTEST, :, ▁{, *, }, {, *, }, ▁', {, *, ...
# 57    [HITtoRDO, ▁{, *, }, ▁*, Stat, *, ▁INFO, ▁|, ▁...
# 93    [HITtoRDO, ▁{, *, }, ▁-, -, -, >, ▁Daughter, :...
# 106   [HITtoRDO, ▁{, *, }, {, *, }, ., ▁INFO, ▁Time,...
# 111   [HITtoRDO, ▁{, *, }, {, *, }, :, {, *, }, ▁INF...
# 121   [HITtoRDO, ▁{, *, }, {, *, }, ., ▁INFO, ▁Time,...
# 188   [HITtoRDO, ▁{, *, }, ▁CreateComposition, :, ▁{...
# 189   [HITtoRDO, ▁{, *, }, ▁CreateComposition, :, ▁{...
# 379   [HITtoRDO, ▁{, *, }, ▁MemStatAuditor, ▁INFO, ▁...
# 1189  [RDOtoRDOTrigger, ▁{, *, }, ▁Py, :, TriggerMen...
# 1199  [RDOtoRDOTrigger, ▁{, *, }, ▁{, *, }, ▁INFO, ▁...
#
#                                                 indices  cluster_size
# 21    [310, 320, 330, 340, 350, 360, 370, 380, 390, ...           125
# 57    [8979, 8810, 8896, 8899, 8777, 8791, 8981, 859...           691
# 93    [2392, 2394, 2396, 2398, 2399, 2400, 2402, 240...          2186
# 106   [8315, 6785, 7081, 7272, 7513, 8320, 6771, 677...          1333
# 111   [6782, 7082, 7087, 8138, 7809, 8112, 7753, 769...           105
# 121   [8376, 8372, 8375, 8092, 8374, 8087, 8377, 836...           318
# 188   [2721, 2740, 2719, 2545, 2547, 2841, 2839, 271...           138
# 189   [2494, 2501, 2653, 2660, 2706, 2874, 2877, 288...           119
# 379   [4852, 4851, 6354, 4869, 5630, 5631, 6468, 155...           324
# 1189  [9751, 9752, 9753, 9754, 9755, 9756, 9757, 975...           249
# 1199  [9580, 9581, 9582, 9583, 9584, 9585, 9586, 958...           150

# %%
clusters.sort_values(by=['cluster_size'],ascending=False).to_csv('undrus_results.csv')

# %%
result.postprocessing()

# %%
result.result_pp
# Out:
#                                                 pattern  \
# 186    HITtoRDO *{*} INFO Time User : Tot= * [{*}] #= *
# 197                         HITtoRDO * --> Daughter:{*}
# 196                         HITtoRDO * ---> Daughter: *
# 191   HITtoRDO **Stat* INFO | "* * | * | * | * | * |...
# 183   HITtoRDO * INFO Time User : Tot= * [{*}] Ave/M...
# ...                                                 ...
# 674   HITtoRDO * Py:LArOFCCondAlg INFO setup for no ...
# 675   HITtoRDO * Py:LArOFCCondAlg INFO entering LArO...
# 676   HITtoRDO * Py:LArPileUpToolDefault: INFO ---- ...
# 677   HITtoRDO * Py:LArPileUpToolDefault: INFO do no...
# 1131                                   which Reco_tf.py
#
#                                                 indices  cluster_size
# 186   [6344, 6592, 8382, 6343, 6789, 7085, 7276, 831...          1314
# 197   [2724, 2743, 2745, 2750, 2751, 2746, 2747, 274...          1150
# 196   [2411, 2412, 2413, 2482, 2483, 2497, 2499, 250...          1036
# 191   [8937, 8827, 8830, 8998, 9009, 9014, 9063, 848...           691
# 183   [8002, 8003, 8011, 8012, 8037, 8044, 8045, 807...           304
# ...                                                 ...           ...
# 674                                              [1153]             1
# 675                                              [1152]             1
# 676                                              [1100]             1
# 677                                              [1114]             1
# 1131                                              [807]             1
#
# [1132 rows x 3 columns]

# %%
result.in_cluster(15)
# Out:
# ["Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
# ...
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found",
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= 1 && JobStatus == 1 )' evaluated to TRUE  ; Worker canceled by harvester due to held too long or not found"]

# %%
result.common.patterns_stats['pattern'].values.tolist()
# Out:
# ['Payload execution error: returned non-zero',
#  'JOB id=* not found',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@*, queue *',
#  'submission failed: Exception OSError: [Errno *] No space left on device',
#  "Condor HoldReason: HTCondor-CE held job due to no matching routes, route job limit, or route failure threshold; see 'HTCondor-CE Troubleshooting Guide'; Worker canceled by harvester due to held too long or not found",
#  'LRMS error: (*) Job finished with unknown exit code',
#  'LRMS error: (*) job killed: vmem',
#  'Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * * failed.: globus_l_gfs_file_open failed. * Unable to open file /var/cream_sandbox/prdatlas/*',
#  '* not submitted due to incomplete data of the worker',
#  'Condor HoldReason: Unspecified gridmanager error; Worker canceled by harvester due to held too long or not found',
#  'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/*/*/* Failed to prepare source: Resource temporarily unavailable: File requests h',
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '(* =?= undefined) || (* =?= undefined) || ((time()> *) && JobStatus =!= * && JobStatus =!= *) || (RoutedBy =?= null && JobU",
#  'LRMS error: (*) Job missing from SLURM',
#  'Condor HoldReason: CREAM error: Job has been terminated (got SIGXCPU); reason=*; Worker canceled by harvester due to held too long or not found',
#  'LRMS error: (*) Job timeout',
#  "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= * && JobStatus == * )' evaluated to TRUE; Worker canceled by harvester due to held too long or not found",
#  'Condor HoldReason: ERROR: Failed to submit job; Worker canceled by harvester due to held too long or not found',
#  'Condor HoldReason: Job not found; Worker canceled by harvester due to held too long or not found',
#  'LRMS error: (*) job killed: wall',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user *@*',
#  'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://*/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#  'Condor HoldReason: CREAM error: CREAM_Job_Register Error: MethodName=[jobRegister] ErrorCode=[*] Description=[The CREAM service cannot accept jobs at the moment] FaultCause=[Submissions are disabled!] Timestamp=[Tue * Dec * *]; Worker canceled',
#  'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/castor/cern.ch/grid/atlas/rucio/derived/*/physics_Main/*/*/*',
#  'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]; Worker canceled by harveste',
#  'Condor HoldReason: CREAM error: reason=*; Worker canceled by harvester due to held too long or not found',
#  'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://*/ce-cream/services/gridsite-delegation] - FaultCode=[',
#  'Condor HoldReason: CREAM error: Cannot move ISB (retry_copy ${globus_transfer_cmd} gsiftp://*/var/cream_sandbox/atlas/*',
#  'LRMS error: (*) Job failed',
#  'LRMS error: (*) Job failed with exit code *',
#  'Condor HoldReason: Failed to start GAHP; Worker canceled by harvester due to held too long or not found',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user *@lcgceatlas.dnp.fmph',
#  'LRMS error: (*) RemoveReason: Job removed by SYSTEM_PERIODIC_REMOVE due to exceeding the requested memory.',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from *) N/A (jobId = *); Worker canceled by harvest',
#  "Failed to create a JOB; HTTPSConnectionPool(host='*', port=*): Max retries exceeded with url: /apis/batch/*/namespaces/default/jobs (Caused by NewConnectionError('<* object at *>: Failed to establish a new connection: [Errno *] Connection refused',))",
#  'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/tape/atlasmctape/*/AOD/*/*',
#  'LRMS error: (*) ExitReason: died on signal * (Hangup)',
#  'Condor HoldReason: CREAM error: CREAM_Job_Register Error: MethodName=[jobRegister] ErrorCode=[*] Description=[The CREAM service cannot accept jobs at the moment] FaultCause=[Threshold for FTP Connection: * => Detected value for FTP Connection: *\\n\\n] Tim',
#  'Condor HoldReason: CREAM error: Cannot move ISB (retry_copy ${globus_transfer_cmd} gsiftp://*/var/cream_sandbox/edguser/*',
#  'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Connection to service [https://*/ce-cream/services/*] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[S',
#  "LRMS error: (*) RemoveReason: The system macro SYSTEM_PERIODIC_REMOVE expression '( RemoteWallClockTime> * * * * *) || (RemoteSysCpu + RemoteUserCpu> * * * * *) || (( JobStatus == * && (CurrentTime - EnteredCurrentStatus) > * * *) ) ||",
#  '*        tmpdM_Hhx+       long    usatlas        *  COMPLETED      * ',
#  'LRMS error: (*) Job missing from SLURM, exitcode recovered from session directory',
#  'Failed in data staging: Failed checking source replica root://*//pnfs/pic.es/data/atlas/tape/atlasmctape//*/HITS/*/*',
#  'LRMS error: (*) RemoveReason: Job removed by SYSTEM_PERIODIC_REMOVE due to job running more than once.',
#  'Condor HoldReason: CREAM error: reason=* /var/lib/slurm-llnl/slurmd/*/slurm_script: line * ./* No such file or directory  ; Worker canceled by harvester due to held too long or not found']
