# %% [markdown]
# # Clusterlogs Notebook

# %%
import pandas as pd
from clusterlogs import multistage

# %% [markdown]
# ### 1. Download data from file and create pandas DataFrame with index

# %%
df = pd.read_csv('samples/fts_mess_panda.csv')

# %%
df
# Out:
#        Unnamed: 0                                            message  count  \
# 0               0  DESTINATION MAKE_PARENT srm-ifce err: Permissi...     27
# 1               1  TRANSFER  globus_ftp_client: the server respon...   1467
# 2               2  TRANSFER  globus_ftp_client: the server respon...      2
# 3               3  TRANSFER  globus_ftp_client: the server respon...     34
# 4               4  TRANSFER  globus_ftp_client: the server respon...      9
# ...           ...                                                ...    ...
# 22787       22787  TRANSFER  globus_ftp_client: the server respon...      1
# 22788       22788  TRANSFER  globus_ftp_client: the server respon...      1
# 22789       22789  TRANSFER CHECKSUM MISMATCH USER_DEFINE and SRC...      3
# 22790       22790  TRANSFER  globus_ftp_client: the server respon...      1
# 22791       22791  TRANSFER  globus_ftp_client: the server respon...      1
#
#           id
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
# ...      ...
# 22787  22788
# 22788  22789
# 22789  22790
# 22790  22791
# 22791  22792
#
# [22792 rows x 4 columns]
#        Unnamed: 0                                            message  count  \
# 0               0  DESTINATION MAKE_PARENT srm-ifce err: Permissi...     27
# 1               1  TRANSFER  globus_ftp_client: the server respon...   1467
# 2               2  TRANSFER  globus_ftp_client: the server respon...      2
# 3               3  TRANSFER  globus_ftp_client: the server respon...     34
# 4               4  TRANSFER  globus_ftp_client: the server respon...      9
# ...           ...                                                ...    ...
# 22787       22787  TRANSFER  globus_ftp_client: the server respon...      1
# 22788       22788  TRANSFER  globus_ftp_client: the server respon...      1
# 22789       22789  TRANSFER CHECKSUM MISMATCH USER_DEFINE and SRC...      3
# 22790       22790  TRANSFER  globus_ftp_client: the server respon...      1
# 22791       22791  TRANSFER  globus_ftp_client: the server respon...      1
#
#           id
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
# ...      ...
# 22787  22788
# 22788  22789
# 22789  22790
# 22790  22791
# 22791  22792
#
# [22792 rows x 4 columns]

# %%
df = pd.read_csv('test/test_data.csv', index_col=0)

# %%
df = pd.read_csv('samples/fts_mess_panda.csv', index_col=0).set_index('id')

# %%
df.head()

# %% [markdown]
# ### 2. Initialize clusterization pipeline

# %% [raw]
# Required parameters are:
# - df - pandas DataFrame with error messages
# - target - name of a column with error messages
#
# Not required parameters are cluster_settings. If not defined - the default values are used.
# Note: It's better to use for big data samples with a vocabulary of more than 1000 tokens.
#
# CLUSTERING_DEFAULTS = {"tokenizer": "nltk",
#                        "w2v_size": "auto",
#                        "w2v_window": 5,
#                        "min_samples": 1}
#
# But you can define these parameters. For example,
#
# clustering_parameters = {'tokenizer':'nltk',
#                          'w2v_size': 200,
#                          'w2v_window': 5,
#                          'min_samples': 1}
#
# cluster = pipeline.ml_clustering(df, target, clustering_parameters)

# %%
target = 'message'

# %%
cluster = multistage.exec(df, target, 'fts.model')

# %%
cluster = pipeline.ml_clustering(df, target, mode='create', model_name='test/harvester_test.model')

# %%
cluster = pipeline.ml_clustering(df, target, mode='create', model_name='test/fts.model')

# %% [markdown]
# ### 3. Execute clusterization pipeline

# %%
cluster.process()

# %%
cluster._1.timings
# Out:
# {'data_preparation': 0.9792,
#  'tokenization': 1.3482,
#  'tokens_vectorization': 2.7637,
#  'sentence_vectorization': 7.8331,
#  'dimensionality_reduction': 0.0959,
#  'kneighbors': 1.1853,
#  'epsilon_search': 0.4355,
#  'dbscan': 2.0652,
#  'extract_patterns': 5.2347,
#  'process': 21.8448}
# {'data_preparation': 0.9792,
#  'tokenization': 1.3482,
#  'tokens_vectorization': 2.7637,
#  'sentence_vectorization': 7.8331,
#  'dimensionality_reduction': 0.0959,
#  'kneighbors': 1.1853,
#  'epsilon_search': 0.4355,
#  'dbscan': 2.0652,
#  'extract_patterns': 5.2347,
#  'process': 21.8448}

# %%
cluster.big_clusters_1
# Out:
#    cluster_name  cluster_size  \
# 27           27          2135
# 15           15          1325
# 36           36          1260
# 31           31           747
# 4             4           696
# 8             8           682
# 7             7           656
# 23           23           656
# 17           17           636
# 2             2           633
# 9             9           633
# 5             5           630
# 3             3           622
# 47           47           620
# 14           14           614
# 29           29           597
# 0             0           571
# 33           33           569
# 78           78           530
# 11           11           494
# 28           28           462
# 37           37           371
# 71           71           332
# 18           18           309
# 20           20           232
# 19           19           227
# 61           61           222
# 43           43           191
# 54           54           190
# 10           10           175
# 38           38           157
# 45           45           147
# 82           82           143
# 64           64           131
# 67           67           113
# 84           84           105
#
#                                               pattern  \
# 27  TRANSFER globus_ftp_client: the server respond...
# 15  TRANSFER globus_ftp_client: the server respond...
# 36  SOURCE CHECKSUM MISMATCH User defined checksum...
# 31  TRANSFER CHECKSUM MISMATCH USER_DEFINE and SRC...
# 4   TRANSFER globus_ftp_client: the server respond...
# 8   TRANSFER globus_ftp_client: the server respond...
# 7   TRANSFER globus_ftp_client: the server respond...
# 23  TRANSFER globus_ftp_client: the server respond...
# 17  TRANSFER globus_ftp_client: the server respond...
# 2   TRANSFER globus_ftp_client: the server respond...
# 9   TRANSFER globus_ftp_client: the server respond...
# 5   TRANSFER globus_ftp_client: the server respond...
# 3   TRANSFER globus_ftp_client: the server respond...
# 47  TRANSFER globus_ftp_client: the server respond...
# 14  TRANSFER globus_ftp_client: the server respond...
# 29  TRANSFER globus_ftp_client: the server respond...
# 0   DESTINATION MAKE_PARENT srm-ifce err: Permissi...
# 33  TRANSFER globus_ftp_client: the server respond...
# 78  TRANSFER globus_ftp_client: the server respond...
# 11  TRANSFER globus_ftp_client: the server respond...
# 28  TRANSFER globus_ftp_client: the server respond...
# 37  TRANSFER globus_ftp_client: the server respond...
# 71  TRANSFER CHECKSUM MISMATCH Source and destinat...
# 18  DESTINATION MAKE_PARENT srm-ifce err: Permissi...
# 20  DESTINATION MAKE_PARENT srm-ifce err: Permissi...
# 19  srm-ifce err: Communication error on send, err...
# 61  TRANSFER globus_ftp_client: the server respond...
# 43  TRANSFER globus_ftp_client: the server respond...
# 54  TRANSFER globus_ftp_client: the server respond...
# 10  DESTINATION MAKE_PARENT srm-ifce err: Permissi...
# 38  TRANSFER globus_ftp_client: the server respond...
# 45  TRANSFER globus_ftp_client: the server respond...
# 82  srm-ifce err: Communication error on send, err...
# 64  srm-ifce err: Communication error on send, err...
# 67  DESTINATION SRM_PUTDONE call to srm_ifce error...
# 84  Error reported from srm_ifce : 2 [SE][Ls][SRM_...
#
#                                              sequence  mean_similarity  \
# 27  [TRANSFER, globus_ftp_client:, the, server, re...             0.99
# 15  [TRANSFER, globus_ftp_client:, the, server, re...             0.97
# 36  [SOURCE, CHECKSUM, MISMATCH, User, defined, ch...             0.93
# 31  [TRANSFER, CHECKSUM, MISMATCH, USER_DEFINE, an...             0.91
# 4   [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 8   [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 7   [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 23  [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 17  [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 2   [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 9   [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 5   [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 3   [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 47  [TRANSFER, globus_ftp_client:, the, server, re...             0.99
# 14  [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 29  [TRANSFER, globus_ftp_client:, the, server, re...             0.97
# 0   [DESTINATION, MAKE_PARENT, srm-ifce, err:, Per...             0.96
# 33  [TRANSFER, globus_ftp_client:, the, server, re...             0.97
# 78  [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 11  [TRANSFER, globus_ftp_client:, the, server, re...             0.99
# 28  [TRANSFER, globus_ftp_client:, the, server, re...             0.97
# 37  [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 71  [TRANSFER, CHECKSUM, MISMATCH, Source, and, de...             0.92
# 18  [DESTINATION, MAKE_PARENT, srm-ifce, err:, Per...             0.96
# 20  [DESTINATION, MAKE_PARENT, srm-ifce, err:, Per...             0.96
# 19  [srm-ifce, err:, Communication, error, on, sen...             0.95
# 61  [TRANSFER, globus_ftp_client:, the, server, re...             0.99
# 43  [TRANSFER, globus_ftp_client:, the, server, re...             0.97
# 54  [TRANSFER, globus_ftp_client:, the, server, re...             0.97
# 10  [DESTINATION, MAKE_PARENT, srm-ifce, err:, Per...             0.96
# 38  [TRANSFER, globus_ftp_client:, the, server, re...             0.99
# 45  [TRANSFER, globus_ftp_client:, the, server, re...             0.97
# 82  [srm-ifce, err:, Communication, error, on, sen...             0.95
# 64  [srm-ifce, err:, Communication, error, on, sen...             0.92
# 67  [DESTINATION, SRM_PUTDONE, call, to, srm_ifce,...             0.95
# 84  [Error, reported, from, srm_ifce, :, 2, [SE][L...             0.96
#
#     std_similarity                                            indices
# 27            0.00  [52, 61, 67, 68, 73, 88, 91, 98, 103, 109, 110...
# 15            0.00  [25, 42, 93, 99, 113, 117, 129, 195, 216, 295,...
# 36            0.00  [77, 80, 85, 102, 114, 132, 133, 175, 177, 196...
# 31            0.00  [65, 75, 82, 96, 130, 134, 162, 221, 223, 232,...
# 4             0.00  [4, 15, 17, 53, 58, 124, 149, 189, 261, 279, 2...
# 8             0.00  [9, 12, 16, 37, 46, 55, 62, 141, 145, 161, 193...
# 7             0.00  [8, 19, 30, 78, 138, 148, 284, 344, 364, 407, ...
# 23            0.00  [44, 50, 57, 81, 125, 136, 146, 156, 159, 166,...
# 17            0.00  [31, 139, 160, 167, 179, 227, 273, 281, 393, 4...
# 2             0.00  [2, 40, 41, 47, 135, 164, 171, 173, 277, 278, ...
# 9             0.00  [10, 11, 48, 64, 79, 163, 181, 188, 197, 240, ...
# 5             0.00  [5, 24, 150, 395, 402, 404, 447, 521, 524, 544...
# 3             0.00  [3, 6, 56, 66, 126, 137, 165, 185, 268, 287, 3...
# 47            0.00  [119, 220, 224, 237, 241, 314, 353, 383, 420, ...
# 14            0.00  [22, 28, 63, 152, 253, 258, 259, 263, 301, 309...
# 29            0.00  [59, 83, 101, 122, 184, 186, 204, 213, 239, 24...
# 0             0.00  [0, 14, 23, 29, 32, 43, 144, 153, 169, 170, 26...
# 33            0.00  [72, 94, 111, 121, 212, 215, 340, 343, 352, 36...
# 78            0.00  [291, 319, 320, 338, 339, 355, 373, 561, 575, ...
# 11            0.00  [18, 71, 107, 206, 257, 313, 451, 510, 585, 62...
# 28            0.00  [54, 90, 105, 214, 230, 368, 371, 401, 458, 46...
# 37            0.00  [87, 243, 322, 379, 680, 697, 699, 746, 772, 9...
# 71            0.00  [238, 246, 297, 316, 358, 452, 569, 633, 891, ...
# 18            0.00  [33, 36, 69, 172, 176, 267, 274, 324, 443, 445...
# 20            0.00  [35, 86, 178, 202, 341, 425, 755, 880, 1000, 1...
# 19            0.00  [34, 264, 331, 444, 480, 596, 627, 640, 650, 9...
# 61            0.00  [207, 245, 378, 465, 785, 977, 1227, 1234, 128...
# 43            0.00  [106, 349, 476, 574, 774, 912, 1027, 1145, 115...
# 54            0.00  [154, 242, 312, 334, 491, 495, 562, 577, 676, ...
# 10            0.00  [13, 27, 142, 270, 276, 504, 607, 617, 628, 84...
# 38            0.00  [89, 147, 254, 255, 453, 576, 670, 687, 1028, ...
# 45            0.00  [115, 369, 436, 441, 696, 741, 984, 1426, 1521...
# 82            0.00  [327, 597, 884, 1086, 1272, 1411, 1511, 1546, ...
# 64            0.01  [225, 672, 749, 904, 1036, 1415, 1726, 1793, 1...
# 67            0.00  [233, 598, 810, 850, 1191, 1311, 1728, 1789, 2...
# 84            0.00  [332, 547, 578, 914, 1010, 1140, 1776, 2032, 2...
#    cluster_name  cluster_size  \
# 27           27          2135
# 15           15          1325
# 36           36          1260
# 31           31           747
# 4             4           696
# 8             8           682
# 7             7           656
# 23           23           656
# 17           17           636
# 2             2           633
# 9             9           633
# 5             5           630
# 3             3           622
# 47           47           620
# 14           14           614
# 29           29           597
# 0             0           571
# 33           33           569
# 78           78           530
# 11           11           494
# 28           28           462
# 37           37           371
# 71           71           332
# 18           18           309
# 20           20           232
# 19           19           227
# 61           61           222
# 43           43           191
# 54           54           190
# 10           10           175
# 38           38           157
# 45           45           147
# 82           82           143
# 64           64           131
# 67           67           113
# 84           84           105
#
#                                               pattern  \
# 27  TRANSFER globus_ftp_client: the server respond...
# 15  TRANSFER globus_ftp_client: the server respond...
# 36  SOURCE CHECKSUM MISMATCH User defined checksum...
# 31  TRANSFER CHECKSUM MISMATCH USER_DEFINE and SRC...
# 4   TRANSFER globus_ftp_client: the server respond...
# 8   TRANSFER globus_ftp_client: the server respond...
# 7   TRANSFER globus_ftp_client: the server respond...
# 23  TRANSFER globus_ftp_client: the server respond...
# 17  TRANSFER globus_ftp_client: the server respond...
# 2   TRANSFER globus_ftp_client: the server respond...
# 9   TRANSFER globus_ftp_client: the server respond...
# 5   TRANSFER globus_ftp_client: the server respond...
# 3   TRANSFER globus_ftp_client: the server respond...
# 47  TRANSFER globus_ftp_client: the server respond...
# 14  TRANSFER globus_ftp_client: the server respond...
# 29  TRANSFER globus_ftp_client: the server respond...
# 0   DESTINATION MAKE_PARENT srm-ifce err: Permissi...
# 33  TRANSFER globus_ftp_client: the server respond...
# 78  TRANSFER globus_ftp_client: the server respond...
# 11  TRANSFER globus_ftp_client: the server respond...
# 28  TRANSFER globus_ftp_client: the server respond...
# 37  TRANSFER globus_ftp_client: the server respond...
# 71  TRANSFER CHECKSUM MISMATCH Source and destinat...
# 18  DESTINATION MAKE_PARENT srm-ifce err: Permissi...
# 20  DESTINATION MAKE_PARENT srm-ifce err: Permissi...
# 19  srm-ifce err: Communication error on send, err...
# 61  TRANSFER globus_ftp_client: the server respond...
# 43  TRANSFER globus_ftp_client: the server respond...
# 54  TRANSFER globus_ftp_client: the server respond...
# 10  DESTINATION MAKE_PARENT srm-ifce err: Permissi...
# 38  TRANSFER globus_ftp_client: the server respond...
# 45  TRANSFER globus_ftp_client: the server respond...
# 82  srm-ifce err: Communication error on send, err...
# 64  srm-ifce err: Communication error on send, err...
# 67  DESTINATION SRM_PUTDONE call to srm_ifce error...
# 84  Error reported from srm_ifce : 2 [SE][Ls][SRM_...
#
#                                              sequence  mean_similarity  \
# 27  [TRANSFER, globus_ftp_client:, the, server, re...             0.99
# 15  [TRANSFER, globus_ftp_client:, the, server, re...             0.97
# 36  [SOURCE, CHECKSUM, MISMATCH, User, defined, ch...             0.93
# 31  [TRANSFER, CHECKSUM, MISMATCH, USER_DEFINE, an...             0.91
# 4   [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 8   [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 7   [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 23  [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 17  [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 2   [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 9   [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 5   [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 3   [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 47  [TRANSFER, globus_ftp_client:, the, server, re...             0.99
# 14  [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 29  [TRANSFER, globus_ftp_client:, the, server, re...             0.97
# 0   [DESTINATION, MAKE_PARENT, srm-ifce, err:, Per...             0.96
# 33  [TRANSFER, globus_ftp_client:, the, server, re...             0.97
# 78  [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 11  [TRANSFER, globus_ftp_client:, the, server, re...             0.99
# 28  [TRANSFER, globus_ftp_client:, the, server, re...             0.97
# 37  [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 71  [TRANSFER, CHECKSUM, MISMATCH, Source, and, de...             0.92
# 18  [DESTINATION, MAKE_PARENT, srm-ifce, err:, Per...             0.96
# 20  [DESTINATION, MAKE_PARENT, srm-ifce, err:, Per...             0.96
# 19  [srm-ifce, err:, Communication, error, on, sen...             0.95
# 61  [TRANSFER, globus_ftp_client:, the, server, re...             0.99
# 43  [TRANSFER, globus_ftp_client:, the, server, re...             0.97
# 54  [TRANSFER, globus_ftp_client:, the, server, re...             0.97
# 10  [DESTINATION, MAKE_PARENT, srm-ifce, err:, Per...             0.96
# 38  [TRANSFER, globus_ftp_client:, the, server, re...             0.99
# 45  [TRANSFER, globus_ftp_client:, the, server, re...             0.97
# 82  [srm-ifce, err:, Communication, error, on, sen...             0.95
# 64  [srm-ifce, err:, Communication, error, on, sen...             0.92
# 67  [DESTINATION, SRM_PUTDONE, call, to, srm_ifce,...             0.95
# 84  [Error, reported, from, srm_ifce, :, 2, [SE][L...             0.96
#
#     std_similarity                                            indices
# 27            0.00  [52, 61, 67, 68, 73, 88, 91, 98, 103, 109, 110...
# 15            0.00  [25, 42, 93, 99, 113, 117, 129, 195, 216, 295,...
# 36            0.00  [77, 80, 85, 102, 114, 132, 133, 175, 177, 196...
# 31            0.00  [65, 75, 82, 96, 130, 134, 162, 221, 223, 232,...
# 4             0.00  [4, 15, 17, 53, 58, 124, 149, 189, 261, 279, 2...
# 8             0.00  [9, 12, 16, 37, 46, 55, 62, 141, 145, 161, 193...
# 7             0.00  [8, 19, 30, 78, 138, 148, 284, 344, 364, 407, ...
# 23            0.00  [44, 50, 57, 81, 125, 136, 146, 156, 159, 166,...
# 17            0.00  [31, 139, 160, 167, 179, 227, 273, 281, 393, 4...
# 2             0.00  [2, 40, 41, 47, 135, 164, 171, 173, 277, 278, ...
# 9             0.00  [10, 11, 48, 64, 79, 163, 181, 188, 197, 240, ...
# 5             0.00  [5, 24, 150, 395, 402, 404, 447, 521, 524, 544...
# 3             0.00  [3, 6, 56, 66, 126, 137, 165, 185, 268, 287, 3...
# 47            0.00  [119, 220, 224, 237, 241, 314, 353, 383, 420, ...
# 14            0.00  [22, 28, 63, 152, 253, 258, 259, 263, 301, 309...
# 29            0.00  [59, 83, 101, 122, 184, 186, 204, 213, 239, 24...
# 0             0.00  [0, 14, 23, 29, 32, 43, 144, 153, 169, 170, 26...
# 33            0.00  [72, 94, 111, 121, 212, 215, 340, 343, 352, 36...
# 78            0.00  [291, 319, 320, 338, 339, 355, 373, 561, 575, ...
# 11            0.00  [18, 71, 107, 206, 257, 313, 451, 510, 585, 62...
# 28            0.00  [54, 90, 105, 214, 230, 368, 371, 401, 458, 46...
# 37            0.00  [87, 243, 322, 379, 680, 697, 699, 746, 772, 9...
# 71            0.00  [238, 246, 297, 316, 358, 452, 569, 633, 891, ...
# 18            0.00  [33, 36, 69, 172, 176, 267, 274, 324, 443, 445...
# 20            0.00  [35, 86, 178, 202, 341, 425, 755, 880, 1000, 1...
# 19            0.00  [34, 264, 331, 444, 480, 596, 627, 640, 650, 9...
# 61            0.00  [207, 245, 378, 465, 785, 977, 1227, 1234, 128...
# 43            0.00  [106, 349, 476, 574, 774, 912, 1027, 1145, 115...
# 54            0.00  [154, 242, 312, 334, 491, 495, 562, 577, 676, ...
# 10            0.00  [13, 27, 142, 270, 276, 504, 607, 617, 628, 84...
# 38            0.00  [89, 147, 254, 255, 453, 576, 670, 687, 1028, ...
# 45            0.00  [115, 369, 436, 441, 696, 741, 984, 1426, 1521...
# 82            0.00  [327, 597, 884, 1086, 1272, 1411, 1511, 1546, ...
# 64            0.01  [225, 672, 749, 904, 1036, 1415, 1726, 1793, 1...
# 67            0.00  [233, 598, 810, 850, 1191, 1311, 1728, 1789, 2...
# 84            0.00  [332, 547, 578, 914, 1010, 1140, 1776, 2032, 2...

# %%
cluster.big_clusters
# Out:
#    cluster_name  cluster_size  \
# 4             4          6467
# 1             1          2613
# 0             0          2357
# 6             6          1888
# 5             5          1394
# 7             7          1347
# 2             2          1262
# 3             3           750
# 11           11           584
# 8             8           532
# 14           14           424
# 9             9           390
# 10           10           341
# 15           15           249
# 12           12           203
# 17           17           156
# 13           13           154
#
#                                               pattern  \
# 4   TRANSFER globus_ftp_client: the server respond...
# 1   TRANSFER globus_ftp_client: the server respond...
# 0   TRANSFER globus_ftp_client: the server respond...
# 6   DESTINATION MAKE_PARENT srm-ifce err: Permissi...
# 5   TRANSFER globus_ftp_client: the server respond...
# 7   TRANSFER globus_ftp_client: the server respond...
# 2   SOURCE CHECKSUM MISMATCH User defined checksum...
# 3   TRANSFER CHECKSUM MISMATCH USER_DEFINE and che...
# 11  srm-ifce err: Communication error on send, err...
# 8   TRANSFER globus_ftp_client: the server respond...
# 14  Error reported from srm_ifce : 2 [SE][Ls][SRM_...
# 9   TRANSFER globus_ftp_client: the server respond...
# 10  TRANSFER CHECKSUM MISMATCH and destination che...
# 15  TRANSFER globus_ftp_client: the server respond...
# 12  srm-ifce err: Communication error on send, err...
# 17  DESTINATION SRM_PUTDONE Error on the surl whil...
# 13  DESTINATION SRM_PUTDONE call to srm_ifce error...
#
#                                              sequence  mean_similarity  \
# 4   [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 1   [TRANSFER, globus_ftp_client:, the, server, re...             0.81
# 0   [TRANSFER, globus_ftp_client:, the, server, re...             0.99
# 6   [DESTINATION, MAKE_PARENT, srm-ifce, err:, Per...             0.95
# 5   [TRANSFER, globus_ftp_client:, the, server, re...             0.78
# 7   [TRANSFER, globus_ftp_client:, the, server, re...             0.84
# 2   [SOURCE, CHECKSUM, MISMATCH, User, defined, ch...             0.93
# 3   [TRANSFER, CHECKSUM, MISMATCH, USER_DEFINE, an...             0.88
# 11  [srm-ifce, err:, Communication, error, on, sen...             0.86
# 8   [TRANSFER, globus_ftp_client:, the, server, re...             0.92
# 14  [Error, reported, from, srm_ifce, :, 2, [SE][L...             0.95
# 9   [TRANSFER, globus_ftp_client:, the, server, re...             0.93
# 10  [TRANSFER, CHECKSUM, MISMATCH, and, destinatio...             0.87
# 15  [TRANSFER, globus_ftp_client:, the, server, re...             0.90
# 12  [srm-ifce, err:, Communication, error, on, sen...             0.87
# 17  [DESTINATION, SRM_PUTDONE, Error, on, the, sur...             0.81
# 13  [DESTINATION, SRM_PUTDONE, call, to, srm_ifce,...             0.91
#
#     std_similarity                                            indices
# 4             0.00  [2, 3, 4, 5, 6, 8, 9, 10, 11, 12, 15, 16, 17, ...
# 1             0.04  [25, 42, 54, 59, 83, 90, 93, 99, 101, 105, 113...
# 0             0.00  [52, 61, 67, 68, 73, 88, 91, 98, 103, 109, 110...
# 6             0.02  [0, 7, 13, 14, 21, 23, 27, 29, 32, 33, 35, 36,...
# 5             0.06  [18, 60, 71, 89, 107, 108, 119, 147, 206, 220,...
# 7             0.09  [70, 72, 84, 94, 106, 111, 115, 121, 190, 212,...
# 2             0.00  [77, 80, 85, 102, 114, 132, 133, 175, 177, 196...
# 3             0.03  [65, 75, 82, 96, 130, 134, 162, 221, 223, 232,...
# 11            0.03  [34, 51, 191, 264, 327, 331, 444, 480, 557, 59...
# 8             0.05  [291, 319, 320, 338, 339, 355, 373, 561, 575, ...
# 14            0.02  [26, 187, 201, 256, 332, 333, 342, 381, 539, 5...
# 9             0.02  [87, 243, 322, 379, 680, 697, 699, 746, 772, 9...
# 10            0.01  [238, 246, 297, 316, 358, 452, 569, 633, 891, ...
# 15            0.02  [92, 118, 432, 563, 564, 579, 799, 801, 812, 8...
# 12            0.02  [225, 672, 749, 882, 904, 997, 1036, 1371, 141...
# 17            0.01  [74, 76, 104, 228, 229, 449, 494, 531, 962, 10...
# 13            0.02  [217, 233, 421, 598, 810, 850, 1191, 1311, 140...
#    cluster_name  cluster_size  \
# 4             4          6467
# 1             1          2613
# 0             0          2357
# 6             6          1888
# 5             5          1394
# 7             7          1347
# 2             2          1262
# 3             3           750
# 11           11           584
# 8             8           532
# 14           14           424
# 9             9           390
# 10           10           341
# 15           15           249
# 12           12           203
# 17           17           156
# 13           13           154
#
#                                               pattern  \
# 4   TRANSFER globus_ftp_client: the server respond...
# 1   TRANSFER globus_ftp_client: the server respond...
# 0   TRANSFER globus_ftp_client: the server respond...
# 6   DESTINATION MAKE_PARENT srm-ifce err: Permissi...
# 5   TRANSFER globus_ftp_client: the server respond...
# 7   TRANSFER globus_ftp_client: the server respond...
# 2   SOURCE CHECKSUM MISMATCH User defined checksum...
# 3   TRANSFER CHECKSUM MISMATCH USER_DEFINE and che...
# 11  srm-ifce err: Communication error on send, err...
# 8   TRANSFER globus_ftp_client: the server respond...
# 14  Error reported from srm_ifce : 2 [SE][Ls][SRM_...
# 9   TRANSFER globus_ftp_client: the server respond...
# 10  TRANSFER CHECKSUM MISMATCH and destination che...
# 15  TRANSFER globus_ftp_client: the server respond...
# 12  srm-ifce err: Communication error on send, err...
# 17  DESTINATION SRM_PUTDONE Error on the surl whil...
# 13  DESTINATION SRM_PUTDONE call to srm_ifce error...
#
#                                              sequence  mean_similarity  \
# 4   [TRANSFER, globus_ftp_client:, the, server, re...             0.98
# 1   [TRANSFER, globus_ftp_client:, the, server, re...             0.81
# 0   [TRANSFER, globus_ftp_client:, the, server, re...             0.99
# 6   [DESTINATION, MAKE_PARENT, srm-ifce, err:, Per...             0.95
# 5   [TRANSFER, globus_ftp_client:, the, server, re...             0.78
# 7   [TRANSFER, globus_ftp_client:, the, server, re...             0.84
# 2   [SOURCE, CHECKSUM, MISMATCH, User, defined, ch...             0.93
# 3   [TRANSFER, CHECKSUM, MISMATCH, USER_DEFINE, an...             0.88
# 11  [srm-ifce, err:, Communication, error, on, sen...             0.86
# 8   [TRANSFER, globus_ftp_client:, the, server, re...             0.92
# 14  [Error, reported, from, srm_ifce, :, 2, [SE][L...             0.95
# 9   [TRANSFER, globus_ftp_client:, the, server, re...             0.93
# 10  [TRANSFER, CHECKSUM, MISMATCH, and, destinatio...             0.87
# 15  [TRANSFER, globus_ftp_client:, the, server, re...             0.90
# 12  [srm-ifce, err:, Communication, error, on, sen...             0.87
# 17  [DESTINATION, SRM_PUTDONE, Error, on, the, sur...             0.81
# 13  [DESTINATION, SRM_PUTDONE, call, to, srm_ifce,...             0.91
#
#     std_similarity                                            indices
# 4             0.00  [2, 3, 4, 5, 6, 8, 9, 10, 11, 12, 15, 16, 17, ...
# 1             0.04  [25, 42, 54, 59, 83, 90, 93, 99, 101, 105, 113...
# 0             0.00  [52, 61, 67, 68, 73, 88, 91, 98, 103, 109, 110...
# 6             0.02  [0, 7, 13, 14, 21, 23, 27, 29, 32, 33, 35, 36,...
# 5             0.06  [18, 60, 71, 89, 107, 108, 119, 147, 206, 220,...
# 7             0.09  [70, 72, 84, 94, 106, 111, 115, 121, 190, 212,...
# 2             0.00  [77, 80, 85, 102, 114, 132, 133, 175, 177, 196...
# 3             0.03  [65, 75, 82, 96, 130, 134, 162, 221, 223, 232,...
# 11            0.03  [34, 51, 191, 264, 327, 331, 444, 480, 557, 59...
# 8             0.05  [291, 319, 320, 338, 339, 355, 373, 561, 575, ...
# 14            0.02  [26, 187, 201, 256, 332, 333, 342, 381, 539, 5...
# 9             0.02  [87, 243, 322, 379, 680, 697, 699, 746, 772, 9...
# 10            0.01  [238, 246, 297, 316, 358, 452, 569, 633, 891, ...
# 15            0.02  [92, 118, 432, 563, 564, 579, 799, 801, 812, 8...
# 12            0.02  [225, 672, 749, 882, 904, 997, 1036, 1371, 141...
# 17            0.01  [74, 76, 104, 228, 229, 449, 494, 531, 962, 10...
# 13            0.02  [217, 233, 421, 598, 810, 850, 1191, 1311, 140...

# %%
cluster.big_clusters.shape
# Out:
# (17, 7)
# (17, 7)

# %%
cluster.big_clusters['pattern'].values
# Out:
# array(['TRANSFER globus_ftp_client: the server responded with an error 500 Command failed.: open/create: [ERROR] Server responded with an error: [3009] Unable to get free physical space No space left on device',
#        'TRANSFER globus_ftp_client: the server responded with an error 451 General problem: to',
#        'TRANSFER globus_ftp_client: the server responded with an error 500 Command failed.: open/create: [ERROR] Server responded with an error: [3021] Unable to get quota space - quota not defined or exhausted Disk quota exceeded',
#        'DESTINATION MAKE_PARENT srm-ifce err: Permission denied, err: [SE][Mkdir][SRM_AUTHORIZATION_FAILURE] Permission denied',
#        'TRANSFER globus_ftp_client: the server responded with an error 500 500-Command failed.: error in 500-globus_xio: A system call failed: 500 End.',
#        'TRANSFER globus_ftp_client: the server responded with an error 451 451-GlobusError: v=1 c=INTERNAL_ERROR 451-GridFTP-Errno: 451-GridFTP-Reason: System error in',
#        'SOURCE CHECKSUM MISMATCH User defined checksum and source checksum do not match!=',
#        'TRANSFER CHECKSUM MISMATCH USER_DEFINE and checksums are different.!=',
#        'srm-ifce err: Communication error on send, err: CGSI-gSOAP running on reports Error reading token data header: Connection',
#        'TRANSFER globus_ftp_client: the server responded with an error 451 Failed to deliver message to Route for not found at',
#        'Error reported from srm_ifce : 2 [SE][Ls][SRM_INVALID_PATH] No such file or',
#        'TRANSFER globus_ftp_client: the server responded with an error 530 Login failed: Failed to deliver LoginMessage message to Route for not found at',
#        'TRANSFER CHECKSUM MISMATCH and destination checksums do not match!=',
#        'TRANSFER globus_ftp_client: the server responded with an error 451 General problem: Problem while connected to',
#        'srm-ifce err: Communication error on send, err: CGSI-gSOAP running on reports could not open connection to',
#        'DESTINATION SRM_PUTDONE Error on the surl while putdone: [SE][PutDone][SRM_INTERNAL_ERROR] PreparedStatementCallback; SQL [UPDATE t_inodes SET inlink=inlink +?,imtime=?,ictime=?,igeneration=igeneration+1 WHERE inumber=?]; ERROR: deadlock detected; Detail: Process waits for ExclusiveLock on tuple',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] CGSI-gSOAP running on reports Error reading token data header: Connection'],
#       dtype=object)
# array(['TRANSFER globus_ftp_client: the server responded with an error 500 Command failed.: open/create: [ERROR] Server responded with an error: [3009] Unable to get free physical space No space left on device',
#        'TRANSFER globus_ftp_client: the server responded with an error 451 General problem: to',
#        'TRANSFER globus_ftp_client: the server responded with an error 500 Command failed.: open/create: [ERROR] Server responded with an error: [3021] Unable to get quota space - quota not defined or exhausted Disk quota exceeded',
#        'DESTINATION MAKE_PARENT srm-ifce err: Permission denied, err: [SE][Mkdir][SRM_AUTHORIZATION_FAILURE] Permission denied',
#        'TRANSFER globus_ftp_client: the server responded with an error 500 500-Command failed.: error in 500-globus_xio: A system call failed: 500 End.',
#        'TRANSFER globus_ftp_client: the server responded with an error 451 451-GlobusError: v=1 c=INTERNAL_ERROR 451-GridFTP-Errno: 451-GridFTP-Reason: System error in',
#        'SOURCE CHECKSUM MISMATCH User defined checksum and source checksum do not match!=',
#        'TRANSFER CHECKSUM MISMATCH USER_DEFINE and checksums are different.!=',
#        'srm-ifce err: Communication error on send, err: CGSI-gSOAP running on reports Error reading token data header: Connection',
#        'TRANSFER globus_ftp_client: the server responded with an error 451 Failed to deliver message to Route for not found at',
#        'Error reported from srm_ifce : 2 [SE][Ls][SRM_INVALID_PATH] No such file or',
#        'TRANSFER globus_ftp_client: the server responded with an error 530 Login failed: Failed to deliver LoginMessage message to Route for not found at',
#        'TRANSFER CHECKSUM MISMATCH and destination checksums do not match!=',
#        'TRANSFER globus_ftp_client: the server responded with an error 451 General problem: Problem while connected to',
#        'srm-ifce err: Communication error on send, err: CGSI-gSOAP running on reports could not open connection to',
#        'DESTINATION SRM_PUTDONE Error on the surl while putdone: [SE][PutDone][SRM_INTERNAL_ERROR] PreparedStatementCallback; SQL [UPDATE t_inodes SET inlink=inlink +?,imtime=?,ictime=?,igeneration=igeneration+1 WHERE inumber=?]; ERROR: deadlock detected; Detail: Process waits for ExclusiveLock on tuple',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] CGSI-gSOAP running on reports Error reading token data header: Connection'],
#       dtype=object)

# %%
cluster.df['cluster_2'].unique()

# %%
cluster.results.to_csv('harvester_results_hdbscan.csv')

# %%
cluster.results

# %%
cluster.results[['pattern']].values

# %%
cluster.timings

# %%
x = cluster.in_cluster(4,2)

# %%
print(x)

# %% [markdown]
# ### 4. Get clusters statistics

# %% [raw]
# Clusters Statistics returns DataFrame with statistic for all clusters:
# - "cluster_name" - name of a cluster
# - "cluster_size" - number of log messages in cluster
# - "pattern" - all common substrings in messages in the cluster
# - "vocab" - all tokens in error messasges
# - "vocab_length" - the length of cluster's vocabulary
# - "mean_length" - average length of log messages in cluster
# - "std_length" - standard deviation of length of log messages in cluster
# - "mean_similarity" - average similarity of log messages in cluster
# (calculated as the levenshtein distances between the 1st and all other log messages)
# - "std_similarity" - standard deviation of similarity of log messages in cluster

# %%
output = cluster_output.Output(cluster.df, 
                               cluster.target)

# %%
mode = 'INDEX'

# %%
output.clustered_output(mode)
stats = output.statistics(output_mode='frame')

# %%
stats.sort_values(by=['mean_similarity'])

# %%
patterns = stats.sort_values(by='mean_similarity')[['pattern']].values

# %%
patterns

# %%
stats_1 = output.postprocessing(1)

# %%
stats_1.sort_values(by=['mean_similarity'])

# %%
output.in_cluster(20,2)

# %%
patterns1 = stats_1.sort_values(by='mean_similarity')[['pattern']].values

# %%
patterns1

# %%
import difflib

# %%
sorted_df = output.stat_df.sort_values(by=['cluster_size'])[['cluster_size','cluster_name','pattern']]

# %%
sorted_df

# %%
def match(df, new_clusters):
    start = df.head(1)['pattern'].values[0]
#     print(start)
    ratio = [difflib.SequenceMatcher(None, start, x).ratio() for x in df['pattern']]
    df['ratio'] = ratio
    filtered = df[df['ratio'] > 0.6]['cluster_name'].values
    new_clusters.append(filtered)
#     print(filtered)
    df.drop(df[df['cluster_name'].isin(filtered)].index, inplace=True)
#     print(df)
    while df.shape[0] > 0:
        match(df, new_clusters)

# %%
new_clusters = []
# start = sorted_df.head(1)['pattern'].values[0]
# print(start)
match(sorted_df, new_clusters)

# %%
new_clusters

# %%
a = []
for i in new_clusters:
    x = cluster.df[cluster.df['cluster'].isin(i)].index
    a.append({'cluster_name':i[-1],'idx':x})
print(a)

for i in a:
    cluster.df.loc[i['idx'], 'cluster_level_2'] = i['cluster_name']

# %%
cluster.df['cluster_level_2'].describe()

# %%
sorted_list = sorted_df['pattern'].tolist()

# %%
start = sorted_list[0]
print(start)
ratio = []
for x in sorted_list:
    ratio.append(difflib.SequenceMatcher(None, start, x).ratio())
print(ratio)
ids = [i for i,x in enumerate(ratio) if x > 0.6]
print(ids)

# %%
result = output.postprocessing()

# %%
result

# %%
import numpy as np

# %%
threshold = 0.6
rows = np.where(result > threshold)

# %%
rows

# %%
similar

# %% [markdown]
# ### Timings for all stages of clusterization pipeline

# %% [markdown]
# process - timing of all process

# %%
cluster.timings

# %% [markdown]
# ### Get all error messages in single cluster

# %%
output.in_cluster(10)

# %%
output.in_cluster(34)

# %% [markdown]
# ### Output clusters - mode == 'ALL'  (for cluster '2')

# %%
output.clustered_output(mode='ALL')['1']

# %% [markdown]
# ### Output clusters - mode == 'INDEX' (for cluster '2')

# %%
output.clustered_output(mode='INDEX')['1']

# %% [markdown]
# ### Output clusters - mode == 'TARGET' (for cluster '2')

# %%
output.clustered_output(mode='TARGET')['1']

# %% [markdown]
# ### Output clusters - cluster labels

# %%
cluster.cluster_labels

# %% [markdown]
# ### Get epsilon value (which was used in DBSCAN algorithm)

# %%
cluster.epsilon
