# %% [markdown]
# # Clusterlogs Notebook

# %%
import pandas as pd
from clusterlogs import pipeline

# %% [markdown]
# ### 1. Download data from file and create pandas DataFrame with index

# %%
df = pd.read_csv('samples/fts_mess_panda.csv')

# %%
df
# Out:
#        Unnamed: 0                                            message  count  \
# 0               0  DESTINATION MAKE_PARENT srm-ifce err: Permissi...     27
# 1               1  TRANSFER  globus_ftp_client: the server respon...   1467
# 2               2  TRANSFER  globus_ftp_client: the server respon...      2
# 3               3  TRANSFER  globus_ftp_client: the server respon...     34
# 4               4  TRANSFER  globus_ftp_client: the server respon...      9
# ...           ...                                                ...    ...
# 22787       22787  TRANSFER  globus_ftp_client: the server respon...      1
# 22788       22788  TRANSFER  globus_ftp_client: the server respon...      1
# 22789       22789  TRANSFER CHECKSUM MISMATCH USER_DEFINE and SRC...      3
# 22790       22790  TRANSFER  globus_ftp_client: the server respon...      1
# 22791       22791  TRANSFER  globus_ftp_client: the server respon...      1
#
#           id
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
# ...      ...
# 22787  22788
# 22788  22789
# 22789  22790
# 22790  22791
# 22791  22792
#
# [22792 rows x 4 columns]

# %%
target = 'message'

# %%
cluster = pipeline.ml_clustering(df, target, mode='create', model_name='fts.model').process()

# %%
cluster.timings
# Out:
# {'data_preparation': 0.9422,
#  'tokenization': 2.3496,
#  'clustering': 23.0221,
#  'clustered_data': 24.5819,
#  'process': 27.875}

# %%
#df = pd.read_csv('test/test_data.csv', index_col=0)

# %%
cluster.clusters
# Out:
#    cluster_name  cluster_size  \
# 2             2          6468
# 5             5          2403
# 10           10          2357
# 0             0          1887
# 3             3          1434
# 12           12          1355
# 14           14          1268
# 15           15           922
# 7             7           829
# 11           11           750
# 6             6           417
# 27           27           335
# 8             8           329
# 13           13           156
# 4             4           133
# 17           17           100
#
#                                               pattern  \
# 2   TRANSFER globus_ftp_client: the server respond...
# 5   TRANSFER globus_ftp_client: the server respond...
# 10  TRANSFER globus_ftp_client: the server respond...
# 0   DESTINATION MAKE_PARENT srm-ifce err: Permissi...
# 3   TRANSFER globus_ftp_client: the server respond...
# 12  TRANSFER globus_ftp_client: the server respond...
# 14  {*} CHECKSUM MISMATCH User defined checksum an...
# 15  TRANSFER globus_ftp_client: the server respond...
# 7   {*} err:{*} error on{*} err: [SE][{*}][] httpg...
# 11  TRANSFER CHECKSUM MISMATCH USER_DEFINE and{*} ...
# 6   Error reported from srm_ifce : 2 [SE][Ls][SRM_...
# 27  TRANSFER CHECKSUM MISMATCH Source and destinat...
# 8   TRANSFER globus_ftp_client: the server respond...
# 13  DESTINATION SRM_PUTDONE Error on the surl srm:...
# 4   Error on XrdCl:CopyProcess:Run(): [ERROR] Serv...
# 17  DESTINATION SRM_PUTDONE Error on the surl srm:...
#
#                                              sequence  mean_similarity  \
# 2   [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            91.74
# 5   [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            96.13
# 10  [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            99.12
# 0   [DESTINATION, ▁MAKE_PARENT, ▁srm-ifce, ▁err, :...            97.94
# 3   [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            96.12
# 12  [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            94.03
# 14  [{*}, ▁CHECKSUM, ▁MISMATCH, ▁User, ▁defined, ▁...            99.88
# 15  [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            75.94
# 7   [{*}, ▁err, :, {*}, ▁error, ▁on, {*}, ▁err, :,...            86.36
# 11  [TRANSFER, ▁CHECKSUM, ▁MISMATCH, ▁USER_DEFINE,...            99.97
# 6   [Error, ▁reported, ▁from, ▁srm_ifce, ▁:, ▁2, ▁...            81.70
# 27  [TRANSFER, ▁CHECKSUM, ▁MISMATCH, ▁Source, ▁and...            99.82
# 8   [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            85.96
# 13  [DESTINATION, ▁SRM_PUTDONE, ▁Error, ▁on, ▁the,...            90.96
# 4   [Error, ▁on, ▁XrdCl, :, CopyProcess, :, Run, (...            78.13
# 17  [DESTINATION, ▁SRM_PUTDONE, ▁Error, ▁on, ▁the,...            77.35
#
#     std_similarity                                            indices
# 2             4.35  [2, 3, 4, 5, 6, 8, 9, 10, 11, 12, 15, 16, 17, ...
# 5             6.37  [25, 42, 54, 59, 83, 90, 93, 99, 101, 105, 113...
# 10            2.74  [52, 61, 67, 68, 73, 88, 91, 98, 103, 109, 110...
# 0             1.65  [0, 7, 13, 14, 21, 23, 27, 29, 32, 33, 35, 36,...
# 3             6.26  [18, 39, 60, 71, 89, 107, 108, 119, 123, 147, ...
# 12            3.27  [70, 72, 84, 94, 106, 111, 115, 121, 190, 212,...
# 14            1.55  [77, 80, 85, 102, 114, 132, 133, 175, 177, 196...
# 15           20.35  [87, 243, 291, 319, 320, 322, 338, 339, 355, 3...
# 7            10.71  [34, 51, 191, 225, 233, 264, 327, 331, 444, 48...
# 11            0.55  [65, 75, 82, 96, 130, 134, 162, 221, 223, 232,...
# 6            12.48  [26, 187, 201, 256, 332, 333, 342, 381, 539, 5...
# 27            1.91  [238, 246, 297, 316, 358, 452, 569, 633, 891, ...
# 8             1.88  [38, 92, 154, 242, 312, 334, 491, 495, 562, 57...
# 13            7.34  [74, 76, 104, 228, 229, 449, 494, 531, 962, 10...
# 4            16.77  [20, 729, 790, 976, 1160, 1485, 1590, 1701, 18...
# 17           12.32  [97, 157, 222, 439, 973, 1054, 1067, 1320, 172...

# %%
cluster.in_cluster(7)
# Out:
# array(['srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://srmcms.pic.es:8443/srm/managerv2: CGSI-gSOAP running on fts436.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://srmv2.ific.uv.es:8443/srm/managerv2: CGSI-gSOAP running on fts808.cern.ch reports Error reading token data header: Connection closed ',
#        'SOURCE SRM_GET_TURL srm-ifce err: Communication error on send, err: [SE][StatusOfGetRequest][] httpg://srmv2.ific.uv.es:8443/srm/managerv2: CGSI-gSOAP running on fts814.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lcgse0.shef.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts811.cern.ch reports could not open connection to lcgse0.shef.ac.uk:8446  ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://lcg-se0.ifh.de:8443/srm/managerv2: CGSI-gSOAP running on fts801.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcsrm.usatlas.bnl.gov:8443/srm/managerv2: CGSI-gSOAP running on fts308.usatlas.bnl.gov reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://recas-se-01.cs.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts801.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://storm-se-01.ba.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts434.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se01.indiacms.res.in:8446/srm/managerv2: CGSI-gSOAP running on fts430.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://t2cmcondor.mi.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts309.usatlas.bnl.gov reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on lcgfts09.gridpp.rl.ac.uk reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://t2cmcondor.mi.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts802.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on lcgfts06.gridpp.rl.ac.uk reports Error reading token data header: Connection reset by peer ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://ccsrm.in2p3.fr:8443/srm/managerv2: CGSI-gSOAP running on fts801.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://bohr3226.tier2.hep.manchester.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts308.usatlas.bnl.gov reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lyogrid06.in2p3.fr:8446/srm/managerv2: CGSI-gSOAP running on fts439.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://f-dpm001.grid.sinica.edu.tw:8446/srm/managerv2: CGSI-gSOAP running on fts811.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://storm-se-01.ba.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts430.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lcgse0.shef.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on lcgfts01.gridpp.rl.ac.uk reports could not open connection to lcgse0.shef.ac.uk:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lcgse0.shef.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts704.cern.ch reports could not open connection to lcgse0.shef.ac.uk:8446  ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://t2cmcondor.mi.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts808.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://srm01.ncg.ingrid.pt:8444/srm/managerv2: CGSI-gSOAP running on fts436.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://storm-01.roma3.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts801.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://srmv2.ific.uv.es:8443/srm/managerv2: CGSI-gSOAP running on fts811.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://node12.datagrid.cea.fr:8446/srm/managerv2: CGSI-gSOAP running on fts435.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'SOURCE SRM_GET_TURL srm-ifce err: Communication error on send, err: [SE][StatusOfGetRequest][] httpg://se03.esc.qmul.ac.uk:8444/srm/managerv2: CGSI-gSOAP running on fts813.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://recas-se-01.cs.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts812.cern.ch reports could not open connection to recas-se-01.cs.infn.it:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lyogrid06.in2p3.fr:8446/srm/managerv2: CGSI-gSOAP running on fts435.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on lcgfts08.gridpp.rl.ac.uk reports Error reading token data header: Connection reset by peer ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts307.usatlas.bnl.gov reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts119.cern.ch reports could not open connection to se2.ppgrid1.rhul.ac.uk:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://node12.datagrid.cea.fr:8446/srm/managerv2: CGSI-gSOAP running on fts437.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts804.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://atlasse.lnf.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts803.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'SOURCE SRM_GET_TURL srm-ifce err: Communication error on send, err: [SE][StatusOfGetRequest][] httpg://srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts813.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://gse1.physik.uni-mainz.de:8444/srm/managerv2: CGSI-gSOAP running on fts814.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://srmcms.pic.es:8443/srm/managerv2: CGSI-gSOAP running on fts437.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://node12.datagrid.cea.fr:8446/srm/managerv2: CGSI-gSOAP running on cmsftssrv1.fnal.gov reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lcgsedc01.jinr.ru:8443/srm/managerv2: CGSI-gSOAP running on fts434.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://storm-fe.cr.cnaf.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts802.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://t2-srm-02.lnl.infn.it:8443/srm/managerv2: CGSI-gSOAP running on fts441.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcsrm.usatlas.bnl.gov:8443/srm/managerv2: CGSI-gSOAP running on lcgfts07.gridpp.rl.ac.uk reports Error reading token data header: Connection closed ',
#        'SOURCE SRM_GET_TURL srm-ifce err: Communication error on send, err: [SE][StatusOfGetRequest][] httpg://srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts120.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts706.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lcgse0.shef.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts814.cern.ch reports could not open connection to lcgse0.shef.ac.uk:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://atlassrm-kit.gridka.de:8443/srm/managerv2: CGSI-gSOAP running on fts309.usatlas.bnl.gov reports Error reading token data header: Connection closed ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se03.esc.qmul.ac.uk:8444/srm/managerv2: CGSI-gSOAP running on fts801.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on fts802.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://ccsrm.in2p3.fr:8443/srm/managerv2: CGSI-gSOAP running on fts433.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://node12.datagrid.cea.fr:8446/srm/managerv2: CGSI-gSOAP running on fts704.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://osg-se.sprace.org.br:8443/srm/managerv2: CGSI-gSOAP running on fts436.cern.ch reports Error reading token data header: Connection closed ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on fts706.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://recas-se-01.cs.infn.it:8446/srm/managerv2: CGSI-gSOAP running on lcgfts09.gridpp.rl.ac.uk reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcache-se-cms.desy.de:8443/srm/managerv2: CGSI-gSOAP running on fts439.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://storm-se-01.ba.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts441.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://t2cmcondor.mi.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts800.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://srmv2.ific.uv.es:8443/srm/managerv2: CGSI-gSOAP running on fts813.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on fts804.cern.ch reports could not open connection to agh3.atlas.unimelb.edu.au:8446  ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://srm-cms.jinr-t1.ru:8443/srm/managerv2: CGSI-gSOAP running on fts435.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://srmatlas.pic.es:8443/srm/managerv2: CGSI-gSOAP running on fts307.usatlas.bnl.gov reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts309.usatlas.bnl.gov reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se01.indiacms.res.in:8446/srm/managerv2: CGSI-gSOAP running on fts439.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts800.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on fts307.usatlas.bnl.gov reports could not open connection to agh3.atlas.unimelb.edu.au:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on lcgfts10.gridpp.rl.ac.uk reports could not open connection to se2.ppgrid1.rhul.ac.uk:8446  ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts708.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://srmv2.ific.uv.es:8443/srm/managerv2: CGSI-gSOAP running on fts803.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://node12.datagrid.cea.fr:8446/srm/managerv2: CGSI-gSOAP running on fts801.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lcgse0.shef.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts804.cern.ch reports could not open connection to lcgse0.shef.ac.uk:8446  ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on lcgfts01.gridpp.rl.ac.uk reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://node12.datagrid.cea.fr:8446/srm/managerv2: CGSI-gSOAP running on fts430.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://srm-cms.jinr-t1.ru:8443/srm/managerv2: CGSI-gSOAP running on fts438.cern.ch reports could not open connection to srm-cms.jinr-t1.ru:8443  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on lcgfts08.gridpp.rl.ac.uk reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on lcgfts05.gridpp.rl.ac.uk reports could not open connection to agh3.atlas.unimelb.edu.au:8446  ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://storm-fe.cr.cnaf.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts804.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://se01.dur.scotgrid.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on lcgfts01.gridpp.rl.ac.uk reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://node12.datagrid.cea.fr:8446/srm/managerv2: CGSI-gSOAP running on lcgfts02.gridpp.rl.ac.uk reports could not open connection to node12.datagrid.cea.fr:8446  ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://recas-se-01.cs.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts802.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts814.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on lcgfts06.gridpp.rl.ac.uk reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts801.cern.ch reports could not open connection to se2.ppgrid1.rhul.ac.uk:8446  ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://dpm.lhep.unibe.ch:8446/srm/managerv2: CGSI-gSOAP running on fts808.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://t2cmcondor.mi.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts814.cern.ch reports Error reading token data header: Connection closed ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://atlasse.lnf.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts106.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts814.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on fts704.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://srmcms.pic.es:8443/srm/managerv2: CGSI-gSOAP running on fts439.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://recas-se-01.cs.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts801.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcsrm.usatlas.bnl.gov:8443/srm/managerv2: CGSI-gSOAP running on fts800.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on fts706.cern.ch reports could not open connection to agh3.atlas.unimelb.edu.au:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts707.cern.ch reports could not open connection to se2.ppgrid1.rhul.ac.uk:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://t2-srm-02.lnl.infn.it:8443/srm/managerv2: CGSI-gSOAP running on fts430.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://dpm.lhep.unibe.ch:8446/srm/managerv2: CGSI-gSOAP running on fts800.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts706.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://recas-se-01.cs.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts707.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://atlasse.lnf.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts804.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on lcgfts09.gridpp.rl.ac.uk reports Error reading token data header: Connection closed ',
#        'SOURCE SRM_GET_TURL srm-ifce err: Communication error on send, err: [SE][StatusOfGetRequest][] httpg://srmv2.ific.uv.es:8443/srm/managerv2: CGSI-gSOAP running on fts808.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://osg-se.sprace.org.br:8443/srm/managerv2: CGSI-gSOAP running on fts438.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lcgse0.shef.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts106.cern.ch reports could not open connection to lcgse0.shef.ac.uk:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://recas-se-01.cs.infn.it:8446/srm/managerv2: CGSI-gSOAP running on lcgfts07.gridpp.rl.ac.uk reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on lcgfts09.gridpp.rl.ac.uk reports could not open connection to agh3.atlas.unimelb.edu.au:8446  ',
#        'SOURCE SRM_GET_TURL srm-ifce err: Communication error on send, err: [SE][StatusOfGetRequest][] httpg://srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts800.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se.hpc.utfsm.cl:8443/srm/managerv2: CGSI-gSOAP running on lcgfts10.gridpp.rl.ac.uk reports could not open connection to se.hpc.utfsm.cl:8443  ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lcgse0.shef.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts708.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://storm.mib.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts435.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on lcgfts02.gridpp.rl.ac.uk reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://eymir.grid.metu.edu.tr:8446/srm/managerv2: CGSI-gSOAP running on fts438.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://recas-se-01.cs.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts800.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://srm.grid.sara.nl:8443/srm/managerv2: CGSI-gSOAP running on fts120.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://t2cmcondor.mi.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts808.cern.ch reports Error reading token data header: Connection closed ',
#        'SOURCE SRM_GET_TURL srm-ifce err: Communication error on send, err: [SE][StatusOfGetRequest][] httpg://se03.esc.qmul.ac.uk:8444/srm/managerv2: CGSI-gSOAP running on fts811.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se.hpc.utfsm.cl:8443/srm/managerv2: CGSI-gSOAP running on fts106.cern.ch reports could not open connection to se.hpc.utfsm.cl:8443  ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on fts307.usatlas.bnl.gov reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcsrm.usatlas.bnl.gov:8443/srm/managerv2: CGSI-gSOAP running on fts811.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://storm-se-01.ba.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts436.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://srmv2.ific.uv.es:8443/srm/managerv2: CGSI-gSOAP running on fts813.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on lcgfts06.gridpp.rl.ac.uk reports could not open connection to se2.ppgrid1.rhul.ac.uk:8446  ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts812.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://srm-cms.jinr-t1.ru:8443/srm/managerv2: CGSI-gSOAP running on cmsftssrv1.fnal.gov reports could not open connection to srm-cms.jinr-t1.ru:8443  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts307.usatlas.bnl.gov reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://eymir.grid.metu.edu.tr:8446/srm/managerv2: CGSI-gSOAP running on fts430.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts800.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on lcgfts02.gridpp.rl.ac.uk reports could not open connection to se2.ppgrid1.rhul.ac.uk:8446  ',
#        'DESTINATION MAKE_PARENT srm-ifce err: Communication error on send, err: [SE][Mkdir][] httpg://srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts803.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se01.dur.scotgrid.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on lcgfts02.gridpp.rl.ac.uk reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts309.usatlas.bnl.gov reports could not open connection to se2.ppgrid1.rhul.ac.uk:8446  ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://f-dpm001.grid.sinica.edu.tw:8446/srm/managerv2: CGSI-gSOAP running on fts813.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://lcg-se0.ifh.de:8443/srm/managerv2: CGSI-gSOAP running on fts803.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://srm-cms.jinr-t1.ru:8443/srm/managerv2: CGSI-gSOAP running on fts439.cern.ch reports could not open connection to srm-cms.jinr-t1.ru:8443  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://t2-srm-02.lnl.infn.it:8443/srm/managerv2: CGSI-gSOAP running on fts435.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on lcgfts01.gridpp.rl.ac.uk reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://eymir.grid.metu.edu.tr:8446/srm/managerv2: CGSI-gSOAP running on fts435.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://srm.ihep.ac.cn:8443/srm/managerv2: CGSI-gSOAP running on fts437.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://srmv2.ific.uv.es:8443/srm/managerv2: CGSI-gSOAP running on fts802.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on fts119.cern.ch reports could not open connection to agh3.atlas.unimelb.edu.au:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://srmcms.pic.es:8443/srm/managerv2: CGSI-gSOAP running on fts438.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on lcgfts08.gridpp.rl.ac.uk reports could not open connection to agh3.atlas.unimelb.edu.au:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://ccsrm.in2p3.fr:8443/srm/managerv2: CGSI-gSOAP running on fts434.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://atlasse.lnf.infn.it:8446/srm/managerv2: CGSI-gSOAP running on lcgfts10.gridpp.rl.ac.uk reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://osg-se.sprace.org.br:8443/srm/managerv2: CGSI-gSOAP running on fts437.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on lcgfts05.gridpp.rl.ac.uk reports could not open connection to se2.ppgrid1.rhul.ac.uk:8446  ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on fts803.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on lcgfts01.gridpp.rl.ac.uk reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://recas-se-01.cs.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts808.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on lcgfts05.gridpp.rl.ac.uk reports Error reading token data header: Connection closed ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://storm-fe.cr.cnaf.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts813.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcache-se-cms.desy.de:8443/srm/managerv2: CGSI-gSOAP running on fts438.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://cmssrm-kit.gridka.de:8443/srm/managerv2: CGSI-gSOAP running on fts436.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://recas-se-01.cs.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts803.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lcg-se0.ifh.de:8443/srm/managerv2: CGSI-gSOAP running on fts308.usatlas.bnl.gov reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://se.le.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts812.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lcgse0.shef.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts119.cern.ch reports could not open connection to lcgse0.shef.ac.uk:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://srmv2.ific.uv.es:8443/srm/managerv2: CGSI-gSOAP running on fts309.usatlas.bnl.gov reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://srm-cms.jinr-t1.ru:8443/srm/managerv2: CGSI-gSOAP running on fts432.cern.ch reports could not open connection to srm-cms.jinr-t1.ru:8443  ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://se01.dur.scotgrid.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on lcgfts08.gridpp.rl.ac.uk reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://t2-srm-02.lnl.infn.it:8443/srm/managerv2: CGSI-gSOAP running on fts438.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lyogrid06.in2p3.fr:8446/srm/managerv2: CGSI-gSOAP running on fts437.cern.ch reports Error reading token data header: Connection closed ',
#        'SOURCE SRM_GET_TURL srm-ifce err: Communication error on send, err: [SE][StatusOfGetRequest][] httpg://srmv2.ific.uv.es:8443/srm/managerv2: CGSI-gSOAP running on fts812.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://atlasse.lnf.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts814.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://recas-se-01.cs.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts814.cern.ch reports could not open connection to recas-se-01.cs.infn.it:8446  ',
#        'SOURCE SRM_GET_TURL srm-ifce err: Communication error on send, err: [SE][StatusOfGetRequest][] httpg://se03.esc.qmul.ac.uk:8444/srm/managerv2: CGSI-gSOAP running on fts814.cern.ch reports Error reading token data header: Connection closed ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://recas-se-01.cs.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts808.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://f-dpm001.grid.sinica.edu.tw:8446/srm/managerv2: CGSI-gSOAP running on lcgfts10.gridpp.rl.ac.uk reports could not open connection to f-dpm001.grid.sinica.edu.tw:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://ccsrm.in2p3.fr:8443/srm/managerv2: CGSI-gSOAP running on fts436.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://grid-srm.physik.rwth-aachen.de:8443/srm/managerv2: CGSI-gSOAP running on fts439.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://se.le.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts808.cern.ch reports Error reading token data header: Connection closed ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on fts119.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://t2cmcondor.mi.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts804.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se01.dur.scotgrid.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on lcgfts10.gridpp.rl.ac.uk reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://atlasse.lnf.infn.it:8446/srm/managerv2: CGSI-gSOAP running on lcgfts09.gridpp.rl.ac.uk reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcsrm.usatlas.bnl.gov:8443/srm/managerv2: CGSI-gSOAP running on fts814.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcsrm.usatlas.bnl.gov:8443/srm/managerv2: CGSI-gSOAP running on fts811.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lcgse0.shef.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts307.usatlas.bnl.gov reports could not open connection to lcgse0.shef.ac.uk:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://node12.datagrid.cea.fr:8446/srm/managerv2: CGSI-gSOAP running on lcgfts08.gridpp.rl.ac.uk reports could not open connection to node12.datagrid.cea.fr:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcache-se-atlas.desy.de:8443/srm/managerv2: CGSI-gSOAP running on fts120.cern.ch reports could not open connection to dcache-se-atlas.desy.de:8443  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lcgse0.shef.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts708.cern.ch reports could not open connection to lcgse0.shef.ac.uk:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://eymir.grid.metu.edu.tr:8446/srm/managerv2: CGSI-gSOAP running on fts437.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://se0002.m45.ihep.su:8443/srm/managerv2: CGSI-gSOAP running on fts803.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts808.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts704.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://srmv2.ific.uv.es:8443/srm/managerv2: CGSI-gSOAP running on fts812.cern.ch reports Error reading token data header: Connection closed ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://node12.datagrid.cea.fr:8446/srm/managerv2: CGSI-gSOAP running on fts802.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lcgse0.shef.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts707.cern.ch reports could not open connection to lcgse0.shef.ac.uk:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://t2cmcondor.mi.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts801.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts708.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://srmatlas.pic.es:8443/srm/managerv2: CGSI-gSOAP running on fts800.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://node12.datagrid.cea.fr:8446/srm/managerv2: CGSI-gSOAP running on lcgfts01.gridpp.rl.ac.uk reports could not open connection to node12.datagrid.cea.fr:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcache-se-cms.desy.de:8443/srm/managerv2: CGSI-gSOAP running on fts441.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se-goegrid.gwdg.de:8443/srm/managerv2: CGSI-gSOAP running on fts307.usatlas.bnl.gov reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://sbgse1.in2p3.fr:8446/srm/managerv2: CGSI-gSOAP running on fts441.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lcgsedc01.jinr.ru:8443/srm/managerv2: CGSI-gSOAP running on fts438.cern.ch reports Error reading token data header: Connection closed ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se03.esc.qmul.ac.uk:8444/srm/managerv2: CGSI-gSOAP running on fts812.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://f-dpm001.grid.sinica.edu.tw:8446/srm/managerv2: CGSI-gSOAP running on fts800.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://recas-se-01.cs.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts800.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://srm01.ncg.ingrid.pt:8444/srm/managerv2: CGSI-gSOAP running on fts430.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se.reef.man.poznan.pl:8446/srm/managerv2: CGSI-gSOAP running on lcgfts06.gridpp.rl.ac.uk reports could not open connection to se.reef.man.poznan.pl:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcsrm.usatlas.bnl.gov:8443/srm/managerv2: CGSI-gSOAP running on fts812.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://node12.datagrid.cea.fr:8446/srm/managerv2: CGSI-gSOAP running on fts106.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://t2cmcondor.mi.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts801.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://cms-t2-se01.sdfarm.kr:8443/srm/managerv2: CGSI-gSOAP running on fts430.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://node12.datagrid.cea.fr:8446/srm/managerv2: CGSI-gSOAP running on fts106.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://srmv2.ific.uv.es:8443/srm/managerv2: CGSI-gSOAP running on fts802.cern.ch reports Error reading token data header: Connection closed ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://atlasse.lnf.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts804.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://t2cmcondor.mi.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts814.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on lcgfts05.gridpp.rl.ac.uk reports Error reading token data header: Connection reset by peer ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://dpm.lhep.unibe.ch:8446/srm/managerv2: CGSI-gSOAP running on fts813.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcache-se-cms.desy.de:8443/srm/managerv2: CGSI-gSOAP running on cmsftssrv1.fnal.gov reports could not open connection to dcache-se-cms.desy.de:8443  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lcgse0.shef.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on lcgfts09.gridpp.rl.ac.uk reports could not open connection to lcgse0.shef.ac.uk:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://f-dpm001.grid.sinica.edu.tw:8446/srm/managerv2: CGSI-gSOAP running on fts811.cern.ch reports could not open connection to f-dpm001.grid.sinica.edu.tw:8446  ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts803.cern.ch reports Error reading token data header: Connection closed ',
# ...
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://storm-fe-archive.cr.cnaf.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts309.usatlas.bnl.gov reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://sbgse1.in2p3.fr:8446/srm/managerv2: CGSI-gSOAP running on cmsftssrv1.fnal.gov reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://grid-srm.physik.rwth-aachen.de:8443/srm/managerv2: CGSI-gSOAP running on fts437.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://srm.ihep.ac.cn:8443/srm/managerv2: CGSI-gSOAP running on fts438.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://storm-fe.cr.cnaf.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts812.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts813.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on fts309.usatlas.bnl.gov reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts707.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lcgse0.shef.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts802.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on fts801.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on fts708.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://t2cmcondor.mi.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts811.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts811.cern.ch reports could not open connection to se2.ppgrid1.rhul.ac.uk:8446  ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://se.le.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts811.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se.hpc.utfsm.cl:8443/srm/managerv2: CGSI-gSOAP running on lcgfts07.gridpp.rl.ac.uk reports could not open connection to se.hpc.utfsm.cl:8443  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts801.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lcgse0.shef.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on lcgfts06.gridpp.rl.ac.uk reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://lcgse0.shef.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on fts119.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://srm.ihep.ac.cn:8443/srm/managerv2: CGSI-gSOAP running on fts441.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://dcsrm.usatlas.bnl.gov:8443/srm/managerv2: CGSI-gSOAP running on fts307.usatlas.bnl.gov reports Error reading token data header: Connection reset by peer ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://atlasse.lnf.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts800.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://se.hpc.utfsm.cl:8443/srm/managerv2: CGSI-gSOAP running on fts811.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcsrm.usatlas.bnl.gov:8443/srm/managerv2: CGSI-gSOAP running on fts801.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://atlasse.lnf.infn.it:8446/srm/managerv2: CGSI-gSOAP running on lcgfts08.gridpp.rl.ac.uk reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcsrm.usatlas.bnl.gov:8443/srm/managerv2: CGSI-gSOAP running on fts704.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://srm.triumf.ca:8443/srm/managerv2: CGSI-gSOAP running on fts307.usatlas.bnl.gov reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts802.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://se.le.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts801.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://ccsrm.in2p3.fr:8443/srm/managerv2: CGSI-gSOAP running on fts435.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se.hpc.utfsm.cl:8443/srm/managerv2: CGSI-gSOAP running on lcgfts06.gridpp.rl.ac.uk reports could not open connection to se.hpc.utfsm.cl:8443  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://osg-se.sprace.org.br:8443/srm/managerv2: CGSI-gSOAP running on fts440.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://node12.datagrid.cea.fr:8446/srm/managerv2: CGSI-gSOAP running on fts802.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se03.esc.qmul.ac.uk:8444/srm/managerv2: CGSI-gSOAP running on fts802.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://ccsrm.in2p3.fr:8443/srm/managerv2: CGSI-gSOAP running on fts432.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcache-se-cms.desy.de:8443/srm/managerv2: CGSI-gSOAP running on fts437.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://recas-se-01.cs.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts814.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on fts811.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on lcgfts01.gridpp.rl.ac.uk reports could not open connection to se2.ppgrid1.rhul.ac.uk:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://cms-se0.kipt.kharkov.ua:8446/srm/managerv2: CGSI-gSOAP running on fts430.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on lcgfts07.gridpp.rl.ac.uk reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://node12.datagrid.cea.fr:8446/srm/managerv2: CGSI-gSOAP running on fts119.cern.ch reports could not open connection to node12.datagrid.cea.fr:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://srm-cms.jinr-t1.ru:8443/srm/managerv2: CGSI-gSOAP running on fts436.cern.ch reports could not open connection to srm-cms.jinr-t1.ru:8443  ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://f-dpm001.grid.sinica.edu.tw:8446/srm/managerv2: CGSI-gSOAP running on fts812.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://head01.aglt2.org:8443/srm/managerv2: CGSI-gSOAP running on fts309.usatlas.bnl.gov reports Error reading token data header: Connection closed ',
#        'SOURCE SRM_GET_TURL srm-ifce err: Communication error on send, err: [SE][StatusOfGetRequest][] httpg://srm-cms.jinr-t1.ru:8443/srm/managerv2: CGSI-gSOAP running on fts435.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts801.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://node12.datagrid.cea.fr:8446/srm/managerv2: CGSI-gSOAP running on fts120.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://atlasse.lnf.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts814.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://t2cmcondor.mi.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts803.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://eymir.grid.metu.edu.tr:8446/srm/managerv2: CGSI-gSOAP running on fts436.cern.ch reports Error reading token data header: Connection closed ',
#        'SOURCE SRM_GET_TURL srm-ifce err: Communication error on send, err: [SE][PrepareToGet][] httpg://sbgse1.in2p3.fr:8446/srm/managerv2: CGSI-gSOAP running on cmsftssrv1.fnal.gov reports Error reading token data header: Connection closed ',
#        'SOURCE SRM_GET_TURL srm-ifce err: Communication error on send, err: [SE][StatusOfGetRequest][] httpg://srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts308.usatlas.bnl.gov reports Error reading token data header: Connection closed ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://sdrm.t1.grid.kiae.ru:8443/srm/managerv2: CGSI-gSOAP running on fts803.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://eymir.grid.metu.edu.tr:8446/srm/managerv2: CGSI-gSOAP running on fts434.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://storm-fe-archive.cr.cnaf.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts308.usatlas.bnl.gov reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcsrm.usatlas.bnl.gov:8443/srm/managerv2: CGSI-gSOAP running on fts704.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://node12.datagrid.cea.fr:8446/srm/managerv2: CGSI-gSOAP running on fts120.cern.ch reports could not open connection to node12.datagrid.cea.fr:8446  ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on fts811.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://atlasse.lnf.infn.it:8446/srm/managerv2: CGSI-gSOAP running on fts812.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://agh3.atlas.unimelb.edu.au:8446/srm/managerv2: CGSI-gSOAP running on fts307.usatlas.bnl.gov reports Error reading token data header: Connection reset by peer ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se2.ppgrid1.rhul.ac.uk:8446/srm/managerv2: CGSI-gSOAP running on lcgfts02.gridpp.rl.ac.uk reports Error reading token data header: Connection reset by peer ',
#        'DESTINATION OVERWRITE srm-ifce err: Communication error on send, err: [SE][srmRm][] httpg://storm-fe.cr.cnaf.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts813.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://eymir.grid.metu.edu.tr:8446/srm/managerv2: CGSI-gSOAP running on fts441.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcsrm.usatlas.bnl.gov:8443/srm/managerv2: CGSI-gSOAP running on fts802.cern.ch reports Error reading token data header: Connection reset by peer ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://srm-cms.jinr-t1.ru:8443/srm/managerv2: CGSI-gSOAP running on fts439.cern.ch reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://se03.esc.qmul.ac.uk:8444/srm/managerv2: CGSI-gSOAP running on fts307.usatlas.bnl.gov reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts707.cern.ch reports Error reading token data header: Connection closed ',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg://srm.triumf.ca:8443/srm/managerv2: CGSI-gSOAP running on fts308.usatlas.bnl.gov reports Error reading token data header: Connection closed ',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://storm-se-01.ba.infn.it:8444/srm/managerv2: CGSI-gSOAP running on fts438.cern.ch reports Error reading token data header: Connection closed ',
#        'SOURCE CHECKSUM srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://preprod-srm.ndgf.org:8443/srm/managerv2: CGSI-gSOAP running on fts808.cern.ch reports Error reading token data header: Connection closed '],
#       dtype=object)

# %%
#df = pd.read_csv('samples/fts_mess_panda.csv', index_col=0).set_index('id')

# %%
#df.head()

# %%
target = 'message'

# %%
cluster = multistage.exec(df, target, 'fts.model')
# Out:
#      cluster_name  cluster_size  \
# 27             27          2135
# 15             15          1325
# 36             36          1260
# 31             31           747
# 4               4           696
# ...           ...           ...
# 599           599             1
# 600           600             1
# 601           601             1
# 602           602             1
# 1210         1210             1
#
#                                                 pattern  \
# 27    TRANSFER globus_ftp_client: the server respond...
# 15    TRANSFER globus_ftp_client: the server respond...
# 36    SOURCE CHECKSUM MISMATCH User defined checksum...
# 31    TRANSFER CHECKSUM MISMATCH USER_DEFINE and SRC...
# 4     TRANSFER globus_ftp_client: the server respond...
# ...                                                 ...
# 599   Error reported from srm_ifce : 2 [SE][Ls][SRM_...
# 600              User and source checksums do not match
# 601   TRANSFER ERROR: Copy failed with mode 3rd push...
# 602   Result HTTP 404 : File not found after 1 attempts
# 1210  TRANSFER globus_ftp_client: the server respond...
#
#                                                sequence  mean_similarity  \
# 27    [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            100.0
# 15    [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            100.0
# 36    [SOURCE, ▁CHECKSUM, ▁MISMATCH, ▁User, ▁defined...            100.0
# 31    [TRANSFER, ▁CHECKSUM, ▁MISMATCH, ▁USER_DEFINE,...            100.0
# 4     [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            100.0
# ...                                                 ...              ...
# 599   [Error, ▁reported, ▁from, ▁srm_ifce, ▁:, ▁2, ▁...            100.0
# 600   [User, ▁and, ▁source, ▁checksums, ▁do, ▁not, ▁...            100.0
# 601   [TRANSFER, ▁ERROR, :, ▁Copy, ▁failed, ▁with, ▁...            100.0
# 602   [Result, ▁HTTP, ▁404, ▁:, ▁File, ▁not, ▁found,...            100.0
# 1210  [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            100.0
#
#       std_similarity                                            indices
# 27               0.0  [52, 61, 67, 68, 73, 88, 91, 98, 103, 109, 110...
# 15               0.0  [25, 42, 93, 99, 113, 117, 129, 195, 216, 295,...
# 36               0.0  [77, 80, 85, 102, 114, 132, 133, 175, 177, 196...
# 31               0.0  [65, 75, 82, 96, 130, 134, 162, 221, 223, 232,...
# 4                0.0  [4, 15, 17, 53, 58, 124, 149, 189, 261, 279, 2...
# ...              ...                                                ...
# 599              0.0                                             [8124]
# 600              0.0                                             [8129]
# 601              0.0                                             [8151]
# 602              0.0                                             [8166]
# 1210             0.0                                            [22756]
#
# [1211 rows x 7 columns]
#     cluster_name  cluster_size  \
# 4              4          6461
# 0              0          2357
# 7              7          1887
# 6              6          1426
# 8              8          1349
# ..           ...           ...
# 206          206             1
# 208          208             1
# 209          209             1
# 210          210             1
# 322          322             1
#
#                                                pattern  \
# 4    TRANSFER globus_ftp_client: the server respond...
# 0    TRANSFER globus_ftp_client: the server respond...
# 7    DESTINATION MAKE_PARENT srm-ifce err: Permissi...
# 6    TRANSFER globus_ftp_client: the server respond...
# 8    TRANSFER globus_ftp_client: the server respond...
# ..                                                 ...
# 206  DESTINATION SRM_PUT_TURL error on the turl req...
# 208                                  Transfer canceled
# 209  Failed to create directory root://ccdcalitest1...
# 210  Error reported from srm_ifce : 16 [SE][Ls][SRM...
# 322  Result HTTP 404 : File not found after 1 attempts
#
#                                               sequence  mean_similarity  \
# 4    [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            91.75
# 0    [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            99.12
# 7    [DESTINATION, ▁MAKE_PARENT, ▁srm-ifce, ▁err, :...            97.94
# 6    [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            87.66
# 8    [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            94.13
# ..                                                 ...              ...
# 206  [DESTINATION, ▁SRM_PUT_TURL, ▁error, ▁on, ▁the...           100.00
# 208                              [Transfer, ▁canceled]           100.00
# 209  [Failed, ▁to, ▁create, ▁directory, ▁root, :, /...           100.00
# 210  [Error, ▁reported, ▁from, ▁srm_ifce, ▁:, ▁16, ...           100.00
# 322  [Result, ▁HTTP, ▁404, ▁:, ▁File, ▁not, ▁found,...           100.00
#
#      std_similarity                                            indices
# 4              4.34  [2, 3, 4, 5, 6, 8, 9, 10, 11, 12, 15, 16, 17, ...
# 0              2.74  [52, 61, 67, 68, 73, 88, 91, 98, 103, 109, 110...
# 7              1.65  [0, 7, 13, 14, 21, 23, 27, 29, 32, 33, 35, 36,...
# 6              9.76  [54, 59, 83, 90, 101, 105, 118, 122, 154, 184,...
# 8              2.82  [70, 72, 84, 94, 106, 111, 115, 121, 190, 212,...
# ..              ...                                                ...
# 206            0.00                                            [16640]
# 208            0.00                                            [16053]
# 209            0.00                                            [16138]
# 210            0.00                                            [16204]
# 322            0.00                                             [8166]
#
# [323 rows x 7 columns]

# %% [markdown]
# ### 3. Execute clusterization pipeline

# %%
cluster.clusterization.timings
# Out:
# {'data_preparation': 0.9221,
#  'tokenization': 2.2053,
#  'tokens_vectorization': 3.8773,
#  'sentence_vectorization': 8.068,
#  'dimensionality_reduction': 0.0049,
#  'kneighbors': 0.9819,
#  'epsilon_search': 0.366,
#  'dbscan': 2.0273,
#  'extract_patterns': 1.5593,
#  'process': 18.6594}

# %%
cluster.clusterization.big['pattern'].values
# Out:
# array(['TRANSFER globus_ftp_client: the server responded with an error 500 Command failed. : open/create : [ERROR] Server responded with an error: [3021] Unable to get quota space - quota not defined or exhausted /eos/cms/store/user/fengwang/crab_2019-10-29_MuMuTauTauLimits_HybridNew_v1/mmmt_mm_h_parametric_unbinned_lowmassWith1DFitsDoubleExpo/{*}/{*}/Combine/crab_2019-10-29_MuMuTauTauLimits_HybridNew_v1/{*}/0000/{*}; Disk quota exceeded',
#        'TRANSFER globus_ftp_client: the server responded with an error 451 General problem: Failed to connect{*}:{*}: Connection timed out',
#        'SOURCE CHECKSUM MISMATCH User defined checksum and source checksum do not match{*} !={*}',
#        'TRANSFER CHECKSUM MISMATCH USER_DEFINE and SRC checksums are different.{*} !={*}',
#        'TRANSFER globus_ftp_client: the server responded with an error 500 Command failed. : open/create : [ERROR] Server responded with an error: [3009] Unable to get free physical space /eos/eulake/tests/rutests/spb/rain/ruandcern/hammercloud/atlas/testb/rucio/step14/ESD/{*}/{*}/{*}; No space left on device',
#        'TRANSFER globus_ftp_client: the server responded with an error 500 Command failed. : open/create : [ERROR] Server responded with an error: [3009] Unable to get free physical space /eos/eulake/tests/rutests/spb/rain/hammercloud/atlas/testc/rucio/step14/ESD/{*}/{*}/{*}; No space left on device',
#        'TRANSFER globus_ftp_client: the server responded with an error 500 Command failed. : open/create : [ERROR] Server responded with an error: [3009] Unable to get free physical space /eos/eulake/tests/rutests/spb/rain/ruandcern/hammercloud/atlas/testa/rucio/step14/ESD/{*}/{*}/{*}; No space left on device',
#        'TRANSFER globus_ftp_client: the server responded with an error 500 Command failed. : open/create : [ERROR] Server responded with an error: [3009] Unable to get free physical space /eos/eulake/tests/rutests/spb/rain/hammercloud/atlas/testb/rucio/step14/ESD/{*}/{*}/{*}; No space left on device',
#        'TRANSFER globus_ftp_client: the server responded with an error 500 Command failed. : open/create : [ERROR] Server responded with an error: [3009] Unable to get free physical space /eulake/lcg/test/hammercloud/atlas/testc/rucio/step14/ESD/{*}/{*}/{*}; No space left on device',
#        'TRANSFER globus_ftp_client: the server responded with an error 500 Command failed. : open/create : [ERROR] Server responded with an error: [3009] Unable to get free physical space /eulake/lcg/test/hammercloud/atlas/testd/rucio/step14/ESD/{*}/{*}/{*}; No space left on device',
#        'TRANSFER globus_ftp_client: the server responded with an error 500 Command failed. : open/create : [ERROR] Server responded with an error: [3009] Unable to get free physical space /eos/eulake/tests/rutests/spb/rain/ruandcern/hammercloud/atlas/testc/rucio/step14/ESD/{*}/{*}/{*}; No space left on device',
#        'TRANSFER globus_ftp_client: the server responded with an error 500 Command failed. : open/create : [ERROR] Server responded with an error: [3009] Unable to get free physical space /eos/eulake/tests/rutests/spb/rain/hammercloud/atlas/testd/rucio/step14/ESD/{*}/{*}/{*}; No space left on device',
#        'TRANSFER globus_ftp_client: the server responded with an error 500 Command failed. : open/create : [ERROR] Server responded with an error: [3009] Unable to get free physical space /eos/eulake/tests/rutests/spb/rain/hammercloud/atlas/testa/rucio/step14/ESD/{*}/{*}/{*}; No space left on device',
#        'TRANSFER globus_ftp_client: the server responded with an error 500 500-Command failed. : globus_xio: Unable to connect to{*}:{*}:{*}:{*}:{*}:{*}:{*}:{*}:{*} 500-globus_xio: System error in connect: Connection timed out 500-globus_xio: A system call failed: Connection timed out 500- 500 End.',
#        'TRANSFER globus_ftp_client: the server responded with an error 500 Command failed. : open/create : [ERROR] Server responded with an error: [3009] Unable to get free physical space /eos/eulake/tests/rutests/spb/rain/ruandcern/hammercloud/atlas/testd/rucio/step14/ESD/{*}/{*}/{*}; No space left on device',
#        'TRANSFER globus_ftp_client: the server responded with an error 451 General problem: Failed to connect [{*}:{*}:{*}:{*}:{*}:{*}:{*}:{*}]:{*}: Connection timed out',
#        'DESTINATION MAKE_PARENT srm-ifce err: Permission denied, err: [SE][Mkdir][SRM_AUTHORIZATION_FAILURE] httpg:/recas-se-01.cs.infn.it:8446/srm/managerv2: srm:/recas-se-01.cs.infn.it/dpm/cs.infn.it/home/atlas/atlasdatadisk/rucio/user/lxu/{*}/{*}: Permission denied',
#        'TRANSFER globus_ftp_client: the server responded with an error 451 451-GlobusError: v=1 c=INTERNAL_ERROR 451-GridFTP-Errno: 255 451-GridFTP-Reason: System error in write into HDFS (host={*}, user=cms, path=/cms/store/mc/{*}/{*}/AODSIM/{*}/{*}/{*}) 451-GridFTP-Error-String: Unknown error 255 451 End.',
#        'TRANSFER globus_ftp_client: the server responded with an error 451 Failed to deliver PoolMgrSelectWritePoolMsg message <{*}:{*}> to [SpaceManager@local:>PoolManager@local]: Route for >*@dCacheDomain< not found at >spacemanagerDomain<',
#        'TRANSFER globus_ftp_client: the server responded with an error 500 500-Command failed. : globus_xio: Unable to connect to{*}:{*} 500-globus_xio: System error in connect: Connection timed out 500-globus_xio: A system call failed: Connection timed out 500 End.',
#        'TRANSFER globus_ftp_client: the server responded with an error 451 General problem: Failed to connect [{*}:{*}:{*}:{*}:{*}]:{*}:',
#        'TRANSFER globus_ftp_client: the server responded with an error 530 Login failed: Failed to deliver LoginMessage message <{*}:{*}> to [>gPlazma@local]: Route for >gPlazma@local< not found at >dCacheDomain<',
#        'TRANSFER CHECKSUM MISMATCH Source and destination checksums do not match{*} !={*}',
#        'DESTINATION MAKE_PARENT srm-ifce err: Permission denied, err: [SE][Mkdir][SRM_AUTHORIZATION_FAILURE] httpg:/recas-se-01.cs.infn.it:8446/srm/managerv2: srm:/recas-se-01.cs.infn.it/dpm/cs.infn.it/home/atlas/atlasdatadisk/rucio/user/hteagle/{*}/{*}: Permission denied',
#        'DESTINATION MAKE_PARENT srm-ifce err: Permission denied, err: [SE][Mkdir][SRM_AUTHORIZATION_FAILURE] httpg:/recas-se-01.cs.infn.it:8446/srm/managerv2: srm:/recas-se-01.cs.infn.it/dpm/cs.infn.it/home/atlas/atlasdatadisk/rucio/user/ymino/{*}/{*}: Permission denied',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg:/{*}:{*}/srm/managerv2: CGSI-gSOAP running on{*} reports Error reading token data header: Connection closed',
#        'TRANSFER globus_ftp_client: the server responded with an error 500 Command failed. : open/create : [ERROR] Server responded with an error: [3021] Unable to get quota space - quota not defined or exhausted /eos/cms/store/cmst3/user/echapon/pA_8p16TeV/miniAOD/PASingleMuon/{*}/{*}/0000/{*}; Disk quota exceeded',
#        'TRANSFER globus_ftp_client: the server responded with an error 451 451-GlobusError: v=1 c=INTERNAL_ERROR 451-GridFTP-Errno: 255 451-GridFTP-Reason: System error in write into HDFS (host={*}, user=cms, path=/cms/store/data/Run2018C/{*}/AOD/PromptReco-v2/000/319/{*}/00000/{*}) 451-GridFTP-Error-String: Unknown error 255 451 End.',
#        'TRANSFER globus_ftp_client: the server responded with an error 451 General problem: Problem while connected to [{*}:{*}:{*}:{*}]:{*}: Connection timed out',
#        'DESTINATION MAKE_PARENT srm-ifce err: Permission denied, err: [SE][Mkdir][SRM_AUTHORIZATION_FAILURE] httpg:/recas-se-01.cs.infn.it:8446/srm/managerv2: srm:/recas-se-01.cs.infn.it/dpm/cs.infn.it/home/atlas/atlasdatadisk/rucio/user/arsahu/{*}/{*}: Permission denied',
#        'TRANSFER globus_ftp_client: the server responded with an error 500 500-Command failed. : globus_xio: Unable to connect to{*}:{*}:{*}:{*}:{*} 500-globus_xio: System error in connect: Network is unreachable 500-globus_xio: A system call failed: Network is unreachable 500 End.',
#        'TRANSFER globus_ftp_client: the server responded with an error 451 451-GlobusError: v=1 c=INTERNAL_ERROR 451-GridFTP-Errno: 255 451-GridFTP-Reason: System error in write into HDFS (host={*}, user=cms, path=/cms/store/mc/{*}/{*}/MINIAODSIM/{*}/{*}/{*}) 451-GridFTP-Error-String: Unknown error 255 451 End.',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg:/{*}:{*}/srm/managerv2: CGSI-gSOAP running on{*} reports Error reading token data header: Connection reset by peer',
#        'srm-ifce err: Communication error on send, err: [SE][Ls][] httpg:/{*}:8446/srm/managerv2: CGSI-gSOAP running on{*} reports could not open connection to{*}:8446',
#        'DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg:/{*}:{*}/srm/managerv2: CGSI-gSOAP running on{*} reports Error reading token data header: Connection closed',
#        'Error reported from srm_ifce : 2 [SE][Ls][SRM_INVALID_PATH] No such file or directory /pnfs/usatlas.bnl.gov/BNLT0D1/rucio/{*}/{*}/{*}/{*}.{*}'],
#       dtype=object)

# %%
cluster.clusters
# Out:
#    cluster_name  cluster_size  \
# 4             4          6461
# 0             0          2357
# 7             7          1887
# 6             6          1426
# 8             8          1349
# 1             1          1342
# 5             5          1277
# 2             2          1268
# 12           12           829
# 3             3           749
# 9             9           530
# 10           10           390
# 13           13           366
# 11           11           335
# 15           15           156
# 16           16           144
#
#                                               pattern  \
# 4   TRANSFER globus_ftp_client: the server respond...
# 0   TRANSFER globus_ftp_client: the server respond...
# 7   DESTINATION MAKE_PARENT srm-ifce err: Permissi...
# 6   TRANSFER globus_ftp_client: the server respond...
# 8   TRANSFER globus_ftp_client: the server respond...
# 1   TRANSFER globus_ftp_client: the server respond...
# 5   TRANSFER globus_ftp_client: the server respond...
# 2   {*} CHECKSUM MISMATCH User defined checksum an...
# 12  {*} err:{*} error on{*} err: [SE][{*}][] httpg...
# 3   TRANSFER CHECKSUM MISMATCH USER_DEFINE and SRC...
# 9   TRANSFER globus_ftp_client: the server respond...
# 10  TRANSFER globus_ftp_client: the server respond...
# 13  Error reported from srm_ifce : 2 [SE][Ls][SRM_...
# 11  TRANSFER CHECKSUM MISMATCH Source and destinat...
# 15  DESTINATION SRM_PUTDONE Error on the surl srm:...
# 16  TRANSFER globus_ftp_client: the server respond...
#
#                                              sequence  mean_similarity  \
# 4   [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            91.75
# 0   [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            99.12
# 7   [DESTINATION, ▁MAKE_PARENT, ▁srm-ifce, ▁err, :...            97.94
# 6   [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            87.66
# 8   [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            94.13
# 1   [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            99.88
# 5   [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            97.04
# 2   [{*}, ▁CHECKSUM, ▁MISMATCH, ▁User, ▁defined, ▁...            99.88
# 12  [{*}, ▁err, :, {*}, ▁error, ▁on, {*}, ▁err, :,...            86.36
# 3   [TRANSFER, ▁CHECKSUM, ▁MISMATCH, ▁USER_DEFINE,...            99.97
# 9   [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...           100.00
# 10  [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            99.67
# 13  [Error, ▁reported, ▁from, ▁srm_ifce, ▁:, ▁2, ▁...            83.00
# 11  [TRANSFER, ▁CHECKSUM, ▁MISMATCH, ▁Source, ▁and...            99.82
# 15  [DESTINATION, ▁SRM_PUTDONE, ▁Error, ▁on, ▁the,...            90.96
# 16  [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            87.16
#
#     std_similarity                                            indices
# 4             4.34  [2, 3, 4, 5, 6, 8, 9, 10, 11, 12, 15, 16, 17, ...
# 0             2.74  [52, 61, 67, 68, 73, 88, 91, 98, 103, 109, 110...
# 7             1.65  [0, 7, 13, 14, 21, 23, 27, 29, 32, 33, 35, 36,...
# 6             9.76  [54, 59, 83, 90, 101, 105, 118, 122, 154, 184,...
# 8             2.82  [70, 72, 84, 94, 106, 111, 115, 121, 190, 212,...
# 1             1.06  [25, 42, 93, 99, 113, 117, 129, 195, 216, 295,...
# 5             5.81  [18, 71, 89, 107, 119, 147, 206, 220, 224, 237...
# 2             1.55  [77, 80, 85, 102, 114, 132, 133, 175, 177, 196...
# 12           10.71  [34, 51, 191, 225, 233, 264, 327, 331, 444, 48...
# 3             0.53  [65, 75, 82, 96, 130, 134, 162, 221, 223, 232,...
# 9             0.00  [291, 319, 320, 338, 339, 355, 373, 561, 575, ...
# 10            1.57  [87, 243, 322, 379, 680, 697, 699, 746, 772, 9...
# 13           12.69  [26, 187, 201, 332, 333, 342, 381, 547, 578, 7...
# 11            1.91  [238, 246, 297, 316, 358, 452, 569, 633, 891, ...
# 15            7.34  [74, 76, 104, 228, 229, 449, 494, 531, 962, 10...
# 16           10.75  [39, 60, 108, 123, 200, 375, 678, 765, 1058, 1...

# %%
cluster.in_cluster()
# Out:
#     cluster_name  cluster_size  \
# 24            24            99
# 14            14            88
# 19            19            78
# 18            18            72
# 21            21            72
# ..           ...           ...
# 206          206             1
# 208          208             1
# 209          209             1
# 210          210             1
# 322          322             1
#
#                                                pattern  \
# 24   Error on XrdCl:CopyProcess:Run(): [ERROR] Serv...
# 14   {*} on XrdCl:CopyProcess:Run(): [ERROR] Server...
# 19   DESTINATION SRM_PUTDONE Error on the surl srm:...
# 18   TRANSFER globus_ftp_client: the server respond...
# 21   {*} err: Communication error on send, err: [SE...
# ..                                                 ...
# 206  DESTINATION SRM_PUT_TURL error on the turl req...
# 208                                  Transfer canceled
# 209  Failed to create directory root://ccdcalitest1...
# 210  Error reported from srm_ifce : 16 [SE][Ls][SRM...
# 322  Result HTTP 404 : File not found after 1 attempts
#
#                                               sequence  mean_similarity  \
# 24   [Error, ▁on, ▁XrdCl, :, CopyProcess, :, Run, (...            76.02
# 14   [{*}, ▁on, ▁XrdCl, :, CopyProcess, :, Run, (, ...            99.27
# 19   [DESTINATION, ▁SRM_PUTDONE, ▁Error, ▁on, ▁the,...            99.60
# 18   [TRANSFER, ▁globus_ftp_client, :, ▁the, ▁serve...            94.95
# 21   [{*}, ▁err, :, ▁Communication, ▁error, ▁on, ▁s...            92.23
# ..                                                 ...              ...
# 206  [DESTINATION, ▁SRM_PUT_TURL, ▁error, ▁on, ▁the...           100.00
# 208                              [Transfer, ▁canceled]           100.00
# 209  [Failed, ▁to, ▁create, ▁directory, ▁root, :, /...           100.00
# 210  [Error, ▁reported, ▁from, ▁srm_ifce, ▁:, ▁16, ...           100.00
# 322  [Result, ▁HTTP, ▁404, ▁:, ▁File, ▁not, ▁found,...           100.00
#
#      std_similarity                                            indices
# 24            16.87  [729, 790, 976, 1160, 1485, 1590, 1701, 1875, ...
# 14             3.37  [1142, 1379, 1380, 1595, 1623, 1840, 2281, 249...
# 19             0.70  [95, 370, 481, 482, 655, 1264, 1856, 2456, 248...
# 18            11.31  [128, 183, 654, 709, 870, 1211, 1312, 1881, 20...
# 21             7.50  [882, 997, 1371, 2174, 2350, 2924, 2936, 3269,...
# ..              ...                                                ...
# 206            0.00                                            [16640]
# 208            0.00                                            [16053]
# 209            0.00                                            [16138]
# 210            0.00                                            [16204]
# 322            0.00                                             [8166]
#
# [307 rows x 7 columns]

# %%
cluster.in_cluster(15)
# Out:
# ['DESTINATION SRM_PUTDONE Error on the surl srm://tech-se.hep.technion.ac.il/atlas/atlasdatadisk/rucio/mc16_13TeV/55/7b/AOD.16512878._000135.pool.root.1 while putdone : [SE][PutDone][SRM_INVALID_PATH] PtP status for this SURL is SRM_ABORTED',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/b6/26/DAOD_TOPQ5.19542826._001161.pool.root.1 while putdone : [SE][PutDone][SRM_INVALID_PATH] SURL is not local: srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/b6/26/DAOD_TOPQ5.19542826._001161.pool.root.1',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://f-dpm001.grid.sinica.edu.tw/dpm/grid.sinica.edu.tw/home/atlas/atlasdatadisk/rucio/mc15_13TeV/11/d7/EVNT.19582724._139247.pool.root.1 while putdone : [SE][PutDone][SRM_AUTHORIZATION_FAILURE] <none>',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://svr018.gla.scotgrid.ac.uk/dpm/gla.scotgrid.ac.uk/home/atlas/atlasdatadisk/rucio/mc16_13TeV/e1/fc/DAOD_JETM1.18074520._000052.pool.root.1 while putdone : [SE][PutDone][SRM_FILE_LIFETIME_EXPIRED] <none>',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/6e/71/DAOD_TOPQ1.17832531._000050.pool.root.1 while putdone : [SE][PutDone][SRM_INVALID_PATH] SURL is not local: srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/6e/71/DAOD_TOPQ1.17832531._000050.pool.root.1',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://se01.indiacms.res.in/dpm/indiacms.res.in/home/cms/store/mc/PhaseIITDRFall17DR/QCD_Flat_Pt-15to7000_TuneCUETP8M1_14TeV_pythia8/GEN-SIM-RECO/PU200FEVT_93X_upgrade2023_realistic_v2_ext1-v1/210000/B0E2B684-F9CB-E711-AB02-001E677927A2.root while putdone : [SE][PutDone][SRM_FILE_LIFETIME_EXPIRED] <none>',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/d4/24/DAOD_TOPQ5.19542826._001471.pool.root.1 while putdone : [SE][PutDone][SRM_INVALID_PATH] SURL is not local: srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/d4/24/DAOD_TOPQ5.19542826._001471.pool.root.1',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/16/09/DAOD_TOPQ5.19542826._000972.pool.root.1 while putdone : [SE][PutDone][SRM_INVALID_PATH] SURL is not local: srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/16/09/DAOD_TOPQ5.19542826._000972.pool.root.1',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/35/f5/DAOD_TOPQ5.19542826._001270.pool.root.1 while putdone : [SE][PutDone][SRM_INVALID_PATH] SURL is not local: srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/35/f5/DAOD_TOPQ5.19542826._001270.pool.root.1',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://agh3.atlas.unimelb.edu.au/dpm/atlas.unimelb.edu.au/home/atlas/atlasdatadisk/rucio/mc16_13TeV/aa/f0/DAOD_JETM1.19763255._000574.pool.root.1 while putdone : [SE][PutDone][SRM_FILE_LIFETIME_EXPIRED] <none>',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://svr018.gla.scotgrid.ac.uk/dpm/gla.scotgrid.ac.uk/home/atlas/atlasdatadisk/rucio/mc16_13TeV/03/cc/DAOD_JETM1.18074520._000043.pool.root.1 while putdone : [SE][PutDone][SRM_FILE_LIFETIME_EXPIRED] <none>',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://se01.indiacms.res.in/dpm/indiacms.res.in/home/cms/store/mc/PhaseIITDRFall17DR/QCD_Flat_Pt-15to7000_TuneCUETP8M1_14TeV_pythia8/GEN-SIM-RECO/PU200FEVT_93X_upgrade2023_realistic_v2_ext1-v1/210000/42EA870B-BDCB-E711-BA64-A4BF0112E330.root while putdone : [SE][PutDone][SRM_FILE_LIFETIME_EXPIRED] <none>',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/ab/54/DAOD_TOPQ5.19542826._000984.pool.root.1 while putdone : [SE][PutDone][SRM_INVALID_PATH] SURL is not local: srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/ab/54/DAOD_TOPQ5.19542826._000984.pool.root.1',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://agh3.atlas.unimelb.edu.au/dpm/atlas.unimelb.edu.au/home/atlas/atlasdatadisk/rucio/mc16_13TeV/39/9f/DAOD_JETM1.19763255._000605.pool.root.1 while putdone : [SE][PutDone][SRM_FILE_LIFETIME_EXPIRED] <none>',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://tech-se.hep.technion.ac.il/atlas/atlasdatadisk/rucio/mc16_13TeV/71/6f/AOD.16512878._000145.pool.root.1 while putdone : [SE][PutDone][SRM_INVALID_PATH] PtP status for this SURL is SRM_ABORTED',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://recas-se-01.cs.infn.it/dpm/cs.infn.it/home/atlas/atlasdatadisk/rucio/data15_13TeV/f7/48/AOD.13100414._035219.pool.root.1 while putdone : [SE][PutDone][SRM_INTERNAL_ERROR] Timed out',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/5d/44/DAOD_TOPQ5.19542826._001305.pool.root.1 while putdone : [SE][PutDone][SRM_INVALID_PATH] SURL is not local: srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/5d/44/DAOD_TOPQ5.19542826._001305.pool.root.1',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://f-dpm001.grid.sinica.edu.tw/dpm/grid.sinica.edu.tw/home/atlas/atlasdatadisk/rucio/mc16_13TeV/14/d8/DAOD_JETM1.19763238._000015.pool.root.1 while putdone : [SE][PutDone][SRM_AUTHORIZATION_FAILURE] Permission denied (error 13 on smstor32.grid.sinica.edu.tw)',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://sbgse1.in2p3.fr/dpm/in2p3.fr/home/cms/phedex/store/mc/Run3Summer19DRPremix/SingleMuon_E-30/GEN-SIM-RECO/2021ScenarioRECO_106X_mcRun3_2021_realistic_v3-v2/260000/F31C4D72-2A07-9043-AD1B-6A114B40B456.root while putdone : [SE][PutDone][SRM_FILE_LIFETIME_EXPIRED] <none>',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV
pool.root.1 while putdone : [SE][PutDone][SRM_FILE_LIFETIME_EXPIRED] <none>',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://se01.indiacms.res.in/dpm/indiacms.res.in/home/cms/store/mc/PhaseIITDRFall17DR/QCD_Flat_Pt-15to7000_TuneCUETP8M1_14TeV_pythia8/GEN-SIM-RECO/PU200FEVT_93X_upgrade2023_realistic_v2_ext1-v1/20002/16283CC2-EAC1-E711-94AC-001E67E34034.root while putdone : [SE][PutDone][SRM_FAILURE] Incompatible with current file status',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://tech-se.hep.technion.ac.il/atlas/atlasdatadisk/rucio/mc16_13TeV/cd/5a/AOD.16512878._000134.pool.root.1 while putdone : [SE][PutDone][SRM_INVALID_PATH] PtP status for this SURL is SRM_ABORTED',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/ea/03/DAOD_TOPQ5.19542826._001258.pool.root.1 while putdone : [SE][PutDone][SRM_INVALID_PATH] SURL is not local: srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/ea/03/DAOD_TOPQ5.19542826._001258.pool.root.1',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://f-dpm001.grid.sinica.edu.tw/dpm/grid.sinica.edu.tw/home/atlas/atlasdatadisk/rucio/data17_13TeV/b6/1b/DAOD_HIGG3D3.19835731._000162.pool.root.1 while putdone : [SE][PutDone][SRM_AUTHORIZATION_FAILURE] <none>',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://se01.indiacms.res.in/dpm/indiacms.res.in/home/cms/store/mc/PhaseIITDRFall17DR/QCD_Flat_Pt-15to7000_TuneCUETP8M1_14TeV_pythia8/GEN-SIM-RECO/PU200FEVT_93X_upgrade2023_realistic_v2_ext1-v1/20000/FABEBA5F-5DCC-E711-999D-008CFAF28F22.root while putdone : [SE][PutDone][SRM_FAILURE] Incompatible with current file status',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://tech-se.hep.technion.ac.il/atlas/atlasdatadisk/rucio/mc16_13TeV/be/b1/AOD.16512878._000130.pool.root.1 while putdone : [SE][PutDone][SRM_INVALID_PATH] PtP status for this SURL is SRM_ABORTED',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/40/52/DAOD_TOPQ5.19542826._001384.pool.root.1 while putdone : [SE][PutDone][SRM_INVALID_PATH] SURL is not local: srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/40/52/DAOD_TOPQ5.19542826._001384.pool.root.1',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/09/d4/DAOD_TOPQ1.17832531._000017.pool.root.1 while putdone : [SE][PutDone][SRM_INVALID_PATH] SURL is not local: srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/09/d4/DAOD_TOPQ1.17832531._000017.pool.root.1',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://se01.indiacms.res.in/dpm/indiacms.res.in/home/cms/store/mc/PhaseIITDRFall17DR/QCD_Flat_Pt-15to7000_TuneCUETP8M1_14TeV_pythia8/GEN-SIM-RECO/PU200FEVT_93X_upgrade2023_realistic_v2_ext1-v1/20001/282E997F-EAC1-E711-B223-FA163E361A4E.root while putdone : [SE][PutDone][SRM_FILE_LIFETIME_EXPIRED] <none>',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/96/ab/DAOD_TOPQ1.17832531._000045.pool.root.1 while putdone : [SE][PutDone][SRM_INVALID_PATH] SURL is not local: srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/96/ab/DAOD_TOPQ1.17832531._000045.pool.root.1',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/86/79/DAOD_TOPQ5.19542826._001330.pool.root.1 while putdone : [SE][PutDone][SRM_INVALID_PATH] SURL is not local: srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/86/79/DAOD_TOPQ5.19542826._001330.pool.root.1',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/f7/b5/DAOD_TOPQ5.19542826._001221.pool.root.1 while putdone : [SE][PutDone][SRM_INVALID_PATH] SURL is not local: srm://srm.grid.sara.nl/pnfs/grid.sara.nl/data/atlas/atlasdatadisk/rucio/mc16_13TeV/f7/b5/DAOD_TOPQ5.19542826._001221.pool.root.1']

# %%
cluster.outliers.shape
# Out:
# (148, 7)

# %%
cluster.in_cluster(29)
# Out:
# ['DESTINATION SRM_PUTDONE Error on the surl srm://se.reef.man.poznan.pl/dpm/reef.man.poznan.pl/home/atlas/atlasdatadisk/rucio/data12_8TeV/fe/a7/data12_8TeV.00214176.physics_Egamma.merge.AOD.f486_m1255._lb0166._0001.1 while putdone : [SE][PutDone][SRM_FAILURE] Incompatible with current file status',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://se01.grid.nchc.org.tw/dpm/grid.nchc.org.tw/home/cms/store/data/Run2017E/ZeroBias/AOD/17Nov2017-v1/40001/7C9FE70C-EBD4-E711-90DF-A4BF01125C70.root while putdone : [SE][PutDone][SRM_FAILURE] Incompatible with current file status',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://svr018.gla.scotgrid.ac.uk/dpm/gla.scotgrid.ac.uk/home/atlas/atlasdatadisk/rucio/mc16_13TeV/4e/45/DAOD_JETM1.18074520._000042.pool.root.1 while putdone : [SE][PutDone][SRM_FAILURE] Incompatible with current file status',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://se01.grid.nchc.org.tw/dpm/grid.nchc.org.tw/home/cms/store/data/Run2018A/ZeroBias/ALCARECO/SiStripCalMinBias-17Sep2018_pilot-v1/100000/2AFA104B-197E-F447-ACB4-DDD3BA62DD14.root while putdone : [SE][PutDone][SRM_FAILURE] Incompatible with current file status',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://se01.grid.nchc.org.tw/dpm/grid.nchc.org.tw/home/cms/store/data/Run2018A/ZeroBias/ALCARECO/SiStripCalMinBias-17Sep2018_pilot-v1/100000/DD87BC63-2E63-B044-B56C-CCC02DCA2D41.root while putdone : [SE][PutDone][SRM_FAILURE] Incompatible with current file status',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://se01.grid.nchc.org.tw/dpm/grid.nchc.org.tw/home/cms/store/data/Run2018A/ZeroBias/ALCARECO/SiStripCalMinBias-17Sep2018_pilot-v1/100000/D9636794-3321-4641-968C-22BF0E807C15.root while putdone : [SE][PutDone][SRM_FAILURE] Incompatible with current file status',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://se01.grid.nchc.org.tw/dpm/grid.nchc.org.tw/home/cms/store/data/Run2017E/ZeroBias/AOD/17Nov2017-v1/30000/60849C93-6FD3-E711-9D62-6C3BE5B5F218.root while putdone : [SE][PutDone][SRM_FAILURE] Incompatible with current file status',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://se01.grid.nchc.org.tw/dpm/grid.nchc.org.tw/home/cms/store/data/Run2017E/ZeroBias/AOD/17Nov2017-v1/40002/5C501A20-D8D4-E711-9FEB-001E6779255C.root while putdone : [SE][PutDone][SRM_FAILURE] Incompatible with current file status',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://se01.grid.nchc.org.tw/dpm/grid.nchc.org.tw/home/cms/store/mc/RunIIFall17DRPremix/QCD_bEnriched_HT300to500_TuneCP5_13TeV-madgraph-pythia8/AODSIM/PU2017_94X_mc2017_realistic_v11-v2/100000/56F9B94B-E7C4-E811-9691-5065F3812201.root while putdone : [SE][PutDone][SRM_FAILURE] Incompatible with current file status',
#  'DESTINATION SRM_PUTDONE Error on the surl srm://atlasse.lnf.infn.it/dpm/lnf.infn.it/home/atlas/atlasdatadisk/rucio/mc15_13TeV