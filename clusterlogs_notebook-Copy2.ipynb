# %% [markdown]
# # Clusterlogs Notebook

# %%
import pandas as pd
from clusterlogs import multistage

# %% [markdown]
# ### 1. Download data from file and create pandas DataFrame with index

# %%
df = pd.read_csv('samples/harvester_errors24.csv', sep=';')

# %%
df.head()
# Out:
#                          id                                     message
# 0  CERN_central_B|111388583  Payload execution error: returned non-zero
# 1  CERN_central_B|111388549  Payload execution error: returned non-zero
# 2  CERN_central_B|111388581  Payload execution error: returned non-zero
# 3  CERN_central_B|111388573  Payload execution error: returned non-zero
# 4  CERN_central_B|111389035  Payload execution error: returned non-zero

# %% [markdown]
# ### 2. Initialize clusterization pipeline

# %% [raw]
# Required parameters are:
# - df - pandas DataFrame with error messages
# - target - name of a column with error messages
#
# Not required parameters are cluster_settings. If not defined - the default values are used.
# Note: It's better to use for big data samples with a vocabulary of more than 1000 tokens.
#
# CLUSTERING_DEFAULTS = {"tokenizer": "nltk",
#                        "w2v_size": "auto",
#                        "w2v_window": 5,
#                        "min_samples": 1}
#
# But you can define these parameters. For example,
#
# clustering_parameters = {'tokenizer':'nltk',
#                          'w2v_size': 200,
#                          'w2v_window': 5,
#                          'min_samples': 1}
#
# cluster = pipeline.ml_clustering(df, target, clustering_parameters)

# %%
target = 'message'

# %%
result = multistage.exec(df, target, 'harvester.model', threshold=100)
# Out:
# /Users/maria/anaconda3/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# /Users/maria/anaconda3/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
result.clusters.sort_values(by=['pattern'])['pattern'].values
# Out:
# array(['* *+ long usatlas * COMPLETED *', '* *+ long usatlas * FAILED *',
#        '* *+ regular * * PENDING *', '* long usatlas * COMPLETED *',
#        '* long usatlas * FAILED *',
#        '* not submitted due to incomplete data of the worker',
#        '* regular * * PENDING *', ': *',
#        'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:/usr/libexec/pbs_submit.sh: line * [: -gt: unary operator expected-pbs_iff: cannot read reply from pbs_server-No Permission.-qsub: cannot connect to ',
#        "Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:mkdir: cannot create directory `/var/jwgen//*': File exists-cp: accessing `/var/jwgen//*/submit.req': Permission",
#        'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from *) N/A (jobId = *); Worker canceled by harvest',
#        'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: Invalid credential MSG=Hosts do not match-) N/A (jobId = *); Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: Invalid credential-) N/A (jobId = *); Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@*, queue *',
#        'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlpilot@*, queue atlasana-',
#        'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user *@*',
#        'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user *@lcgceatlas.dnp.fmph',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Connection to service [https://*/ce-cream/services/*] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[S',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: MethodName=[JobRegister] ErrorCode=[*] Description=[Authorization failure: No PEP Server [https://*/authz] was able to process the request] FaultCause=[Authorization error]',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: MethodName=[JobRegister] ErrorCode=[*] Description=[Authorization failure: No PEP Server [https://*/authz] was able to process the request] FaultCause=[Authorization error] Ti',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: MethodName=[JobRegister] ErrorCode=[*] Description=[CN=Robot: ATLAS *,CN=*,CN=*,OU=Users,OU=Organic Units,DC=cern,DC=ch not authorized for {http://glite.org/*/*/ce/cream/types}J',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: MethodName=[jobRegister] ErrorCode=[*] Description=[The CREAM service cannot accept jobs at the moment] FaultCause=[Submissions are disabled!] Timestamp=[Mon * Dec * *]; Worker canceled',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: MethodName=[jobRegister] ErrorCode=[*] Description=[The CREAM service cannot accept jobs at the moment] FaultCause=[Submissions are disabled!] Timestamp=[Tue * Dec * *]; Worker canceled',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: MethodName=[jobRegister] ErrorCode=[*] Description=[The CREAM service cannot accept jobs at the moment] FaultCause=[Threshold for FTP Connection: * => Detected value for FTP Connection: *\\n\\n] Tim',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: MethodName=[jobRegister] Timestamp=[Mon * Dec * *] ErrorCode=[*] Description=[system error] FaultCause=[database error occurred]; Worker canceled by harvester due to held too long or no',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: MethodName=[jobRegister] Timestamp=[Tue * Dec * *] ErrorCode=[*] Description=[system error] FaultCause=[database error occurred]  ; Worker canceled by harvester due to held too long or no',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Resolver internal error]; Worke',
#        'Condor HoldReason: CREAM error: CREAM_Job_Start Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker cancel',
#        'Condor HoldReason: CREAM error: CREAM_Job_Status Error: MethodName=[JobStatus] ErrorCode=[*] Description=[Authorization failure: No PEP Server [https://*/authz] was able to process the request] FaultCause=[Authorization error] Timest',
#        'Condor HoldReason: CREAM error: Cannot move /home/*/*/*/../* to /home/*/*/*  ; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: CREAM error: Cannot move /home/*/*/*/../* to /home/*/*/* mv: cannot stat \x18/home/*/*/*/../ru',
#        'Condor HoldReason: CREAM error: Cannot move ISB (retry_copy ${globus_transfer_cmd}',
#        'Condor HoldReason: CREAM error: Cannot move ISB (retry_copy ${globus_transfer_cmd} gsiftp://*/var/cream_sandbox/atlas/*',
#        'Condor HoldReason: CREAM error: Cannot move ISB (retry_copy ${globus_transfer_cmd} gsiftp://*/var/cream_sandbox/atlasprd/*',
#        'Condor HoldReason: CREAM error: Cannot move ISB (retry_copy ${globus_transfer_cmd} gsiftp://*/var/cream_sandbox/pilatlas/*',
#        'Condor HoldReason: CREAM error: Cannot move ISB (retry_copy ${globus_transfer_cmd} gsiftp://*/var/cream_sandbox/prdatl/*',
#        'Condor HoldReason: CREAM error: Cannot move ISB (retry_copy ${globus_transfer_cmd} gsiftp://ce.le.infn.it/var/cream_sandbox/pilatlas/*',
#        'Condor HoldReason: CREAM error: Cannot move ISB (retry_copy ${globus_transfer_cmd} gsiftp://cream-ce.core.wits.ac.za/var/cream_sandbox/prdatlas/*',
#        'Condor HoldReason: CREAM error: Job has been terminated (got SIGTERM)',
#        'Condor HoldReason: CREAM error: Job has been terminated (got SIGTERM); Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: CREAM error: Job has been terminated (got SIGTERM); reason=*; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: CREAM error: Job has been terminated (got SIGXCPU); Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: CREAM error: Job has been terminated (got SIGXCPU); reason=*',
#        'Condor HoldReason: CREAM error: Job has been terminated (got SIGXCPU); reason=* Job has been terminated (got SIGXCPU) ',
#        'Condor HoldReason: CREAM error: Job has been terminated (got SIGXCPU); reason=* Job has been terminated (got SIGXCPU); Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: CREAM error: Job has been terminated (got SIGXCPU); reason=*; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: CREAM error: Problem to detect the lifetime of the proxy; Job has been terminated (got SIGTERM); Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: CREAM error: Problem to detect the lifetime of the proxy; Job has been terminated (got SIGTERM); reason=*; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: CREAM error: Transfer failed: GRIDFTP_TRANSFER timed out  ; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: CREAM error: Transfer failed: an end-of-file was reached globus_xio: An end of file occurred  ; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * * failed. : *  * failed.  *',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * * failed.: callback failed. * Unable to connect to * * System error in connect: Connecti',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * * failed.: callback failed. * Unable to connect to * * System error in connect: Connection',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * * failed.: globus_l_gfs_file_open failed. * Unable to open file',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * * failed.: globus_l_gfs_file_open failed. * Unable to open file /var/cream_sandbox/atlasprd/*',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * * failed.: globus_l_gfs_file_open failed. * Unable to open file /var/cream_sandbox/pilatlas/*',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * * failed.: globus_l_gfs_file_open failed. * Unable to open file /var/cream_sandbox/prdatl/*',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * * failed.: globus_l_gfs_file_open failed. * Unable to open file /var/cream_sandbox/prdatlas/*',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * * failed.: globus_l_gfs_file_open failed. * Unable to open file /var/glite/cream_sandbox/atlas/*',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * * failed.: globus_l_gfs_file_open failed. * Unable to open file /vols/cream_sandbox/*/*',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * * incorrect.: globus_gss_assist: Error invoking callout * The callout returned an error * unknown error occu',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * Please login with USER and PASS.; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_xio: System error in recv: Connection reset by peer globus_xio: A system call failed: Connection reset by peer; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_xio: System error in send: Connection reset by peer globus_xio: A system call failed: Connection reset by peer  ; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_xio: Unable to connect to * globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out; Worker canceled by',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_xio: Unable to connect to * globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out; Worker canceled by harveste',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_xio: Unable to connect to * globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out; Worker canceled by harvester',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_xio: Unable to connect to * globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out; Worker canceled by harvester',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_xio: Unable to connect to * globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out; Worker canceled by harvester due',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_xio: Unable to connect to * globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out; Worker canceled by harvester due to',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_xio: Unable to connect to * globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out; Worker canceled by harvester due to h',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_xio: Unable to connect to * globus_xio: System error in connect: No route to host globus_xio: A system call failed: No route to host; Worker canceled by harvester due to h',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_xio: Unable to connect to * globus_xio: System error in connect: No route to host globus_xio: A system call failed: No route to host; Worker canceled by harvester due to held to',
#        'Condor HoldReason: CREAM error: reason=*',
#        'Condor HoldReason: CREAM error: reason=* /data/* line * ./* No such file or directory; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: CREAM error: reason=* /var/lib/slurm-llnl/slurmd/*/slurm_script: line * ./* No such file or directory; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: CREAM error: reason=*; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [http(s)://*/ce-cream/services/gridsite-delegation] failed: FaultString=[HTTP Error] - FaultCode=[SOAP-ENV:Server] - FaultSubCode=[SOAP-ENV:Server] - FaultDetail=[HTTP/* *',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://*/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://*/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection reset by peer]; Worker canceled by ha',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]; Worker canceled by harves',
#        'Condor HoldReason: ERROR: Failed to submit job; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: Error connecting to schedd * * to received post-auth * to authenticate using FS; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: Error from *@* CPU usage exceeded request_cpus; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: Error locating schedd *',
#        'Condor HoldReason: Error locating schedd *; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: Error parsing classad or job not found; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: Error receiving files from schedd * * transfer failed for target job * SCHEDD at * failed to send file(s) to <*>: error reading from',
#        'Condor HoldReason: Error receiving files from schedd * * transfer failed for target job * SCHEDD at * failed to send file(s) to <*>: error reading from /',
#        'Condor HoldReason: Error sending files to schedd * * transfer failed for target job * Failed to receive GoAhead message from *  ; Worker canceled by harvester due to held too long',
#        'Condor HoldReason: Error sending files to schedd * * transfer failed for target job * Failed to receive GoAhead message from *  ; Worker canceled by harvester due to held too long o',
#        'Condor HoldReason: Error sending files to schedd * * transfer failed for target job * Failed to receive GoAhead message from *; Worker canceled by harvester due to held too long or',
#        'Condor HoldReason: Failed to start GAHP; Worker canceled by harvester due to held too long or not found',
#        "Condor HoldReason: HTCondor-CE held job due to no matching routes, route job limit, or route failure threshold; see 'HTCondor-CE Troubleshooting Guide'",
#        "Condor HoldReason: HTCondor-CE held job due to no matching routes, route job limit, or route failure threshold; see 'HTCondor-CE Troubleshooting Guide'; Worker canceled by harvester due to held too long or not found",
#        'Condor HoldReason: Job not found; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: Job removed from batch queue manually',
#        'Condor HoldReason: Job removed from batch queue manually; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: NORDUGRID_SUBMIT timed out; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: Network error talking to schedd, probably an authorization failure  ; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: Spooling input data files; Worker canceled by harvester due to held too long or not found',
#        "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= * && JobStatus == * )' evaluated to TRUE",
#        "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= * && JobStatus == * )' evaluated to TRUE; Worker canceled by harvester due to held too long or not found",
#        "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '(* =?= undefined) || (* =?= undefined) || ((time()> *) && JobStatus =!= * && JobStatus =!= *) || (RoutedBy =?= null && JobU",
#        'Condor HoldReason: Unspecified gridmanager error',
#        'Condor HoldReason: Unspecified gridmanager error; Condor RemoveReason: Python-initiated action. (by user atlpan)',
#        'Condor HoldReason: Unspecified gridmanager error; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: an end-of-file was reached globus_xio: An end of file occurred  ; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: globus_xio: System error in recv: Connection reset by peer globus_xio: A system call failed: Connection reset by peer ; Condor RemoveReason: Python-initiated action. (by user atlpan) ',
#        'Condor HoldReason: globus_xio: System error in recv: Connection reset by peer globus_xio: A system call failed: Connection reset by peer; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: globus_xio: Unable to connect to * globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out  ; Worker canceled by harvester due to held too long or not found',
#        'Condor HoldReason: globus_xio: Unable to connect to * globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out; Worker canceled by harvester due to held too long or no',
#        'Condor HoldReason: globus_xio: Unable to connect to * globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out; Worker canceled by harvester due to held too long or not',
#        'Condor HoldReason: globus_xio: Unable to connect to * globus_xio: globus_libc_getaddrinfo failed. globus_common: Name or service not known  ; Worker canceled by harvester due to held too long or not found',
#        'Error reading user generated output file list',
#        'Failed during processing failure; Serious troubles (problems during processing problems)',
#        'Failed in data staging: Could not resolve any source replicas for rucio://rucio-lb-prod.cern.ch/replicas/*/*',
#        'Failed in data staging: Could not resolve any source replicas for rucio://rucio-lb-prod.cern.ch/replicas/*/* Failed in data staging: Could not resolve any source replicas for rucio://rucio-lb-prod.cern.ch/replicas/m',
#        'Failed in data staging: Could not resolve any source replicas for rucio://rucio-lb-prod.cern.ch/replicas/*/* Resolving of index service for source failed: Failed to conta',
#        'Failed in data staging: Could not resolve any source replicas for rucio://rucio-lb-prod.cern.ch/replicas/*/* Resolving of index service for source failed: Failed to contact server: Connection was closed',
#        'Failed in data staging: Could not resolve any source replicas for rucio://rucio-lb-prod.cern.ch/replicas/*/* Resolving of index service for source failed: No such file or',
#        'Failed in data staging: Could not resolve any source replicas for rucio://rucio-lb-prod.cern.ch/replicas/*/* Resolving of index service for source failed: No such file or directory',
#        'Failed in data staging: Could not resolve any source replicas for rucio://rucio-lb-prod.cern.ch/replicas/*/* Resolving of index service for source failed: No such file or directory: No valid locations fou',
#        'Failed in data staging: Could not resolve any source replicas for rucio://rucio-lb-prod.cern.ch/replicas/*/* Resolving of index service for source failed: No such file or directory: No valid locations found',
#        'Failed in data staging: Could not resolve any source replicas for rucio://rucio-lb-prod.cern.ch/replicas/*/* Resolving of index service for source failed: No such file or directory; Failed in data staging: Co',
#        'Failed in data staging: Could not resolve any source replicas for rucio://rucio-lb-prod.cern.ch/replicas/*/* Resolving of index service for source failed: No such file or directory; Failed in data staging: Could no',
#        'Failed in data staging: Could not resolve any source replicas for rucio://rucio-lb-prod.cern.ch/replicas/*/* Resolving of index service for source failed: No such file or directory; Failed in data staging: Could not',
#        'Failed in data staging: Could not resolve any source replicas for rucio://rucio-lb-prod.cern.ch/replicas/*/* Resolving of index service for source failed: No such file or directory|Failed in data staging: Could not ',
#        'Failed in data staging: Failed checking source replica davs://*/webdav/atlas/atlaslocalgroupdisk/rucio/*/*/*/* Failed to obtain information about file: SSL error, "* alert handshake',
#        'Failed in data staging: Failed checking source replica https://*/arex/cache/rucio://rucio-lb-prod.cern.ch/replicas/*/* Failed to obtain information about file: No such file or dir',
#        'Failed in data staging: Failed checking source replica root://*//dpm/*/home/atlas/atlasdatadisk/rucio/*/*/*/* Failed to obtain information about file: Permission denied',
#        'Failed in data staging: Failed checking source replica root://*//dpm/*/home/atlas/atlasdatadisk/rucio/*/*/*/* Failed to obtain information about file: Permission denied;',
#        'Failed in data staging: Failed checking source replica root://*//dpm/*/home/atlas/atlasdatadisk/rucio/*/*/*/* Failed to obtain information about file: Permission denied; Failed in',
#        'Failed in data staging: Failed checking source replica root://*//dpm/*/home/atlas/atlasdatadisk/rucio/*/*/ac/* Failed to obtain information about file: Permission denied',
#        'Failed in data staging: Failed checking source replica root://*//dpm/*/home/atlas/atlasdatadisk/rucio/*/*/bb/* Failed to obtain information about file: Permission denied',
#        'Failed in data staging: Failed checking source replica root://*//dpm/*/home/atlas/atlasdatadisk/rucio/*/*/bd/* Failed to obtain information about file: Permission denied; Fai',
#        'Failed in data staging: Failed checking source replica root://*//dpm/*/home/atlas/atlasdatadisk/rucio/*/*/bd/* Failed to obtain information about file: Permission denied; Failed in dat',
#        'Failed in data staging: Failed checking source replica root://*//dpm/*/home/atlas/atlasdatadisk/rucio/*/ac/*/* Failed to obtain information about file: Permission denied',
#        'Failed in data staging: Failed checking source replica root://*//dpm/*/home/atlas/atlasdatadisk/rucio/*/ac/*/* Failed to obtain information about file: Permission denied; Fai',
#        'Failed in data staging: Failed checking source replica root://*//dpm/*/home/atlas/atlasdatadisk/rucio/*/af/*/* Failed to obtain information about file: Permission denied; Failed in dat',
#        'Failed in data staging: Failed checking source replica root://*//dpm/*/home/atlas/atlasdatadisk/rucio/*/ed/fc/* Failed to obtain information about file: Permission denied',
#        'Failed in data staging: Failed checking source replica root://*//dpm/*/home/atlas/atlasdatadisk/rucio/*/fa/*/* Failed to obtain information about file: Permission denied',
#        'Failed in data staging: Failed checking source replica root://*//dpm/atlas.unimelb.edu.au/home/atlas/atlasdatadisk/rucio/*/*/*/* Failed to obtain information about file: Permission de',
#        'Failed in data staging: Failed checking source replica root://*//dpm/grid.sinica.edu.tw/home/atlas/atlasdatadisk/rucio/*/*/*/* Failed to obtain information about file: Perm',
#        'Failed in data staging: Failed checking source replica root://*//dpm/ph.liv.ac.uk/home/atlas/atlasdatadisk/rucio/*/*/*/* Failed to obtain information about file: Permission denied',
#        'Failed in data staging: Failed checking source replica root://*//dpm/ph.liv.ac.uk/home/atlas/atlasdatadisk/rucio/*/*/*/* Failed to obtain information about file: Permission denied; Fail',
#        'Failed in data staging: Failed checking source replica root://*//dpm/ph.liv.ac.uk/home/atlas/atlasdatadisk/rucio/*/ed/*/* Failed to obtain information about file: Permission denied',
#        'Failed in data staging: Failed checking source replica root://*//eos/atlas/atlasdatadisk/rucio/*/*/*/* Failed to obtain information about file: Permission denied',
#        'Failed in data staging: Failed checking source replica root://*//eos/atlas/atlasdatadisk/rucio/*/*/ce/* Failed to obtain information about file: Permission denied',
#        'Failed in data staging: Failed checking source replica root://*//eos/atlas/atlasdatadisk/rucio/*/ac/*/* Failed to obtain information about file: Permission denied',
#        'Failed in data staging: Failed checking source replica root://*//pnfs/*/atlasdatadisk/rucio/*/*/ee/* Failed to obtain information about file: Permission denied',
#        'Failed in data staging: Failed checking source replica root://*//pnfs/*/atlasdatadisk/rucio/*/ab/*/* Failed to obtain information about file: Permission denied',
#        'Failed in data staging: Failed checking source replica root://*//pnfs/pic.es/data/atlas/atlasdatadisk/rucio/*/*/*/* Failed to obtain information about file: Permission denied',
#        'Failed in data staging: Failed checking source replica root://*//pnfs/pic.es/data/atlas/atlasdatadisk/rucio/*/*/*/* Failed to obtain information about file: Permission denied; Failed in',
#        'Failed in data staging: Failed checking source replica root://*//pnfs/pic.es/data/atlas/atlasdatadisk/rucio/*/*/bb/* Failed to obtain information about file: Permission denied',
#        'Failed in data staging: Failed checking source replica root://*//pnfs/pic.es/data/atlas/atlasdatadisk/rucio/*/aa/*/* Failed to obtain information about file: Permission denied; Failed in',
#        'Failed in data staging: Failed checking source replica root://*//pnfs/pic.es/data/atlas/atlasdatadisk/rucio/*/bb/*/* Failed to obtain information about file: Permission denied',
#        'Failed in data staging: Failed checking source replica root://*//pnfs/pic.es/data/atlas/tape/atlasdatatape//*/AOD/*/*/*',
#        'Failed in data staging: Failed checking source replica root://*//pnfs/pic.es/data/atlas/tape/atlasmctape//*/HITS/*/*',
#        "Failed in data staging: Failed reading from source: gsiftp://*/*/mnt/*/atlas/*/* : Can't read from source: globus_ftp_client: the server re",
#        'Failed in data staging: Failed to prepare destination srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/*/*/*=*=* Failed to prepare destination: Fi',
#        'Failed in data staging: Failed to prepare destination srm://*/srm/*?SFN=/atlas/disk/atlasscratchdisk/rucio/panda/*/*/*',
#        'Failed in data staging: Failed to prepare destination srm://*/srm/*?SFN=/dpm/lhep.unibe.ch/home/atlas/atlasscratchdisk/rucio/panda/ca/*/*',
#        'Failed in data staging: Failed to prepare source',
#        'Failed in data staging: Failed to prepare source Failed to prepare source: Resource te',
#        'Failed in data staging: Failed to prepare source Failed to prepare source: Resource te',
#        'Failed in data staging: Failed to prepare source Failed to prepare source: Resource temporarily unavailable: File reques',
#        'Failed in data staging: Failed to prepare source Failed to prepare source: Resource temporarily unavailable: File reques',
#        'Failed in data staging: Failed to prepare source Failed to prepare source: Resource temporarily unavailable: File reques',
#        'Failed in data staging: Failed to prepare source Failed to prepare source: Resource temporarily unavailable: File request',
#        'Failed in data staging: Failed to prepare source Failed to prepare source: Resource temporarily unavailable: File requests',
#        'Failed in data staging: Failed to prepare source Failed to prepare source: Resource temporarily unavailable: File requests',
#        'Failed in data staging: Failed to prepare source Failed to prepare source: Resource temporarily unavailable: File requests',
#        'Failed in data staging: Failed to prepare source Failed to prepare source: Resource temporarily unavailable: File requests h',
#        'Failed in data staging: Failed to prepare source Failed to prepare source: Resource temporarily unavailable: File requests h',
#        'Failed in data staging: Failed to prepare source Failed to prepare source: Resource temporarily unavailable: File requests h',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/*/*/* Failed to prepare source: Resource te',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/*/*/* Failed to prepare source: Resource temporarily unavailable: File reques',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/*/*/* Failed to prepare source: Resource temporarily unavailable: File request',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/*/*/* Failed to prepare source: Resource temporarily unavailable: File requests',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/*/*/* Failed to prepare source: Resource temporarily unavailable: File requests h',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/*/*/* Failed to prepare source: Resource temporarily unavailable: File requests have',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/*/be/* Failed to prepare source: Resource temporarily unavailable: File requests',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/*/be/* Failed to prepare source: Resource temporarily unavailable: File requests h',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/*/be/* Failed to prepare source: Resource temporarily unavailable: File requests have fai',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/*/ce/* Failed to prepare source: Resource temporarily unavailable: File requests h',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/*/ff/* Failed to prepare source: Resource temporarily unavailable: File requests have f',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/be/*/* Failed to prepare source: Resource temporarily unavailable: File requests',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/be/*/* Failed to prepare source: Resource temporarily unavailable: File requests h',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/be/ca/* Failed to prepare source: Resource temporarily unavailable: File requests h',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/bf/ce/* Failed to prepare source: Resource temporarily unavailable: File reques',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/ce/*/* Failed to prepare source: Resource temporarily unavailable: File reques',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/ce/*/* Failed to prepare source: Resource temporarily unavailable: File requests ',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/ce/*/* Failed to prepare source: Resource temporarily unavailable: File requests h',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/ce/ea/* Failed to prepare source: Resource temporarily unavailable: File requests h',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/ec/*/* Failed to prepare source: Resource temporarily unavailable: File requests have fai',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/fd/cb/* Failed to prepare source: Resource te',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/tape/atlasdatatape/*/AOD/*/*/*',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/atlas/tape/atlasmctape/*/AOD/*/*',
#        'Failed in data staging: Failed to prepare source srm://*/srm/*?SFN=/castor/cern.ch/grid/atlas/rucio/derived/*/physics_Main/*/*/*',
#        "Failed in data staging: Failed writing to destination: file:/arc/abisko/*/data/*/* : Can't write to destination: File exists: Failed to create file /arc/abisko/*/data/*/*",
#        "Failed in data staging: Failed writing to destination: file:/ceph/grid/cache/data/*/* : Can't write to destination: File exists: Failed to create file /ceph/grid/cache/data/*/*",
#        'Failed in data staging: Transfer timed out',
#        "Failed to create a JOB; ('Connection aborted.', ConnectionResetError(*, 'Connection reset by peer'))",
#        "Failed to create a JOB; HTTPSConnectionPool(host='*', port=*): Max retries exceeded with url: /apis/batch/*/namespaces/default/jobs (Caused by NewConnectionError('<* object at *>: Failed to establish a new connection: [Errno *] Connection refused',))",
#        'JOB id=* not found', 'Job submission to LRMS failed',
#        'LRMS error: (*)',
#        'LRMS error: (*) ExitReason: died on signal * (Hangup)',
#        'LRMS error: (*) Job exceeded time limit.',
#        'LRMS error: (*) Job failed',
#        'LRMS error: (*) Job failed with exit code *',
#        'LRMS error: (*) Job finished with unknown exit code',
#        'LRMS error: (*) Job missing from SLURM',
#        'LRMS error: (*) Job missing from SLURM, exitcode recovered from session directory',
#        'LRMS error: (*) Job missing from SLURM|Failed in data staging: Failed to prepare destination',
#        'LRMS error: (*) Job missing from SLURM|Failed in data staging: Failed to prepare destination srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/*/*/*=*=f',
#        'LRMS error: (*) Job missing from SLURM|Failed in data staging: Failed to prepare destination srm://*/srm/*?SFN=/atlas/disk/atlasdatadisk/rucio/*/cb/*/*=*=*',
#        'LRMS error: (*) Job missing from SLURM|Failed in data staging: Failed to prepare destination srm://*/srm/*?SFN=/lustre/ific.uv.es/grid/atlas/atlasdatadisk/rucio/*/*/*/*=a',
#        'LRMS error: (*) Job missing from SLURM|Failed in data staging: Failed to prepare destination srm://*/srm/*?SFN=/lustre/ific.uv.es/grid/atlas/atlasdatadisk/rucio/*/*/*/*=ad',
#        'LRMS error: (*) Job missing from SLURM|Failed in data staging: Failed to prepare destination srm://*/srm/*?SFN=/lustre/ific.uv.es/grid/atlas/atlasdatadisk/rucio/*/ff/*/*=ad',
#        'LRMS error: (*) Job timeout', 'LRMS error: (*) Job was cancelled',
#        'LRMS error: (*) Job was cancelled by SLURM',
#        'LRMS error: (*) Node fail',
#        'LRMS error: (*) RemoveReason: Job removed by SYSTEM_PERIODIC_REMOVE due to exceeding the requested memory.',
#        'LRMS error: (*) RemoveReason: Job removed by SYSTEM_PERIODIC_REMOVE due to job running more than once.',
#        "LRMS error: (*) RemoveReason: The system macro SYSTEM_PERIODIC_REMOVE expression '( RemoteWallClockTime> * * * * *) || (RemoteSysCpu + RemoteUserCpu> * * * * *) || (( JobStatus == * && (CurrentTime - EnteredCurrentStatus) > * * *) ) ||",
#        "LRMS error: (*) RemoveReason: The system macro SYSTEM_PERIODIC_REMOVE expression '(RemoteWallClockTime> * * * * *) || (RemoteSysCpu + RemoteUserCpu> * * * * *) || ((JobStatus == * && (CurrentTime - EnteredCurrentStatus)> * * *)) || (ResidentS",
#        'LRMS error: (*) job killed: cput',
#        'LRMS error: (*) job killed: vmem',
#        'LRMS error: (*) job killed: wall',
#        'Payload execution error: returned non-zero', 'Unknown error',
#        'condor job submissionHost=LOCAL batchID=* not found. Skipped',
#        'submission failed:',
#        'submission failed: Exception OSError: [Errno *] No space left on device'],
#       dtype=object)

# %%
result._1.timings
# Out:
# {'data_preparation': 1.192,
#  'tokenization': 1.7429,
#  'tokens_vectorization': 3.0018,
#  'sentence_vectorization': 11.9688,
#  'dimensionality_reduction': 0.1306,
#  'kneighbors': 16.3482,
#  'epsilon_search': 0.095,
#  'dbscan': 15.8324,
#  'extract_patterns': 12.0629,
#  'process': 62.2441}

# %%
result._2.timings
# Out:
# {'data_preparation': 0.062,
#  'tokenization': 0.0708,
#  'tokens_vectorization': 0.0086,
#  'sentence_vectorization': 0.4832,
#  'dimensionality_reduction': 0.0135,
#  'kneighbors': 0.1351,
#  'epsilon_search': 0.0031,
#  'dbscan': 0.1116,
#  'extract_patterns': 0.45,
#  'process': 1.3244}

# %%
result.out.patterns.sort_values(by=['pattern'])['pattern']
# Out:
# 7     * not submitted due to incomplete data of the ...
# 22    Condor HoldReason: CREAM error: BLAH error: su...
# 2     Condor HoldReason: CREAM error: BLAH error: su...
# 16    Condor HoldReason: CREAM error: CREAM_Job_Regi...
# 25    Condor HoldReason: CREAM error: CREAM_Job_Regi...
# 20    Condor HoldReason: CREAM error: Cannot move IS...
# 9     Condor HoldReason: CREAM error: Transfer faile...
# 19    Condor HoldReason: CREAM_Delegate Error: Recei...
# 29    Condor HoldReason: Error receiving files from ...
# 15    Condor HoldReason: Error: Connection to servic...
# 18    Condor HoldReason: Error: Received NULL fault;...
# 4     Condor HoldReason: HTCondor-CE held job due to...
# 14    Condor HoldReason: The system macro SYSTEM_PER...
# 10    Condor HoldReason: The system macro SYSTEM_PER...
# 26    Condor HoldReason: globus_xio: Unable to conne...
# 8     Condor HoldReason:; Worker canceled by harvest...
# 17            Failed in data staging: Failed to prepare
# 12    Failed in data staging: Failed to prepare sour...
# 23    Failed to create a JOB; HTTPSConnectionPool(ho...
# 1                                    JOB id=* not found
# 13                                      LRMS error: (*)
# 24    LRMS error: (*) ExitReason: died on signal * (...
# 11               LRMS error: (*) Job missing from SLURM
# 5                    LRMS error: (*) Job with exit code
# 21    LRMS error: (*) RemoveReason: Job removed by S...
# 6                           LRMS error: (*) job killed:
# 0            Payload execution error: returned non-zero
# 3     submission failed: Exception OSError: [Errno *...
# Name: pattern, dtype: object

# %%
result.out.patterns['pattern'].values
# Out:
# array(['Payload execution error: returned non-zero', 'JOB id=* not found',
#        'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user',
#        'submission failed: Exception OSError: [Errno *] No space left on device',
#        'Condor HoldReason:; Worker canceled by harvester due to held too long or not found',
#        "Condor HoldReason: HTCondor-CE held job due to no matching routes, route job limit, or route failure threshold; see 'HTCondor-CE Troubleshooting Guide'",
#        'LRMS error: (*) job killed:',
#        'LRMS error: (*) Job with exit code',
#        'Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * * failed.: failed. *',
#        '* not submitted due to incomplete data of the worker',
#        'Failed in data staging: Failed to prepare source Failed to prepare source: Resource',
#        "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '(* =?= undefined) || (* =?= undefined) || ((time()> *) && JobStatus =!= * && JobStatus =!= *) || (RoutedBy =?= null && JobU",
#        'LRMS error: (*) Job missing from SLURM', 'LRMS error: (*)',
#        'Condor HoldReason: CREAM error: Cannot move ISB (retry_copy ${globus_transfer_cmd}',
#        "Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( NumJobStarts >= * && JobStatus == * )' evaluated to TRUE",
#        'Failed in data staging: Failed to prepare',
#        'Condor HoldReason: Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] -',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: MethodName=[jobRegister] ErrorCode=[*] Description=[The CREAM service cannot accept jobs at the moment] FaultCause=[Submissions are disabled!] * Dec * *]; Worker canceled',
#        'Condor HoldReason: Error: Connection to service failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] -',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://*/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: globus_xio: Unable to connect to * globus_xio: System error in connect: globus_xio: A system call failed:; Worker canceled by',
#        'Condor HoldReason: Error receiving files from schedd * * transfer failed for target job * SCHEDD at * failed to send file(s) to <*>: error reading from',
#        'LRMS error: (*) RemoveReason: Job removed by SYSTEM_PERIODIC_REMOVE due to exceeding the requested memory.',
#        'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from *) N/A (jobId = *); Worker canceled by harvest',
#        "Failed to create a JOB; HTTPSConnectionPool(host='*', port=*): Max retries exceeded with url: /apis/batch/*/namespaces/default/jobs (Caused by NewConnectionError('<* object at *>: Failed to establish a new connection: [Errno *] Connection refused',))",
#        'LRMS error: (*) ExitReason: died on signal * (Hangup)',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: MethodName=[jobRegister] ErrorCode=[*] Description=[The CREAM service cannot accept jobs at the moment] FaultCause=[Threshold for FTP Connection: * => Detected value for FTP Connection: *\\n\\n] Tim'],
#       dtype=object)

# %%
result.in_cluster(137)
# Out:
# ['Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM858028119)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM835662398)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM682667198)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM895417508)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM609791913)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM928990450)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM748070022)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM740192963)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM612761320)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM581024746)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM032991545)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM045305548)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM622877993)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM681196369)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM069193096)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM737713224)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM720658284)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM419742023)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM117588446)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM937517608)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM706154001)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM260361024)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM402333433)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM092181586)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM898939721)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM662522036)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM133989674)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM242942662)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM477374323)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM483796847)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM114401305)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM477693312)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM397556402)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM240667315)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM961354812)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM368498971)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM019981485)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM474316473)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM223937036)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM109423765)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM175653249)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM431677702)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM904500082)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM707573006)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM167703361)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM610888330)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM157588366)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM385019139)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM477897388)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM766336802)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM681976530)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM202032582)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM261924669)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM961103258)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM442346273)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM981974789)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM820357029)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM719135276)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM357889880)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM201809912)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM991973045)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM843793293)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM917776280)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM554583509)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM667321996)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM852696042)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM339613188)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM350018531)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM968261881)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM705647111)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM123894646)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM211666404)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM017224518)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM784103725)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM074136580)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM125226951)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM922199243)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM109481397)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM863143839)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM754640458)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM284723341)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM340246050)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM540872109)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM027925438)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM883166525)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM603280300)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM754500219)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM760573791)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM822351656)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM716929358)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM533218120)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM213051301)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM147305588)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM611738938)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM657151172)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM792345749)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM138781699)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM773623623)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM520045783)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM973586869)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM405608326)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM186822474)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM750068387)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM456508783)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM926444430)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM432155573)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM275044996)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM271445847)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM438027633)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM061154412)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM718884669)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM900227008)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM380052194)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM358064998)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM412483908)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM839835906)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM547607684)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce03.in2p3.fr-) N/A (jobId = CREAM850272846)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM465322901)  ; Worker canceled by harvest',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce01.in2p3.fr-) N/A (jobId = CREAM632972347)  ; Worker canceled by harvest']

# %%
result.in_cluster(3)
# Out:
# ['Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
# ...
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce03.in2p3.fr, queue atlasMC8-',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce01.in2p3.fr, queue atlasMC8-',
#  ...]

# %%
result.in_cluster(18)
# Out:
# ['Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
# ...
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru',
#  'Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = 1) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasprd005@creamce1.itep.ru']

# %%
result.outliers
# Out:
#     cluster_name  cluster_size  \
# 43            45            92
# 44             0            91
# 45            50            90
# 46             1            90
# 47             2            86
# ..           ...           ...
# 245          169             1
# 246          170             1
# 247          171             1
# 248          172             1
# 249          206             1
#
#                                                pattern  \
# 43   Failed in data staging: Failed to prepare sour...
# 44   Condor HoldReason: CREAM error: Transfer faile...
# 45   Failed in data staging: Failed to prepare sour...
# 46   Condor HoldReason: CREAM error: Cannot move IS...
# 47   Condor HoldReason: CREAM error: BLAH error: su...
# ..                                                 ...
# 245  Condor HoldReason: globus_xio: Unable to conne...
# 246  Failed in data staging: Failed to prepare sour...
# 247  Condor HoldReason: globus_xio: Unable to conne...
# 248  Failed in data staging: Failed to prepare sour...
# 249                                    LRMS error: (*)
#
#                                               sequence  mean_similarity  \
# 43   [Failed, in, data, staging:, Failed, to, prepa...             0.98
# 44   [Condor, HoldReason:, CREAM, error:, Transfer,...             1.00
# 45   [Failed, in, data, staging:, Failed, to, prepa...             0.98
# 46   [Condor, HoldReason:, CREAM, error:, Cannot, m...             1.00
# 47   [Condor, HoldReason:, CREAM, error:, BLAH, err...             1.00
# ..                                                 ...              ...
# 245  [Condor, HoldReason:, globus_xio:, Unable, to,...             1.00
# 246  [Failed, in, data, staging:, Failed, to, prepa...             1.00
# 247  [Condor, HoldReason:, globus_xio:, Unable, to,...             1.00
# 248  [Failed, in, data, staging:, Failed, to, prepa...             1.00
# 249                                [LRMS, error:, (*)]             1.00
#
#      std_similarity                                            indices
# 43             0.01  [23886, 34635, 41481, 43000, 43544, 45665, 519...
# 44             0.00  [1653, 1654, 1709, 1710, 1711, 1750, 1752, 179...
# 45             0.01  [3911, 7519, 27353, 43897, 45473, 46081, 47151...
# 46             0.00  [12311, 12880, 17220, 19426, 23570, 24303, 251...
# 47             0.00  [1249, 1257, 1258, 1259, 5611, 5612, 5613, 595...
# ..              ...                                                ...
# 245            0.00                                            [12174]
# 246            0.00                                            [15292]
# 247            0.00                                            [15831]
# 248            0.00                                            [19572]
# 249            0.00                                            [31952]
#
# [207 rows x 7 columns]

# %% [markdown]
# ### 3. Execute clusterization pipeline

# %%
cluster.process()
# Out:
# /Users/maria/anaconda3/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
cluster.w2v_size
# Out:
# 67

# %%
cluster.timings
# Out:
# {'data_preparation': 2.1246,
#  'tokenization': 8.3617,
#  'tokens_vectorization': 1.9031,
#  'sentence_vectorization': 6.6761,
#  'kneighbors': 83.3987,
#  'epsilon_search': 0.0869,
#  'dbscan': 16.2257,
#  'process': 123.3461}

# %%
cluster.output.stat_df.to_csv('harvester_results.csv')

# %%
cluster.output.in_cluster(5, level=2)
# Out:
# array([], dtype=object)

# %%
cluster.statistics

# %% [markdown]
# ### 4. Get clusters statistics

# %% [raw]
# Clusters Statistics returns DataFrame with statistic for all clusters:
# - "cluster_name" - name of a cluster
# - "cluster_size" - number of log messages in cluster
# - "pattern" - all common substrings in messages in the cluster
# - "vocab" - all tokens in error messasges
# - "vocab_length" - the length of cluster's vocabulary
# - "mean_length" - average length of log messages in cluster
# - "std_length" - standard deviation of length of log messages in cluster
# - "mean_similarity" - average similarity of log messages in cluster
# (calculated as the levenshtein distances between the 1st and all other log messages)
# - "std_similarity" - standard deviation of similarity of log messages in cluster

# %%
output = cluster_output.Output(cluster.df, 
                               cluster.target)

# %%
mode = 'INDEX'

# %%
output.clustered_output(mode)
stats = output.statistics(output_mode='frame')

# %%
stats.sort_values(by=['mean_similarity'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-756a51b10428> in <module>
# ----> 1 stats.sort_values(by=['mean_similarity'])
#
# AttributeError: 'NoneType' object has no attribute 'sort_values'

# %%
patterns = stats.sort_values(by='mean_similarity')[['pattern']].values

# %%
patterns
# Out:
# array([['* tmp+ regular m* * PENDING *:*'],
#        ['* tmp+ long usatlas * FAILED *:*'],
#        ['* tmp+ long usatlas * COMPLETED *:*'],
#        ['Failed in data staging: Could not resolve any source replicas for rucio*'],
#        ['Condor HoldReason: globus_xio: Unable to connect to :* globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out ; Worker canceled by harvester due to held too long or no'],
#        ['Condor HoldReason: CREAM error: Transfer failed: globus_xio: Unable to connect to *:* globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out ; Worker canceled by harv'],
#        ['Condor HoldReason: CREAM error: Transfer failed: globus_xio: Unable to connect to :* globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out ; Worker canceled by harvester'],
#        ['Condor HoldReason: Error sending files to schedd gk*.: DCSchedd::*:*:File transfer failed for target job *.*: Failed to receive GoAhead message from *.*.*.*. ; Worker canceled by harvester due to held too long'],
#        ['Condor HoldReason: CREAM error: Transfer failed: globus_xio: Unable to connect to g*..:* globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out ; Worker canceled by harvester due'],
#        ["Failed in data staging: Failed writing to destination: * : Can't write to destination: File exists: Failed to create file ****"],
#        ['Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: submit error (Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user prd*@.p.'],
#        ['Condor HoldReason: CREAM error: CREAM_Job_Register Error: MethodName=[jobRegister] ErrorCode=[*] Description=[The CREAM service cannot accept jobs at the moment] FaultCause=[Submissions are disabled!] Timestamp=[ * Dec * *:*:*] ; Worker canceled'],
#        ['Condor HoldReason: CREAM error: reason=*; *ll: line *: .**_jobWrapper.sh: No such file or directory ; Worker canceled by harvester due to held too long or not found'],
#        ['Failed in data staging: Failed to prepare source * Failed to prepare source: Resource temporarily unavailable: File requests have f'],
#        ['Failed in data staging: Could not resolve any source replicas for rucio* Resolving of index service for source failed: No such file or directory; Failed in data staging: Co'],
#        ['Condor HoldReason: CREAM error: Transfer failed: globus_xio: System error in : Connection reset by peer globus_xio: A system call failed: Connection reset by peer ; Worker canceled by harvester due to held too long or not found'],
#        ['Condor HoldReason: CREAM error: Cannot move ***_cr*_*****-wrapper.sh to ***_cr*_***; mv: cannot stat \x18***_cr*_****'],
#        ['Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * *-Command failed. : callback failed. *-globus_xio: Unable to connect to *.*.*.*:* *-globus_xio: System error in connect: Connecti'],
#        ['LRMS error: (*) Job was cancelled by SLURM'],
#        ['LRMS error: (*) Job exceeded time limit.'],
#        ['Failed in data staging: Failed checking source replica davs* Failed to obtain information about file: SSL error, "sslv* alert handshake'],
#        ["Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:mkdir: cannot create directory `**_*.debug': File exists-cp: accessing `**_*.debug*': Permission"],
#        ['Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: Invalid credential MSG=Hosts do not match-) N*(jobId = *) ; Worker canceled by harvester due to held too long or not found'],
#        ['Failed in data staging: Could not resolve any source replicas for rucio* Resolving of index service for source failed: Failed to contact server: Connection was closed'],
#        ['Condor HoldReason: Unspecified gridmanager error ; Condor *: Python-initiated action. (by user atlpan)'],
#        ['Condor HoldReason: globus_xio: System error in recv: Connection reset by peer globus_xio: A system call failed: Connection reset by peer ; Worker canceled by harvester due to held too long or not found'],
#        ['Payload execution error: returned non-zero'],
#        ['Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - *=[SOAP-ENV:Client] - FaultDetail=[Connection reset by peer] ; Worker canceled by ha'],
#        ['Condor HoldReason: Error locating schedd htc*.ppgrid*.rhul.ac.uk ; Worker canceled by harvester due to held too long or not found'],
#        ['Failed in data staging: Failed checking source replica * Failed to obtain information about file: Permission denied; Failed in dat'],
#        ['Unknown error'],
#        ['Condor HoldReason: CREAM error: reason=*'],
#        ['Failed in data staging: Failed checking source replica * Failed to obtain information about file: Permission denied; Failed in'],
#        ['Condor HoldReason: CREAM error: Job has been terminated (got SIGXCPU); reason=*'],
#        ['Condor HoldReason: Job removed from batch queue manually'],
#        ["LRMS error: (-*) *: The system macro SYSTEM_PERIODIC_REMOVE expression '( * > * * * * * ) || ( * + * > * * * * * ) || ( ( JobStatus == * && ( CurrentTime - * ) > * * * ) ) ||"],
#        ['LRMS error: (-*) Job failed with exit code *'],
#        ['Condor HoldReason: Error connecting to schedd htc*.ppgrid*.rhul.ac.uk: SECMAN:*:Failed to received post-auth ClassAd|*:*:Failed to * using FS ; Worker canceled by harvester due to held too long or not found'],
#        ['Condor HoldReason: CREAM_Delegate Error: Connection to service [http(s)* failed: FaultString=[HTTP Error] - FaultCode=[SOAP-ENV:Server] - *=[SOAP-ENV:Server] - FaultDetail=[HTTP**.* *'],
#        ["Failed to create a JOB; ('Connection aborted.', *(*, 'Connection reset by peer'))"],
#        ['Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * Please login with USER and PASS. ; Worker canceled by harvester due to held too long or not found'],
#        ['Failed in data staging: Failed checking source replica * Failed to obtain information about file: Permission denied; Fa'],
#        ['Failed in data staging: Failed to prepare destination *'],
#        ['Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * *-Command failed. : callback failed. *-globus_xio: Unable to connect to *.*.*.*:* *-globus_xio: System error in connect: Connection'],
#        ['Condor HoldReason: CREAM error: Problem to detect the lifetime of the proxy; Job has been terminated (got SIGTERM); reason=* ; Worker canceled by harvester due to held too long or not found'],
#        ['Condor HoldReason: CREAM error: Transfer failed: globus_xio: Unable to connect to creamce*.itep.ru:* globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out ; Worker canceled by harvester due to'],
#        ['Condor HoldReason: globus_xio: Unable to connect to arc-node.itim-cj.ro:* globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out ; Worker canceled by harvester due to held too long or not found'],
#        ['Condor HoldReason: globus_xio: System error in recv: Connection reset by peer globus_xio: A system call failed: Connection reset by peer ; Condor *: Python-initiated action. (by user atlpan)'],
#        ['Condor HoldReason: an end-of-file was reached globus_xio: An end of file occurred ; Worker canceled by harvester due to held too long or not found'],
#        ['Failed in data staging: Failed checking source replica * Failed to obtain information about file: Perm'],
#        ['Condor HoldReason: CREAM error: Transfer failed: GRIDFTP_TRANSFER timed out ; Worker canceled by harvester due to held too long or not found'],
#        ['Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * *-Command failed. : *:globus_l_gfs_file_send:*: *-globus_l_gfs_file_open failed. **'],
#        ['Condor HoldReason: CREAM error: CREAM_Job_Status Error: MethodName=[JobStatus] ErrorCode=[*] Description=[* failure: No PEP Server [* was able to process the request] FaultCause=[* error] Timest'],
#        ['Condor HoldReason: CREAM error: Cannot move ***_cr*_*****-wrapper.sh to ***_cr*_*** ; Worker canceled by harvester due to held too long or not found'],
#        ['Condor HoldReason: CREAM error: Job has been terminated (got SIGXCPU); reason=*; Job has been terminated (got SIGXCPU)'],
#        ['Condor HoldReason: CREAM error: CREAM_Job_Register Error: MethodName=[JobRegister] ErrorCode=[*] Description=[CN=Robot: ATLAS Pilot*,CN=*,CN=atlpilo*,OU=Users,OU=Organic Units,DC=cern,DC=ch not authorized for {http*}J'],
#        ['Failed in data staging: Failed to prepare destination * Failed to prepare destination: Fi'],
#        ['Failed in data staging: Failed checking source replica * Failed to obtain information about file: Permission de'],
#        ["Failed in data staging: Failed reading from source: gsiftp* : Can't read from source: globus_ftp_client: the server re"],
#        ['Condor HoldReason: Network error talking to schedd, probably an * failure ; Worker canceled by harvester due to held too long or not found'],
#        ['Condor HoldReason: globus_xio: Unable to connect to t*-arc*.grid.sinica.edu.tw:* globus_xio: globus_libc_getaddrinfo failed. globus_common: Name or service not known ; Worker canceled by harvester due to held too long or not found'],
#        ['LRMS error: (*)'],
#        ['Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr* line *: [: -gt: unary operator expected-pbs_iff: cannot read reply from pbs_server-No Permission.-qsub: cannot connect to'],
#        ['Failed in data staging: Could not resolve any source replicas for rucio* Resolving of index service for source failed: Failed to conta'],
#        ['Condor HoldReason: CREAM error: Transfer failed: globus_xio: Unable to connect to grid*.ft.uam.es:* globus_xio: System error in connect: No route to host globus_xio: A system call failed: No route to host ; Worker canceled by harvester due to held to'],
#        ['Condor HoldReason: Error from slot*_*@tds*.pic.es: CPU usage exceeded request_cpus ; Worker canceled by harvester due to held too long or not found'],
#        ['Condor HoldReason: CREAM error: Job has been terminated (got SIGTERM); reason=-* ; Worker canceled by harvester due to held too long or not found'],
#        ['Condor HoldReason: CREAM error: Transfer failed: globus_xio: Unable to connect to v*.pnpi.nw.ru:* globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out ; Worker canceled by harvester due to h'],
#        ['Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlpilot@lpsc-ce.in*p*.fr, queue atlasana-'],
#        ['Failed in data staging: Could not resolve any source replicas for rucio* Resolving of index service for source failed: No such file or'],
#        ['Condor HoldReason: NORDUGRID_SUBMIT timed out ; Worker canceled by harvester due to held too long or not found'],
#        ['Condor HoldReason: CREAM error: Transfer failed: globus_xio: Unable to connect to carceri.hec.lancs.ac.uk:* globus_xio: System error in connect: No route to host globus_xio: A system call failed: No route to host ; Worker canceled by harvester due to h'],
#        ['Condor HoldReason: CREAM error: Job has been terminated (got SIGXCPU); reason=*; Job has been terminated (got SIGXCPU) ; Worker canceled by harvester due to held too long or not found'],
#        ['Condor HoldReason: CREAM error: Problem to detect the lifetime of the proxy; Job has been terminated (got SIGTERM) ; Worker canceled by harvester due to held too long or not found'],
#        ['Failed in data staging: Failed checking source replica * Failed to obtain information about file: No such file or dir'],
#        ["LRMS error: (-*) *: The system macro SYSTEM_PERIODIC_REMOVE expression '(* > * * * * *) || (* + * > * * * * *) || ((JobStatus == * && (CurrentTime - *) > * * *)) || (ResidentS"],
#        ['Condor HoldReason: CREAM error: CREAM_Job_Start Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - *=[SOAP-ENV:Client] - FaultDetail=[Connection refused] ; Worker cancel'],
#        ['Failed during processing failure; Serious troubles (problems during processing problems)'],
#        ['Failed in data staging: Could not resolve any source replicas for rucio* Resolving of index service for source failed: No such file or directory|Failed in data staging: Could not'],
#        ['Failed in data staging: Transfer timed out'],
#        [': **'],
#        ['Condor HoldReason: Error parsing classad or job not found ; Worker canceled by harvester due to held too long or not found'],
#        ['condor job *=LOCAL batchID=*.* not found. Skipped'],
#        ['Condor HoldReason: CREAM error: Job has been terminated (got SIGTERM)'],
#        ['Condor HoldReason: Job not found ; Worker canceled by harvester due to held too long or not found'],
#        ['LRMS error: (*) job killed: wall'],
#        ['Condor HoldReason: CREAM_Delegate Error: Connection to service [* failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - *=[SOAP-ENV:Client] - FaultDetail=[SSL a'],
#        ['Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * *-Command failed. : globus_l_gfs_file_open failed. *-globus_xio: Unable to open file *_sandbox*_Robot__ATLAS_Pilot*_CN_*_'],
#        ['Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - *=[SOAP-ENV:Client] - FaultDetail=[Connection refused] ; Worker canceled by harveste'],
#        ['Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) * - FaultCode=['],
#        ['Failed in data staging: Failed to prepare source *'],
#        ['Condor HoldReason: CREAM error: reason=* ; Worker canceled by harvester due to held too long or not found'],
#        ['Condor HoldReason: Failed to start GAHP ; Worker canceled by harvester due to held too long or not found'],
#        ['LRMS error: (*) Job failed with exit code *'],
#        ['LRMS error: (*) Job failed'],
#        ['Condor HoldReason: CREAM error: Job has been terminated (got SIGTERM) ; Worker canceled by harvester due to held too long or not found'],
#        ['Condor HoldReason: Error receiving files from schedd osgserv*.slac.stanford.edu: DCSchedd::*:*:File transfer failed for target job *.*: SCHEDD at *.*.*.* failed to send file(s) to <*.*.*.*:*>: error reading from *'],
#        ['LRMS error: (-*) *: Job removed by SYSTEM_PERIODIC_REMOVE due to exceeding the requested memory.'],
#        ['Condor HoldReason: CREAM error: Job has been terminated (got SIGXCPU) ; Worker canceled by harvester due to held too long or not found'],
#        ['Condor HoldReason: ERROR: Failed to submit job ; Worker canceled by harvester due to held too long or not found'],
#        ["Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( * >= * && JobStatus == * )' evaluated to TRUE ; Worker canceled by harvester due to held too long or not found"],
#        ['LRMS error: (*) Job timeout'],
#        ['JOB id=adc-job-ac-cc*-k*s-*-custom-sched-* not found'],
#        ['Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlasp@lapp-ce*.in*p*.fr, queue atlasMC*-'],
#        ['submission failed: Exception OSError: [Errno *] No space left on device'],
#        ["Condor HoldReason: HTCondor-CE held job due to no matching routes, route job limit, or route failure threshold; see 'HTCondor-CE * Guide' ; Worker canceled by harvester due to held too long or not found"],
#        ['LRMS error: (-*) Job finished with unknown exit code'],
#        ['LRMS error: (*) job killed: vmem'],
#        ['* not submitted due to incomplete data of the worker'],
#        ['Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * *-Command failed. : globus_l_gfs_file_open failed. *-globus_xio: Unable to open file *_sandbox*_Robot__ATLAS_Pilot*_CN_*'],
#        ['Condor HoldReason: Unspecified gridmanager error ; Worker canceled by harvester due to held too long or not found'],
#        ["Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '(* =?= undefined) || (* =?= undefined) || ((time() > *) && JobStatus =!= * && JobStatus =!= *) || (RoutedBy =?= null && JobU"],
#        ['LRMS error: (-*) Job missing from SLURM'],
#        ['Failed in data staging: Failed to prepare source * Failed to prepare source: Resource temporarily unavailable: File requests h'],
#        ['Failed in data staging: Failed to prepare source * Failed to prepare source: Resource temporarily unavailable: File requests'],
#        ['Condor HoldReason: CREAM error: Job has been terminated (got SIGXCPU); reason=* ; Worker canceled by harvester due to held too long or not found'],
#        ['Condor HoldReason: CREAM error: Cannot move ISB (retry_copy ${globus_transfer_cmd} gsiftp*'],
#        ['Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: Bad UID for job execution MSG=could not authorize user atlasp from lapp-ce*.in*p*.fr-) N*(jobId = *) ; Worker canceled by harvest'],
#        ["Failed to create a JOB; *(host='*.*.*.*', port=*): Max retries exceeded with url: ***(Caused by *('<urllib*.connection.* object at *>: Failed to establish a new connection: [Errno *] Connection refused',))"],
#        ['LRMS error: (-*) ExitReason: died on signal * (Hangup)'],
#        ['Condor HoldReason: CREAM error: CREAM_Job_Register Error: MethodName=[jobRegister] ErrorCode=[*] Description=[The CREAM service cannot accept jobs at the moment] FaultCause=[Threshold for FTP Connection: * => Detected value for FTP Connection: *\\n\\n] Tim'],
#        ['Condor HoldReason: CREAM error: CREAM_Job_Register Error: Connection to service [* failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - *=[SOAP-ENV:Client] - FaultDetail=[S'],
#        ['LRMS error: (-*) Job missing from SLURM|Failed in data staging: Failed to prepare destination *'],
#        ['Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * *-Login incorrect. : globus_gss_assist: Error invoking callout *-globus_callout_module: The callout returned an error *-an unknown error occu'],
#        ['Condor HoldReason: CREAM error: reason=-*'],
#        ['submission failed:'],
#        ['Condor HoldReason: CREAM error: CREAM_Job_Register Error: MethodName=[jobRegister] Timestamp=[ * Dec * *:*:*] ErrorCode=[*] Description=[system error] FaultCause=[database error occurred] ; Worker canceled by harvester due to held too long or no'],
#        ['Failed in data staging: Could not resolve any source replicas for rucio* Resolving of index service for source failed: No such file or directory: No valid locations found'],
#        ['Failed in data staging: Failed checking source replica *'],
#        ["Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '( * >= * && JobStatus == * )' evaluated to TRUE"],
#        ['Condor HoldReason: CREAM error: CREAM_Job_Register Error: MethodName=[JobRegister] ErrorCode=[*] Description=[* failure: No PEP Server [* was able to process the request] FaultCause=[* error]'],
#        ['Job submission to LRMS failed'],
#        ['Condor HoldReason: CREAM error: CREAM_Job_Register Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - *=[SOAP-ENV:Client] - FaultDetail=[Resolver internal error] ; Worke'],
#        ['Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - *=[SOAP-ENV:Client] - FaultDetail=[Connection refused]'],
#        ['Failed in data staging: Could not resolve any source replicas for rucio* Resolving of index service for source failed: No such file or directory: No valid locations fou'],
#        ['Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * *-Command failed. : globus_l_gfs_file_open failed. *-globus_xio: Unable to open file *_sandbox*_Robot__ATLAS_Pilot*_CN_'],
#        ['Condor HoldReason: Job removed from batch queue manually ; Worker canceled by harvester due to held too long or not found'],
#        ['Condor HoldReason: Spooling input data files ; Worker canceled by harvester due to held too long or not found'],
#        ['LRMS error: (-*) Node fail'],
#        ['Condor HoldReason: Error locating schedd htc*.ppgrid*.rhul.ac.uk'],
#        ['Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: Invalid credential-) N*(jobId = *) ; Worker canceled by harvester due to held too long or not found'],
#        ["Condor HoldReason: HTCondor-CE held job due to no matching routes, route job limit, or route failure threshold; see 'HTCondor-CE * Guide'"],
#        ['LRMS error: (*) Job was cancelled'],
#        ['LRMS error: (*) job killed: cput'],
#        ['Failed in data staging: Failed to prepare source * Failed to prepare source: Resource temporarily unavailable: File reques'],
#        ['LRMS error: (*) Job missing from SLURM, exitcode recovered from session directory'],
#        ['Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - *=[SOAP-ENV:Client] - FaultDetail=[Connection timed out] ; Worker canceled by harves'],
#        ['Condor HoldReason: Unspecified gridmanager error'],
#        ['Error reading user generated output file list'],
#        ['LRMS error: (-*) Job failed'],
#        ['Failed in data staging: Failed checking source replica * Failed to obtain information about file: Permission denied'],
#        ['LRMS error: (-*) *: Job removed by SYSTEM_PERIODIC_REMOVE due to job running more than once.'],
#        ['Condor HoldReason: CREAM error: reason=-* ; Worker canceled by harvester due to held too long or not found'],
#        ['Failed in data staging: Failed to prepare source * Failed to prepare source: Resource te'],
#        ['Failed in data staging: Could not resolve any source replicas for rucio* Resolving of index service for source failed: No such file or directory'],
#        ['LRMS error: (*) Node fail'],
#        ['Condor HoldReason: CREAM error: Transfer failed: an end-of-file was reached globus_xio: An end of file occurred ; Worker canceled by harvester due to held too long or not found']],
#       dtype=object)

# %%
stats_1 = output.postprocessing(1)

# %%
stats_1.sort_values(by=['mean_similarity'])
# Out:
#    cluster_name  cluster_size  \
# 1           1.0           904
# 3           3.0            77
# 9           9.0          1693
# 13         13.0           680
# 6           6.0          4946
# 10         10.0            13
# 11         11.0          2204
# 8           8.0           141
# 5           5.0             3
# 12         12.0           516
# 31         31.0            89
# 23         23.0            94
# 0           0.0          4370
# 4           4.0           423
# 36         36.0           438
# 33         33.0           173
# 27         27.0          1135
# 22         22.0             7
# 35         35.0          3048
# 17         17.0            58
# 16         16.0             9
# 14         14.0          8730
# 20         20.0             6
# 21         21.0             7
# 18         18.0             3
# 25         25.0             8
# 15         15.0             2
# 24         24.0             8
# 26         26.0            10
# 28         28.0            11
# 19         19.0             4
# 44         44.0         21436
# 30         30.0            16
# 32         32.0            26
# 34         34.0            55
# 7           7.0             1
# 37         37.0           104
# 38         38.0           111
# 39         39.0           135
# 40         40.0          1981
# 41         41.0          2758
# 42         42.0          7771
# 43         43.0         10838
# 29         29.0            15
# 2           2.0             1
#
#                                               pattern  mean_length  \
# 1            Condor HoldReason: CREAM_g Fault - Fault       202.39
# 3   Failed in data staging: ld en source replica f...       145.10
# 9                 Failed in data staging: Failed e se       124.08
# 13  Condor HoldReason: CREAM error: BLAH error: su...       245.83
# 6                                     LRMS error: (*)        33.05
# 10  Condor HoldReason: CREAM error: CREAM_Job_s Er...       193.69
# 11  Condor HoldReason: CREAM error: Transfer faile...       225.31
# 8     Condor HoldReason: globus_xio: System error in        248.78
# 5   Condor HoldReason: CREAM error: BLAH error: su...       208.67
# 12                 Condor HoldReason: CREAM error: an        87.34
# 31  LRMS error: (*) Job missing from SLURMied  ses...        83.67
# 23                               * tmp+ gula * ED *:*        38.77
# 0   Condor HoldReason:  ; Worker canceled by harve...       124.70
# 4                      Failed in data staging: aied o        50.22
# 36  Condor HoldReason: CREAM error: CREAM_Job_Regi...       249.40
# 33  LRMS error: (-*) *: Job removed by SYSTEM_PERI...        95.12
# 27  Condor HoldReason: The system macro SYSTEM_PER...       192.25
# 22  Condor HoldReason: Error sending files to sche...       226.00
# 35  Condor HoldReason: HTCondor-CE held job due to...       200.21
# 17   Condor HoldReason: Unspecified gridmanager error        50.79
# 16  LRMS error: (-*) *: The system macro SYSTEM_PE...       174.22
# 14  Condor HoldReason: CREAM error: BLAH error: su...       255.00
# 20                                      Unknown error        13.00
# 21  Condor HoldReason: Job removed from batch queu...        56.00
# 18  Condor HoldReason: CREAM error: Cannot move **...       114.00
# 25  Failed to create a JOB; ('Connection aborted.'...        81.00
# 15                                               : **         4.00
# 24  Condor HoldReason: Error connecting to schedd ...       206.00
# 26  condor job *=LOCAL batchID=*.* not found. Skipped        49.00
# 28                      Job submission to LRMS failed        29.00
# 19  Condor HoldReason: globus_xio: System error in...       201.00
# 44         Payload execution error: returned non-zero        42.00
# 30                                 submission failed:        18.00
# 32  Condor HoldReason: Error locating schedd htc*....        64.00
# 34      Error reading user generated output file list        45.00
# 7   Condor HoldReason: globus_xio: Unable to conne...       230.00
# 37  LRMS error: (-*) ExitReason: died on signal * ...        54.00
# 38  Failed to create a JOB; *(host='*.*.*.*', port...       205.00
# 39  Condor HoldReason: Error receiving files from ...       213.00
# 40  * not submitted due to incomplete data of the ...        52.00
# 41  LRMS error: (-*) Job finished with unknown exi...        52.00
# 42  submission failed: Exception OSError: [Errno *...        71.00
# 43  JOB id=adc-job-ac-cc*-k*s-*-custom-sched-* not...        52.00
# 29  Condor HoldReason: CREAM error: CREAM_Job_Regi...       248.00
# 2   Failed during processing failure; Serious trou...        88.00
#
#     mean_similarity  std_length  std_similarity
# 1              0.45       32.82            0.06
# 3              0.53       30.65            0.11
# 9              0.60        5.56            0.10
# 13             0.62       15.19            0.04
# 6              0.65        4.16            0.07
# 10             0.68        6.84            0.05
# 11             0.68        2.11            0.07
# 8              0.71        7.10            0.25
# 5              0.75       12.26            0.25
# 12             0.75       10.58            0.20
# 31             0.76        5.50            0.07
# 23             0.76        2.10            0.08
# 0              0.81       25.27            0.09
# 4              0.83        1.22            0.07
# 36             0.84        2.54            0.02
# 33             0.87        1.66            0.02
# 27             0.93        7.54            0.13
# 22             0.96        0.53            0.01
# 35             0.98       10.64            0.06
# 17             0.98       11.96            0.08
# 16             0.98        0.42            0.02
# 14             0.99        0.02            0.00
# 20             1.00        0.00            0.00
# 21             1.00        0.00            0.00
# 18             1.00        0.00            0.00
# 25             1.00        0.00            0.00
# 15             1.00        0.00            0.00
# 24             1.00        0.00            0.00
# 26             1.00        0.00            0.00
# 28             1.00        0.00            0.00
# 19             1.00        0.00            0.00
# 44             1.00        0.00            0.00
# 30             1.00        0.00            0.00
# 32             1.00        0.00            0.00
# 34             1.00        0.00            0.00
# 7              1.00        0.00            0.00
# 37             1.00        0.00            0.00
# 38             1.00        0.00            0.00
# 39             1.00        0.00            0.00
# 40             1.00        0.00            0.00
# 41             1.00        0.00            0.00
# 42             1.00        0.00            0.00
# 43             1.00        0.00            0.00
# 29             1.00        0.00            0.00
# 2              1.00        0.00            0.00

# %%
output.in_cluster(1,2)
# Out:
# array(['Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/CREAM2] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[S',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/CREAM2] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[S',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/CREAM2] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[S',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/CREAM2] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[S',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/CREAM2] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[S',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection reset by peer]  ; Worker canceled by ha',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Resolver internal error]  ; Worke',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection reset by peer]  ; Worker canceled by ha',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Resolver internal error]  ; Worke',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Resolver internal error]  ; Worke',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Resolver internal error]  ; Worke',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/CREAM2] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[S',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/CREAM2] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[S',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/CREAM2] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[S',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Resolver internal error]  ; Worke',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Resolver internal error]  ; Worke',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection reset by peer]  ; Worker canceled by ha',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection reset by peer]  ; Worker canceled by ha',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection reset by peer]  ; Worker canceled by ha',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Resolver internal error]  ; Worke',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/CREAM2] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[S',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/CREAM2] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[S',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/CREAM2] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[S',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/CREAM2] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[S',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/CREAM2] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[S',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection timed out]  ; Worker canceled by harves',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Resolver internal error]  ; Worke',
#        'Condor HoldReason: CREAM error: CREAM_Job_Register Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Resolver internal error]  ; Worke',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
# ...
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused] ',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Connection to service [https://creamce3.goegrid.gwdg.de:8443/ce-cream/services/gridsite-delegation] failed: FaultString=[SSL error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[SSL a',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[The service cannot be found for the endpoint reference (EPR) https://clrccece01.in2p3.fr:8443/ce-cream/services/gridsite-delegation] - FaultCode=[',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused] ',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused] ',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM error: CREAM_Job_Start Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker cancel',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused] ',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused] ',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused] ',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused] ',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused]  ; Worker canceled by harveste',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused] ',
#        'Condor HoldReason: CREAM_Delegate Error: Received NULL fault; the error is due to another cause: FaultString=[connection error] - FaultCode=[SOAP-ENV:Client] - FaultSubCode=[SOAP-ENV:Client] - FaultDetail=[Connection refused] '],
#       dtype=object)

# %%
patterns1 = stats_1.sort_values(by='mean_similarity')[['pattern']].values

# %%
patterns1
# Out:
# array([['Condor HoldReason: CREAM_g Fault - Fault'],
#        ['Failed in data staging: ld en source replica forio'],
#        ['Failed in data staging: Failed e se'],
#        ['Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: '],
#        ['LRMS error: (*)'],
#        ['Condor HoldReason: CREAM error: CREAM_Job_s Error: MethodName=[Jobs] ErrorCode=[*] Description=[ fp'],
#        ['Condor HoldReason: CREAM error: Transfer failed: globus_ftp_client: the server responded with an error * *-m *-'],
#        ['Condor HoldReason: globus_xio: System error in '],
#        ['Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderrry _.'],
#        ['Condor HoldReason: CREAM error: an'],
#        ['LRMS error: (*) Job missing from SLURMied  sesion '],
#        ['* tmp+ gula * ED *:*'],
#        ['Condor HoldReason:  ; Worker canceled by harvester due to held to'],
#        ['Failed in data staging: aied o'],
#        ['Condor HoldReason: CREAM error: CREAM_Job_Register Error: MethodName=[jobRegister] ErrorCode=[*] Description=[The CREAM service cannot accept jobs at the moment] FaultCause=[T De'],
#        ['LRMS error: (-*) *: Job removed by SYSTEM_PERIODIC_REMOVE due to ing mor.'],
#        ["Condor HoldReason: The system macro SYSTEM_PERIODIC_HOLD expression '(* >= * && JobStatus == *) uted  U"],
#        ['Condor HoldReason: Error sending files to schedd gk*.: DCSchedd::*:*:File transfer failed for target job *.*: Failed to receive GoAhead message from *.*.*.*. ; Worker canceled by harvester due to held too long'],
#        ["Condor HoldReason: HTCondor-CE held job due to no matching routes, route job limit, or route failure threshold; see 'HTCondor-CE * Guide'"],
#        ['Condor HoldReason: Unspecified gridmanager error'],
#        ["LRMS error: (-*) *: The system macro SYSTEM_PERIODIC_REMOVE expression '(* > * * * * *) || (* + * > * * * * *) || ((JobStatus == * && (CurrentTime - *) > * * *)) ||"],
#        ['Condor HoldReason: CREAM error: BLAH error: submission command failed (exit code = *) (stdout:) (stderr:qsub: Maximum number of jobs already in queue MSG=total number of jobs in queue exceeds the queue limit: user atlp@lp-ce.in*p*.fr, queue atlas-'],
#        ['Unknown error'],
#        ['Condor HoldReason: Job removed from batch queue manually'],
#        ['Condor HoldReason: CREAM error: Cannot move ***_cr*_*****-wrapper.sh to ***_cr*_***; mv: cannot stat \x18***_cr*_****'],
#        ["Failed to create a JOB; ('Connection aborted.', *(*, 'Connection reset by peer'))"],
#        [': **'],
#        ['Condor HoldReason: Error connecting to schedd htc*.ppgrid*.rhul.ac.uk: SECMAN:*:Failed to received post-auth ClassAd|*:*:Failed to * using FS ; Worker canceled by harvester due to held too long or not found'],
#        ['condor job *=LOCAL batchID=*.* not found. Skipped'],
#        ['Job submission to LRMS failed'],
#        ['Condor HoldReason: globus_xio: System error in recv: Connection reset by peer globus_xio: A system call failed: Connection reset by peer ; Worker canceled by harvester due to held too long or not found'],
#        ['Payload execution error: returned non-zero'],
#        ['submission failed:'],
#        ['Condor HoldReason: Error locating schedd htc*.ppgrid*.rhul.ac.uk'],
#        ['Error reading user generated output file list'],
#        ['Condor HoldReason: globus_xio: Unable to connect to t*-arc*.grid.sinica.edu.tw:* globus_xio: globus_libc_getaddrinfo failed. globus_common: Name or service not known ; Worker canceled by harvester due to held too long or not found'],
#        ['LRMS error: (-*) ExitReason: died on signal * (Hangup)'],
#        ["Failed to create a JOB; *(host='*.*.*.*', port=*): Max retries exceeded with url: ***(Caused by *('<urllib*.connection.* object at *>: Failed to establish a new connection: [Errno *] Connection refused',))"],
#        ['Condor HoldReason: Error receiving files from schedd osgserv*.slac.stanford.edu: DCSchedd::*:*:File transfer failed for target job *.*: SCHEDD at *.*.*.* failed to send file(s) to <*.*.*.*:*>: error reading from *'],
#        ['* not submitted due to incomplete data of the worker'],
#        ['LRMS error: (-*) Job finished with unknown exit code'],
#        ['submission failed: Exception OSError: [Errno *] No space left on device'],
#        ['JOB id=adc-job-ac-cc*-k*s-*-custom-sched-* not found'],
#        ['Condor HoldReason: CREAM error: CREAM_Job_Register Error: MethodName=[jobRegister] Timestamp=[ * Dec * *:*:*] ErrorCode=[*] Description=[system error] FaultCause=[database error occurred] ; Worker canceled by harvester due to held too long or no'],
#        ['Failed during processing failure; Serious troubles (problems during processing problems)']],
#       dtype=object)

# %%
import difflib

# %%
sorted_df = output.stat_df.sort_values(by=['cluster_size'])[['cluster_size','cluster_name','pattern']]

# %%
sorted_df
# Out:
#     cluster_size cluster_name  \
# 2              1          2.0
# 7              1          7.0
# 15             2         15.0
# 5              3          5.0
# 18             3         18.0
# 19             4         19.0
# 20             6         20.0
# 21             7         21.0
# 22             7         22.0
# 25             8         25.0
# 24             8         24.0
# 16             9         16.0
# 26            10         26.0
# 28            11         28.0
# 10            13         10.0
# 29            15         29.0
# 30            16         30.0
# 32            26         32.0
# 34            55         34.0
# 17            58         17.0
# 3             77          3.0
# 31            89         31.0
# 23            94         23.0
# 37           104         37.0
# 38           111         38.0
# 39           135         39.0
# 8            141          8.0
# 33           173         33.0
# 4            423          4.0
# 36           438         36.0
# 12           516         12.0
# 13           680         13.0
# 1            904          1.0
# 27          1135         27.0
# 9           1693          9.0
# 40          1981         40.0
# 11          2204         11.0
# 41          2758         41.0
# 35          3048         35.0
# 0           4370          0.0
# 6           4946          6.0
# 42          7771         42.0
# 14          8730         14.0
# 43         10838         43.0
# 44         21436         44.0
#
#                                               pattern
# 2   Failed during processing failure; Serious trou...
# 7   Condor HoldReason: globus_xio: Unable to conne...
# 15                                               : **
# 5   Condor HoldReason: CREAM error: BLAH error: su...
# 18  Condor HoldReason: CREAM error: Cannot move **...
# 19  Condor HoldReason: globus_xio: System error in...
# 20                                      Unknown error
# 21  Condor HoldReason: Job removed from batch queu...
# 22  Condor HoldReason: Error sending files to sche...
# 25  Failed to create a JOB; ('Connection aborted.'...
# 24  Condor HoldReason: Error connecting to schedd ...
# 16  LRMS error: (-*) *: The system macro SYSTEM_PE...
# 26  condor job *=LOCAL batchID=*.* not found. Skipped
# 28                      Job submission to LRMS failed
# 10  Condor HoldReason: CREAM error: CREAM_Job_s Er...
# 29  Condor HoldReason: CREAM error: CREAM_Job_Regi...
# 30                                 submission failed:
# 32  Condor HoldReason: Error locating schedd htc*....
# 34      Error reading user generated output file list
# 17   Condor HoldReason: Unspecified gridmanager error
# 3   Failed in data staging: ld en source replica f...
# 31  LRMS error: (*) Job missing from SLURMied  ses...
# 23                               * tmp+ gula * ED *:*
# 37  LRMS error: (-*) ExitReason: died on signal * ...
# 38  Failed to create a JOB; *(host='*.*.*.*', port...
# 39  Condor HoldReason: Error receiving files from ...
# 8     Condor HoldReason: globus_xio: System error in
# 33  LRMS error: (-*) *: Job removed by SYSTEM_PERI...
# 4                      Failed in data staging: aied o
# 36  Condor HoldReason: CREAM error: CREAM_Job_Regi...
# 12                 Condor HoldReason: CREAM error: an
# 13  Condor HoldReason: CREAM error: BLAH error: su...
# 1            Condor HoldReason: CREAM_g Fault - Fault
# 27  Condor HoldReason: The system macro SYSTEM_PER...
# 9                 Failed in data staging: Failed e se
# 40  * not submitted due to incomplete data of the ...
# 11  Condor HoldReason: CREAM error: Transfer faile...
# 41  LRMS error: (-*) Job finished with unknown exi...
# 35  Condor HoldReason: HTCondor-CE held job due to...
# 0   Condor HoldReason:  ; Worker canceled by harve...
# 6                                     LRMS error: (*)
# 42  submission failed: Exception OSError: [Errno *...
# 14  Condor HoldReason: CREAM error: BLAH error: su...
# 43  JOB id=adc-job-ac-cc*-k*s-*-custom-sched-* not...
# 44         Payload execution error: returned non-zero

# %%
def match(df, new_clusters):
    start = df.head(1)['pattern'].values[0]
#     print(start)
    ratio = [difflib.SequenceMatcher(None, start, x).ratio() for x in df['pattern']]
    df['ratio'] = ratio
    filtered = df[df['ratio'] > 0.6]['cluster_name'].values
    new_clusters.append(filtered)
#     print(filtered)
    df.drop(df[df['cluster_name'].isin(filtered)].index, inplace=True)
#     print(df)
    while df.shape[0] > 0:
        match(df, new_clusters)

# %%
new_clusters = []
# start = sorted_df.head(1)['pattern'].values[0]
# print(start)
match(sorted_df, new_clusters)

# %%
new_clusters
# Out:
# [array(['149', '136', '139', '133', '142', '143', '146', '144', '123',
#         '105', '102', '51', '87', '79', '73', '72', '118', '112', '106',
#         '48', '122', '109', '110', '108', '59', '90', '17', '3', '58',
#         '93', '1', '36', '70', '39', '52', '74', '37', '24', '14', '45',
#         '19'], dtype=object),
#  array(['138', '97', '25', '86', '85', '9', '57'], dtype=object),
#  array(['140'], dtype=object),
#  array(['141', '117', '76', '67', '23', '28'], dtype=object),
#  array(['135', '148', '30', '29'], dtype=object),
#  array(['134', '81', '80'], dtype=object),
#  array(['132', '95'], dtype=object),
#  array(['131', '128', '91', '22'], dtype=object),
#  array(['145', '137', '88'], dtype=object),
#  array(['130', '84', '82', '101'], dtype=object),
#  array(['129'], dtype=object),
#  array(['127', '21', '99'], dtype=object),
#  array(['126'], dtype=object),
#  array(['124', '41', '8', '32', '26'], dtype=object),
#  array(['107'], dtype=object),
#  array(['120', '115', '69'], dtype=object),
#  array(['121', '89', '27', '71', '113', '100', '54', '40', '43'],
#        dtype=object),
#  array(['116'], dtype=object),
#  array(['114'], dtype=object),
#  array(['111'], dtype=object),
#  array(['4', '94', '119', '77', '66', '98', '125', '46', '7', '6', '47',
#         '33'], dtype=object),
#  array(['104'], dtype=object),
#  array(['83', '96', '78', '60', '56'], dtype=object),
#  array(['2'], dtype=object),
#  array(['92'], dtype=object),
#  array(['12', '103', '75', '10'], dtype=object),
#  array(['68'], dtype=object),
#  array(['65', '55'], dtype=object),
#  array(['35', '49', '62'], dtype=object),
#  array(['42', '38', '16', '34'], dtype=object),
#  array(['63'], dtype=object),
#  array(['11'], dtype=object),
#  array(['61'], dtype=object),
#  array(['15', '20'], dtype=object),
#  array(['64'], dtype=object),
#  array(['44'], dtype=object),
#  array(['147'], dtype=object),
#  array(['50'], dtype=object),
#  array(['18', '13'], dtype=object),
#  array(['31'], dtype=object),
#  array(['5'], dtype=object),
#  array(['53'], dtype=object),
#  array(['0'], dtype=object)]

# %%
a = []
for i in new_clusters:
    x = cluster.df[cluster.df['cluster'].isin(i)].index
    a.append({'cluster_name':i[-1],'idx':x})
print(a)

for i in a:
    cluster.df.loc[i['idx'], 'cluster_level_2'] = i['cluster_name']
# Out:
# [{'cluster_name': '19', 'idx': Int64Index([   2,    6,    7,    8,    9,   46,   59,   62,   63,   64,
#             ...
#             4861, 4874, 4875, 4897, 4912, 4915, 4937, 4949, 4956, 4967],
#            dtype='int64', length=568)}, {'cluster_name': '57', 'idx': Int64Index([  50,   54,   55,  105,  275,  394,  580,  581,  645,  674,  914,
#              923,  925,  926,  987,  993,  994, 1012, 1022, 1030, 1031, 1032,
#             1037, 1246, 1268, 1343, 1389, 1555, 1843, 1845, 1863, 1944, 1948,
#             1952, 1956, 1957, 1961, 2298, 2372, 2811, 2815, 2825, 2843, 2888,
#             2913, 2915, 2926, 2932, 2933, 3022, 3251, 3524, 3572, 3763, 3772,
#             3850, 3869, 3897, 3902, 3912, 4382, 4490, 4753, 4758, 4845, 4855,
#             4883],
#            dtype='int64')}, {'cluster_name': '140', 'idx': Int64Index([4037], dtype='int64')}, {'cluster_name': '28', 'idx': Int64Index([  90,  128,  260,  280,  290,  306,  408,  409,  410,  419,
#             ...
#             4374, 4390, 4403, 4405, 4406, 4425, 4427, 4458, 4707, 4851],
#            dtype='int64', length=125)}, {'cluster_name': '29', 'idx': Int64Index([ 130,  133,  135,  138,  139,  141,  147,  148,  150,  155,
#             ...
#             4103, 4115, 4124, 4126, 4139, 4187, 4189, 4235, 4276, 4881],
#            dtype='int64', length=144)}, {'cluster_name': '80', 'idx': Int64Index([911, 912, 1851, 1854, 3790, 3793, 3798, 4756], dtype='int64')}, {'cluster_name': '95', 'idx': Int64Index([1312, 1325, 1347, 1354, 1387, 3193, 3303, 3757], dtype='int64')}, {'cluster_name': '22', 'idx': Int64Index([88, 1082, 1109, 1983, 2002, 2006, 2054, 2075, 2963, 3048, 3203,
#             3426, 4011],
#            dtype='int64')}, {'cluster_name': '88', 'idx': Int64Index([1068, 1789, 3801, 4654], dtype='int64')}, {'cluster_name': '101', 'idx': Int64Index([942, 967, 1553, 3425, 3458, 4422, 4798], dtype='int64')}, {'cluster_name': '129', 'idx': Int64Index([3343], dtype='int64')}, {'cluster_name': '99', 'idx': Int64Index([84, 1534, 2089, 2443, 3199, 3999], dtype='int64')}, {'cluster_name': '126', 'idx': Int64Index([3143], dtype='int64')}, {'cluster_name': '26', 'idx': Int64Index([  41,  108,  115,  169,  181,  245,  470,  596,  597, 1056, 1084,
#             1089, 1092, 1115, 1135, 1255, 2020, 2060, 2076, 2524, 2975, 2985,
#             3004, 3024, 3075, 3258, 3477, 3762, 3979, 3983, 4014, 4022, 4091,
#             4327, 4736, 4979],
#            dtype='int64')}, {'cluster_name': '107', 'idx': Int64Index([2009], dtype='int64')}, {'cluster_name': '69', 'idx': Int64Index([609, 2288, 2793], dtype='int64')}, {'cluster_name': '43', 'idx': Int64Index([ 117,  239,  259,  322,  328,  335,  350,  367,  369,  375,
#             ...
#             4444, 4475, 4862, 4911, 4917, 4947, 4953, 4954, 4955, 4958],
#            dtype='int64', length=158)}, {'cluster_name': '116', 'idx': Int64Index([2361], dtype='int64')}, {'cluster_name': '114', 'idx': Int64Index([2234], dtype='int64')}, {'cluster_name': '111', 'idx': Int64Index([2211], dtype='int64')}, {'cluster_name': '33', 'idx': Int64Index([  11,   24,   28,   29,   37,   43,  178,  184,  301,  305,  327,
#              344,  468,  474,  553,  630,  791,  804,  851, 1253, 1276, 1306,
#             1486, 1520, 1643, 1779, 2067, 2085, 2121, 2189, 2201, 2279, 2305,
#             2703, 2867, 3051, 3134, 3138, 3272, 3397, 3482, 3615, 3723, 4161,
#             4175, 4205, 4252, 4253, 4397, 4452, 4519, 4691, 4782, 4803, 4871,
#             4873],
#            dtype='int64')}, {'cluster_name': '104', 'idx': Int64Index([1852], dtype='int64')}, {'cluster_name': '56', 'idx': Int64Index([ 387,  398,  416,  429,  432,  433,  436,  437,  484,  501,
#             ...
#             4899, 4904, 4905, 4906, 4907, 4913, 4942, 4968, 4985, 4986],
#            dtype='int64', length=204)}, {'cluster_name': '2', 'idx': Int64Index([5, 10], dtype='int64')}, {'cluster_name': '92', 'idx': Int64Index([1119, 2965], dtype='int64')}, {'cluster_name': '10', 'idx': Int64Index([  51,   52,   53,   57,  154,  381,  388,  389,  390,  392,
#             ...
#             4849, 4850, 4853, 4854, 4856, 4858, 4859, 4880, 4965, 4969],
#            dtype='int64', length=602)}, {'cluster_name': '68', 'idx': Int64Index([590, 592, 1565, 1566, 1567, 2518, 4434, 4435], dtype='int64')}, {'cluster_name': '55', 'idx': Int64Index([ 384,  385,  386,  530,  535, 1315, 1510, 1512, 2452, 3239, 3240,
#             3241, 3277, 3412, 3413, 3414, 4239, 4240, 4241, 4386],
#            dtype='int64')}, {'cluster_name': '62', 'idx': Int64Index([ 192,  311,  337,  430,  476,  482,  483,  486,  490,  491,
#             ...
#             4991, 4992, 4993, 4994, 4995, 4996, 4997, 4998, 4999, 5000],
#            dtype='int64', length=1141)}, {'cluster_name': '34', 'idx': Int64Index([  68,  182,  194,  201,  234,  235,  253,  297,  298,  314,  316,
#              320,  345,  373,  397,  457, 1053, 1054, 1055, 1139, 1189, 1190,
#             1240, 1242, 1288, 1289, 1291, 1299, 1300, 1301, 1304, 1333, 1352,
#             1404, 1405, 1406, 1407, 1975, 1976, 1977, 2073, 2080, 2123, 2124,
#             2125, 2126, 2145, 2195, 2196, 2200, 2217, 2244, 2254, 2256, 2270,
#             2355, 2356, 2357, 3057, 3078, 3263, 3934, 3949, 3950, 4034, 4047,
#             4048, 4082, 4156, 4157, 4162, 4215, 4222, 4223, 4224, 4230, 4243,
#             4316, 4317],
#            dtype='int64')}, {'cluster_name': '63', 'idx': Int64Index([519, 811, 1379, 1528, 2307, 2574, 3161, 3364, 4194, 4254], dtype='int64')}, {'cluster_name': '11', 'idx': Int64Index([56, 356, 414, 1338, 1341, 1394, 2304, 2516, 3269, 3281, 4200, 4266,
#             4309],
#            dtype='int64')}, {'cluster_name': '61', 'idx': Int64Index([439, 442, 443, 1391, 1392, 2339, 2929, 2930, 2931, 3748, 3919,
#             4306, 4308, 4857],
#            dtype='int64')}, {'cluster_name': '20', 'idx': Int64Index([  61,   78,   82,   83,   85,   86,   87,   89,   91,   92,
#             ...
#             4878, 4889, 4893, 4900, 4916, 4948, 4957, 4960, 4964, 4976],
#            dtype='int64', length=819)}, {'cluster_name': '64', 'idx': Int64Index([ 529,  531, 1511, 1513, 2451, 2453, 3408, 3409, 3410, 3411, 3415,
#             3416, 3417, 4387],
#            dtype='int64')}, {'cluster_name': '44', 'idx': Int64Index([ 263,  264,  277, 1215, 2142, 2143, 2144, 2162, 2169, 3101, 3129,
#             4096, 4112, 4127, 4128],
#            dtype='int64')}, {'cluster_name': '147', 'idx': Int64Index([4879, 4908, 4909, 4910, 4914, 4921, 4925, 4926, 4927, 4929, 4930,
#             4933, 4950, 4951, 4952, 4972, 4974, 4975],
#            dtype='int64')}, {'cluster_name': '50', 'idx': Int64Index([ 313,  317,  379,  411,  418,  475,  479, 1271, 1357, 1358, 1360,
#             1430, 2224, 2281, 2384, 2386, 2387, 2388, 3158, 3164, 3172, 3284,
#             3285, 3291, 3292, 3340, 3342, 4170, 4231, 4264],
#            dtype='int64')}, {'cluster_name': '13', 'idx': Int64Index([  58,   60,   70,   71,   73,   75,   76,   77,   79,   80,
#             ...
#             4797, 4802, 4804, 4806, 4807, 4808, 4809, 4810, 4811, 4813],
#            dtype='int64', length=427)}, {'cluster_name': '31', 'idx': Int64Index([ 142,  143,  144,  145,  146,  161,  162,  163,  164,  165,  166,
#              167,  170,  174,  175,  218,  219,  220,  225,  226,  227,  230,
#              265,  266, 1100, 1101, 1102, 1117, 1118, 1123, 1124, 1127, 1128,
#             1174, 1181, 1182, 1186, 1216, 2039, 2040, 2055, 2057, 2058, 2059,
#             2061, 2065, 2066, 2108, 2115, 2116, 2117, 2118, 2119, 2163, 3012,
#             3013, 3014, 3015, 3018, 3019, 3025, 3026, 3067, 3072, 3073, 3116,
#             3117, 3118, 4018, 4023, 4024, 4025, 4026, 4027, 4028, 4069, 4070,
#             4071, 4072, 4074, 4079, 4080, 4081, 4113],
#            dtype='int64')}, {'cluster_name': '5', 'idx': Int64Index([  16,   93,  100,  172,  210,  216,  243,  271,  299,  326,  334,
#              341,  370,  473,  835,  878, 1073, 1122, 1142, 1166, 1184, 1191,
#             1257, 1285, 1294, 1311, 1359, 1363, 1378, 1380, 1412, 1429, 1472,
#             1480, 1803, 1828, 1930, 1963, 2000, 2015, 2070, 2081, 2186, 2237,
#             2250, 2295, 2364, 2511, 2532, 2537, 2629, 2766, 2984, 3077, 3127,
#             3168, 3179, 3186, 3198, 3224, 3261, 3264, 3293, 3300, 3505, 3512,
#             3714, 3747, 3786, 3825, 3952, 4015, 4061, 4077, 4114, 4118, 4119,
#             4147, 4180, 4197, 4250, 4273, 4278, 4325, 4401, 4402, 4679, 4865,
#             4884],
#            dtype='int64')}, {'cluster_name': '53', 'idx': Int64Index([ 368,  380,  417,  444,  446,  448,  450,  452,  453,  454,  462,
#              464,  466,  469,  503,  537,  601, 1149, 1219, 1283, 1313, 1345,
#             1349, 1369, 1390, 1403, 1411, 1424, 1425, 1481, 1525, 1527, 1570,
#             2181, 2268, 2272, 2289, 2302, 2328, 2340, 2344, 2347, 2349, 2368,
#             2379, 2383, 2423, 2442, 2449, 2480, 2561, 3040, 3089, 3141, 3148,
#             3236, 3238, 3262, 3309, 3311, 3313, 3325, 3326, 3337, 3338, 3357,
#             3391, 3423, 4106, 4153, 4198, 4204, 4208, 4236, 4294, 4297, 4307,
#             4310, 4311, 4312, 4313, 4315, 4318, 4319, 4321, 4385, 4391, 4395,
#             4430, 4459],
#            dtype='int64')}, {'cluster_name': '0', 'idx': Int64Index([   0,    1,    3,    4,   12,   13,   14,   15,   17,   18,
#             ...
#             4389, 4411, 4413, 4415, 4416, 4419, 4420, 4421, 4895, 4943],
#            dtype='int64', length=109)}]

# %%
cluster.df['cluster_level_2'].describe()
# Out:
# count     5001
# unique      43
# top         62
# freq      1141
# Name: cluster_level_2, dtype: object

# %%
sorted_list = sorted_df['pattern'].tolist()

# %%
start = sorted_list[0]
print(start)
ratio = []
for x in sorted_list:
    ratio.append(difflib.SequenceMatcher(None, start, x).ratio())
print(ratio)
ids = [i for i,x in enumerate(ratio) if x > 0.6]
print(ids)
# Out:
# Non-zero return code from EVNTtoHITS (*); Logfile error in log.EVNTtoHITS: "StreamHITS FATAL * failed."
# [1.0, 0.5638766519823789, 0.6181818181818182, 0.6272727272727273, 0.592057761732852, 0.1917808219178082, 0.44776119402985076, 0.4740740740740741, 0.6698113207547169, 0.6334841628959276, 0.32727272727272727, 0.4397163120567376, 0.6564102564102564, 0.3488372093023256, 0.39069767441860465, 0.2302158273381295, 0.5757575757575758, 0.3333333333333333, 0.5957446808510638, 0.6538461538461539, 0.17582417582417584, 0.15942028985507245, 0.663594470046083, 0.611353711790393, 0.5144927536231884, 0.5989304812834224, 0.455026455026455, 0.48, 0.2054794520547945, 0.5220588235294118, 0.39344262295081966, 0.5194805194805194, 0.273972602739726, 0.5886524822695035, 0.6255506607929515, 0.5841584158415841, 0.8682926829268293, 0.5517241379310345, 0.578397212543554, 0.5092250922509225, 0.784688995215311, 0.7159090909090909, 0.03289473684210526, 0.1793103448275862, 0.6666666666666666, 0.49122807017543857, 0.1643835616438356, 0.845771144278607, 0.6188340807174888, 0.47342995169082125, 0.4329004329004329, 0.7980295566502463, 0.625, 0.5517241379310345, 0.490272373540856, 0.6390041493775933, 0.4507042253521127, 0.5907172995780591, 0.5092250922509225, 0.7465437788018433, 0.861878453038674, 0.18181818181818182, 0.5801526717557252, 0.28431372549019607, 0.36619718309859156, 0.21262458471760798, 0.5779816513761468, 0.4962962962962963, 0.20689655172413793, 0.6731707317073171, 0.37037037037037035, 0.032679738562091505, 0.5637583892617449, 0.13664596273291926, 0.5953488372093023, 0.5035971223021583, 0.639269406392694, 0.4808362369337979, 0.6046511627906976, 0.2898550724637681, 0.7303370786516854, 0.1625, 0.8341708542713567, 0.639269406392694, 0.22784810126582278, 0.6741573033707865, 0.5907172995780591, 0.1728395061728395, 0.4927536231884058, 0.35797665369649806, 0.5874125874125874, 0.14012738853503184, 0.5907172995780591, 0.07547169811320754, 0.36213991769547327, 0.28, 0.26459143968871596, 0.639269406392694, 0.1945945945945946, 0.7685589519650655, 0.8720379146919431, 0.5363984674329502, 0.1643835616438356, 0.6, 0.5818181818181818, 0.22594142259414227, 0.5, 0.18309859154929578, 0.05504587155963303, 0.5802047781569966, 0.16793893129770993, 0.5185185185185185, 0.171875, 0.508833922261484, 0.1891891891891892, 0.5739910313901345, 0.05504587155963303, 0.14634146341463414, 0.4908424908424908, 0.6464646464646465, 0.65625, 0.6372549019607843, 0.8058252427184466, 0.8, 0.07692307692307693, 0.5907172995780591, 0.18627450980392157, 0.21818181818181817, 0.16574585635359115, 0.6970954356846473, 0.4807692307692308, 0.26356589147286824, 0.5596707818930041, 0.19117647058823528, 0.6691449814126395, 0.6082949308755761, 0.6055045871559633, 0.1774193548387097, 0.55, 0.28865979381443296, 0.40476190476190477, 0.16923076923076924, 0.16326530612244897, 0.7272727272727273, 0.20270270270270271, 0.5594405594405595, 0.20606060606060606, 0.1728395061728395, 0.5690376569037657, 0.17733990147783252]
# [0, 2, 3, 8, 9, 12, 19, 22, 23, 34, 36, 40, 41, 44, 47, 48, 51, 52, 55, 59, 60, 69, 76, 78, 80, 82, 83, 85, 97, 99, 100, 119, 120, 121, 122, 123, 129, 134, 135, 136, 143]

# %%
result = output.postprocessing()

# %%
result
# Out:
# matrix([[1.        , 0.18644068, 0.31446541, ..., 0.20979021, 0.19402985,
#          0.1773399 ],
#         [0.18644068, 1.        , 0.22564103, ..., 0.1452514 , 0.51973684,
#          0.56903766],
#         [0.33962264, 0.21538462, 1.        , ..., 0.23529412, 0.14977974,
#          0.17283951],
#         ...,
#         [0.11188811, 0.16759777, 0.21568627, ..., 1.        , 0.14218009,
#          0.20547945],
#         [0.21641791, 0.53947368, 0.15859031, ..., 0.12322275, 1.        ,
#          0.50922509],
#         [0.1773399 , 0.56903766, 0.17283951, ..., 0.17808219, 0.50922509,
#          1.        ]])

# %%
import numpy as np

# %%
threshold = 0.6
rows = np.where(result > threshold)

# %%
rows
# Out:
# (array([  0,   0,   0, ..., 149, 149, 149]),
#  array([  0,  23,  51, ..., 139, 141, 149]))

# %%
similar
# Out:
# matrix([[1.        , 0.8159204 , 0.89010989, ..., 0.86829268, 0.62555066,
#          1.        ]])

# %% [markdown]
# ### Timings for all stages of clusterization pipeline

# %% [markdown]
# process - timing of all process

# %%
cluster.timings

# %% [markdown]
# ### Get all error messages in single cluster

# %%
output.in_cluster(10)

# %%
output.in_cluster(34)

# %% [markdown]
# ### Output clusters - mode == 'ALL'  (for cluster '2')

# %%
output.clustered_output(mode='ALL')['1']

# %% [markdown]
# ### Output clusters - mode == 'INDEX' (for cluster '2')

# %%
output.clustered_output(mode='INDEX')['1']

# %% [markdown]
# ### Output clusters - mode == 'TARGET' (for cluster '2')

# %%
output.clustered_output(mode='TARGET')['1']

# %% [markdown]
# ### Output clusters - cluster labels

# %%
cluster.cluster_labels

# %% [markdown]
# ### Get epsilon value (which was used in DBSCAN algorithm)

# %%
cluster.epsilon
