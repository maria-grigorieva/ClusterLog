# %% [markdown]
# # Clusterlogs Notebook

# %%
import pandas as pd
from clusterlogs import pipeline

# %% [markdown]
# ### 1. Download data from file and create pandas DataFrame with index

# %%
df = pd.read_csv('test/test_data.csv', index_col=0).set_index('pandaid')

# %%
df.head(10)
# Out:
#                       starttime  exeerrorcode  \
# pandaid
# 4498866929  2019-10-01T09:04:39            65
# 4498851809  2019-10-01T09:13:17            11
# 4499004301  2019-10-01T10:18:49            15
# 4499011565  2019-10-01T10:25:17            65
# 4499004297  2019-10-01T10:15:46            15
# 4499011462  2019-10-01T10:22:04            65
# 4499008082  2019-10-01T10:23:28            65
# 4499011446  2019-10-01T10:21:21            65
# 4499011466  2019-10-01T10:23:13            65
# 4499008070  2019-10-01T10:26:24            65
#
#                                                  exeerrordiag
# pandaid
# 4498866929  Non-zero return code from EVNTtoHITS (8); Logf...
# 4498851809  Missing AthenaMP outputs file athenaMP-outputs...
# 4499004301  No events to process: 16000 (skipEvents) >= 23...
# 4499011565  Non-zero return code from AODtoDAOD (8); Logfi...
# 4499004297  No events to process: 14000 (skipEvents) >= 23...
# 4499011462  Non-zero return code from AODtoDAOD (8); Logfi...
# 4499008082  Non-zero return code from AODtoDAOD (8); Logfi...
# 4499011446  Non-zero return code from AODtoDAOD (8); Logfi...
# 4499011466  Non-zero return code from AODtoDAOD (8); Logfi...
# 4499008070  Non-zero return code from AODtoDAOD (8); Logfi...

# %% [markdown]
# ### 2. Initialize clusterization pipeline

# %% [raw]
# Required parameters are:
# - df - pandas DataFrame with error messages
# - target - name of a column with error messages
#
# Not required parameters are cluster_settings. If not defined - the default values are used.
# Note: It's better to use for big data samples with a vocabulary of more than 1000 tokens.
#
# CLUSTERING_DEFAULTS = {"tokenizer": "nltk",
#                        "w2v_size": "auto",
#                        "w2v_window": 5,
#                        "min_samples": 1}
#
# But you can define these parameters. For example,
#
# clustering_parameters = {'tokenizer':'nltk',
#                          'w2v_size': 200,
#                          'w2v_window': 5,
#                          'min_samples': 1}
#
# cluster = pipeline.ml_clustering(df, target, clustering_parameters)

# %%
target = 'exeerrordiag'

# %%
cluster = pipeline.ml_clustering(df, target, mode='process', model_name='test/word2vec.model')

# %% [markdown]
# ### 3. Execute clusterization pipeline

# %%
cluster.process()
# Out:
# /Users/maria/anaconda3/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
cluster.w2v_size
# Out:
# 15

# %% [markdown]
# ### 4. Get clusters statistics

# %% [raw]
# Clusters Statistics returns DataFrame with statistic for all clusters:
# - "cluster_name" - name of a cluster
# - "cluster_size" - number of log messages in cluster
# - "first_entry" - first log message in cluster
# - "vocab" - all tokens in error messasges
# - "vocab_length" - the length of cluster's vocabulary
# - "mean_length" - average length of log messages in cluster
# - "std_length" - standard deviation of length of log messages in cluster
# - "mean_similarity" - average similarity of log messages in cluster
# (calculated as the levenshtein distances between the 1st and all other log messages)
# - "std_similarity" - standard deviation of similarity of log messages in cluster

# %%
stat = cluster.statistics()

# %%
stat_df = pd.DataFrame.from_dict(stat)

# %%
stat_df.sort_values(by='mean_similarity')
# Out:
#    cluster_name  cluster_size  \
# 10           10             8
# 34           34            15
# 29           29            10
# 2             2             7
# 30           30            48
# 43           43             1
# 39           39             1
# 0             0             1
# 26           26             1
# 25           25             1
# 24           24             1
# 23           23             1
# 21           21             1
# 17           17             1
# 19           19             1
# 42           42             1
# 16           16             1
# 15           15             1
# 14           14             1
# 12           12             1
# 11           11             1
# 8             8             1
# 20           20             1
# 40           40             1
# 33           33             1
# 5             5             1
# 7             7            35
# 3             3            24
# 31           31            22
# 35           35            17
# 4             4             6
# 9             9             4
# 13           13             4
# 36           36             4
# 6             6             4
# 41           41             3
# 22           22             3
# 1             1             2
# 18           18             2
# 27           27             2
# 37           37             2
# 38           38             2
# 28           28             2
# 32           32             1
# 44           44             1
#
#                                           first_entry  \
# 10  Fatal error in athena logfile: "G4 exception a...
# 34  Fatal error in athena logfile: "Long ERROR mes...
# 29  No events to process: 2100 (skipEvents) >= 200...
# 2   No events to process: 16000 (skipEvents) >= 23...
# 30  Missing AthenaMP outputs file athenaMP-outputs...
# 43  Fatal error in athena logfile: "Logfile error ...
# 39  Non-zero return code from AODtoDAOD (8); Logfi...
# 0   Non-zero return code from EVNTtoHITS (8); Logf...
# 26  Input file argument testRTT.RDO.pool.root glob...
# 25  Non-zero return code from RDOtoRDOTrigger (33)...
# 24  Non-zero return code from AODtoDAOD (8); Logfi...
# 23  Non-zero return code from AODtoDAOD (65); Long...
# 21  Non-zero return code from RAWtoALL (65); Logfi...
# 17  Fatal error in athena logfile: "Logfile error ...
# 19     AODtoDAOD got a SIGKILL signal (exit code 137)
# 42      Error reading user generated output file list
# 16  Non-zero return code from RAWtoALL (65); Long ...
# 15  File data18_13TeV.00363033.physics_Main.merge....
# 14  Non-zero return code from RAWtoESD (8); Logfil...
# 12  Non-zero return code from EVNTtoHITS (65); G4 ...
# 11  Non-zero return code from ESDtoDPD (65); Logfi...
# 8   Non-zero return code from POOLMergeAthenaMPDES...
# 20  Non-zero return code from RAWtoESD (65); Logfi...
# 40  Fatal error in athena logfile: "Logfile error ...
# 33  No events to process: 2000 (skipEvents) >= 200...
# 5   Non-zero return code from AODtoDAOD (64); Logf...
# 7   Non-zero return code from AODtoDAOD (65); Logf...
# 3   Non-zero return code from AODtoDAOD (8); Logfi...
# 31                LRMS error: (271) Job was cancelled
# 35  Non-zero return code from HITtoRDO (65); Logfi...
# 4   Non-zero return code from AODtoDAOD (8); Logfi...
# 9   Fatal error in athena logfile: "Logfile error ...
# 13  Input file argument(s) ['RDO.pool.root'] globb...
# 36  Missing AthenaMP outputs file athenaMP-outputs...
# 6   Non-zero return code from AODtoDAOD (65); Logf...
# 41  Non-zero return code from RAWtoESD (65); Logfi...
# 22    EVNTtoHITS got a SIGKILL signal (exit code 137)
# 1   Missing AthenaMP outputs file athenaMP-outputs...
# 18  Fatal error in athena logfile: "Logfile error ...
# 27         Non-zero return code from EVNTtoHITS (255)
# 37                      LRMS error: (271) Job timeout
# 38  Non-zero return code from RDOtoRDOTrigger (65)...
# 28  Non-zero return code from EVNTtoHITS (33); Log...
# 32  No events to process: 2500 (skipEvents) >= 200...
# 44  Non-zero return code from EVNTtoHITS (65); Log...
#
#                                                 vocab  vocab_length  \
# 10  {athena, G4, logfile, exception, see, line, er...            10
# 34  {athena, logfile, see, line, error, Long, Fata...            11
# 29   {EVNT, process, skipEvents, inputEvents, events}             5
# 2    {process, skipEvents, HITS, inputEvents, events}             5
# 30  {Missing, file, athena, athenaMP-outputs-HITto...             8
# 43  {data, Logfile, athena, logfile, retrieve, COO...            16
# 39  {Logfile, 'nentries, code, log.AODtoDAOD, erro...             9
# 0   {Logfile, ValueError, EVNTtoHITS, expected, lo...            15
# 26  {Input, files, file, globbed, argument, testRT...             9
# 25  {Logfile, Signature, sequence, matching, code,...            17
# 24  {identify, Logfile, exception, Unable, specifi...            11
# 23  {see, code, line, Long, Non-zero, FATAL, jobRe...            11
# 21  {Logfile, code, m_trackCollKey, evtStore, FILE...            19
# 17  {Logfile, athena, logfile, caught, exception, ...            13
# 19      {exit, code, AODtoDAOD, SIGKILL, signal, got}             6
# 42  {generated, file, Error, list, reading, output...             7
# 16  {see, RAWtoALL, code, line, Long, Non-zero, ER...            11
# 15  {File, test, data18_13TeV.00363033.physics_Mai...             5
# 14  {Logfile, RAWtoESD, code, error, Non-zero, log...             7
# 12  {G4, EVNTtoHITS, exception, see, code, line, N...            10
# 11  {Logfile, abnormally, finished, waiting, log.E...            14
# 8   {Logfile, number, POOLMergeAthenaMPDESDMCALJET...            12
# 20  {event, Logfile, fail, RAWtoESD, Failed, detec...            17
# 40  {data, Logfile, athena, logfile, retrieve, COO...            17
# 33   {EVNT, process, skipEvents, inputEvents, events}             5
# 5   {Logfile, caught, JETM7Kernel_Skim, code, log....            13
# 7   {Logfile, abnormally, finished, waiting, code,...            14
# 3   {Logfile, 'module, attribute, code, log.AODtoD...            12
# 31                      {error, Job, cancelled, LRMS}             4
# 35  {Logfile, abnormally, finished, waiting, log.H...            14
# 4   {slimming, Logfile, Smart, exist, list, code, ...            15
# 9   {Logfile, athena, logfile, caught, exception, ...            13
# 13  {'RDO.pool.root, Input, files, file, globbed, ...             9
# 36  {Missing, file, athena, athenaMP-outputs-RDOto...             8
# 6   {makePool, Logfile, failed, code, log.AODtoDAO...            12
# 41  {Logfile, abnormally, RAWtoESD, finished, wait...            14
# 22     {EVNTtoHITS, exit, code, SIGKILL, signal, got}             6
# 1   {Missing, file, athena, crashed, outputs, Athe...             8
# 18  {Logfile, athena, logfile, SimGeoID=0, log.EVN...            15
# 27               {EVNTtoHITS, Non-zero, code, return}             4
# 37                        {error, Job, LRMS, timeout}             4
# 38  {Logfile, abnormally, finished, waiting, code,...            14
# 28  {opened, connection, Logfile, EVNTtoHITS, data...            15
# 32   {EVNT, process, skipEvents, inputEvents, events}             5
# 44  {Logfile, abnormally, finished, EVNTtoHITS, wa...            14
#
#     mean_length  mean_similarity  std_length  std_similarity
# 10        95.00            96.18        0.00            1.74
# 34       100.00            97.47        0.00            1.15
# 29        68.00            98.24        0.00            0.88
# 2         68.71            98.34        0.45            0.93
# 30        85.00           100.00        0.00            0.00
# 43       190.00           100.00        0.00            0.00
# 39        95.00           100.00        0.00            0.00
# 0        206.00           100.00        0.00            0.00
# 26       102.00           100.00        0.00            0.00
# 25       227.00           100.00        0.00            0.00
# 24       112.00           100.00        0.00            0.00
# 23       109.00           100.00        0.00            0.00
# 21       251.00           100.00        0.00            0.00
# 17       174.00           100.00        0.00            0.00
# 19        46.00           100.00        0.00            0.00
# 42        45.00           100.00        0.00            0.00
# 16       109.00           100.00        0.00            0.00
# 15       105.00           100.00        0.00            0.00
# 14        73.00           100.00        0.00            0.00
# 12       105.00           100.00        0.00            0.00
# 11       185.00           100.00        0.00            0.00
# 8        171.00           100.00        0.00            0.00
# 20       190.00           100.00        0.00            0.00
# 40       211.00           100.00        0.00            0.00
# 33        68.00           100.00        0.00            0.00
# 5        168.00           100.00        0.00            0.00
# 7        187.00           100.00        0.00            0.00
# 3        150.00           100.00        0.00            0.00
# 31        35.00           100.00        0.00            0.00
# 35       153.00           100.00        0.00            0.00
# 4        190.00           100.00        0.00            0.00
# 9        174.00           100.00        0.00            0.00
# 13       101.00           100.00        0.00            0.00
# 36        92.00           100.00        0.00            0.00
# 6        192.00           100.00        0.00            0.00
# 41       185.00           100.00        0.00            0.00
# 22        47.00           100.00        0.00            0.00
# 1         87.00           100.00        0.00            0.00
# 18       151.00           100.00        0.00            0.00
# 27        42.00           100.00        0.00            0.00
# 37        29.00           100.00        0.00            0.00
# 38       199.00           100.00        0.00            0.00
# 28       180.00           100.00        0.00            0.00
# 32        68.00           100.00        0.00            0.00
# 44       157.00           100.00        0.00            0.00

# %% [markdown]
# ### Timings for all stages of clusterization pipeline

# %% [markdown]
# process - timing of all process

# %%
cluster.timings
# Out:
# {'data_preparation': 0.0033,
#  'tokenization': 0.0251,
#  'tokens_vectorization': 0.156,
#  'sentence_vectorization': 0.0346,
#  'kneighbors': 0.0133,
#  'epsilon_search': 0.0005,
#  'dbscan': 0.1106,
#  'process': 0.3434}

# %% [markdown]
# ### Get all error messages in single cluster

# %%
cluster.in_cluster(10)
# Out:
# ['Fatal error in athena logfile: "G4 exception at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "G4 exception at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "G4 exception at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "G4 exception at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "G4 exception at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "G4 exception at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "G4 exception at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "G4 exception at line LINE_NUMBER (see jobReport for further details)"']

# %%
cluster.in_cluster(34)
# Out:
# ['Fatal error in athena logfile: "Long ERROR message at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line LINE_NUMBER (see jobReport for further details)"',
#  'Fatal error in athena logfile: "Long ERROR message at line LINE_NUMBER (see jobReport for further details)"']

# %% [markdown]
# ### Output clusters - mode == 'ALL'  (for cluster '2')

# %%
cluster.clustered_output(mode='ALL')['1']
# Out:
# [{'starttime': '2019-10-01T09:13:17',
#   'exeerrorcode': 11,
#   'exeerrordiag': 'Missing AthenaMP outputs file athenaMP-outputs-EVNTtoHITS-sim (probably athena crashed)',
#   'cluster': 1},
#  {'starttime': '2019-10-01T10:26:22',
#   'exeerrorcode': 11,
#   'exeerrordiag': 'Missing AthenaMP outputs file athenaMP-outputs-EVNTtoHITS-sim (probably athena crashed)',
#   'cluster': 1}]

# %% [markdown]
# ### Output clusters - mode == 'INDEX' (for cluster '2')

# %%
cluster.clustered_output(mode='INDEX')['1']
# Out:
# [4498851809, 4499017793]

# %% [markdown]
# ### Output clusters - mode == 'TARGET' (for cluster '2')

# %%
cluster.clustered_output(mode='TARGET')['1']
# Out:
# ['Missing AthenaMP outputs file athenaMP-outputs-EVNTtoHITS-sim (probably athena crashed)',
#  'Missing AthenaMP outputs file athenaMP-outputs-EVNTtoHITS-sim (probably athena crashed)']

# %% [markdown]
# ### Output clusters - cluster labels

# %%
cluster.cluster_labels
# Out:
# array([ 0,  1,  2,  3,  2,  4,  3,  3,  3,  3,  3,  5,  6,  7,  8,  9,  7,
#        10,  7,  7, 11, 12, 13, 13, 13,  2,  3,  4,  2,  3, 14,  3,  1,  7,
#         7,  7, 15,  7,  7,  7, 16, 17,  7, 18, 19, 10,  3,  3,  4,  2,  3,
#         3,  4,  3, 20,  9,  7,  7,  7,  7, 10,  7,  9,  7, 21, 22,  4,  3,
#         3,  3,  4,  3,  2, 23, 24,  7,  7,  7,  9, 25,  7, 26, 18, 22, 13,
#        27, 27, 28,  2,  3,  3,  3,  3,  3,  3,  7,  7,  6, 10,  7,  7,  7,
#         7,  7, 29, 29, 29, 30, 30, 30, 30, 30, 30, 30, 30, 30, 31, 31, 29,
#        32, 29, 30, 30, 30, 30, 30, 31, 31, 31, 31, 31, 31, 31, 31, 29, 29,
#        30, 30, 30, 30, 30, 30, 30, 30, 31, 31, 31, 33, 29, 30, 30, 30, 30,
#        30, 30, 31, 31, 31, 31, 31, 31, 29, 29, 30, 30, 30, 30, 30, 30, 30,
#        31, 31, 31,  7,  6, 34, 34,  7, 35, 35, 35, 36, 10, 37, 35,  7, 30,
#         7, 34,  7, 34, 34, 35,  7, 30, 30, 35, 35, 38, 39, 35, 30, 30, 10,
#        10, 37, 34, 34, 34, 30, 35, 40, 35, 35, 36, 41, 41, 22, 34, 34, 34,
#        34, 10, 34, 42, 35, 36, 35, 35, 41, 30, 30, 30, 38, 28, 30,  6, 34,
#        43, 34,  7, 44, 30, 36, 35, 30, 35, 35, 30])

# %% [markdown]
# ### Get epsilon value (which was used in DBSCAN algorithm)

# %%
cluster.epsilon
# Out:
# 0.05653438724138101
